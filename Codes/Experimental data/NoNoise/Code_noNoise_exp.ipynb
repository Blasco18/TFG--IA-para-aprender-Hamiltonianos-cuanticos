# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "axes.labelsize": 20, 
    "axes.titlesize": 22, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [12, 7], 
    "figure.dpi": 300 
})

# %% [markdown]
# #### Define $S_{21}$($\omega$):
# $$S_{21}(\omega)=1 - \frac{\kappa_c}{i(\Omega-\omega)+\kappa+\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def S21 (w, k, kc, Omega, DeltaE, gamma, g):
    up = kc
    down = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = 1 - up / (1j * down)
    return np.abs(t)

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %% [markdown]
# ## Creamos base de datos

# %%
# Definimos una función que genere la base de datos
# def Parameters_generator (num_datos): # General
#     k = np.random.uniform(1e-4, 1e-2, num_datos)
#     kc = np.random.uniform(1e-6, 1e-4, num_datos)
#     gamma = np.random.uniform(1e-4, 1e-2, num_datos)
#     g = np.random.uniform(1e-4, 1e-2, num_datos)
#     DeltaE = np.random.uniform(0.5, 1.5, num_datos)

#     return k, kc, gamma, g, DeltaE

def Parameters_generator (num_datos): # Acotado
    k = np.random.uniform(1e-4, 1e-3, num_datos)
    kc = np.random.uniform(1e-5, 1e-4, num_datos)
    gamma = np.random.uniform(5e-3, 8e-3, num_datos)
    g = np.random.uniform(1e-2, 1.5e-2, num_datos)
    DeltaE = np.random.uniform(1.8, 2.4, num_datos)

    return k, kc, gamma, g, DeltaE

num_datos = 10000

# %%
# #Creamos base de datos y guardamos en .txt
# k, kc, gamma, g, DeltaE = Parameters_generator (num_datos)
# np.savetxt('Parameters_noNoise_acotado.txt', np.column_stack((k, kc, gamma, g, DeltaE)),
#             header='\u03BA \u03BA_c \u213D g \u0394E', encoding='utf8')

# %%
datos = np.loadtxt('Parameters_noNoise.txt', skiprows=1, usecols=(0, 1, 2, 3))
k = datos[:,0]
kc = datos[:,1]
gamma = datos[:,2]
g = datos[:,3]
DeltaE = np.loadtxt('Parameters_noNoise.txt', skiprows=1, usecols=4)
Omega = 1
# Omega = 2.116451

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.85, 1.15, 2500)
# w_values = np.linspace(2.09, 2.14, 2500)


# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))

w1 = w2 = np.zeros(num_datos)
w1=w_1(k, Omega, DeltaE, gamma, g)
w2=w_2(k, Omega, DeltaE, gamma, g)

# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = S21(w_values, k[i], kc[i], Omega, DeltaE[i], gamma[i], g[i])

# %% [markdown]
# ### Dibujamos las curvas

# %%
# plt.rcParams.update({
#     "text.usetex": False,
#     "font.family": "serif",
#     "font.serif": ['DejaVu Sans'],
# }) # Para visualizar LaTeX es muy lento (cuando sepa cual gráfica guaradr, se hará con latex)

# i=0
# while i<=1000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values[i,:], label='Curva original')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$")
#     plt.ylabel(r"t ($\omega$)")
#     #plt.legend()
#     # plt.ylim(0) 
#     # plt.xlim(0.85, 1.15) 

#     # # Calcula los valores de t(w) en w1 y w2
#     # t_w1 = t_w(w1[i], k[i], Omega, DeltaE[i], gamma[i], g[i])
#     # t_w2 = t_w(w2[i], k[i], Omega, DeltaE[i], gamma[i], g[i])

#     # if w_values.min() <= w1[i] <= w_values.max():
#     #     plt.vlines(w1[i], 0, t_w1, colors='black', linewidth=0.5)
#     # if w_values.min() <= w2[i] <= w_values.max():
#     #     plt.vlines(w2[i], 0, t_w2, colors='black', linewidth=0.5)
    
#     plt.draw()  # Dibuja la figura actual

#     # Muestra los valores como un recuadro dentro de la gráfica
#     text = f"$\kappa$ = {k[i]:.2e}\n"\
#            f"$\kappa_c$ = {kc[i]:.2e}\n"\
#            f"$\gamma$ = {gamma[i]:.2e}\n"\
#            f"g = {g[i]:.2e}\n"\
#            f"$\Delta$E = {DeltaE[i]:.3f}"
#     plt.text(0.011, 0.3, text, transform=plt.gca().transAxes, fontsize=16, verticalalignment='top', 
#              bbox=dict(facecolor='white', alpha=1))

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'):
#         break
#     elif keyboard.is_pressed('right'):
#         i += 1
#         if i >= num_datos:
#             i = num_datos - 1  # Asegura que no exceda el índice máximo
#     elif keyboard.is_pressed('left'):
#         i -= 1
#         if i < 0:
#             i = 0  # Asegura que no baje del índice mínimo

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
import joblib

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
indices = np.arange(num_datos)
indices_train, indices_post = train_test_split(indices, test_size=0.2, random_state=18)
indices_val, indices_test = train_test_split(indices_post, test_size=0.5, random_state=18)


x_train = t_values[indices_train]
x_val = t_values[indices_val]
x_test = t_values[indices_test]
y_train = datos[indices_train]
y_val = datos[indices_val]
y_test = datos[indices_test]

# Normalizamos los datos
scaler_x = RobustScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)
x_test_norm = scaler_x.transform(x_test)

scaler_y = RobustScaler()
scaler_exp = RobustScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_train_save = y_train[np.random.choice(len(y_train), 41, replace=False)]
y_train_save = scaler_exp.fit_transform(y_train_save)
joblib.dump(scaler_exp, 'scaler_y.save')
y_val_norm = scaler_y.transform(y_val)
y_test_norm = scaler_y.transform(y_test)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'validation samples')
print(x_test.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 250
epochs = 1000
optimizer = Adam()
# Out:
# 8000 train samples
# 1000 validation samples
# 1000 test samples
# x_train shape (8000, 2500)
# y_train shape (8000, 4)

# %% [markdown]
# #### Definimos modelo

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm , y_train_norm , batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_noNoise.keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 32/32 - 2s - 58ms/step - loss: 0.3144 - mean_absolute_error: 0.4590 - val_loss: 0.2716 - val_mean_absolute_error: 0.4230
# Epoch 2/1000
# 32/32 - 0s - 6ms/step - loss: 0.2570 - mean_absolute_error: 0.4029 - val_loss: 0.2596 - val_mean_absolute_error: 0.4049
# Epoch 3/1000
# 32/32 - 0s - 7ms/step - loss: 0.2478 - mean_absolute_error: 0.3912 - val_loss: 0.2468 - val_mean_absolute_error: 0.3868
# Epoch 4/1000
# 32/32 - 0s - 7ms/step - loss: 0.2401 - mean_absolute_error: 0.3829 - val_loss: 0.2403 - val_mean_absolute_error: 0.3803
# Epoch 5/1000
# 32/32 - 0s - 7ms/step - loss: 0.2349 - mean_absolute_error: 0.3761 - val_loss: 0.2347 - val_mean_absolute_error: 0.3725
# Epoch 6/1000
# 32/32 - 0s - 7ms/step - loss: 0.2277 - mean_absolute_error: 0.3668 - val_loss: 0.2314 - val_mean_absolute_error: 0.3723
# Epoch 7/1000
# 32/32 - 0s - 6ms/step - loss: 0.2222 - mean_absolute_error: 0.3601 - val_loss: 0.2237 - val_mean_absolute_error: 0.3598
# Epoch 8/1000
# 32/32 - 0s - 7ms/step - loss: 0.2172 - mean_absolute_error: 0.3521 - val_loss: 0.2216 - val_mean_absolute_error: 0.3530
# Epoch 9/1000
# 32/32 - 0s - 7ms/step - loss: 0.2136 - mean_absolute_error: 0.3476 - val_loss: 0.2166 - val_mean_absolute_error: 0.3473
# Epoch 10/1000
# 32/32 - 0s - 7ms/step - loss: 0.2108 - mean_absolute_error: 0.3451 - val_loss: 0.2164 - val_mean_absolute_error: 0.3503
# Epoch 11/1000
# 32/32 - 0s - 7ms/step - loss: 0.2077 - mean_absolute_error: 0.3453 - val_loss: 0.2095 - val_mean_absolute_error: 0.3407
# Epoch 12/1000
# 32/32 - 0s - 7ms/step - loss: 0.2037 - mean_absolute_error: 0.3383 - val_loss: 0.2071 - val_mean_absolute_error: 0.3375
# Epoch 13/1000
# 32/32 - 0s - 7ms/step - loss: 0.2007 - mean_absolute_error: 0.3322 - val_loss: 0.2049 - val_mean_absolute_error: 0.3354
# Epoch 14/1000
# 32/32 - 0s - 7ms/step - loss: 0.1983 - mean_absolute_error: 0.3299 - val_loss: 0.2023 - val_mean_absolute_error: 0.3321
# Epoch 15/1000
# 32/32 - 0s - 6ms/step - loss: 0.1969 - mean_absolute_error: 0.3291 - val_loss: 0.2009 - val_mean_absolute_error: 0.3321
# Epoch 16/1000
# 32/32 - 0s - 6ms/step - loss: 0.1955 - mean_absolute_error: 0.3279 - val_loss: 0.1993 - val_mean_absolute_error: 0.3272
# Epoch 17/1000
# 32/32 - 0s - 6ms/step - loss: 0.1924 - mean_absolute_error: 0.3205 - val_loss: 0.1973 - val_mean_absolute_error: 0.3219
# Epoch 18/1000
# 32/32 - 0s - 6ms/step - loss: 0.1913 - mean_absolute_error: 0.3198 - val_loss: 0.1962 - val_mean_absolute_error: 0.3242
# Epoch 19/1000
# 32/32 - 0s - 6ms/step - loss: 0.1898 - mean_absolute_error: 0.3191 - val_loss: 0.1945 - val_mean_absolute_error: 0.3205
# Epoch 20/1000
# 32/32 - 0s - 6ms/step - loss: 0.1880 - mean_absolute_error: 0.3141 - val_loss: 0.1932 - val_mean_absolute_error: 0.3188
# Epoch 21/1000
# 32/32 - 0s - 7ms/step - loss: 0.1884 - mean_absolute_error: 0.3182 - val_loss: 0.1943 - val_mean_absolute_error: 0.3219
# Epoch 22/1000
# 32/32 - 0s - 7ms/step - loss: 0.1866 - mean_absolute_error: 0.3144 - val_loss: 0.1913 - val_mean_absolute_error: 0.3136
# Epoch 23/1000
# 32/32 - 0s - 7ms/step - loss: 0.1846 - mean_absolute_error: 0.3088 - val_loss: 0.1895 - val_mean_absolute_error: 0.3078
# Epoch 24/1000
# 32/32 - 0s - 7ms/step - loss: 0.1831 - mean_absolute_error: 0.3056 - val_loss: 0.1892 - val_mean_absolute_error: 0.3080
# Epoch 25/1000
# 32/32 - 0s - 7ms/step - loss: 0.1825 - mean_absolute_error: 0.3061 - val_loss: 0.1914 - val_mean_absolute_error: 0.3122
# Epoch 26/1000
# 32/32 - 0s - 7ms/step - loss: 0.1836 - mean_absolute_error: 0.3074 - val_loss: 0.1889 - val_mean_absolute_error: 0.3125
# Epoch 27/1000
# 32/32 - 0s - 7ms/step - loss: 0.1816 - mean_absolute_error: 0.3038 - val_loss: 0.1868 - val_mean_absolute_error: 0.3076
# Epoch 28/1000
# 32/32 - 0s - 7ms/step - loss: 0.1797 - mean_absolute_error: 0.3010 - val_loss: 0.1850 - val_mean_absolute_error: 0.3005
# Epoch 29/1000
# 32/32 - 0s - 6ms/step - loss: 0.1786 - mean_absolute_error: 0.2982 - val_loss: 0.1869 - val_mean_absolute_error: 0.3088
# Epoch 30/1000
# 32/32 - 0s - 6ms/step - loss: 0.1781 - mean_absolute_error: 0.2987 - val_loss: 0.1834 - val_mean_absolute_error: 0.2995
# Epoch 31/1000
# 32/32 - 0s - 6ms/step - loss: 0.1792 - mean_absolute_error: 0.3024 - val_loss: 0.1829 - val_mean_absolute_error: 0.3013
# Epoch 32/1000
# 32/32 - 0s - 6ms/step - loss: 0.1779 - mean_absolute_error: 0.2997 - val_loss: 0.1853 - val_mean_absolute_error: 0.3076
# Epoch 33/1000
# 32/32 - 0s - 6ms/step - loss: 0.1771 - mean_absolute_error: 0.2968 - val_loss: 0.1823 - val_mean_absolute_error: 0.2943
# Epoch 34/1000
# 32/32 - 0s - 6ms/step - loss: 0.1756 - mean_absolute_error: 0.2934 - val_loss: 0.1805 - val_mean_absolute_error: 0.2964
# Epoch 35/1000
# 32/32 - 0s - 6ms/step - loss: 0.1733 - mean_absolute_error: 0.2915 - val_loss: 0.1810 - val_mean_absolute_error: 0.3020
# Epoch 36/1000
# 32/32 - 0s - 6ms/step - loss: 0.1715 - mean_absolute_error: 0.2900 - val_loss: 0.1755 - val_mean_absolute_error: 0.2893
# Epoch 37/1000
# 32/32 - 0s - 7ms/step - loss: 0.1691 - mean_absolute_error: 0.2852 - val_loss: 0.1783 - val_mean_absolute_error: 0.2944
# Epoch 38/1000
# 32/32 - 0s - 6ms/step - loss: 0.1695 - mean_absolute_error: 0.2860 - val_loss: 0.1745 - val_mean_absolute_error: 0.2872
# Epoch 39/1000
# 32/32 - 0s - 6ms/step - loss: 0.1665 - mean_absolute_error: 0.2825 - val_loss: 0.1740 - val_mean_absolute_error: 0.2935
# Epoch 40/1000
# 32/32 - 0s - 6ms/step - loss: 0.1669 - mean_absolute_error: 0.2833 - val_loss: 0.1707 - val_mean_absolute_error: 0.2842
# Epoch 41/1000
# 32/32 - 0s - 6ms/step - loss: 0.1673 - mean_absolute_error: 0.2842 - val_loss: 0.1736 - val_mean_absolute_error: 0.2855
# Epoch 42/1000
# 32/32 - 0s - 6ms/step - loss: 0.1654 - mean_absolute_error: 0.2810 - val_loss: 0.1687 - val_mean_absolute_error: 0.2822
# Epoch 43/1000
# 32/32 - 0s - 7ms/step - loss: 0.1657 - mean_absolute_error: 0.2811 - val_loss: 0.1719 - val_mean_absolute_error: 0.2862
# Epoch 44/1000
# 32/32 - 0s - 6ms/step - loss: 0.1614 - mean_absolute_error: 0.2734 - val_loss: 0.1658 - val_mean_absolute_error: 0.2741
# Epoch 45/1000
# 32/32 - 0s - 6ms/step - loss: 0.1588 - mean_absolute_error: 0.2696 - val_loss: 0.1671 - val_mean_absolute_error: 0.2753
# Epoch 46/1000
# 32/32 - 0s - 6ms/step - loss: 0.1615 - mean_absolute_error: 0.2728 - val_loss: 0.1642 - val_mean_absolute_error: 0.2710
# Epoch 47/1000
# 32/32 - 0s - 6ms/step - loss: 0.1582 - mean_absolute_error: 0.2703 - val_loss: 0.1629 - val_mean_absolute_error: 0.2757
# Epoch 48/1000
# 32/32 - 0s - 6ms/step - loss: 0.1578 - mean_absolute_error: 0.2729 - val_loss: 0.1620 - val_mean_absolute_error: 0.2727
# Epoch 49/1000
# 32/32 - 0s - 6ms/step - loss: 0.1554 - mean_absolute_error: 0.2681 - val_loss: 0.1610 - val_mean_absolute_error: 0.2725
# Epoch 50/1000
# 32/32 - 0s - 7ms/step - loss: 0.1537 - mean_absolute_error: 0.2676 - val_loss: 0.1582 - val_mean_absolute_error: 0.2710
# Epoch 51/1000
# 32/32 - 0s - 7ms/step - loss: 0.1552 - mean_absolute_error: 0.2712 - val_loss: 0.1557 - val_mean_absolute_error: 0.2684
# Epoch 52/1000
# 32/32 - 0s - 7ms/step - loss: 0.1588 - mean_absolute_error: 0.2753 - val_loss: 0.1667 - val_mean_absolute_error: 0.2830
# Epoch 53/1000
# 32/32 - 0s - 6ms/step - loss: 0.1592 - mean_absolute_error: 0.2772 - val_loss: 0.1635 - val_mean_absolute_error: 0.2823
# Epoch 54/1000
# 32/32 - 0s - 6ms/step - loss: 0.1514 - mean_absolute_error: 0.2653 - val_loss: 0.1571 - val_mean_absolute_error: 0.2782
# Epoch 55/1000
# 32/32 - 0s - 6ms/step - loss: 0.1527 - mean_absolute_error: 0.2664 - val_loss: 0.1564 - val_mean_absolute_error: 0.2675
# Epoch 56/1000
# 32/32 - 0s - 6ms/step - loss: 0.1536 - mean_absolute_error: 0.2675 - val_loss: 0.1563 - val_mean_absolute_error: 0.2686
# Epoch 57/1000
# 32/32 - 0s - 6ms/step - loss: 0.1568 - mean_absolute_error: 0.2751 - val_loss: 0.1585 - val_mean_absolute_error: 0.2673
# Epoch 58/1000
# 32/32 - 0s - 7ms/step - loss: 0.1495 - mean_absolute_error: 0.2625 - val_loss: 0.1558 - val_mean_absolute_error: 0.2690
# Epoch 59/1000
# 32/32 - 0s - 6ms/step - loss: 0.1509 - mean_absolute_error: 0.2661 - val_loss: 0.1557 - val_mean_absolute_error: 0.2704
# Epoch 60/1000
# 32/32 - 0s - 6ms/step - loss: 0.1480 - mean_absolute_error: 0.2618 - val_loss: 0.1478 - val_mean_absolute_error: 0.2570
# Epoch 61/1000
# 32/32 - 0s - 7ms/step - loss: 0.1450 - mean_absolute_error: 0.2587 - val_loss: 0.1563 - val_mean_absolute_error: 0.2686
# Epoch 62/1000
# 32/32 - 0s - 6ms/step - loss: 0.1432 - mean_absolute_error: 0.2560 - val_loss: 0.1452 - val_mean_absolute_error: 0.2617
# Epoch 63/1000
# 32/32 - 0s - 7ms/step - loss: 0.1480 - mean_absolute_error: 0.2628 - val_loss: 0.1642 - val_mean_absolute_error: 0.2799
# Epoch 64/1000
# 32/32 - 0s - 7ms/step - loss: 0.1575 - mean_absolute_error: 0.2743 - val_loss: 0.1535 - val_mean_absolute_error: 0.2633
# Epoch 65/1000
# 32/32 - 0s - 6ms/step - loss: 0.1454 - mean_absolute_error: 0.2545 - val_loss: 0.1455 - val_mean_absolute_error: 0.2537
# Epoch 66/1000
# 32/32 - 0s - 6ms/step - loss: 0.1418 - mean_absolute_error: 0.2531 - val_loss: 0.1595 - val_mean_absolute_error: 0.2765
# Epoch 67/1000
# 32/32 - 0s - 6ms/step - loss: 0.1499 - mean_absolute_error: 0.2678 - val_loss: 0.1535 - val_mean_absolute_error: 0.2738
# Epoch 68/1000
# 32/32 - 0s - 6ms/step - loss: 0.1435 - mean_absolute_error: 0.2582 - val_loss: 0.1402 - val_mean_absolute_error: 0.2503
# Epoch 69/1000
# 32/32 - 0s - 6ms/step - loss: 0.1467 - mean_absolute_error: 0.2599 - val_loss: 0.1443 - val_mean_absolute_error: 0.2550
# Epoch 70/1000
# 32/32 - 0s - 6ms/step - loss: 0.1382 - mean_absolute_error: 0.2504 - val_loss: 0.1360 - val_mean_absolute_error: 0.2425
# Epoch 71/1000
# 32/32 - 0s - 6ms/step - loss: 0.1354 - mean_absolute_error: 0.2446 - val_loss: 0.1399 - val_mean_absolute_error: 0.2510
# Epoch 72/1000
# 32/32 - 0s - 6ms/step - loss: 0.1335 - mean_absolute_error: 0.2434 - val_loss: 0.1531 - val_mean_absolute_error: 0.2642
# Epoch 73/1000
# 32/32 - 0s - 6ms/step - loss: 0.1397 - mean_absolute_error: 0.2491 - val_loss: 0.1454 - val_mean_absolute_error: 0.2546
# Epoch 74/1000
# 32/32 - 0s - 6ms/step - loss: 0.1324 - mean_absolute_error: 0.2423 - val_loss: 0.1272 - val_mean_absolute_error: 0.2336
# Epoch 75/1000
# 32/32 - 0s - 7ms/step - loss: 0.1306 - mean_absolute_error: 0.2395 - val_loss: 0.1326 - val_mean_absolute_error: 0.2383
# Epoch 76/1000
# 32/32 - 0s - 7ms/step - loss: 0.1305 - mean_absolute_error: 0.2368 - val_loss: 0.1332 - val_mean_absolute_error: 0.2365
# Epoch 77/1000
# 32/32 - 0s - 6ms/step - loss: 0.1271 - mean_absolute_error: 0.2334 - val_loss: 0.1254 - val_mean_absolute_error: 0.2274
# Epoch 78/1000
# 32/32 - 0s - 6ms/step - loss: 0.1197 - mean_absolute_error: 0.2233 - val_loss: 0.1234 - val_mean_absolute_error: 0.2220
# Epoch 79/1000
# 32/32 - 0s - 6ms/step - loss: 0.1228 - mean_absolute_error: 0.2267 - val_loss: 0.1281 - val_mean_absolute_error: 0.2348
# Epoch 80/1000
# 32/32 - 0s - 6ms/step - loss: 0.1171 - mean_absolute_error: 0.2209 - val_loss: 0.1185 - val_mean_absolute_error: 0.2161
# Epoch 81/1000
# 32/32 - 0s - 6ms/step - loss: 0.1123 - mean_absolute_error: 0.2115 - val_loss: 0.1180 - val_mean_absolute_error: 0.2165
# Epoch 82/1000
# 32/32 - 0s - 7ms/step - loss: 0.1140 - mean_absolute_error: 0.2129 - val_loss: 0.1279 - val_mean_absolute_error: 0.2291
# Epoch 83/1000
# 32/32 - 0s - 6ms/step - loss: 0.1153 - mean_absolute_error: 0.2147 - val_loss: 0.1170 - val_mean_absolute_error: 0.2136
# Epoch 84/1000
# 32/32 - 0s - 6ms/step - loss: 0.1224 - mean_absolute_error: 0.2262 - val_loss: 0.1258 - val_mean_absolute_error: 0.2266
# Epoch 85/1000
# 32/32 - 0s - 7ms/step - loss: 0.1204 - mean_absolute_error: 0.2255 - val_loss: 0.1255 - val_mean_absolute_error: 0.2268
# Epoch 86/1000
# 32/32 - 0s - 6ms/step - loss: 0.1169 - mean_absolute_error: 0.2193 - val_loss: 0.1233 - val_mean_absolute_error: 0.2260
# Epoch 87/1000
# 32/32 - 0s - 6ms/step - loss: 0.1140 - mean_absolute_error: 0.2139 - val_loss: 0.1239 - val_mean_absolute_error: 0.2204
# Epoch 88/1000
# 32/32 - 0s - 6ms/step - loss: 0.1145 - mean_absolute_error: 0.2139 - val_loss: 0.1220 - val_mean_absolute_error: 0.2188
# Epoch 89/1000
# 32/32 - 0s - 7ms/step - loss: 0.1091 - mean_absolute_error: 0.2049 - val_loss: 0.1135 - val_mean_absolute_error: 0.2067
# Epoch 90/1000
# 32/32 - 0s - 7ms/step - loss: 0.1091 - mean_absolute_error: 0.2062 - val_loss: 0.1133 - val_mean_absolute_error: 0.2066
# Epoch 91/1000
# 32/32 - 0s - 6ms/step - loss: 0.1098 - mean_absolute_error: 0.2080 - val_loss: 0.1142 - val_mean_absolute_error: 0.2078
# Epoch 92/1000
# 32/32 - 0s - 6ms/step - loss: 0.1073 - mean_absolute_error: 0.2018 - val_loss: 0.1141 - val_mean_absolute_error: 0.2081
# Epoch 93/1000
# 32/32 - 0s - 6ms/step - loss: 0.1080 - mean_absolute_error: 0.2042 - val_loss: 0.1202 - val_mean_absolute_error: 0.2153
# Epoch 94/1000
# 32/32 - 0s - 7ms/step - loss: 0.1080 - mean_absolute_error: 0.2022 - val_loss: 0.1119 - val_mean_absolute_error: 0.2015
# Epoch 95/1000
# 32/32 - 0s - 6ms/step - loss: 0.1080 - mean_absolute_error: 0.2011 - val_loss: 0.1160 - val_mean_absolute_error: 0.2083
# Epoch 96/1000
# 32/32 - 0s - 6ms/step - loss: 0.1091 - mean_absolute_error: 0.2047 - val_loss: 0.1143 - val_mean_absolute_error: 0.2043
# Epoch 97/1000
# 32/32 - 0s - 6ms/step - loss: 0.1083 - mean_absolute_error: 0.2030 - val_loss: 0.1129 - val_mean_absolute_error: 0.2070
# Epoch 98/1000
# 32/32 - 0s - 6ms/step - loss: 0.1100 - mean_absolute_error: 0.2059 - val_loss: 0.1279 - val_mean_absolute_error: 0.2256
# Epoch 99/1000
# 32/32 - 0s - 6ms/step - loss: 0.1160 - mean_absolute_error: 0.2133 - val_loss: 0.1326 - val_mean_absolute_error: 0.2360
# Epoch 100/1000
# 32/32 - 0s - 8ms/step - loss: 0.1108 - mean_absolute_error: 0.2081 - val_loss: 0.1121 - val_mean_absolute_error: 0.2019
# Epoch 101/1000
# 32/32 - 0s - 8ms/step - loss: 0.1085 - mean_absolute_error: 0.2030 - val_loss: 0.1136 - val_mean_absolute_error: 0.2055
# Epoch 102/1000
# 32/32 - 0s - 7ms/step - loss: 0.1072 - mean_absolute_error: 0.2020 - val_loss: 0.1152 - val_mean_absolute_error: 0.2084
# Epoch 103/1000
# 32/32 - 0s - 6ms/step - loss: 0.1112 - mean_absolute_error: 0.2084 - val_loss: 0.1181 - val_mean_absolute_error: 0.2161
# Epoch 104/1000
# 32/32 - 0s - 6ms/step - loss: 0.1042 - mean_absolute_error: 0.1960 - val_loss: 0.1192 - val_mean_absolute_error: 0.2104
# Epoch 105/1000
# 32/32 - 0s - 6ms/step - loss: 0.1088 - mean_absolute_error: 0.2045 - val_loss: 0.1169 - val_mean_absolute_error: 0.2097
# Epoch 106/1000
# 32/32 - 0s - 7ms/step - loss: 0.1100 - mean_absolute_error: 0.2046 - val_loss: 0.1146 - val_mean_absolute_error: 0.2054
# Epoch 107/1000
# 32/32 - 0s - 7ms/step - loss: 0.1050 - mean_absolute_error: 0.1960 - val_loss: 0.1112 - val_mean_absolute_error: 0.1984
# Epoch 108/1000
# 32/32 - 0s - 6ms/step - loss: 0.1049 - mean_absolute_error: 0.1968 - val_loss: 0.1115 - val_mean_absolute_error: 0.1972
# Epoch 109/1000
# 32/32 - 0s - 6ms/step - loss: 0.1043 - mean_absolute_error: 0.1955 - val_loss: 0.1159 - val_mean_absolute_error: 0.2073
# Epoch 110/1000
# 32/32 - 0s - 6ms/step - loss: 0.1044 - mean_absolute_error: 0.1937 - val_loss: 0.1129 - val_mean_absolute_error: 0.1983
# Epoch 111/1000
# 32/32 - 0s - 7ms/step - loss: 0.1035 - mean_absolute_error: 0.1935 - val_loss: 0.1154 - val_mean_absolute_error: 0.2068
# Epoch 112/1000
# 32/32 - 0s - 7ms/step - loss: 0.1092 - mean_absolute_error: 0.2021 - val_loss: 0.1366 - val_mean_absolute_error: 0.2427
# Epoch 113/1000
# 32/32 - 0s - 7ms/step - loss: 0.1136 - mean_absolute_error: 0.2159 - val_loss: 0.1133 - val_mean_absolute_error: 0.2064
# Epoch 114/1000
# 32/32 - 0s - 7ms/step - loss: 0.1068 - mean_absolute_error: 0.2011 - val_loss: 0.1162 - val_mean_absolute_error: 0.2077
# Epoch 115/1000
# 32/32 - 0s - 6ms/step - loss: 0.1077 - mean_absolute_error: 0.2006 - val_loss: 0.1326 - val_mean_absolute_error: 0.2281
# Epoch 116/1000
# 32/32 - 0s - 7ms/step - loss: 0.1097 - mean_absolute_error: 0.2078 - val_loss: 0.1202 - val_mean_absolute_error: 0.2127
# Epoch 117/1000
# 32/32 - 0s - 8ms/step - loss: 0.1062 - mean_absolute_error: 0.1986 - val_loss: 0.1108 - val_mean_absolute_error: 0.1974
# Epoch 118/1000
# 32/32 - 0s - 7ms/step - loss: 0.1051 - mean_absolute_error: 0.1954 - val_loss: 0.1108 - val_mean_absolute_error: 0.1951
# Epoch 119/1000
# 32/32 - 0s - 6ms/step - loss: 0.1037 - mean_absolute_error: 0.1919 - val_loss: 0.1205 - val_mean_absolute_error: 0.2145
# Epoch 120/1000
# 32/32 - 0s - 7ms/step - loss: 0.1066 - mean_absolute_error: 0.1997 - val_loss: 0.1102 - val_mean_absolute_error: 0.1983
# Epoch 121/1000
# 32/32 - 0s - 7ms/step - loss: 0.1008 - mean_absolute_error: 0.1887 - val_loss: 0.1142 - val_mean_absolute_error: 0.2024
# Epoch 122/1000
# 32/32 - 0s - 7ms/step - loss: 0.1016 - mean_absolute_error: 0.1903 - val_loss: 0.1126 - val_mean_absolute_error: 0.2028
# Epoch 123/1000
# 32/32 - 0s - 7ms/step - loss: 0.1049 - mean_absolute_error: 0.1965 - val_loss: 0.1166 - val_mean_absolute_error: 0.2057
# Epoch 124/1000
# 32/32 - 0s - 6ms/step - loss: 0.1037 - mean_absolute_error: 0.1929 - val_loss: 0.1110 - val_mean_absolute_error: 0.1953
# Epoch 125/1000
# 32/32 - 0s - 6ms/step - loss: 0.1064 - mean_absolute_error: 0.1980 - val_loss: 0.1119 - val_mean_absolute_error: 0.1977
# Epoch 126/1000
# 32/32 - 0s - 6ms/step - loss: 0.1038 - mean_absolute_error: 0.1944 - val_loss: 0.1120 - val_mean_absolute_error: 0.1989
# Epoch 127/1000
# 32/32 - 0s - 7ms/step - loss: 0.1043 - mean_absolute_error: 0.1937 - val_loss: 0.1114 - val_mean_absolute_error: 0.1970
# Epoch 128/1000
# 32/32 - 0s - 7ms/step - loss: 0.1022 - mean_absolute_error: 0.1915 - val_loss: 0.1183 - val_mean_absolute_error: 0.2116
# Epoch 129/1000
# 32/32 - 0s - 6ms/step - loss: 0.1005 - mean_absolute_error: 0.1890 - val_loss: 0.1097 - val_mean_absolute_error: 0.1937
# Epoch 130/1000
# 32/32 - 0s - 6ms/step - loss: 0.1045 - mean_absolute_error: 0.1957 - val_loss: 0.1109 - val_mean_absolute_error: 0.1987
# Epoch 131/1000
# 32/32 - 0s - 6ms/step - loss: 0.1016 - mean_absolute_error: 0.1904 - val_loss: 0.1127 - val_mean_absolute_error: 0.2011
# Epoch 132/1000
# 32/32 - 0s - 6ms/step - loss: 0.1025 - mean_absolute_error: 0.1902 - val_loss: 0.1127 - val_mean_absolute_error: 0.1978
# Epoch 133/1000
# 32/32 - 0s - 6ms/step - loss: 0.1035 - mean_absolute_error: 0.1934 - val_loss: 0.1105 - val_mean_absolute_error: 0.1964
# Epoch 134/1000
# 32/32 - 0s - 6ms/step - loss: 0.1010 - mean_absolute_error: 0.1886 - val_loss: 0.1110 - val_mean_absolute_error: 0.1973
# Epoch 135/1000
# 32/32 - 0s - 7ms/step - loss: 0.1034 - mean_absolute_error: 0.1915 - val_loss: 0.1147 - val_mean_absolute_error: 0.2059
# Epoch 136/1000
# 32/32 - 0s - 8ms/step - loss: 0.1012 - mean_absolute_error: 0.1910 - val_loss: 0.1109 - val_mean_absolute_error: 0.1971
# Epoch 137/1000
# 32/32 - 0s - 6ms/step - loss: 0.0990 - mean_absolute_error: 0.1863 - val_loss: 0.1088 - val_mean_absolute_error: 0.1911
# Epoch 138/1000
# 32/32 - 0s - 6ms/step - loss: 0.1047 - mean_absolute_error: 0.1963 - val_loss: 0.1127 - val_mean_absolute_error: 0.2050
# Epoch 139/1000
# 32/32 - 0s - 7ms/step - loss: 0.1023 - mean_absolute_error: 0.1919 - val_loss: 0.1304 - val_mean_absolute_error: 0.2236
# Epoch 140/1000
# 32/32 - 0s - 7ms/step - loss: 0.1062 - mean_absolute_error: 0.1983 - val_loss: 0.1099 - val_mean_absolute_error: 0.1921
# Epoch 141/1000
# 32/32 - 0s - 6ms/step - loss: 0.0991 - mean_absolute_error: 0.1845 - val_loss: 0.1085 - val_mean_absolute_error: 0.1910
# Epoch 142/1000
# 32/32 - 0s - 6ms/step - loss: 0.1031 - mean_absolute_error: 0.1905 - val_loss: 0.1151 - val_mean_absolute_error: 0.2041
# Epoch 143/1000
# 32/32 - 0s - 6ms/step - loss: 0.1031 - mean_absolute_error: 0.1958 - val_loss: 0.1091 - val_mean_absolute_error: 0.1954
# Epoch 144/1000
# 32/32 - 0s - 6ms/step - loss: 0.0983 - mean_absolute_error: 0.1843 - val_loss: 0.1088 - val_mean_absolute_error: 0.1925
# Epoch 145/1000
# 32/32 - 0s - 7ms/step - loss: 0.1037 - mean_absolute_error: 0.1937 - val_loss: 0.1111 - val_mean_absolute_error: 0.1967
# Epoch 146/1000
# 32/32 - 0s - 7ms/step - loss: 0.1015 - mean_absolute_error: 0.1906 - val_loss: 0.1153 - val_mean_absolute_error: 0.2007
# Epoch 147/1000
# 32/32 - 0s - 7ms/step - loss: 0.0992 - mean_absolute_error: 0.1867 - val_loss: 0.1171 - val_mean_absolute_error: 0.2017
# Epoch 148/1000
# 32/32 - 0s - 7ms/step - loss: 0.0995 - mean_absolute_error: 0.1847 - val_loss: 0.1081 - val_mean_absolute_error: 0.1906
# Epoch 149/1000
# 32/32 - 0s - 7ms/step - loss: 0.0991 - mean_absolute_error: 0.1843 - val_loss: 0.1097 - val_mean_absolute_error: 0.1955
# Epoch 150/1000
# 32/32 - 0s - 7ms/step - loss: 0.1071 - mean_absolute_error: 0.2001 - val_loss: 0.1135 - val_mean_absolute_error: 0.2098
# Epoch 151/1000
# 32/32 - 0s - 7ms/step - loss: 0.1001 - mean_absolute_error: 0.1903 - val_loss: 0.1072 - val_mean_absolute_error: 0.1887
# Epoch 152/1000
# 32/32 - 0s - 6ms/step - loss: 0.0974 - mean_absolute_error: 0.1805 - val_loss: 0.1105 - val_mean_absolute_error: 0.1916
# Epoch 153/1000
# 32/32 - 0s - 6ms/step - loss: 0.1009 - mean_absolute_error: 0.1876 - val_loss: 0.1124 - val_mean_absolute_error: 0.1956
# Epoch 154/1000
# 32/32 - 0s - 6ms/step - loss: 0.1055 - mean_absolute_error: 0.1960 - val_loss: 0.1136 - val_mean_absolute_error: 0.2005
# Epoch 155/1000
# 32/32 - 0s - 7ms/step - loss: 0.1013 - mean_absolute_error: 0.1913 - val_loss: 0.1092 - val_mean_absolute_error: 0.1934
# Epoch 156/1000
# 32/32 - 0s - 7ms/step - loss: 0.1012 - mean_absolute_error: 0.1884 - val_loss: 0.1119 - val_mean_absolute_error: 0.2015
# Epoch 157/1000
# 32/32 - 0s - 6ms/step - loss: 0.1026 - mean_absolute_error: 0.1945 - val_loss: 0.1114 - val_mean_absolute_error: 0.1965
# Epoch 158/1000
# 32/32 - 0s - 6ms/step - loss: 0.1008 - mean_absolute_error: 0.1890 - val_loss: 0.1075 - val_mean_absolute_error: 0.1935
# Epoch 159/1000
# 32/32 - 0s - 6ms/step - loss: 0.1011 - mean_absolute_error: 0.1899 - val_loss: 0.1080 - val_mean_absolute_error: 0.1957
# Epoch 160/1000
# 32/32 - 0s - 6ms/step - loss: 0.1005 - mean_absolute_error: 0.1873 - val_loss: 0.1173 - val_mean_absolute_error: 0.2030
# Epoch 161/1000
# 32/32 - 0s - 6ms/step - loss: 0.1019 - mean_absolute_error: 0.1888 - val_loss: 0.1103 - val_mean_absolute_error: 0.1947
# Epoch 162/1000
# 32/32 - 0s - 6ms/step - loss: 0.0991 - mean_absolute_error: 0.1856 - val_loss: 0.1110 - val_mean_absolute_error: 0.1964
# Epoch 163/1000
# 32/32 - 0s - 7ms/step - loss: 0.1006 - mean_absolute_error: 0.1869 - val_loss: 0.1114 - val_mean_absolute_error: 0.1974
# Epoch 164/1000
# 32/32 - 0s - 7ms/step - loss: 0.0987 - mean_absolute_error: 0.1844 - val_loss: 0.1125 - val_mean_absolute_error: 0.1989
# Epoch 165/1000
# 32/32 - 0s - 7ms/step - loss: 0.0993 - mean_absolute_error: 0.1856 - val_loss: 0.1095 - val_mean_absolute_error: 0.1942
# Epoch 166/1000
# 32/32 - 0s - 7ms/step - loss: 0.1040 - mean_absolute_error: 0.1939 - val_loss: 0.1087 - val_mean_absolute_error: 0.1952
# Epoch 167/1000
# 32/32 - 0s - 7ms/step - loss: 0.1010 - mean_absolute_error: 0.1883 - val_loss: 0.1178 - val_mean_absolute_error: 0.2062
# Epoch 168/1000
# 32/32 - 0s - 7ms/step - loss: 0.1045 - mean_absolute_error: 0.1939 - val_loss: 0.1151 - val_mean_absolute_error: 0.2083
# Epoch 169/1000
# 32/32 - 0s - 7ms/step - loss: 0.0995 - mean_absolute_error: 0.1860 - val_loss: 0.1091 - val_mean_absolute_error: 0.1919
# Epoch 170/1000
# 32/32 - 0s - 7ms/step - loss: 0.1005 - mean_absolute_error: 0.1867 - val_loss: 0.1089 - val_mean_absolute_error: 0.1921
# Epoch 171/1000
# 32/32 - 0s - 7ms/step - loss: 0.1060 - mean_absolute_error: 0.1960 - val_loss: 0.1113 - val_mean_absolute_error: 0.1978
# Epoch 172/1000
# 32/32 - 0s - 7ms/step - loss: 0.1001 - mean_absolute_error: 0.1872 - val_loss: 0.1080 - val_mean_absolute_error: 0.1905
# Epoch 173/1000
# 32/32 - 0s - 7ms/step - loss: 0.0974 - mean_absolute_error: 0.1816 - val_loss: 0.1086 - val_mean_absolute_error: 0.1919
# Epoch 174/1000
# 32/32 - 0s - 7ms/step - loss: 0.0984 - mean_absolute_error: 0.1834 - val_loss: 0.1115 - val_mean_absolute_error: 0.1988
# Epoch 175/1000
# 32/32 - 0s - 6ms/step - loss: 0.1054 - mean_absolute_error: 0.1955 - val_loss: 0.1134 - val_mean_absolute_error: 0.2055
# Epoch 176/1000
# 32/32 - 0s - 6ms/step - loss: 0.1031 - mean_absolute_error: 0.1931 - val_loss: 0.1302 - val_mean_absolute_error: 0.2254
# Epoch 177/1000
# 32/32 - 0s - 6ms/step - loss: 0.1081 - mean_absolute_error: 0.2018 - val_loss: 0.1097 - val_mean_absolute_error: 0.1984
# Epoch 178/1000
# 32/32 - 0s - 6ms/step - loss: 0.1002 - mean_absolute_error: 0.1878 - val_loss: 0.1082 - val_mean_absolute_error: 0.1930
# Epoch 179/1000
# 32/32 - 0s - 6ms/step - loss: 0.0983 - mean_absolute_error: 0.1826 - val_loss: 0.1134 - val_mean_absolute_error: 0.1989
# Epoch 180/1000
# 32/32 - 0s - 6ms/step - loss: 0.0991 - mean_absolute_error: 0.1841 - val_loss: 0.1103 - val_mean_absolute_error: 0.1985
# Epoch 181/1000
# 32/32 - 0s - 6ms/step - loss: 0.0972 - mean_absolute_error: 0.1820 - val_loss: 0.1143 - val_mean_absolute_error: 0.1977
# Epoch 182/1000
# 32/32 - 0s - 6ms/step - loss: 0.1049 - mean_absolute_error: 0.1943 - val_loss: 0.1102 - val_mean_absolute_error: 0.1993
# Epoch 183/1000
# 32/32 - 0s - 7ms/step - loss: 0.0999 - mean_absolute_error: 0.1865 - val_loss: 0.1113 - val_mean_absolute_error: 0.1964
# Epoch 184/1000
# 32/32 - 0s - 7ms/step - loss: 0.0997 - mean_absolute_error: 0.1860 - val_loss: 0.1135 - val_mean_absolute_error: 0.1999
# Epoch 185/1000
# 32/32 - 0s - 6ms/step - loss: 0.1019 - mean_absolute_error: 0.1906 - val_loss: 0.1080 - val_mean_absolute_error: 0.1925
# Epoch 186/1000
# 32/32 - 0s - 6ms/step - loss: 0.0972 - mean_absolute_error: 0.1822 - val_loss: 0.1100 - val_mean_absolute_error: 0.1958
# Epoch 187/1000
# 32/32 - 0s - 6ms/step - loss: 0.0979 - mean_absolute_error: 0.1825 - val_loss: 0.1102 - val_mean_absolute_error: 0.1988
# Epoch 188/1000
# 32/32 - 0s - 6ms/step - loss: 0.0979 - mean_absolute_error: 0.1824 - val_loss: 0.1088 - val_mean_absolute_error: 0.1933
# Epoch 189/1000
# 32/32 - 0s - 6ms/step - loss: 0.0984 - mean_absolute_error: 0.1843 - val_loss: 0.1116 - val_mean_absolute_error: 0.1990
# Epoch 190/1000
# 32/32 - 0s - 6ms/step - loss: 0.1028 - mean_absolute_error: 0.1925 - val_loss: 0.1150 - val_mean_absolute_error: 0.2000
# Epoch 191/1000
# 32/32 - 0s - 7ms/step - loss: 0.0983 - mean_absolute_error: 0.1846 - val_loss: 0.1071 - val_mean_absolute_error: 0.1910
# Epoch 192/1000
# 32/32 - 0s - 7ms/step - loss: 0.0984 - mean_absolute_error: 0.1836 - val_loss: 0.1096 - val_mean_absolute_error: 0.1962
# Epoch 193/1000
# 32/32 - 0s - 7ms/step - loss: 0.0963 - mean_absolute_error: 0.1789 - val_loss: 0.1106 - val_mean_absolute_error: 0.1965
# Epoch 194/1000
# 32/32 - 0s - 6ms/step - loss: 0.0973 - mean_absolute_error: 0.1815 - val_loss: 0.1094 - val_mean_absolute_error: 0.1989
# Epoch 195/1000
# 32/32 - 0s - 7ms/step - loss: 0.0982 - mean_absolute_error: 0.1851 - val_loss: 0.1088 - val_mean_absolute_error: 0.1938
# Epoch 196/1000
# 32/32 - 0s - 7ms/step - loss: 0.0999 - mean_absolute_error: 0.1870 - val_loss: 0.1123 - val_mean_absolute_error: 0.1974
# Epoch 197/1000
# 32/32 - 0s - 7ms/step - loss: 0.1015 - mean_absolute_error: 0.1886 - val_loss: 0.1093 - val_mean_absolute_error: 0.1948
# Epoch 198/1000
# 32/32 - 0s - 6ms/step - loss: 0.0982 - mean_absolute_error: 0.1840 - val_loss: 0.1073 - val_mean_absolute_error: 0.1917
# Epoch 199/1000
# 32/32 - 0s - 6ms/step - loss: 0.0981 - mean_absolute_error: 0.1855 - val_loss: 0.1109 - val_mean_absolute_error: 0.1991
# Epoch 200/1000
# 32/32 - 0s - 6ms/step - loss: 0.1004 - mean_absolute_error: 0.1868 - val_loss: 0.1255 - val_mean_absolute_error: 0.2179
# Epoch 201/1000
# 32/32 - 0s - 11ms/step - loss: 0.1002 - mean_absolute_error: 0.1879 - val_loss: 0.1073 - val_mean_absolute_error: 0.1911
# Epoch 202/1000
# 32/32 - 0s - 6ms/step - loss: 0.0974 - mean_absolute_error: 0.1814 - val_loss: 0.1097 - val_mean_absolute_error: 0.1950
# Epoch 203/1000
# 32/32 - 0s - 6ms/step - loss: 0.0972 - mean_absolute_error: 0.1802 - val_loss: 0.1063 - val_mean_absolute_error: 0.1920
# Epoch 204/1000
# 32/32 - 0s - 6ms/step - loss: 0.0965 - mean_absolute_error: 0.1801 - val_loss: 0.1091 - val_mean_absolute_error: 0.1933
# Epoch 205/1000
# 32/32 - 0s - 6ms/step - loss: 0.1045 - mean_absolute_error: 0.1952 - val_loss: 0.1104 - val_mean_absolute_error: 0.2004
# Epoch 206/1000
# 32/32 - 0s - 6ms/step - loss: 0.1000 - mean_absolute_error: 0.1891 - val_loss: 0.1081 - val_mean_absolute_error: 0.1926
# Epoch 207/1000
# 32/32 - 0s - 6ms/step - loss: 0.0974 - mean_absolute_error: 0.1829 - val_loss: 0.1074 - val_mean_absolute_error: 0.1932
# Epoch 208/1000
# 32/32 - 0s - 6ms/step - loss: 0.0980 - mean_absolute_error: 0.1840 - val_loss: 0.1121 - val_mean_absolute_error: 0.1992
# Epoch 209/1000
# 32/32 - 0s - 6ms/step - loss: 0.1034 - mean_absolute_error: 0.1933 - val_loss: 0.1124 - val_mean_absolute_error: 0.2025
# Epoch 210/1000
# 32/32 - 0s - 6ms/step - loss: 0.1006 - mean_absolute_error: 0.1897 - val_loss: 0.1137 - val_mean_absolute_error: 0.2044
# Epoch 211/1000
# 32/32 - 0s - 7ms/step - loss: 0.0963 - mean_absolute_error: 0.1805 - val_loss: 0.1083 - val_mean_absolute_error: 0.1932
# Epoch 212/1000
# 32/32 - 0s - 7ms/step - loss: 0.0971 - mean_absolute_error: 0.1810 - val_loss: 0.1123 - val_mean_absolute_error: 0.2018
# Epoch 213/1000
# 32/32 - 0s - 6ms/step - loss: 0.0985 - mean_absolute_error: 0.1842 - val_loss: 0.1080 - val_mean_absolute_error: 0.1941
# Epoch 214/1000
# 32/32 - 0s - 6ms/step - loss: 0.0972 - mean_absolute_error: 0.1816 - val_loss: 0.1049 - val_mean_absolute_error: 0.1845
# Epoch 215/1000
# 32/32 - 0s - 7ms/step - loss: 0.0947 - mean_absolute_error: 0.1761 - val_loss: 0.1048 - val_mean_absolute_error: 0.1854
# Epoch 216/1000
# 32/32 - 0s - 7ms/step - loss: 0.0971 - mean_absolute_error: 0.1813 - val_loss: 0.1060 - val_mean_absolute_error: 0.1892
# Epoch 217/1000
# 32/32 - 0s - 7ms/step - loss: 0.0976 - mean_absolute_error: 0.1843 - val_loss: 0.1082 - val_mean_absolute_error: 0.1935
# Epoch 218/1000
# 32/32 - 0s - 6ms/step - loss: 0.1020 - mean_absolute_error: 0.1906 - val_loss: 0.1168 - val_mean_absolute_error: 0.2099
# Epoch 219/1000
# 32/32 - 0s - 7ms/step - loss: 0.0976 - mean_absolute_error: 0.1856 - val_loss: 0.1090 - val_mean_absolute_error: 0.1894
# Epoch 220/1000
# 32/32 - 0s - 6ms/step - loss: 0.0963 - mean_absolute_error: 0.1800 - val_loss: 0.1071 - val_mean_absolute_error: 0.1885
# Epoch 221/1000
# 32/32 - 0s - 6ms/step - loss: 0.0970 - mean_absolute_error: 0.1838 - val_loss: 0.1080 - val_mean_absolute_error: 0.1927
# Epoch 222/1000
# 32/32 - 0s - 6ms/step - loss: 0.0990 - mean_absolute_error: 0.1859 - val_loss: 0.1196 - val_mean_absolute_error: 0.2120
# Epoch 223/1000
# 32/32 - 0s - 8ms/step - loss: 0.1007 - mean_absolute_error: 0.1896 - val_loss: 0.1085 - val_mean_absolute_error: 0.1913
# Epoch 224/1000
# 32/32 - 0s - 7ms/step - loss: 0.0960 - mean_absolute_error: 0.1799 - val_loss: 0.1075 - val_mean_absolute_error: 0.1891
# Epoch 225/1000
# 32/32 - 0s - 7ms/step - loss: 0.0992 - mean_absolute_error: 0.1858 - val_loss: 0.1107 - val_mean_absolute_error: 0.1941
# Epoch 226/1000
# 32/32 - 0s - 6ms/step - loss: 0.0968 - mean_absolute_error: 0.1818 - val_loss: 0.1089 - val_mean_absolute_error: 0.1962
# Epoch 227/1000
# 32/32 - 0s - 7ms/step - loss: 0.1007 - mean_absolute_error: 0.1893 - val_loss: 0.1101 - val_mean_absolute_error: 0.1939
# Epoch 228/1000
# 32/32 - 0s - 6ms/step - loss: 0.0971 - mean_absolute_error: 0.1834 - val_loss: 0.1082 - val_mean_absolute_error: 0.1940
# Epoch 229/1000
# 32/32 - 0s - 7ms/step - loss: 0.0948 - mean_absolute_error: 0.1787 - val_loss: 0.1063 - val_mean_absolute_error: 0.1895
# Epoch 230/1000
# 32/32 - 0s - 7ms/step - loss: 0.0949 - mean_absolute_error: 0.1799 - val_loss: 0.1098 - val_mean_absolute_error: 0.1955
# Epoch 231/1000
# 32/32 - 0s - 7ms/step - loss: 0.0941 - mean_absolute_error: 0.1786 - val_loss: 0.1088 - val_mean_absolute_error: 0.1938
# Epoch 232/1000
# 32/32 - 0s - 6ms/step - loss: 0.0948 - mean_absolute_error: 0.1796 - val_loss: 0.1080 - val_mean_absolute_error: 0.1939
# Epoch 233/1000
# 32/32 - 0s - 7ms/step - loss: 0.0999 - mean_absolute_error: 0.1891 - val_loss: 0.1150 - val_mean_absolute_error: 0.2049
# Epoch 234/1000
# 32/32 - 0s - 6ms/step - loss: 0.0959 - mean_absolute_error: 0.1833 - val_loss: 0.1092 - val_mean_absolute_error: 0.1943
# Epoch 235/1000
# 32/32 - 0s - 6ms/step - loss: 0.0980 - mean_absolute_error: 0.1853 - val_loss: 0.1081 - val_mean_absolute_error: 0.1911
# Epoch 236/1000
# 32/32 - 0s - 7ms/step - loss: 0.0942 - mean_absolute_error: 0.1784 - val_loss: 0.1076 - val_mean_absolute_error: 0.1924
# Epoch 237/1000
# 32/32 - 0s - 7ms/step - loss: 0.0951 - mean_absolute_error: 0.1790 - val_loss: 0.1085 - val_mean_absolute_error: 0.1920
# Epoch 238/1000
# 32/32 - 0s - 8ms/step - loss: 0.0955 - mean_absolute_error: 0.1813 - val_loss: 0.1094 - val_mean_absolute_error: 0.1910
# Epoch 239/1000
# 32/32 - 0s - 7ms/step - loss: 0.0957 - mean_absolute_error: 0.1811 - val_loss: 0.1177 - val_mean_absolute_error: 0.2044
# Epoch 240/1000
# 32/32 - 0s - 7ms/step - loss: 0.0941 - mean_absolute_error: 0.1791 - val_loss: 0.1110 - val_mean_absolute_error: 0.1911
# Epoch 241/1000
# 32/32 - 0s - 7ms/step - loss: 0.0942 - mean_absolute_error: 0.1797 - val_loss: 0.1080 - val_mean_absolute_error: 0.1894
# Epoch 242/1000
# 32/32 - 0s - 6ms/step - loss: 0.0969 - mean_absolute_error: 0.1846 - val_loss: 0.1093 - val_mean_absolute_error: 0.1921
# Epoch 243/1000
# 32/32 - 0s - 6ms/step - loss: 0.0949 - mean_absolute_error: 0.1808 - val_loss: 0.1106 - val_mean_absolute_error: 0.1942
# Epoch 244/1000
# 32/32 - 0s - 6ms/step - loss: 0.0923 - mean_absolute_error: 0.1780 - val_loss: 0.1154 - val_mean_absolute_error: 0.1968
# Epoch 245/1000
# 32/32 - 0s - 6ms/step - loss: 0.1010 - mean_absolute_error: 0.1900 - val_loss: 0.1131 - val_mean_absolute_error: 0.1995
# Epoch 246/1000
# 32/32 - 0s - 6ms/step - loss: 0.0949 - mean_absolute_error: 0.1813 - val_loss: 0.1105 - val_mean_absolute_error: 0.1911
# Epoch 247/1000
# 32/32 - 0s - 6ms/step - loss: 0.0940 - mean_absolute_error: 0.1781 - val_loss: 0.1092 - val_mean_absolute_error: 0.1916
# Epoch 248/1000
# 32/32 - 0s - 6ms/step - loss: 0.0956 - mean_absolute_error: 0.1809 - val_loss: 0.1112 - val_mean_absolute_error: 0.1982
# Epoch 249/1000
# 32/32 - 0s - 7ms/step - loss: 0.1024 - mean_absolute_error: 0.1940 - val_loss: 0.1121 - val_mean_absolute_error: 0.1952
# Epoch 250/1000
# 32/32 - 0s - 6ms/step - loss: 0.0977 - mean_absolute_error: 0.1863 - val_loss: 0.1132 - val_mean_absolute_error: 0.2014
# Epoch 251/1000
# 32/32 - 0s - 6ms/step - loss: 0.0961 - mean_absolute_error: 0.1832 - val_loss: 0.1132 - val_mean_absolute_error: 0.1952
# Epoch 252/1000
# 32/32 - 0s - 6ms/step - loss: 0.0971 - mean_absolute_error: 0.1857 - val_loss: 0.1094 - val_mean_absolute_error: 0.1890
# Epoch 253/1000
# 32/32 - 0s - 6ms/step - loss: 0.0924 - mean_absolute_error: 0.1769 - val_loss: 0.1099 - val_mean_absolute_error: 0.1914
# Epoch 254/1000
# 32/32 - 0s - 7ms/step - loss: 0.0961 - mean_absolute_error: 0.1832 - val_loss: 0.1176 - val_mean_absolute_error: 0.2106
# Epoch 255/1000
# 32/32 - 0s - 7ms/step - loss: 0.0988 - mean_absolute_error: 0.1897 - val_loss: 0.1097 - val_mean_absolute_error: 0.1929
# Epoch 256/1000
# 32/32 - 0s - 6ms/step - loss: 0.0944 - mean_absolute_error: 0.1810 - val_loss: 0.1103 - val_mean_absolute_error: 0.1915
# Epoch 257/1000
# 32/32 - 0s - 6ms/step - loss: 0.0941 - mean_absolute_error: 0.1804 - val_loss: 0.1144 - val_mean_absolute_error: 0.1983
# Epoch 258/1000
# 32/32 - 0s - 6ms/step - loss: 0.0943 - mean_absolute_error: 0.1805 - val_loss: 0.1130 - val_mean_absolute_error: 0.1984
# Epoch 259/1000
# 32/32 - 0s - 6ms/step - loss: 0.0937 - mean_absolute_error: 0.1806 - val_loss: 0.1136 - val_mean_absolute_error: 0.1981
# Epoch 260/1000
# 32/32 - 0s - 6ms/step - loss: 0.0920 - mean_absolute_error: 0.1750 - val_loss: 0.1085 - val_mean_absolute_error: 0.1882
# Epoch 261/1000
# 32/32 - 0s - 6ms/step - loss: 0.0931 - mean_absolute_error: 0.1782 - val_loss: 0.1080 - val_mean_absolute_error: 0.1910
# Epoch 262/1000
# 32/32 - 0s - 6ms/step - loss: 0.0921 - mean_absolute_error: 0.1776 - val_loss: 0.1098 - val_mean_absolute_error: 0.1895
# Epoch 263/1000
# 32/32 - 0s - 7ms/step - loss: 0.0939 - mean_absolute_error: 0.1804 - val_loss: 0.1115 - val_mean_absolute_error: 0.1951
# Epoch 264/1000
# 32/32 - 0s - 6ms/step - loss: 0.0933 - mean_absolute_error: 0.1812 - val_loss: 0.1114 - val_mean_absolute_error: 0.1947
# Epoch 265/1000
# 32/32 - 0s - 6ms/step - loss: 0.0936 - mean_absolute_error: 0.1798 - val_loss: 0.1123 - val_mean_absolute_error: 0.1997
# Epoch 266/1000
# 32/32 - 0s - 7ms/step - loss: 0.1004 - mean_absolute_error: 0.1925 - val_loss: 0.1115 - val_mean_absolute_error: 0.2010
# Epoch 267/1000
# 32/32 - 0s - 7ms/step - loss: 0.0929 - mean_absolute_error: 0.1818 - val_loss: 0.1087 - val_mean_absolute_error: 0.1937
# Epoch 268/1000
# 32/32 - 0s - 6ms/step - loss: 0.0928 - mean_absolute_error: 0.1788 - val_loss: 0.1065 - val_mean_absolute_error: 0.1875
# Epoch 269/1000
# 32/32 - 0s - 6ms/step - loss: 0.0942 - mean_absolute_error: 0.1821 - val_loss: 0.1075 - val_mean_absolute_error: 0.1952
# Epoch 270/1000
# 32/32 - 0s - 6ms/step - loss: 0.0968 - mean_absolute_error: 0.1874 - val_loss: 0.1096 - val_mean_absolute_error: 0.1959
# Epoch 271/1000
# 32/32 - 0s - 6ms/step - loss: 0.0911 - mean_absolute_error: 0.1771 - val_loss: 0.1074 - val_mean_absolute_error: 0.1883
# Epoch 272/1000
# 32/32 - 0s - 6ms/step - loss: 0.0943 - mean_absolute_error: 0.1806 - val_loss: 0.1096 - val_mean_absolute_error: 0.1967
# Epoch 273/1000
# 32/32 - 0s - 6ms/step - loss: 0.0993 - mean_absolute_error: 0.1906 - val_loss: 0.1172 - val_mean_absolute_error: 0.2073
# Epoch 274/1000
# 32/32 - 0s - 7ms/step - loss: 0.0953 - mean_absolute_error: 0.1853 - val_loss: 0.1131 - val_mean_absolute_error: 0.1961
# Epoch 275/1000
# 32/32 - 0s - 7ms/step - loss: 0.0967 - mean_absolute_error: 0.1873 - val_loss: 0.1093 - val_mean_absolute_error: 0.1962
# Epoch 276/1000
# 32/32 - 0s - 7ms/step - loss: 0.0912 - mean_absolute_error: 0.1767 - val_loss: 0.1118 - val_mean_absolute_error: 0.1994
# Epoch 277/1000
# 32/32 - 0s - 6ms/step - loss: 0.0922 - mean_absolute_error: 0.1784 - val_loss: 0.1098 - val_mean_absolute_error: 0.1959
# Epoch 278/1000
# 32/32 - 0s - 6ms/step - loss: 0.0980 - mean_absolute_error: 0.1892 - val_loss: 0.1075 - val_mean_absolute_error: 0.1931
# Epoch 279/1000
# 32/32 - 0s - 6ms/step - loss: 0.0940 - mean_absolute_error: 0.1818 - val_loss: 0.1118 - val_mean_absolute_error: 0.1957
# Epoch 280/1000
# 32/32 - 0s - 7ms/step - loss: 0.0943 - mean_absolute_error: 0.1835 - val_loss: 0.1066 - val_mean_absolute_error: 0.1858
# Epoch 281/1000
# 32/32 - 0s - 6ms/step - loss: 0.0967 - mean_absolute_error: 0.1842 - val_loss: 0.1177 - val_mean_absolute_error: 0.2116
# Epoch 282/1000
# 32/32 - 0s - 7ms/step - loss: 0.0933 - mean_absolute_error: 0.1827 - val_loss: 0.1088 - val_mean_absolute_error: 0.1912
# Epoch 283/1000
# 32/32 - 0s - 6ms/step - loss: 0.0951 - mean_absolute_error: 0.1840 - val_loss: 0.1143 - val_mean_absolute_error: 0.2010
# Epoch 284/1000
# 32/32 - 0s - 6ms/step - loss: 0.0931 - mean_absolute_error: 0.1811 - val_loss: 0.1064 - val_mean_absolute_error: 0.1879
# Epoch 285/1000
# 32/32 - 0s - 6ms/step - loss: 0.0896 - mean_absolute_error: 0.1736 - val_loss: 0.1108 - val_mean_absolute_error: 0.1955
# Epoch 286/1000
# 32/32 - 0s - 6ms/step - loss: 0.0919 - mean_absolute_error: 0.1793 - val_loss: 0.1104 - val_mean_absolute_error: 0.1996
# Epoch 287/1000
# 32/32 - 0s - 7ms/step - loss: 0.0910 - mean_absolute_error: 0.1779 - val_loss: 0.1069 - val_mean_absolute_error: 0.1896
# Epoch 288/1000
# 32/32 - 0s - 6ms/step - loss: 0.0907 - mean_absolute_error: 0.1766 - val_loss: 0.1141 - val_mean_absolute_error: 0.2005
# Epoch 289/1000
# 32/32 - 0s - 7ms/step - loss: 0.0917 - mean_absolute_error: 0.1783 - val_loss: 0.1072 - val_mean_absolute_error: 0.1941
# Epoch 290/1000
# 32/32 - 0s - 7ms/step - loss: 0.0924 - mean_absolute_error: 0.1800 - val_loss: 0.1083 - val_mean_absolute_error: 0.1890
# Epoch 291/1000
# 32/32 - 0s - 12ms/step - loss: 0.0905 - mean_absolute_error: 0.1760 - val_loss: 0.1087 - val_mean_absolute_error: 0.1921
# Epoch 292/1000
# 32/32 - 0s - 6ms/step - loss: 0.0911 - mean_absolute_error: 0.1763 - val_loss: 0.1079 - val_mean_absolute_error: 0.1913
# Epoch 293/1000
# 32/32 - 0s - 6ms/step - loss: 0.0890 - mean_absolute_error: 0.1743 - val_loss: 0.1055 - val_mean_absolute_error: 0.1865
# Epoch 294/1000
# 32/32 - 0s - 6ms/step - loss: 0.0924 - mean_absolute_error: 0.1805 - val_loss: 0.1070 - val_mean_absolute_error: 0.1872
# Epoch 295/1000
# 32/32 - 0s - 7ms/step - loss: 0.0911 - mean_absolute_error: 0.1778 - val_loss: 0.1103 - val_mean_absolute_error: 0.1935
# Epoch 296/1000
# 32/32 - 0s - 6ms/step - loss: 0.0889 - mean_absolute_error: 0.1753 - val_loss: 0.1109 - val_mean_absolute_error: 0.1969
# Epoch 297/1000
# 32/32 - 0s - 6ms/step - loss: 0.0914 - mean_absolute_error: 0.1789 - val_loss: 0.1097 - val_mean_absolute_error: 0.1938
# Epoch 298/1000
# 32/32 - 0s - 7ms/step - loss: 0.0905 - mean_absolute_error: 0.1781 - val_loss: 0.1104 - val_mean_absolute_error: 0.1954
# Epoch 299/1000
# 32/32 - 0s - 6ms/step - loss: 0.0955 - mean_absolute_error: 0.1861 - val_loss: 0.1094 - val_mean_absolute_error: 0.1982
# Epoch 300/1000
# 32/32 - 0s - 6ms/step - loss: 0.0890 - mean_absolute_error: 0.1757 - val_loss: 0.1044 - val_mean_absolute_error: 0.1856
# Epoch 301/1000
# 32/32 - 0s - 6ms/step - loss: 0.0877 - mean_absolute_error: 0.1740 - val_loss: 0.1084 - val_mean_absolute_error: 0.1925
# Epoch 302/1000
# 32/32 - 0s - 6ms/step - loss: 0.0873 - mean_absolute_error: 0.1719 - val_loss: 0.1066 - val_mean_absolute_error: 0.1912
# Epoch 303/1000
# 32/32 - 0s - 6ms/step - loss: 0.0997 - mean_absolute_error: 0.1916 - val_loss: 0.1091 - val_mean_absolute_error: 0.1982
# Epoch 304/1000
# 32/32 - 0s - 6ms/step - loss: 0.0904 - mean_absolute_error: 0.1782 - val_loss: 0.1063 - val_mean_absolute_error: 0.1917
# Epoch 305/1000
# 32/32 - 0s - 6ms/step - loss: 0.0865 - mean_absolute_error: 0.1719 - val_loss: 0.1085 - val_mean_absolute_error: 0.1938
# Epoch 306/1000
# 32/32 - 0s - 6ms/step - loss: 0.0918 - mean_absolute_error: 0.1792 - val_loss: 0.1074 - val_mean_absolute_error: 0.1891
# Epoch 307/1000
# 32/32 - 0s - 6ms/step - loss: 0.0891 - mean_absolute_error: 0.1758 - val_loss: 0.1099 - val_mean_absolute_error: 0.1924
# Epoch 308/1000
# 32/32 - 0s - 6ms/step - loss: 0.0893 - mean_absolute_error: 0.1768 - val_loss: 0.1119 - val_mean_absolute_error: 0.1971
# Epoch 309/1000
# 32/32 - 0s - 6ms/step - loss: 0.0887 - mean_absolute_error: 0.1752 - val_loss: 0.1090 - val_mean_absolute_error: 0.1949
# Epoch 310/1000
# 32/32 - 0s - 7ms/step - loss: 0.0886 - mean_absolute_error: 0.1752 - val_loss: 0.1076 - val_mean_absolute_error: 0.1942
# Epoch 311/1000
# 32/32 - 0s - 6ms/step - loss: 0.0901 - mean_absolute_error: 0.1782 - val_loss: 0.1085 - val_mean_absolute_error: 0.1955
# Epoch 312/1000
# 32/32 - 0s - 6ms/step - loss: 0.0898 - mean_absolute_error: 0.1790 - val_loss: 0.1076 - val_mean_absolute_error: 0.1947
# Epoch 313/1000
# 32/32 - 0s - 6ms/step - loss: 0.0868 - mean_absolute_error: 0.1722 - val_loss: 0.1046 - val_mean_absolute_error: 0.1848
# Epoch 314/1000
# 32/32 - 0s - 6ms/step - loss: 0.0869 - mean_absolute_error: 0.1716 - val_loss: 0.1074 - val_mean_absolute_error: 0.1893
# Epoch 315/1000
# 32/32 - 0s - 6ms/step - loss: 0.0873 - mean_absolute_error: 0.1732 - val_loss: 0.1103 - val_mean_absolute_error: 0.1942
# Epoch 316/1000
# 32/32 - 0s - 6ms/step - loss: 0.0902 - mean_absolute_error: 0.1779 - val_loss: 0.1069 - val_mean_absolute_error: 0.1885
# Epoch 317/1000
# 32/32 - 0s - 6ms/step - loss: 0.0867 - mean_absolute_error: 0.1722 - val_loss: 0.1065 - val_mean_absolute_error: 0.1891
# Epoch 318/1000
# 32/32 - 0s - 6ms/step - loss: 0.0917 - mean_absolute_error: 0.1807 - val_loss: 0.1152 - val_mean_absolute_error: 0.2023
# Epoch 319/1000
# 32/32 - 0s - 6ms/step - loss: 0.0879 - mean_absolute_error: 0.1746 - val_loss: 0.1063 - val_mean_absolute_error: 0.1891
# Epoch 320/1000
# 32/32 - 0s - 7ms/step - loss: 0.0863 - mean_absolute_error: 0.1722 - val_loss: 0.1043 - val_mean_absolute_error: 0.1887
# Epoch 321/1000
# 32/32 - 0s - 7ms/step - loss: 0.0950 - mean_absolute_error: 0.1851 - val_loss: 0.1080 - val_mean_absolute_error: 0.1931
# Epoch 322/1000
# 32/32 - 0s - 6ms/step - loss: 0.0877 - mean_absolute_error: 0.1763 - val_loss: 0.1129 - val_mean_absolute_error: 0.1975
# Epoch 323/1000
# 32/32 - 0s - 6ms/step - loss: 0.0860 - mean_absolute_error: 0.1713 - val_loss: 0.1036 - val_mean_absolute_error: 0.1892
# Epoch 324/1000
# 32/32 - 0s - 6ms/step - loss: 0.0900 - mean_absolute_error: 0.1781 - val_loss: 0.1091 - val_mean_absolute_error: 0.1953
# Epoch 325/1000
# 32/32 - 0s - 7ms/step - loss: 0.0868 - mean_absolute_error: 0.1748 - val_loss: 0.1122 - val_mean_absolute_error: 0.2010
# Epoch 326/1000
# 32/32 - 0s - 6ms/step - loss: 0.0901 - mean_absolute_error: 0.1788 - val_loss: 0.1043 - val_mean_absolute_error: 0.1860
# Epoch 327/1000
# 32/32 - 0s - 6ms/step - loss: 0.0846 - mean_absolute_error: 0.1693 - val_loss: 0.1018 - val_mean_absolute_error: 0.1851
# Epoch 328/1000
# 32/32 - 0s - 6ms/step - loss: 0.0840 - mean_absolute_error: 0.1699 - val_loss: 0.1054 - val_mean_absolute_error: 0.1881
# Epoch 329/1000
# 32/32 - 0s - 6ms/step - loss: 0.0842 - mean_absolute_error: 0.1698 - val_loss: 0.1034 - val_mean_absolute_error: 0.1839
# Epoch 330/1000
# 32/32 - 0s - 6ms/step - loss: 0.0844 - mean_absolute_error: 0.1691 - val_loss: 0.1103 - val_mean_absolute_error: 0.1927
# Epoch 331/1000
# 32/32 - 0s - 6ms/step - loss: 0.0856 - mean_absolute_error: 0.1709 - val_loss: 0.1076 - val_mean_absolute_error: 0.1905
# Epoch 332/1000
# 32/32 - 0s - 6ms/step - loss: 0.0845 - mean_absolute_error: 0.1695 - val_loss: 0.1097 - val_mean_absolute_error: 0.1952
# Epoch 333/1000
# 32/32 - 0s - 6ms/step - loss: 0.0889 - mean_absolute_error: 0.1757 - val_loss: 0.1237 - val_mean_absolute_error: 0.2175
# Epoch 334/1000
# 32/32 - 0s - 6ms/step - loss: 0.0890 - mean_absolute_error: 0.1777 - val_loss: 0.1037 - val_mean_absolute_error: 0.1872
# Epoch 335/1000
# 32/32 - 0s - 6ms/step - loss: 0.0864 - mean_absolute_error: 0.1752 - val_loss: 0.1129 - val_mean_absolute_error: 0.2017
# Epoch 336/1000
# 32/32 - 0s - 6ms/step - loss: 0.0893 - mean_absolute_error: 0.1800 - val_loss: 0.1071 - val_mean_absolute_error: 0.1930
# Epoch 337/1000
# 32/32 - 0s - 6ms/step - loss: 0.0851 - mean_absolute_error: 0.1711 - val_loss: 0.1056 - val_mean_absolute_error: 0.1901
# Epoch 338/1000
# 32/32 - 0s - 6ms/step - loss: 0.0884 - mean_absolute_error: 0.1761 - val_loss: 0.1076 - val_mean_absolute_error: 0.1948
# Epoch 339/1000
# 32/32 - 0s - 6ms/step - loss: 0.0852 - mean_absolute_error: 0.1723 - val_loss: 0.1094 - val_mean_absolute_error: 0.1968
# Epoch 340/1000
# 32/32 - 0s - 6ms/step - loss: 0.0846 - mean_absolute_error: 0.1707 - val_loss: 0.1056 - val_mean_absolute_error: 0.1941
# Epoch 341/1000
# 32/32 - 0s - 6ms/step - loss: 0.0829 - mean_absolute_error: 0.1672 - val_loss: 0.1022 - val_mean_absolute_error: 0.1831
# Epoch 342/1000
# 32/32 - 0s - 6ms/step - loss: 0.0831 - mean_absolute_error: 0.1670 - val_loss: 0.1112 - val_mean_absolute_error: 0.1980
# Epoch 343/1000
# 32/32 - 0s - 6ms/step - loss: 0.0847 - mean_absolute_error: 0.1711 - val_loss: 0.1070 - val_mean_absolute_error: 0.1904
# Epoch 344/1000
# 32/32 - 0s - 6ms/step - loss: 0.0849 - mean_absolute_error: 0.1707 - val_loss: 0.1061 - val_mean_absolute_error: 0.1930
# Epoch 345/1000
# 32/32 - 0s - 6ms/step - loss: 0.0839 - mean_absolute_error: 0.1695 - val_loss: 0.1079 - val_mean_absolute_error: 0.1928
# Epoch 346/1000
# 32/32 - 0s - 6ms/step - loss: 0.0826 - mean_absolute_error: 0.1674 - val_loss: 0.1014 - val_mean_absolute_error: 0.1842
# Epoch 347/1000
# 32/32 - 0s - 6ms/step - loss: 0.0846 - mean_absolute_error: 0.1714 - val_loss: 0.1023 - val_mean_absolute_error: 0.1852
# Epoch 348/1000
# 32/32 - 0s - 6ms/step - loss: 0.0826 - mean_absolute_error: 0.1680 - val_loss: 0.1018 - val_mean_absolute_error: 0.1851
# Epoch 349/1000
# 32/32 - 0s - 6ms/step - loss: 0.0835 - mean_absolute_error: 0.1691 - val_loss: 0.1028 - val_mean_absolute_error: 0.1835
# Epoch 350/1000
# 32/32 - 0s - 6ms/step - loss: 0.0843 - mean_absolute_error: 0.1691 - val_loss: 0.1073 - val_mean_absolute_error: 0.1929
# Epoch 351/1000
# 32/32 - 0s - 6ms/step - loss: 0.0863 - mean_absolute_error: 0.1734 - val_loss: 0.1121 - val_mean_absolute_error: 0.1984
# Epoch 352/1000
# 32/32 - 0s - 7ms/step - loss: 0.0874 - mean_absolute_error: 0.1740 - val_loss: 0.1065 - val_mean_absolute_error: 0.1894
# Epoch 353/1000
# 32/32 - 0s - 7ms/step - loss: 0.0834 - mean_absolute_error: 0.1690 - val_loss: 0.1059 - val_mean_absolute_error: 0.1931
# Epoch 354/1000
# 32/32 - 0s - 7ms/step - loss: 0.0818 - mean_absolute_error: 0.1651 - val_loss: 0.1057 - val_mean_absolute_error: 0.1893
# Epoch 355/1000
# 32/32 - 0s - 6ms/step - loss: 0.0829 - mean_absolute_error: 0.1684 - val_loss: 0.1030 - val_mean_absolute_error: 0.1873
# Epoch 356/1000
# 32/32 - 0s - 6ms/step - loss: 0.0832 - mean_absolute_error: 0.1691 - val_loss: 0.1064 - val_mean_absolute_error: 0.1953
# Epoch 357/1000
# ...
# Epoch 883/1000
# 32/32 - 0s - 6ms/step - loss: 0.0655 - mean_absolute_error: 0.1432 - val_loss: 0.1020 - val_mean_absolute_error: 0.1788
# Epoch 884/1000
# 32/32 - 0s - 6ms/step - loss: 0.0631 - mean_absolute_error: 0.1399 - val_loss: 0.0995 - val_mean_absolute_error: 0.1788
# Epoch 885/1000
# 32/32 - 0s - 6ms/step - loss: 0.0640 - mean_absolute_error: 0.1412 - val_loss: 0.1167 - val_mean_absolute_error: 0.1973
# Epoch 886/1000
# 32/32 - 0s - 6ms/step - loss: 0.0696 - mean_absolute_error: 0.1498 - val_loss: 0.1010 - val_mean_absolute_error: 0.1762
# Epoch 887/1000
# 32/32 - 0s - 6ms/step - loss: 0.0671 - mean_absolute_error: 0.1461 - val_loss: 0.1033 - val_mean_absolute_error: 0.1834
# Epoch 888/1000
# 32/32 - 0s - 6ms/step - loss: 0.0656 - mean_absolute_error: 0.1435 - val_loss: 0.1118 - val_mean_absolute_error: 0.1929
# Epoch 889/1000
# 32/32 - 0s - 6ms/step - loss: 0.0648 - mean_absolute_error: 0.1442 - val_loss: 0.0958 - val_mean_absolute_error: 0.1737
# Epoch 890/1000
# 32/32 - 0s - 6ms/step - loss: 0.0625 - mean_absolute_error: 0.1386 - val_loss: 0.1002 - val_mean_absolute_error: 0.1817
# Epoch 891/1000
# 32/32 - 0s - 6ms/step - loss: 0.0664 - mean_absolute_error: 0.1451 - val_loss: 0.1038 - val_mean_absolute_error: 0.1810
# Epoch 892/1000
# 32/32 - 0s - 6ms/step - loss: 0.0682 - mean_absolute_error: 0.1486 - val_loss: 0.1131 - val_mean_absolute_error: 0.1991
# Epoch 893/1000
# 32/32 - 0s - 6ms/step - loss: 0.0692 - mean_absolute_error: 0.1493 - val_loss: 0.1062 - val_mean_absolute_error: 0.1830
# Epoch 894/1000
# 32/32 - 0s - 6ms/step - loss: 0.0656 - mean_absolute_error: 0.1445 - val_loss: 0.1043 - val_mean_absolute_error: 0.1830
# Epoch 895/1000
# 32/32 - 0s - 6ms/step - loss: 0.0639 - mean_absolute_error: 0.1424 - val_loss: 0.1023 - val_mean_absolute_error: 0.1779
# Epoch 896/1000
# 32/32 - 0s - 6ms/step - loss: 0.0637 - mean_absolute_error: 0.1410 - val_loss: 0.1023 - val_mean_absolute_error: 0.1783
# Epoch 897/1000
# 32/32 - 0s - 6ms/step - loss: 0.0629 - mean_absolute_error: 0.1392 - val_loss: 0.1017 - val_mean_absolute_error: 0.1775
# Epoch 898/1000
# 32/32 - 0s - 6ms/step - loss: 0.0637 - mean_absolute_error: 0.1412 - val_loss: 0.1009 - val_mean_absolute_error: 0.1771
# Epoch 899/1000
# 32/32 - 0s - 6ms/step - loss: 0.0693 - mean_absolute_error: 0.1471 - val_loss: 0.1206 - val_mean_absolute_error: 0.2058
# Epoch 900/1000
# 32/32 - 0s - 6ms/step - loss: 0.0725 - mean_absolute_error: 0.1538 - val_loss: 0.1049 - val_mean_absolute_error: 0.1846
# Epoch 901/1000
# 32/32 - 0s - 6ms/step - loss: 0.0659 - mean_absolute_error: 0.1444 - val_loss: 0.0978 - val_mean_absolute_error: 0.1744
# Epoch 902/1000
# 32/32 - 0s - 6ms/step - loss: 0.0634 - mean_absolute_error: 0.1393 - val_loss: 0.0998 - val_mean_absolute_error: 0.1785
# Epoch 903/1000
# 32/32 - 0s - 6ms/step - loss: 0.0628 - mean_absolute_error: 0.1398 - val_loss: 0.1033 - val_mean_absolute_error: 0.1856
# Epoch 904/1000
# 32/32 - 0s - 6ms/step - loss: 0.0662 - mean_absolute_error: 0.1460 - val_loss: 0.1036 - val_mean_absolute_error: 0.1875
# Epoch 905/1000
# 32/32 - 0s - 6ms/step - loss: 0.0644 - mean_absolute_error: 0.1435 - val_loss: 0.1010 - val_mean_absolute_error: 0.1771
# Epoch 906/1000
# 32/32 - 0s - 6ms/step - loss: 0.0640 - mean_absolute_error: 0.1411 - val_loss: 0.1042 - val_mean_absolute_error: 0.1805
# Epoch 907/1000
# 32/32 - 0s - 7ms/step - loss: 0.0635 - mean_absolute_error: 0.1403 - val_loss: 0.1017 - val_mean_absolute_error: 0.1777
# Epoch 908/1000
# 32/32 - 0s - 7ms/step - loss: 0.0693 - mean_absolute_error: 0.1478 - val_loss: 0.1033 - val_mean_absolute_error: 0.1836
# Epoch 909/1000
# 32/32 - 0s - 6ms/step - loss: 0.0684 - mean_absolute_error: 0.1493 - val_loss: 0.1034 - val_mean_absolute_error: 0.1821
# Epoch 910/1000
# 32/32 - 0s - 6ms/step - loss: 0.0638 - mean_absolute_error: 0.1423 - val_loss: 0.1020 - val_mean_absolute_error: 0.1794
# Epoch 911/1000
# 32/32 - 0s - 6ms/step - loss: 0.0637 - mean_absolute_error: 0.1405 - val_loss: 0.0999 - val_mean_absolute_error: 0.1765
# Epoch 912/1000
# 32/32 - 0s - 6ms/step - loss: 0.0638 - mean_absolute_error: 0.1397 - val_loss: 0.1149 - val_mean_absolute_error: 0.1933
# Epoch 913/1000
# 32/32 - 0s - 6ms/step - loss: 0.0700 - mean_absolute_error: 0.1497 - val_loss: 0.1043 - val_mean_absolute_error: 0.1810
# Epoch 914/1000
# 32/32 - 0s - 6ms/step - loss: 0.0689 - mean_absolute_error: 0.1485 - val_loss: 0.1064 - val_mean_absolute_error: 0.1887
# Epoch 915/1000
# 32/32 - 0s - 6ms/step - loss: 0.0665 - mean_absolute_error: 0.1457 - val_loss: 0.1035 - val_mean_absolute_error: 0.1788
# Epoch 916/1000
# 32/32 - 0s - 6ms/step - loss: 0.0631 - mean_absolute_error: 0.1396 - val_loss: 0.1006 - val_mean_absolute_error: 0.1781
# Epoch 917/1000
# 32/32 - 0s - 6ms/step - loss: 0.0655 - mean_absolute_error: 0.1433 - val_loss: 0.1016 - val_mean_absolute_error: 0.1774
# Epoch 918/1000
# 32/32 - 0s - 6ms/step - loss: 0.0639 - mean_absolute_error: 0.1413 - val_loss: 0.1003 - val_mean_absolute_error: 0.1758
# Epoch 919/1000
# 32/32 - 0s - 6ms/step - loss: 0.0620 - mean_absolute_error: 0.1379 - val_loss: 0.1103 - val_mean_absolute_error: 0.1900
# Epoch 920/1000
# 32/32 - 0s - 6ms/step - loss: 0.0639 - mean_absolute_error: 0.1403 - val_loss: 0.1021 - val_mean_absolute_error: 0.1784
# Epoch 921/1000
# 32/32 - 0s - 6ms/step - loss: 0.0638 - mean_absolute_error: 0.1416 - val_loss: 0.1041 - val_mean_absolute_error: 0.1807
# Epoch 922/1000
# 32/32 - 0s - 6ms/step - loss: 0.0651 - mean_absolute_error: 0.1429 - val_loss: 0.1032 - val_mean_absolute_error: 0.1833
# Epoch 923/1000
# 32/32 - 0s - 6ms/step - loss: 0.0644 - mean_absolute_error: 0.1421 - val_loss: 0.1006 - val_mean_absolute_error: 0.1776
# Epoch 924/1000
# 32/32 - 0s - 6ms/step - loss: 0.0653 - mean_absolute_error: 0.1431 - val_loss: 0.1027 - val_mean_absolute_error: 0.1789
# Epoch 925/1000
# 32/32 - 0s - 6ms/step - loss: 0.0659 - mean_absolute_error: 0.1437 - val_loss: 0.1029 - val_mean_absolute_error: 0.1787
# Epoch 926/1000
# 32/32 - 0s - 6ms/step - loss: 0.0636 - mean_absolute_error: 0.1401 - val_loss: 0.1002 - val_mean_absolute_error: 0.1772
# Epoch 927/1000
# 32/32 - 0s - 6ms/step - loss: 0.0640 - mean_absolute_error: 0.1401 - val_loss: 0.1033 - val_mean_absolute_error: 0.1777
# Epoch 928/1000
# 32/32 - 0s - 6ms/step - loss: 0.0615 - mean_absolute_error: 0.1363 - val_loss: 0.1023 - val_mean_absolute_error: 0.1786
# Epoch 929/1000
# 32/32 - 0s - 6ms/step - loss: 0.0640 - mean_absolute_error: 0.1401 - val_loss: 0.0996 - val_mean_absolute_error: 0.1751
# Epoch 930/1000
# 32/32 - 0s - 6ms/step - loss: 0.0632 - mean_absolute_error: 0.1394 - val_loss: 0.1027 - val_mean_absolute_error: 0.1791
# Epoch 931/1000
# 32/32 - 0s - 6ms/step - loss: 0.0661 - mean_absolute_error: 0.1444 - val_loss: 0.1023 - val_mean_absolute_error: 0.1797
# Epoch 932/1000
# 32/32 - 0s - 6ms/step - loss: 0.0620 - mean_absolute_error: 0.1389 - val_loss: 0.1002 - val_mean_absolute_error: 0.1775
# Epoch 933/1000
# 32/32 - 0s - 6ms/step - loss: 0.0633 - mean_absolute_error: 0.1405 - val_loss: 0.1174 - val_mean_absolute_error: 0.2015
# Epoch 934/1000
# 32/32 - 0s - 6ms/step - loss: 0.0674 - mean_absolute_error: 0.1458 - val_loss: 0.1051 - val_mean_absolute_error: 0.1836
# Epoch 935/1000
# 32/32 - 0s - 7ms/step - loss: 0.0707 - mean_absolute_error: 0.1507 - val_loss: 0.1021 - val_mean_absolute_error: 0.1803
# Epoch 936/1000
# 32/32 - 0s - 6ms/step - loss: 0.0667 - mean_absolute_error: 0.1450 - val_loss: 0.1038 - val_mean_absolute_error: 0.1826
# Epoch 937/1000
# 32/32 - 0s - 6ms/step - loss: 0.0639 - mean_absolute_error: 0.1422 - val_loss: 0.0996 - val_mean_absolute_error: 0.1752
# Epoch 938/1000
# 32/32 - 0s - 6ms/step - loss: 0.0640 - mean_absolute_error: 0.1416 - val_loss: 0.1133 - val_mean_absolute_error: 0.1967
# Epoch 939/1000
# 32/32 - 0s - 6ms/step - loss: 0.0638 - mean_absolute_error: 0.1433 - val_loss: 0.0998 - val_mean_absolute_error: 0.1743
# Epoch 940/1000
# 32/32 - 0s - 6ms/step - loss: 0.0644 - mean_absolute_error: 0.1420 - val_loss: 0.1055 - val_mean_absolute_error: 0.1820
# Epoch 941/1000
# 32/32 - 0s - 6ms/step - loss: 0.0672 - mean_absolute_error: 0.1454 - val_loss: 0.1027 - val_mean_absolute_error: 0.1774
# Epoch 942/1000
# 32/32 - 0s - 6ms/step - loss: 0.0626 - mean_absolute_error: 0.1388 - val_loss: 0.1027 - val_mean_absolute_error: 0.1776
# Epoch 943/1000
# 32/32 - 0s - 6ms/step - loss: 0.0643 - mean_absolute_error: 0.1414 - val_loss: 0.1015 - val_mean_absolute_error: 0.1800
# Epoch 944/1000
# 32/32 - 0s - 6ms/step - loss: 0.0614 - mean_absolute_error: 0.1387 - val_loss: 0.1002 - val_mean_absolute_error: 0.1750
# Epoch 945/1000
# 32/32 - 0s - 6ms/step - loss: 0.0624 - mean_absolute_error: 0.1380 - val_loss: 0.1054 - val_mean_absolute_error: 0.1798
# Epoch 946/1000
# 32/32 - 0s - 6ms/step - loss: 0.0644 - mean_absolute_error: 0.1420 - val_loss: 0.1028 - val_mean_absolute_error: 0.1789
# Epoch 947/1000
# 32/32 - 0s - 6ms/step - loss: 0.0633 - mean_absolute_error: 0.1403 - val_loss: 0.0990 - val_mean_absolute_error: 0.1752
# Epoch 948/1000
# 32/32 - 0s - 6ms/step - loss: 0.0634 - mean_absolute_error: 0.1395 - val_loss: 0.1013 - val_mean_absolute_error: 0.1799
# Epoch 949/1000
# 32/32 - 0s - 6ms/step - loss: 0.0623 - mean_absolute_error: 0.1398 - val_loss: 0.0998 - val_mean_absolute_error: 0.1775
# Epoch 950/1000
# 32/32 - 0s - 6ms/step - loss: 0.0703 - mean_absolute_error: 0.1498 - val_loss: 0.1061 - val_mean_absolute_error: 0.1860
# Epoch 951/1000
# 32/32 - 0s - 6ms/step - loss: 0.0648 - mean_absolute_error: 0.1427 - val_loss: 0.1007 - val_mean_absolute_error: 0.1764
# Epoch 952/1000
# 32/32 - 0s - 6ms/step - loss: 0.0670 - mean_absolute_error: 0.1469 - val_loss: 0.1046 - val_mean_absolute_error: 0.1831
# Epoch 953/1000
# 32/32 - 0s - 6ms/step - loss: 0.0667 - mean_absolute_error: 0.1463 - val_loss: 0.1026 - val_mean_absolute_error: 0.1794
# Epoch 954/1000
# 32/32 - 0s - 6ms/step - loss: 0.0634 - mean_absolute_error: 0.1398 - val_loss: 0.1026 - val_mean_absolute_error: 0.1840
# Epoch 955/1000
# 32/32 - 0s - 6ms/step - loss: 0.0660 - mean_absolute_error: 0.1440 - val_loss: 0.1042 - val_mean_absolute_error: 0.1826
# Epoch 956/1000
# 32/32 - 0s - 6ms/step - loss: 0.0670 - mean_absolute_error: 0.1458 - val_loss: 0.1029 - val_mean_absolute_error: 0.1771
# Epoch 957/1000
# 32/32 - 0s - 6ms/step - loss: 0.0630 - mean_absolute_error: 0.1402 - val_loss: 0.1038 - val_mean_absolute_error: 0.1806
# Epoch 958/1000
# 32/32 - 0s - 6ms/step - loss: 0.0616 - mean_absolute_error: 0.1387 - val_loss: 0.0996 - val_mean_absolute_error: 0.1763
# Epoch 959/1000
# 32/32 - 0s - 6ms/step - loss: 0.0631 - mean_absolute_error: 0.1398 - val_loss: 0.1057 - val_mean_absolute_error: 0.1846
# Epoch 960/1000
# 32/32 - 0s - 6ms/step - loss: 0.0644 - mean_absolute_error: 0.1420 - val_loss: 0.1032 - val_mean_absolute_error: 0.1808
# Epoch 961/1000
# 32/32 - 0s - 6ms/step - loss: 0.0661 - mean_absolute_error: 0.1434 - val_loss: 0.1033 - val_mean_absolute_error: 0.1789
# Epoch 962/1000
# 32/32 - 0s - 6ms/step - loss: 0.0619 - mean_absolute_error: 0.1383 - val_loss: 0.0996 - val_mean_absolute_error: 0.1759
# Epoch 963/1000
# 32/32 - 0s - 7ms/step - loss: 0.0621 - mean_absolute_error: 0.1379 - val_loss: 0.1041 - val_mean_absolute_error: 0.1844
# Epoch 964/1000
# 32/32 - 0s - 6ms/step - loss: 0.0640 - mean_absolute_error: 0.1424 - val_loss: 0.0998 - val_mean_absolute_error: 0.1783
# Epoch 965/1000
# 32/32 - 0s - 6ms/step - loss: 0.0642 - mean_absolute_error: 0.1422 - val_loss: 0.1025 - val_mean_absolute_error: 0.1782
# Epoch 966/1000
# 32/32 - 0s - 6ms/step - loss: 0.0638 - mean_absolute_error: 0.1415 - val_loss: 0.1039 - val_mean_absolute_error: 0.1781
# Epoch 967/1000
# 32/32 - 0s - 6ms/step - loss: 0.0642 - mean_absolute_error: 0.1416 - val_loss: 0.1019 - val_mean_absolute_error: 0.1794
# Epoch 968/1000
# 32/32 - 0s - 6ms/step - loss: 0.0650 - mean_absolute_error: 0.1421 - val_loss: 0.1011 - val_mean_absolute_error: 0.1770
# Epoch 969/1000
# 32/32 - 0s - 6ms/step - loss: 0.0666 - mean_absolute_error: 0.1456 - val_loss: 0.1026 - val_mean_absolute_error: 0.1825
# Epoch 970/1000
# 32/32 - 0s - 6ms/step - loss: 0.0632 - mean_absolute_error: 0.1394 - val_loss: 0.1044 - val_mean_absolute_error: 0.1826
# Epoch 971/1000
# 32/32 - 0s - 6ms/step - loss: 0.0637 - mean_absolute_error: 0.1399 - val_loss: 0.1009 - val_mean_absolute_error: 0.1784
# Epoch 972/1000
# 32/32 - 0s - 6ms/step - loss: 0.0615 - mean_absolute_error: 0.1376 - val_loss: 0.1016 - val_mean_absolute_error: 0.1756
# Epoch 973/1000
# 32/32 - 0s - 6ms/step - loss: 0.0608 - mean_absolute_error: 0.1376 - val_loss: 0.1014 - val_mean_absolute_error: 0.1773
# Epoch 974/1000
# 32/32 - 0s - 6ms/step - loss: 0.0620 - mean_absolute_error: 0.1382 - val_loss: 0.1033 - val_mean_absolute_error: 0.1799
# Epoch 975/1000
# 32/32 - 0s - 6ms/step - loss: 0.0630 - mean_absolute_error: 0.1404 - val_loss: 0.1054 - val_mean_absolute_error: 0.1825
# Epoch 976/1000
# 32/32 - 0s - 6ms/step - loss: 0.0664 - mean_absolute_error: 0.1443 - val_loss: 0.1042 - val_mean_absolute_error: 0.1838
# Epoch 977/1000
# 32/32 - 0s - 6ms/step - loss: 0.0624 - mean_absolute_error: 0.1391 - val_loss: 0.1059 - val_mean_absolute_error: 0.1824
# Epoch 978/1000
# 32/32 - 0s - 6ms/step - loss: 0.0678 - mean_absolute_error: 0.1480 - val_loss: 0.1090 - val_mean_absolute_error: 0.1880
# Epoch 979/1000
# 32/32 - 0s - 6ms/step - loss: 0.0692 - mean_absolute_error: 0.1490 - val_loss: 0.1056 - val_mean_absolute_error: 0.1851
# Epoch 980/1000
# 32/32 - 0s - 6ms/step - loss: 0.0629 - mean_absolute_error: 0.1396 - val_loss: 0.1026 - val_mean_absolute_error: 0.1798
# Epoch 981/1000
# 32/32 - 0s - 6ms/step - loss: 0.0647 - mean_absolute_error: 0.1424 - val_loss: 0.1015 - val_mean_absolute_error: 0.1789
# Epoch 982/1000
# 32/32 - 0s - 6ms/step - loss: 0.0649 - mean_absolute_error: 0.1450 - val_loss: 0.1004 - val_mean_absolute_error: 0.1779
# Epoch 983/1000
# 32/32 - 0s - 6ms/step - loss: 0.0635 - mean_absolute_error: 0.1407 - val_loss: 0.0993 - val_mean_absolute_error: 0.1796
# Epoch 984/1000
# 32/32 - 0s - 6ms/step - loss: 0.0620 - mean_absolute_error: 0.1386 - val_loss: 0.1013 - val_mean_absolute_error: 0.1799
# Epoch 985/1000
# 32/32 - 0s - 6ms/step - loss: 0.0609 - mean_absolute_error: 0.1364 - val_loss: 0.1023 - val_mean_absolute_error: 0.1781
# Epoch 986/1000
# 32/32 - 0s - 6ms/step - loss: 0.0625 - mean_absolute_error: 0.1393 - val_loss: 0.1025 - val_mean_absolute_error: 0.1772
# Epoch 987/1000
# 32/32 - 0s - 6ms/step - loss: 0.0634 - mean_absolute_error: 0.1401 - val_loss: 0.1012 - val_mean_absolute_error: 0.1765
# Epoch 988/1000
# 32/32 - 0s - 6ms/step - loss: 0.0730 - mean_absolute_error: 0.1542 - val_loss: 0.1025 - val_mean_absolute_error: 0.1807
# Epoch 989/1000
# 32/32 - 0s - 6ms/step - loss: 0.0690 - mean_absolute_error: 0.1487 - val_loss: 0.1076 - val_mean_absolute_error: 0.1875
# Epoch 990/1000
# 32/32 - 0s - 6ms/step - loss: 0.0663 - mean_absolute_error: 0.1459 - val_loss: 0.1027 - val_mean_absolute_error: 0.1791
# Epoch 991/1000
# 32/32 - 0s - 6ms/step - loss: 0.0637 - mean_absolute_error: 0.1407 - val_loss: 0.1045 - val_mean_absolute_error: 0.1816
# Epoch 992/1000
# 32/32 - 0s - 7ms/step - loss: 0.0616 - mean_absolute_error: 0.1381 - val_loss: 0.1022 - val_mean_absolute_error: 0.1794
# Epoch 993/1000
# 32/32 - 0s - 6ms/step - loss: 0.0616 - mean_absolute_error: 0.1382 - val_loss: 0.1056 - val_mean_absolute_error: 0.1836
# Epoch 994/1000
# 32/32 - 0s - 6ms/step - loss: 0.0637 - mean_absolute_error: 0.1413 - val_loss: 0.1015 - val_mean_absolute_error: 0.1791
# Epoch 995/1000
# 32/32 - 0s - 6ms/step - loss: 0.0641 - mean_absolute_error: 0.1412 - val_loss: 0.1061 - val_mean_absolute_error: 0.1850
# Epoch 996/1000
# 32/32 - 0s - 6ms/step - loss: 0.0653 - mean_absolute_error: 0.1428 - val_loss: 0.1042 - val_mean_absolute_error: 0.1820
# Epoch 997/1000
# 32/32 - 0s - 6ms/step - loss: 0.0651 - mean_absolute_error: 0.1428 - val_loss: 0.1222 - val_mean_absolute_error: 0.2020
# Epoch 998/1000
# 32/32 - 0s - 6ms/step - loss: 0.0670 - mean_absolute_error: 0.1470 - val_loss: 0.1093 - val_mean_absolute_error: 0.1904
# Epoch 999/1000
# 32/32 - 0s - 6ms/step - loss: 0.0638 - mean_absolute_error: 0.1407 - val_loss: 0.1027 - val_mean_absolute_error: 0.1828
# Epoch 1000/1000
# 32/32 - 0s - 6ms/step - loss: 0.0642 - mean_absolute_error: 0.1430 - val_loss: 0.1048 - val_mean_absolute_error: 0.1842

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_noNoise.keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_test_norm, y_test_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  

#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_test_norm)
# Out:
# MSE: 0.1089787557721138
# MAE: 0.18742714822292328
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# ##### Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_test_denorm = scaler_y.inverse_transform(y_test_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

# Dibujamos los datos
symbols = [r'$\kappa$', r'$\kappa_c$', r'$\gamma$', r'$g$']

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [10, 7.5], 
    "figure.dpi": 300 
})

# Crear subgráficos para cada variable
fig, axes = plt.subplots(nrows=2, ncols=2, constrained_layout=True)

# Añadir los subgráficos
for i, ax in enumerate(axes.flatten()):
    if i < y_test_denorm.shape[1]:  # Verifica que no exceda el número de columnas en los datos
        ax.plot(y_test_denorm[:, i], y_pred_denorm[:, i], marker='o', linestyle='',
                markersize=3, color='cornflowerblue')
        ax.plot([y_test_denorm[:, i].min(), y_test_denorm[:, i].max()],
                [y_test_denorm[:, i].min(), y_test_denorm[:, i].max()], linestyle='-', color='red', linewidth=2 )
        ax.set_xlabel('Real')
        ax.set_ylabel('NN')
        ax.set_title(symbols[i])
        # Aplicar notación científica a los ejes
        ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        ax.ticklabel_format(style='sci', axis='both', scilimits=(0,0))



labels = ["Predicciones", "Valor real"]
fig.legend(labels, loc='upper center', bbox_to_anchor=(0.5, 1.08), ncol=2)

plt.show()

# %% [markdown]
# ##### Curvas Validación VS Predicción

# %%
plt.rcParams.update({
    "text.usetex": False,
    "figure.figsize": [8,6], 
})

k_pred = y_pred_denorm[:, 0]
k_test = y_test_denorm[:, 0]
kc_pred = y_pred_denorm[:, 1]
kc_test = y_test_denorm[:, 1]
gamma_pred = y_pred_denorm[:, 2]
gamma_test = y_test_denorm[:, 2]
g_pred = y_pred_denorm[:, 3]
g_test = y_test_denorm[:, 3]
DeltaE_test = DeltaE[indices_test]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_test = np.zeros((x_val.shape[0], len(w_values)))


for i in range (x_val.shape[0]):
    t_values_pred[i,:] = S21(w_values, k_pred[i], k_pred[i], Omega, DeltaE_test[i], gamma_pred[i], g_pred[i])
    t_values_test[i,:] = S21(w_values, k_test[i], k_pred[i],  Omega, DeltaE_test[i], gamma_test[i], g_test[i])

# w1 = w2 = np.zeros(x_val.shape[0])

# w1=w_1(k_test, Omega, DeltaE_test, gamma_test, g_test)
# w2=w_2(k_test, Omega, DeltaE_test, gamma_test, g_test)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_test[i, :], color="b", label="Real")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Network prediction")

    # # Calcula los valores de t(w) en w1 y w2
    # t_w1 = t_w(w1[i], k_test[i], Omega, DeltaE_test[i], gamma_test[i], g_test[i])
    # t_w2 = t_w(w2[i], k_test[i], Omega, DeltaE_test[i], gamma_test[i], g_test[i])
    
    # if w_values.min() <= w1[i] <= w_values.max():
    #     plt.vlines(w1[i], 0, t_w1, colors='black', linewidth=0.5)
    # if w_values.min() <= w2[i] <= w_values.max():
    #     plt.vlines(w2[i], 0, t_w2, colors='black', linewidth=0.5)
   
    plt.title(f"Pred. vs Test. Curve number: {i}")
    plt.xlabel(r"$\omega$")
    plt.ylabel(r"$t (\omega$)")
    #plt.legend(framealpha=1, loc='lower right') 
    # plt.xlim(2.09,2.14) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"$\kappa$ real = {k_test[i]:.2e}, $\kappa$ pred = {k_pred[i]:.2e}\n"\
           f"$\kappa_c$ real = {kc_test[i]:.2e}, $\kappa_c$ pred = {kc_pred[i]:.2e}\n"\
           f"$\gamma$ real = {gamma_test[i]:.2e}, $\gamma$ pred = {gamma_pred[i]:.2e}\n"\
           f"g real = {g_test[i]:.2e}, g pred = {g_pred[i]:.2e}\n"\
           f"$\Delta$E = {DeltaE_test[i]:.3f}"
    # plt.text(0.011, 0.23, text, transform=plt.gca().transAxes, fontsize=14, verticalalignment='top', 
    #          bbox=dict(facecolor='white', alpha=1))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # Dibujos para Memoria

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [12,4], 
    "figure.dpi": 300 
})


pics = [0, 42, 49]
labels_subplots = ["a)", "b)", "c)", "d)", "e)", "f)"]

fig, axes = plt.subplots(1, 3, constrained_layout=True)
for idx, (ax, i) in enumerate(zip(axes.flat, pics)):
    ax.plot(w_values, t_values_test[i, :], color="b")
    ax.plot(w_values, t_values_pred[i, :], color="r", linestyle='--')
    ax.set_yticks(np.arange(0, 1.05, 0.2))
    ax.set_xticks(np.linspace(w_values.min(), w_values.max(), 5))
    ax.set_ylim(-0.03, 1.05)

    ax.text(0.03, 0.1, labels_subplots[idx], transform=ax.transAxes, 
        fontsize=15, fontweight='bold', va='top', ha='left')
    

    # Configurar etiquetas y ticks según la posición del subplot
    if idx % 3 == 0:  # Primera columna
        ax.set_ylabel(r'$S_{21}(\omega)$')  # Etiqueta y en la columna izquierda
    else:
        ax.set_yticklabels([])  # Sin etiquetas en el eje y en la columna derecha
        ax.tick_params(axis='y', labelleft=False)

    ax.set_xlabel(r'$\omega$')

    # if idx // 3 == 1:  # Última fila
    #     ax.set_xlabel(r'$\omega$')  # Etiqueta x en la fila inferior
    # else:
    #     ax.set_xticklabels([])  # Sin etiquetas en el eje x en la fila superior
    #     ax.tick_params(axis='x', labelbottom=False)

    ax.tick_params(axis='both', direction='in')


labels = ["Real", "NN"]
fig.legend(labels, loc='upper center', bbox_to_anchor=(0.525, 1.16), ncol=2)
plt.show()

# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "axes.labelsize": 20, 
    "axes.titlesize": 22, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [12, 7], 
    "figure.dpi": 300 
})

# %% [markdown]
# #### Define $S_{21}$($\omega$):
# $$S_{21}(\omega)=1 - \frac{\kappa_c}{i(\Omega-\omega)+\kappa+\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def S21 (w, k, kc, Omega, DeltaE, gamma, g):
    up = kc
    down = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = 1 - up / (1j * down)
    return np.abs(t)

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %% [markdown]
# ## Creamos base de datos

# %%
# Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    kc = np.random.uniform(1e-6, 1e-4, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)

    return k, kc, gamma, g, DeltaE

# def Parameters_generator (num_datos):
#     k = np.random.uniform(2e-4, 6.5e-4, num_datos)
#     kc = np.random.uniform(1.5e-5, 3.5e-5, num_datos)
#     gamma = np.random.uniform(5e-3, 8e-3, num_datos)
#     g = np.random.uniform(1.15e-2, 1.35e-2, num_datos)
#     DeltaE = np.random.uniform(1.8, 2.4, num_datos)

#     return k, kc, gamma, g, DeltaE

num_datos = 10000

# %%
# #Creamos base de datos y guardamos en .txt
# k, kc, gamma, g, DeltaE = Parameters_generator (num_datos)
# np.savetxt('Parameters_Noise_acotado.txt', np.column_stack((k, kc, gamma, g, DeltaE)),
#             header='\u03BA \u03BA_c \u213D g \u0394E', encoding='utf8')

# %%
datos = np.loadtxt('Parameters_Noise_acotado2.txt', skiprows=1, usecols=(0, 1, 3))
k = datos[:,0]
kc = datos[:,1]
gamma = np.loadtxt('Parameters_Noise_acotado2.txt', skiprows=1, usecols=2)
gamma = 1e-3
gamma = 6.5e-3
g = datos[:,2]
DeltaE = np.loadtxt('Parameters_Noise_acotado2.txt', skiprows=1, usecols=4)
# Omega = 1
Omega = 2.116451

#Creamos los valores de y (la función t(w)) con nuestra base de datos
# w_values = np.linspace(0.85, 1.15, 2500)
w_values = np.linspace(2.09, 2.14, 2500)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))
t_values_noise = np.zeros((num_datos, len(w_values)))

w1 = w2 = np.zeros(num_datos)
w1=w_1(k, Omega, DeltaE, gamma, g)
w2=w_2(k, Omega, DeltaE, gamma, g)

for i in range (num_datos):
    t_values[i,:] = S21(w_values, k[i], kc[i], Omega, DeltaE[i], gamma, g[i])


for i in range(num_datos):
    min_value = np.min(t_values[i, :])
    
    if min_value > 0.975:
        noise_level = 0.075 * (1 - min_value)
    elif min_value > 0.85:
        noise_level = 0.05 * (1 - min_value)
    else:
        noise_level = 0.01 * (1 - min_value)

    noise = np.random.normal(0, noise_level, len(w_values))
    t_values_noise[i, :] = t_values[i, :] + noise

# %% [markdown]
# ### Dibujamos las curvas

# %%
# plt.rcParams.update({
#     "text.usetex": False,
#     "font.family": "serif",
#     "font.serif": ['DejaVu Sans'],
# }) # Para visualizar LaTeX es muy lento (cuando sepa cual gráfica guaradr, se hará con latex)

# i=0
# while i<=10000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.scatter(w_values, t_values_noise[i,:], label='Ruido', marker='.', color='b')
#     plt.plot(w_values, t_values[i,:], label='Original', color='r')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$")
#     plt.ylabel(r"t ($\omega$)")
#     #plt.legend()
#     # plt.ylim(0) 
#     # plt.xlim(0.85, 1.15) 

#     # # Calcula los valores de t(w) en w1 y w2
#     # t_w1 = t_w(w1[i], k[i], Omega, DeltaE[i], gamma[i], g[i])
#     # t_w2 = t_w(w2[i], k[i], Omega, DeltaE[i], gamma[i], g[i])

#     # if w_values.min() <= w1[i] <= w_values.max():
#     #     plt.vlines(w1[i], 0, t_w1, colors='black', linewidth=0.5)
#     # if w_values.min() <= w2[i] <= w_values.max():
#     #     plt.vlines(w2[i], 0, t_w2, colors='black', linewidth=0.5)
    
#     plt.draw()  # Dibuja la figura actual

#     # Muestra los valores como un recuadro dentro de la gráfica
#     text = f"$\kappa$ = {k[i]:.2e}\n"\
#            f"$\kappa_c$ = {kc[i]:.2e}\n"\
#            f"g = {g[i]:.2e}\n"\
#            f"$\Delta$E = {DeltaE[i]:.3f}"
#     plt.text(0.011, 0.2, text, transform=plt.gca().transAxes, fontsize=16, verticalalignment='top', 
#              bbox=dict(facecolor='white', alpha=1))

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
import joblib

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
indices = np.arange(num_datos)
indices_train, indices_post = train_test_split(indices, test_size=0.2, random_state=18)
indices_val, indices_test = train_test_split(indices_post, test_size=0.5, random_state=18)

x_train = t_values_noise[indices_train]
x_val = t_values_noise[indices_val]
x_test = t_values_noise[indices_test]
y_train = datos[indices_train]
y_val = datos[indices_val]
y_test = datos[indices_test]

# Normalizamos los datos
scaler_x = RobustScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)
x_test_norm = scaler_x.transform(x_test)

scaler_y = RobustScaler()
scaler_exp = RobustScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_train_save = y_train[np.random.choice(len(y_train), 41, replace=False)]
y_train_save = scaler_exp.fit_transform(y_train_save)
joblib.dump(scaler_exp, 'scaler_y_acotado2.save')
y_val_norm = scaler_y.transform(y_val)
y_test_norm = scaler_y.transform(y_test)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'validation samples')
print(x_test.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 100
optimizer = Adam()
# Out:
# 8000 train samples
# 1000 validation samples
# 1000 test samples
# x_train shape (8000, 2500)
# y_train shape (8000, 3)

# %% [markdown]
# #### Definimos modelo

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm , y_train_norm , batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save("model_Noise2_acotado2.keras") 

# Visualiza la pérdida y la métrica de entrenamiento
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [10,6], 
    "figure.dpi": 300 
})

plt.plot(history.history['loss'], label='Pérdida entrenamiento')
plt.plot(history.history['mean_absolute_error'], label='MAE entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida validación')
plt.plot(history.history['val_mean_absolute_error'], label='MAE validación')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 160/160 - 2s - 13ms/step - loss: 0.2898 - mean_absolute_error: 0.4546 - val_loss: 0.2541 - val_mean_absolute_error: 0.4191
# Epoch 2/100
# 160/160 - 1s - 4ms/step - loss: 0.2373 - mean_absolute_error: 0.4000 - val_loss: 0.2194 - val_mean_absolute_error: 0.3838
# Epoch 3/100
# 160/160 - 1s - 4ms/step - loss: 0.1928 - mean_absolute_error: 0.3454 - val_loss: 0.2069 - val_mean_absolute_error: 0.3623
# Epoch 4/100
# 160/160 - 1s - 4ms/step - loss: 0.1611 - mean_absolute_error: 0.3045 - val_loss: 0.1715 - val_mean_absolute_error: 0.3188
# Epoch 5/100
# 160/160 - 1s - 4ms/step - loss: 0.1364 - mean_absolute_error: 0.2704 - val_loss: 0.1618 - val_mean_absolute_error: 0.3060
# Epoch 6/100
# 160/160 - 1s - 4ms/step - loss: 0.1188 - mean_absolute_error: 0.2487 - val_loss: 0.1587 - val_mean_absolute_error: 0.2987
# Epoch 7/100
# 160/160 - 1s - 4ms/step - loss: 0.0946 - mean_absolute_error: 0.2188 - val_loss: 0.1606 - val_mean_absolute_error: 0.2911
# Epoch 8/100
# 160/160 - 1s - 4ms/step - loss: 0.0752 - mean_absolute_error: 0.1915 - val_loss: 0.1651 - val_mean_absolute_error: 0.2949
# Epoch 9/100
# 160/160 - 1s - 4ms/step - loss: 0.0601 - mean_absolute_error: 0.1699 - val_loss: 0.1589 - val_mean_absolute_error: 0.2803
# Epoch 10/100
# 160/160 - 1s - 4ms/step - loss: 0.0474 - mean_absolute_error: 0.1481 - val_loss: 0.1623 - val_mean_absolute_error: 0.2828
# Epoch 11/100
# 160/160 - 1s - 4ms/step - loss: 0.0396 - mean_absolute_error: 0.1337 - val_loss: 0.1583 - val_mean_absolute_error: 0.2727
# Epoch 12/100
# 160/160 - 1s - 4ms/step - loss: 0.0316 - mean_absolute_error: 0.1188 - val_loss: 0.1643 - val_mean_absolute_error: 0.2752
# Epoch 13/100
# 160/160 - 1s - 4ms/step - loss: 0.0257 - mean_absolute_error: 0.1060 - val_loss: 0.1568 - val_mean_absolute_error: 0.2711
# Epoch 14/100
# 160/160 - 1s - 4ms/step - loss: 0.0225 - mean_absolute_error: 0.0984 - val_loss: 0.1592 - val_mean_absolute_error: 0.2732
# Epoch 15/100
# 160/160 - 1s - 4ms/step - loss: 0.0203 - mean_absolute_error: 0.0930 - val_loss: 0.1588 - val_mean_absolute_error: 0.2713
# Epoch 16/100
# 160/160 - 1s - 4ms/step - loss: 0.0174 - mean_absolute_error: 0.0844 - val_loss: 0.1555 - val_mean_absolute_error: 0.2671
# Epoch 17/100
# 160/160 - 1s - 4ms/step - loss: 0.0154 - mean_absolute_error: 0.0800 - val_loss: 0.1569 - val_mean_absolute_error: 0.2663
# Epoch 18/100
# 160/160 - 1s - 4ms/step - loss: 0.0149 - mean_absolute_error: 0.0787 - val_loss: 0.1623 - val_mean_absolute_error: 0.2764
# Epoch 19/100
# 160/160 - 1s - 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0771 - val_loss: 0.1544 - val_mean_absolute_error: 0.2635
# Epoch 20/100
# 160/160 - 1s - 4ms/step - loss: 0.0146 - mean_absolute_error: 0.0778 - val_loss: 0.1547 - val_mean_absolute_error: 0.2646
# Epoch 21/100
# 160/160 - 1s - 4ms/step - loss: 0.0140 - mean_absolute_error: 0.0773 - val_loss: 0.1607 - val_mean_absolute_error: 0.2736
# Epoch 22/100
# 160/160 - 1s - 4ms/step - loss: 0.0128 - mean_absolute_error: 0.0745 - val_loss: 0.1649 - val_mean_absolute_error: 0.2772
# Epoch 23/100
# 160/160 - 1s - 4ms/step - loss: 0.0122 - mean_absolute_error: 0.0716 - val_loss: 0.1603 - val_mean_absolute_error: 0.2684
# Epoch 24/100
# 160/160 - 1s - 4ms/step - loss: 0.0109 - mean_absolute_error: 0.0681 - val_loss: 0.1537 - val_mean_absolute_error: 0.2622
# Epoch 25/100
# 160/160 - 1s - 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0664 - val_loss: 0.1607 - val_mean_absolute_error: 0.2666
# Epoch 26/100
# 160/160 - 1s - 4ms/step - loss: 0.0106 - mean_absolute_error: 0.0665 - val_loss: 0.1571 - val_mean_absolute_error: 0.2633
# Epoch 27/100
# 160/160 - 1s - 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0647 - val_loss: 0.1586 - val_mean_absolute_error: 0.2672
# Epoch 28/100
# 160/160 - 1s - 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0632 - val_loss: 0.1548 - val_mean_absolute_error: 0.2583
# Epoch 29/100
# 160/160 - 1s - 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0623 - val_loss: 0.1587 - val_mean_absolute_error: 0.2686
# Epoch 30/100
# 160/160 - 1s - 4ms/step - loss: 0.0089 - mean_absolute_error: 0.0623 - val_loss: 0.1569 - val_mean_absolute_error: 0.2622
# Epoch 31/100
# 160/160 - 1s - 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0627 - val_loss: 0.1575 - val_mean_absolute_error: 0.2647
# Epoch 32/100
# 160/160 - 1s - 4ms/step - loss: 0.0080 - mean_absolute_error: 0.0598 - val_loss: 0.1552 - val_mean_absolute_error: 0.2619
# Epoch 33/100
# 160/160 - 1s - 4ms/step - loss: 0.0081 - mean_absolute_error: 0.0598 - val_loss: 0.1568 - val_mean_absolute_error: 0.2644
# Epoch 34/100
# 160/160 - 1s - 4ms/step - loss: 0.0080 - mean_absolute_error: 0.0582 - val_loss: 0.1619 - val_mean_absolute_error: 0.2712
# Epoch 35/100
# 160/160 - 1s - 4ms/step - loss: 0.0083 - mean_absolute_error: 0.0606 - val_loss: 0.1599 - val_mean_absolute_error: 0.2681
# Epoch 36/100
# 160/160 - 1s - 4ms/step - loss: 0.0077 - mean_absolute_error: 0.0590 - val_loss: 0.1548 - val_mean_absolute_error: 0.2649
# Epoch 37/100
# 160/160 - 1s - 4ms/step - loss: 0.0072 - mean_absolute_error: 0.0559 - val_loss: 0.1606 - val_mean_absolute_error: 0.2715
# Epoch 38/100
# 160/160 - 1s - 4ms/step - loss: 0.0072 - mean_absolute_error: 0.0568 - val_loss: 0.1605 - val_mean_absolute_error: 0.2693
# Epoch 39/100
# 160/160 - 1s - 4ms/step - loss: 0.0071 - mean_absolute_error: 0.0566 - val_loss: 0.1603 - val_mean_absolute_error: 0.2727
# Epoch 40/100
# 160/160 - 1s - 4ms/step - loss: 0.0072 - mean_absolute_error: 0.0570 - val_loss: 0.1532 - val_mean_absolute_error: 0.2598
# Epoch 41/100
# 160/160 - 1s - 4ms/step - loss: 0.0077 - mean_absolute_error: 0.0591 - val_loss: 0.1552 - val_mean_absolute_error: 0.2630
# Epoch 42/100
# 160/160 - 1s - 4ms/step - loss: 0.0073 - mean_absolute_error: 0.0584 - val_loss: 0.1540 - val_mean_absolute_error: 0.2631
# Epoch 43/100
# 160/160 - 1s - 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0552 - val_loss: 0.1523 - val_mean_absolute_error: 0.2587
# Epoch 44/100
# 160/160 - 1s - 4ms/step - loss: 0.0059 - mean_absolute_error: 0.0531 - val_loss: 0.1576 - val_mean_absolute_error: 0.2656
# Epoch 45/100
# 160/160 - 1s - 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0502 - val_loss: 0.1575 - val_mean_absolute_error: 0.2687
# Epoch 46/100
# 160/160 - 1s - 4ms/step - loss: 0.0059 - mean_absolute_error: 0.0515 - val_loss: 0.1565 - val_mean_absolute_error: 0.2651
# Epoch 47/100
# 160/160 - 1s - 4ms/step - loss: 0.0057 - mean_absolute_error: 0.0509 - val_loss: 0.1530 - val_mean_absolute_error: 0.2607
# Epoch 48/100
# 160/160 - 1s - 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0511 - val_loss: 0.1542 - val_mean_absolute_error: 0.2625
# Epoch 49/100
# 160/160 - 1s - 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0505 - val_loss: 0.1532 - val_mean_absolute_error: 0.2606
# Epoch 50/100
# 160/160 - 1s - 4ms/step - loss: 0.0048 - mean_absolute_error: 0.0482 - val_loss: 0.1516 - val_mean_absolute_error: 0.2564
# Epoch 51/100
# 160/160 - 1s - 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0537 - val_loss: 0.1583 - val_mean_absolute_error: 0.2676
# Epoch 52/100
# 160/160 - 1s - 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0516 - val_loss: 0.1523 - val_mean_absolute_error: 0.2581
# Epoch 53/100
# 160/160 - 1s - 4ms/step - loss: 0.0055 - mean_absolute_error: 0.0513 - val_loss: 0.1547 - val_mean_absolute_error: 0.2625
# Epoch 54/100
# 160/160 - 1s - 4ms/step - loss: 0.0047 - mean_absolute_error: 0.0476 - val_loss: 0.1535 - val_mean_absolute_error: 0.2598
# Epoch 55/100
# 160/160 - 1s - 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0467 - val_loss: 0.1542 - val_mean_absolute_error: 0.2598
# Epoch 56/100
# 160/160 - 1s - 4ms/step - loss: 0.0045 - mean_absolute_error: 0.0468 - val_loss: 0.1550 - val_mean_absolute_error: 0.2594
# Epoch 57/100
# 160/160 - 1s - 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0448 - val_loss: 0.1549 - val_mean_absolute_error: 0.2619
# Epoch 58/100
# 160/160 - 1s - 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0432 - val_loss: 0.1566 - val_mean_absolute_error: 0.2640
# Epoch 59/100
# 160/160 - 1s - 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0446 - val_loss: 0.1533 - val_mean_absolute_error: 0.2625
# Epoch 60/100
# 160/160 - 1s - 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0461 - val_loss: 0.1567 - val_mean_absolute_error: 0.2660
# Epoch 61/100
# 160/160 - 1s - 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0440 - val_loss: 0.1536 - val_mean_absolute_error: 0.2613
# Epoch 62/100
# 160/160 - 1s - 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0438 - val_loss: 0.1539 - val_mean_absolute_error: 0.2618
# Epoch 63/100
# 160/160 - 1s - 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0445 - val_loss: 0.1540 - val_mean_absolute_error: 0.2622
# Epoch 64/100
# 160/160 - 1s - 4ms/step - loss: 0.0039 - mean_absolute_error: 0.0448 - val_loss: 0.1511 - val_mean_absolute_error: 0.2594
# Epoch 65/100
# 160/160 - 1s - 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0451 - val_loss: 0.1558 - val_mean_absolute_error: 0.2627
# Epoch 66/100
# 160/160 - 1s - 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0450 - val_loss: 0.1555 - val_mean_absolute_error: 0.2600
# Epoch 67/100
# 160/160 - 1s - 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0433 - val_loss: 0.1533 - val_mean_absolute_error: 0.2603
# Epoch 68/100
# 160/160 - 1s - 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0409 - val_loss: 0.1533 - val_mean_absolute_error: 0.2598
# Epoch 69/100
# 160/160 - 1s - 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0387 - val_loss: 0.1543 - val_mean_absolute_error: 0.2602
# Epoch 70/100
# 160/160 - 1s - 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0385 - val_loss: 0.1541 - val_mean_absolute_error: 0.2598
# Epoch 71/100
# 160/160 - 1s - 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0386 - val_loss: 0.1536 - val_mean_absolute_error: 0.2625
# Epoch 72/100
# 160/160 - 1s - 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0438 - val_loss: 0.1528 - val_mean_absolute_error: 0.2582
# Epoch 73/100
# 160/160 - 1s - 4ms/step - loss: 0.0037 - mean_absolute_error: 0.0430 - val_loss: 0.1509 - val_mean_absolute_error: 0.2567
# Epoch 74/100
# 160/160 - 1s - 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0405 - val_loss: 0.1566 - val_mean_absolute_error: 0.2634
# Epoch 75/100
# 160/160 - 1s - 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0401 - val_loss: 0.1543 - val_mean_absolute_error: 0.2599
# Epoch 76/100
# 160/160 - 1s - 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0404 - val_loss: 0.1521 - val_mean_absolute_error: 0.2604
# Epoch 77/100
# 160/160 - 1s - 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0440 - val_loss: 0.1558 - val_mean_absolute_error: 0.2611
# Epoch 78/100
# 160/160 - 1s - 4ms/step - loss: 0.0040 - mean_absolute_error: 0.0435 - val_loss: 0.1521 - val_mean_absolute_error: 0.2584
# Epoch 79/100
# 160/160 - 1s - 4ms/step - loss: 0.0036 - mean_absolute_error: 0.0423 - val_loss: 0.1523 - val_mean_absolute_error: 0.2601
# Epoch 80/100
# 160/160 - 1s - 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0412 - val_loss: 0.1504 - val_mean_absolute_error: 0.2563
# Epoch 81/100
# 160/160 - 1s - 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0379 - val_loss: 0.1514 - val_mean_absolute_error: 0.2569
# Epoch 82/100
# 160/160 - 1s - 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0357 - val_loss: 0.1534 - val_mean_absolute_error: 0.2609
# Epoch 83/100
# 160/160 - 1s - 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - val_loss: 0.1536 - val_mean_absolute_error: 0.2600
# Epoch 84/100
# 160/160 - 1s - 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0363 - val_loss: 0.1519 - val_mean_absolute_error: 0.2597
# Epoch 85/100
# 160/160 - 1s - 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0364 - val_loss: 0.1536 - val_mean_absolute_error: 0.2594
# Epoch 86/100
# 160/160 - 1s - 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0357 - val_loss: 0.1522 - val_mean_absolute_error: 0.2554
# Epoch 87/100
# 160/160 - 1s - 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0352 - val_loss: 0.1532 - val_mean_absolute_error: 0.2598
# Epoch 88/100
# 160/160 - 1s - 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - val_loss: 0.1542 - val_mean_absolute_error: 0.2612
# Epoch 89/100
# 160/160 - 1s - 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0405 - val_loss: 0.1590 - val_mean_absolute_error: 0.2672
# Epoch 90/100
# 160/160 - 1s - 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0407 - val_loss: 0.1535 - val_mean_absolute_error: 0.2608
# Epoch 91/100
# 160/160 - 1s - 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0384 - val_loss: 0.1538 - val_mean_absolute_error: 0.2587
# Epoch 92/100
# 160/160 - 1s - 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0386 - val_loss: 0.1535 - val_mean_absolute_error: 0.2588
# Epoch 93/100
# 160/160 - 1s - 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0395 - val_loss: 0.1516 - val_mean_absolute_error: 0.2579
# Epoch 94/100
# 160/160 - 1s - 4ms/step - loss: 0.0027 - mean_absolute_error: 0.0376 - val_loss: 0.1530 - val_mean_absolute_error: 0.2617
# Epoch 95/100
# 160/160 - 1s - 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0362 - val_loss: 0.1530 - val_mean_absolute_error: 0.2599
# Epoch 96/100
# 160/160 - 1s - 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0327 - val_loss: 0.1522 - val_mean_absolute_error: 0.2568
# Epoch 97/100
# 160/160 - 1s - 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0310 - val_loss: 0.1565 - val_mean_absolute_error: 0.2608
# Epoch 98/100
# 160/160 - 1s - 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0359 - val_loss: 0.1527 - val_mean_absolute_error: 0.2571
# Epoch 99/100
# 160/160 - 1s - 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0362 - val_loss: 0.1524 - val_mean_absolute_error: 0.2581
# Epoch 100/100
# 160/160 - 1s - 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0345 - val_loss: 0.1541 - val_mean_absolute_error: 0.2596

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_Noise2_acotado2.keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_test_norm, y_test_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  

#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_test_norm)
# Out:
# MSE: 0.16262474656105042
# MAE: 0.2658804655075073
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# ##### Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_test_denorm = scaler_y.inverse_transform(y_test_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

# Dibujamos los datos
symbols = [r'$\kappa$', r'$\kappa_c$', r'$g$']

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [12, 4], 
    "figure.dpi": 300 
})

# Crear subgráficos para cada variable
fig, axes = plt.subplots(nrows=1, ncols=3, constrained_layout=True)

# Añadir los subgráficos
for i, ax in enumerate(axes.flatten()):
    if i < y_test_denorm.shape[1]:  # Verifica que no exceda el número de columnas en los datos
        ax.plot(y_test_denorm[:, i], y_pred_denorm[:, i], marker='o', linestyle='',
                markersize=3, color='cornflowerblue')
        ax.plot([y_test_denorm[:, i].min(), y_test_denorm[:, i].max()],
                [y_test_denorm[:, i].min(), y_test_denorm[:, i].max()], linestyle='-', color='red', linewidth=2 )
        ax.set_xlabel('Valores reales')
        ax.set_ylabel('Red neuronal')
        ax.set_title(symbols[i])
        # Aplicar notación científica a los ejes
        ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        ax.ticklabel_format(style='sci', axis='both', scilimits=(0,0))


labels = ["Predicciones", "Real"]
fig.legend(labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=2)


plt.show()

# %% [markdown]
# ##### Curvas Validación VS Predicción

# %%
plt.rcParams.update({
    "text.usetex": False,
    "figure.figsize": [8,6],
})

k_pred = y_pred_denorm[:, 0]
k_test = y_test_denorm[:, 0]
kc_pred = y_pred_denorm[:, 1]
kc_test = y_test_denorm[:, 1]
g_pred = y_pred_denorm[:, 2]
g_test = y_test_denorm[:, 2]
DeltaE_test = DeltaE[indices_test]

t_values_pred = np.zeros((x_test.shape[0], len(w_values)))
t_values_test_noise = t_values_noise[indices_test]
t_values_test = t_values[indices_test]

for i in range (x_test.shape[0]):
    t_values_pred[i,:] = S21(w_values, k_pred[i], kc_pred[i], Omega, DeltaE_test[i], gamma, g_pred[i])

# w1 = w2 = np.zeros(x_val.shape[0])

# w1=w_1(k_test, Omega, DeltaE_test, gamma_test, g_test)
# w2=w_2(k_test, Omega, DeltaE_test, gamma_test, g_test)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.scatter(w_values, t_values_test_noise[i, :], color="b", marker='.', label="Ruido")
    plt.plot(w_values, t_values_test[i, :], color="xkcd:highlighter green", label="Original")
    plt.plot(w_values, t_values_pred[i, :], color="r", label="NN")

    # # Calcula los valores de t(w) en w1 y w2
    # t_w1 = t_w(w1[i], k_test[i], Omega, DeltaE_test[i], gamma_test[i], g_test[i])
    # t_w2 = t_w(w2[i], k_test[i], Omega, DeltaE_test[i], gamma_test[i], g_test[i])
    
    # if w_values.min() <= w1[i] <= w_values.max():
    #     plt.vlines(w1[i], 0, t_w1, colors='black', linewidth=0.5)
    # if w_values.min() <= w2[i] <= w_values.max():
    #     plt.vlines(w2[i], 0, t_w2, colors='black', linewidth=0.5)
   
    plt.title(f"Pred. vs Test. Curve number: {i}")
    plt.xlabel(r"$\omega$")
    plt.ylabel(r"$t (\omega$)")
    plt.legend(framealpha=1, loc='lower right')
    # plt.ylim(,1) 
    #plt.xlim(0.85,1.15) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"$\kappa$ real = {k_test[i]:.2e}, $\kappa$ pred = {k_pred[i]:.2e}\n"\
           f"$\kappa_c$ real = {kc_test[i]:.2e}, $\kappa_c$ pred = {kc_pred[i]:.2e}\n"\
           f"g real = {g_test[i]:.2e}, g pred = {g_pred[i]:.2e}\n"\
           f"$\Delta$E = {DeltaE_test[i]:.3f}"
    # plt.text(0.011, 0.23, text, transform=plt.gca().transAxes, fontsize=14, verticalalignment='top', 
    #          bbox=dict(facecolor='white', alpha=1))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # Dibujos para Memoria

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [12,4], 
    "figure.dpi": 300 
})


pics = [10, 19, 26]
labels_subplots = ["a)", "b)", "c)", "d)", "e)", "f)"]

fig, axes = plt.subplots(1, 3, constrained_layout=True)
for idx, (ax, i) in enumerate(zip(axes.flat, pics)):
    ax.scatter(w_values, t_values_test_noise[i, :],  marker='.', color="b")
    ax.plot(w_values, t_values_test[i, :], color="gold")
    ax.plot(w_values, t_values_pred[i, :], color="r")
    # ax.set_yticks(np.arange(0, 1.05, 0.2))
    ax.set_xticks(np.linspace(w_values.min(), w_values.max(), 6))
    # ax.set_ylim(-0.03, 1.05)

    ax.text(0.03, 0.1, labels_subplots[idx], transform=ax.transAxes, 
        fontsize=15, fontweight='bold', va='top', ha='left')
    
    ax.set_ylabel(r'$S_{21}(\omega)$') 
    

    # # Configurar etiquetas y ticks según la posición del subplot
    # if idx % 3 == 0:  # Primera columna
    #     ax.set_ylabel(r'$S_{21}(\omega)$')  # Etiqueta y en la columna izquierda
    # else:
    #     ax.set_yticklabels([])  # Sin etiquetas en el eje y en la columna derecha
    #     ax.tick_params(axis='y', labelleft=False)

    ax.set_xlabel(r'$\omega$')

    # if idx // 3 == 1:  # Última fila
    #     ax.set_xlabel(r'$\omega$')  # Etiqueta x en la fila inferior
    # else:
    #     ax.set_xticklabels([])  # Sin etiquetas en el eje x en la fila superior
    #     ax.tick_params(axis='x', labelbottom=False)

    ax.tick_params(axis='both', direction='in')


labels = ["Con ruido", "Original", "NN"]
fig.legend(labels, loc='upper center', bbox_to_anchor=(0.525, 1.16), ncol=3)
plt.show()

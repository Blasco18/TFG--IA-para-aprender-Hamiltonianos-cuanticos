# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos t($\omega$):
# $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # With noise

# %% [markdown]
# ## Creamos base de datos

# %%
#Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)

    return k, gamma, g

def add_noise (data, sig):
    return data + np.random.normal(0,sig)

num_datos = 5000

# %%
# #Creamos base de datos y guardamos en .txt
# k, gamma, g = Parameters_generator (num_datos)

# np.savetxt('Parameters_Noise(DeltaE-fijo).txt', np.column_stack((k, gamma, g)), header='\u03BA \u213D g')

# %%
datos = np.loadtxt('Parameters_Noise(DeltaE-fijo).txt', skiprows=1)
k = datos[:,0]
gamma = datos[:,1]
g = datos[:,2]
DeltaE = 1.02
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.85, 1.15, 300)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))
t_values_noise = np.zeros((num_datos, len(w_values)))


# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k[i], Omega, DeltaE, gamma[i], g[i]) 

for i in range (num_datos):
    t_values_noise[i,:] = [add_noise(t_values[i,j], 0.5*t_values[i,j]*np.random.rand())
                            for j in range(len(w_values))]

# %% [markdown]
# ### Dibujamos las curvas

# %%
# i=0
# while i<=5000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values_noise[i,:], label='Con ruido', color='blue')
#     plt.plot(w_values, t_values[i,:], label='Original', linewidth=0.75, linestyle='--', color='red')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
indices = np.arange(num_datos)
indices_train, indices_val = train_test_split(indices, test_size=0.2)

x_train = t_values_noise[indices_train]
x_val = t_values_noise[indices_val]
y_train = datos[indices_train]
y_val = datos[indices_val]


# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 300)
# y_train shape (4000, 3)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_Noise_five(DeltaE-1.02_50%).keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 1s - loss: 0.7556 - mean_absolute_error: 0.6932 - val_loss: 0.6865 - val_mean_absolute_error: 0.6449 - 957ms/epoch - 12ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.6486 - mean_absolute_error: 0.6223 - val_loss: 0.6341 - val_mean_absolute_error: 0.6109 - 130ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.5887 - mean_absolute_error: 0.5854 - val_loss: 0.5922 - val_mean_absolute_error: 0.5883 - 131ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.5331 - mean_absolute_error: 0.5541 - val_loss: 0.5481 - val_mean_absolute_error: 0.5627 - 134ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.4952 - mean_absolute_error: 0.5306 - val_loss: 0.5228 - val_mean_absolute_error: 0.5480 - 133ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.4441 - mean_absolute_error: 0.4956 - val_loss: 0.5290 - val_mean_absolute_error: 0.5496 - 131ms/epoch - 2ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.4296 - mean_absolute_error: 0.4872 - val_loss: 0.4807 - val_mean_absolute_error: 0.5182 - 135ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.3832 - mean_absolute_error: 0.4537 - val_loss: 0.4614 - val_mean_absolute_error: 0.5010 - 126ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.3437 - mean_absolute_error: 0.4272 - val_loss: 0.4572 - val_mean_absolute_error: 0.4891 - 128ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.3246 - mean_absolute_error: 0.4112 - val_loss: 0.4285 - val_mean_absolute_error: 0.4780 - 133ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.2912 - mean_absolute_error: 0.3888 - val_loss: 0.4295 - val_mean_absolute_error: 0.4725 - 126ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.2644 - mean_absolute_error: 0.3654 - val_loss: 0.4056 - val_mean_absolute_error: 0.4600 - 128ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.2427 - mean_absolute_error: 0.3508 - val_loss: 0.4099 - val_mean_absolute_error: 0.4654 - 129ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.2292 - mean_absolute_error: 0.3382 - val_loss: 0.4095 - val_mean_absolute_error: 0.4522 - 143ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.2093 - mean_absolute_error: 0.3208 - val_loss: 0.3855 - val_mean_absolute_error: 0.4374 - 126ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.2034 - mean_absolute_error: 0.3155 - val_loss: 0.3927 - val_mean_absolute_error: 0.4375 - 130ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.1795 - mean_absolute_error: 0.2951 - val_loss: 0.4025 - val_mean_absolute_error: 0.4377 - 131ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.1686 - mean_absolute_error: 0.2801 - val_loss: 0.3630 - val_mean_absolute_error: 0.4191 - 131ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.1572 - mean_absolute_error: 0.2701 - val_loss: 0.3676 - val_mean_absolute_error: 0.4177 - 131ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.1547 - mean_absolute_error: 0.2690 - val_loss: 0.3732 - val_mean_absolute_error: 0.4156 - 132ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.1484 - mean_absolute_error: 0.2595 - val_loss: 0.3869 - val_mean_absolute_error: 0.4270 - 128ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.1480 - mean_absolute_error: 0.2600 - val_loss: 0.3745 - val_mean_absolute_error: 0.4200 - 126ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.1363 - mean_absolute_error: 0.2482 - val_loss: 0.3753 - val_mean_absolute_error: 0.4136 - 131ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.1296 - mean_absolute_error: 0.2389 - val_loss: 0.3632 - val_mean_absolute_error: 0.4046 - 133ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.1241 - mean_absolute_error: 0.2314 - val_loss: 0.3693 - val_mean_absolute_error: 0.4155 - 159ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.1210 - mean_absolute_error: 0.2317 - val_loss: 0.3618 - val_mean_absolute_error: 0.3997 - 149ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.1152 - mean_absolute_error: 0.2242 - val_loss: 0.3521 - val_mean_absolute_error: 0.4027 - 131ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.1146 - mean_absolute_error: 0.2227 - val_loss: 0.4081 - val_mean_absolute_error: 0.4284 - 131ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.1169 - mean_absolute_error: 0.2251 - val_loss: 0.3785 - val_mean_absolute_error: 0.4100 - 135ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.1123 - mean_absolute_error: 0.2183 - val_loss: 0.3646 - val_mean_absolute_error: 0.3999 - 132ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.1006 - mean_absolute_error: 0.2065 - val_loss: 0.3506 - val_mean_absolute_error: 0.3951 - 132ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.1016 - mean_absolute_error: 0.2041 - val_loss: 0.3478 - val_mean_absolute_error: 0.3896 - 132ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.0933 - mean_absolute_error: 0.1937 - val_loss: 0.3637 - val_mean_absolute_error: 0.3950 - 129ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.1058 - mean_absolute_error: 0.2081 - val_loss: 0.3525 - val_mean_absolute_error: 0.3885 - 129ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.0991 - mean_absolute_error: 0.2007 - val_loss: 0.3567 - val_mean_absolute_error: 0.3905 - 130ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.0884 - mean_absolute_error: 0.1872 - val_loss: 0.3488 - val_mean_absolute_error: 0.3863 - 135ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.0894 - mean_absolute_error: 0.1840 - val_loss: 0.3613 - val_mean_absolute_error: 0.3926 - 131ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.0845 - mean_absolute_error: 0.1796 - val_loss: 0.3592 - val_mean_absolute_error: 0.3926 - 128ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.0848 - mean_absolute_error: 0.1816 - val_loss: 0.3460 - val_mean_absolute_error: 0.3833 - 128ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.0845 - mean_absolute_error: 0.1829 - val_loss: 0.3505 - val_mean_absolute_error: 0.3845 - 129ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.0775 - mean_absolute_error: 0.1726 - val_loss: 0.3449 - val_mean_absolute_error: 0.3790 - 128ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.0802 - mean_absolute_error: 0.1730 - val_loss: 0.3519 - val_mean_absolute_error: 0.3825 - 129ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.0825 - mean_absolute_error: 0.1769 - val_loss: 0.3517 - val_mean_absolute_error: 0.3811 - 127ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.0798 - mean_absolute_error: 0.1720 - val_loss: 0.3631 - val_mean_absolute_error: 0.3828 - 127ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.0780 - mean_absolute_error: 0.1720 - val_loss: 0.3512 - val_mean_absolute_error: 0.3829 - 129ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.0775 - mean_absolute_error: 0.1702 - val_loss: 0.3696 - val_mean_absolute_error: 0.3900 - 129ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.0772 - mean_absolute_error: 0.1681 - val_loss: 0.3493 - val_mean_absolute_error: 0.3867 - 126ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.0767 - mean_absolute_error: 0.1658 - val_loss: 0.3540 - val_mean_absolute_error: 0.3800 - 128ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.0730 - mean_absolute_error: 0.1637 - val_loss: 0.3515 - val_mean_absolute_error: 0.3786 - 126ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.0699 - mean_absolute_error: 0.1534 - val_loss: 0.3450 - val_mean_absolute_error: 0.3771 - 126ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.0708 - mean_absolute_error: 0.1586 - val_loss: 0.3572 - val_mean_absolute_error: 0.3828 - 144ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.0735 - mean_absolute_error: 0.1621 - val_loss: 0.3461 - val_mean_absolute_error: 0.3748 - 140ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.0737 - mean_absolute_error: 0.1587 - val_loss: 0.3594 - val_mean_absolute_error: 0.3818 - 127ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.0744 - mean_absolute_error: 0.1641 - val_loss: 0.3435 - val_mean_absolute_error: 0.3733 - 128ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.0693 - mean_absolute_error: 0.1558 - val_loss: 0.3490 - val_mean_absolute_error: 0.3744 - 129ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.0677 - mean_absolute_error: 0.1554 - val_loss: 0.3467 - val_mean_absolute_error: 0.3754 - 126ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.0727 - mean_absolute_error: 0.1602 - val_loss: 0.3499 - val_mean_absolute_error: 0.3856 - 127ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.0724 - mean_absolute_error: 0.1601 - val_loss: 0.3623 - val_mean_absolute_error: 0.3892 - 133ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.0687 - mean_absolute_error: 0.1544 - val_loss: 0.3372 - val_mean_absolute_error: 0.3717 - 140ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.0677 - mean_absolute_error: 0.1531 - val_loss: 0.3768 - val_mean_absolute_error: 0.3957 - 132ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.0812 - mean_absolute_error: 0.1711 - val_loss: 0.3523 - val_mean_absolute_error: 0.3861 - 130ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.0742 - mean_absolute_error: 0.1622 - val_loss: 0.3507 - val_mean_absolute_error: 0.3791 - 132ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.0626 - mean_absolute_error: 0.1448 - val_loss: 0.3746 - val_mean_absolute_error: 0.3912 - 155ms/epoch - 2ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.0685 - mean_absolute_error: 0.1542 - val_loss: 0.3558 - val_mean_absolute_error: 0.3872 - 129ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.0681 - mean_absolute_error: 0.1542 - val_loss: 0.3330 - val_mean_absolute_error: 0.3676 - 137ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.0662 - mean_absolute_error: 0.1502 - val_loss: 0.3352 - val_mean_absolute_error: 0.3752 - 132ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.0615 - mean_absolute_error: 0.1436 - val_loss: 0.3411 - val_mean_absolute_error: 0.3664 - 131ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.0609 - mean_absolute_error: 0.1351 - val_loss: 0.3531 - val_mean_absolute_error: 0.3786 - 131ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.0614 - mean_absolute_error: 0.1416 - val_loss: 0.3408 - val_mean_absolute_error: 0.3676 - 130ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.0662 - mean_absolute_error: 0.1460 - val_loss: 0.3499 - val_mean_absolute_error: 0.3778 - 128ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.0642 - mean_absolute_error: 0.1507 - val_loss: 0.3461 - val_mean_absolute_error: 0.3730 - 128ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.0608 - mean_absolute_error: 0.1405 - val_loss: 0.3493 - val_mean_absolute_error: 0.3725 - 126ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.0618 - mean_absolute_error: 0.1417 - val_loss: 0.3543 - val_mean_absolute_error: 0.3850 - 144ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.0588 - mean_absolute_error: 0.1397 - val_loss: 0.3370 - val_mean_absolute_error: 0.3658 - 163ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.0635 - mean_absolute_error: 0.1434 - val_loss: 0.3628 - val_mean_absolute_error: 0.3869 - 145ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.0783 - mean_absolute_error: 0.1682 - val_loss: 0.3516 - val_mean_absolute_error: 0.3813 - 147ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.0652 - mean_absolute_error: 0.1514 - val_loss: 0.3467 - val_mean_absolute_error: 0.3738 - 127ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.0556 - mean_absolute_error: 0.1334 - val_loss: 0.3423 - val_mean_absolute_error: 0.3698 - 126ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.0567 - mean_absolute_error: 0.1355 - val_loss: 0.3681 - val_mean_absolute_error: 0.3879 - 128ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.0583 - mean_absolute_error: 0.1361 - val_loss: 0.3408 - val_mean_absolute_error: 0.3725 - 129ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.0547 - mean_absolute_error: 0.1317 - val_loss: 0.3560 - val_mean_absolute_error: 0.3785 - 126ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.0540 - mean_absolute_error: 0.1324 - val_loss: 0.3644 - val_mean_absolute_error: 0.3859 - 126ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.0595 - mean_absolute_error: 0.1397 - val_loss: 0.3418 - val_mean_absolute_error: 0.3711 - 129ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.0547 - mean_absolute_error: 0.1292 - val_loss: 0.3439 - val_mean_absolute_error: 0.3725 - 127ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.0553 - mean_absolute_error: 0.1288 - val_loss: 0.3418 - val_mean_absolute_error: 0.3704 - 127ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.0660 - mean_absolute_error: 0.1448 - val_loss: 0.3584 - val_mean_absolute_error: 0.3853 - 142ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.0675 - mean_absolute_error: 0.1530 - val_loss: 0.3765 - val_mean_absolute_error: 0.3993 - 151ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.0606 - mean_absolute_error: 0.1452 - val_loss: 0.3402 - val_mean_absolute_error: 0.3679 - 146ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.0532 - mean_absolute_error: 0.1280 - val_loss: 0.3499 - val_mean_absolute_error: 0.3689 - 186ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.0527 - mean_absolute_error: 0.1299 - val_loss: 0.3459 - val_mean_absolute_error: 0.3665 - 152ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.0531 - mean_absolute_error: 0.1289 - val_loss: 0.3489 - val_mean_absolute_error: 0.3727 - 133ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.0573 - mean_absolute_error: 0.1356 - val_loss: 0.3385 - val_mean_absolute_error: 0.3679 - 144ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.0526 - mean_absolute_error: 0.1303 - val_loss: 0.3451 - val_mean_absolute_error: 0.3691 - 133ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.0497 - mean_absolute_error: 0.1205 - val_loss: 0.3383 - val_mean_absolute_error: 0.3683 - 129ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.0574 - mean_absolute_error: 0.1355 - val_loss: 0.3459 - val_mean_absolute_error: 0.3762 - 139ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.0524 - mean_absolute_error: 0.1275 - val_loss: 0.3543 - val_mean_absolute_error: 0.3753 - 155ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.0551 - mean_absolute_error: 0.1316 - val_loss: 0.3650 - val_mean_absolute_error: 0.3818 - 175ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.0563 - mean_absolute_error: 0.1341 - val_loss: 0.3431 - val_mean_absolute_error: 0.3768 - 128ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.0535 - mean_absolute_error: 0.1302 - val_loss: 0.3415 - val_mean_absolute_error: 0.3667 - 129ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.0531 - mean_absolute_error: 0.1303 - val_loss: 0.3387 - val_mean_absolute_error: 0.3677 - 130ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.0587 - mean_absolute_error: 0.1371 - val_loss: 0.3464 - val_mean_absolute_error: 0.3721 - 129ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.0594 - mean_absolute_error: 0.1399 - val_loss: 0.3414 - val_mean_absolute_error: 0.3693 - 130ms/epoch - 2ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.0497 - mean_absolute_error: 0.1258 - val_loss: 0.3639 - val_mean_absolute_error: 0.3820 - 132ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.0503 - mean_absolute_error: 0.1242 - val_loss: 0.3485 - val_mean_absolute_error: 0.3813 - 130ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.0504 - mean_absolute_error: 0.1248 - val_loss: 0.3509 - val_mean_absolute_error: 0.3844 - 127ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.0505 - mean_absolute_error: 0.1239 - val_loss: 0.3515 - val_mean_absolute_error: 0.3778 - 124ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.0493 - mean_absolute_error: 0.1194 - val_loss: 0.3427 - val_mean_absolute_error: 0.3746 - 130ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.0513 - mean_absolute_error: 0.1288 - val_loss: 0.3502 - val_mean_absolute_error: 0.3710 - 131ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.0486 - mean_absolute_error: 0.1227 - val_loss: 0.3577 - val_mean_absolute_error: 0.3718 - 129ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.0511 - mean_absolute_error: 0.1230 - val_loss: 0.3437 - val_mean_absolute_error: 0.3704 - 128ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.0504 - mean_absolute_error: 0.1261 - val_loss: 0.3437 - val_mean_absolute_error: 0.3725 - 129ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.0496 - mean_absolute_error: 0.1227 - val_loss: 0.3451 - val_mean_absolute_error: 0.3716 - 124ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.0452 - mean_absolute_error: 0.1179 - val_loss: 0.3574 - val_mean_absolute_error: 0.3744 - 162ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.0522 - mean_absolute_error: 0.1275 - val_loss: 0.3664 - val_mean_absolute_error: 0.3880 - 133ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.0528 - mean_absolute_error: 0.1303 - val_loss: 0.3548 - val_mean_absolute_error: 0.3822 - 127ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.0510 - mean_absolute_error: 0.1294 - val_loss: 0.3460 - val_mean_absolute_error: 0.3747 - 128ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.0494 - mean_absolute_error: 0.1236 - val_loss: 0.3415 - val_mean_absolute_error: 0.3682 - 126ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.0517 - mean_absolute_error: 0.1288 - val_loss: 0.3515 - val_mean_absolute_error: 0.3726 - 133ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.0515 - mean_absolute_error: 0.1290 - val_loss: 0.3572 - val_mean_absolute_error: 0.3767 - 131ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.0460 - mean_absolute_error: 0.1171 - val_loss: 0.3395 - val_mean_absolute_error: 0.3714 - 127ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.0549 - mean_absolute_error: 0.1319 - val_loss: 0.3448 - val_mean_absolute_error: 0.3767 - 124ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.0498 - mean_absolute_error: 0.1240 - val_loss: 0.3398 - val_mean_absolute_error: 0.3721 - 125ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.0444 - mean_absolute_error: 0.1154 - val_loss: 0.3445 - val_mean_absolute_error: 0.3718 - 131ms/epoch - 2ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.0461 - mean_absolute_error: 0.1172 - val_loss: 0.3390 - val_mean_absolute_error: 0.3669 - 124ms/epoch - 2ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.0466 - mean_absolute_error: 0.1172 - val_loss: 0.3371 - val_mean_absolute_error: 0.3689 - 129ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.0439 - mean_absolute_error: 0.1138 - val_loss: 0.3522 - val_mean_absolute_error: 0.3726 - 128ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.0491 - mean_absolute_error: 0.1211 - val_loss: 0.3399 - val_mean_absolute_error: 0.3661 - 126ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.0463 - mean_absolute_error: 0.1176 - val_loss: 0.3427 - val_mean_absolute_error: 0.3672 - 124ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.0491 - mean_absolute_error: 0.1228 - val_loss: 0.3571 - val_mean_absolute_error: 0.3836 - 124ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.0506 - mean_absolute_error: 0.1265 - val_loss: 0.3366 - val_mean_absolute_error: 0.3628 - 140ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.0482 - mean_absolute_error: 0.1212 - val_loss: 0.3463 - val_mean_absolute_error: 0.3751 - 123ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.0499 - mean_absolute_error: 0.1234 - val_loss: 0.3372 - val_mean_absolute_error: 0.3678 - 123ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.0487 - mean_absolute_error: 0.1233 - val_loss: 0.3429 - val_mean_absolute_error: 0.3679 - 124ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.0420 - mean_absolute_error: 0.1086 - val_loss: 0.3471 - val_mean_absolute_error: 0.3681 - 127ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.0402 - mean_absolute_error: 0.1055 - val_loss: 0.3471 - val_mean_absolute_error: 0.3695 - 126ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.0427 - mean_absolute_error: 0.1117 - val_loss: 0.3396 - val_mean_absolute_error: 0.3691 - 127ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.0450 - mean_absolute_error: 0.1164 - val_loss: 0.3489 - val_mean_absolute_error: 0.3696 - 147ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.0483 - mean_absolute_error: 0.1174 - val_loss: 0.3414 - val_mean_absolute_error: 0.3678 - 130ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.0451 - mean_absolute_error: 0.1149 - val_loss: 0.3534 - val_mean_absolute_error: 0.3736 - 124ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.0477 - mean_absolute_error: 0.1197 - val_loss: 0.3483 - val_mean_absolute_error: 0.3737 - 128ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.0437 - mean_absolute_error: 0.1143 - val_loss: 0.3500 - val_mean_absolute_error: 0.3745 - 127ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.0460 - mean_absolute_error: 0.1177 - val_loss: 0.3422 - val_mean_absolute_error: 0.3661 - 187ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.0429 - mean_absolute_error: 0.1085 - val_loss: 0.3368 - val_mean_absolute_error: 0.3661 - 155ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.0547 - mean_absolute_error: 0.1301 - val_loss: 0.3412 - val_mean_absolute_error: 0.3670 - 123ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.0422 - mean_absolute_error: 0.1119 - val_loss: 0.3351 - val_mean_absolute_error: 0.3634 - 123ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.0449 - mean_absolute_error: 0.1138 - val_loss: 0.3368 - val_mean_absolute_error: 0.3686 - 125ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.0443 - mean_absolute_error: 0.1126 - val_loss: 0.3438 - val_mean_absolute_error: 0.3693 - 124ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.0491 - mean_absolute_error: 0.1217 - val_loss: 0.3426 - val_mean_absolute_error: 0.3693 - 123ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.0419 - mean_absolute_error: 0.1135 - val_loss: 0.3384 - val_mean_absolute_error: 0.3632 - 226ms/epoch - 3ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.0528 - mean_absolute_error: 0.1238 - val_loss: 0.3434 - val_mean_absolute_error: 0.3665 - 131ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.0433 - mean_absolute_error: 0.1120 - val_loss: 0.3417 - val_mean_absolute_error: 0.3662 - 173ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.0413 - mean_absolute_error: 0.1071 - val_loss: 0.3500 - val_mean_absolute_error: 0.3705 - 179ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.0462 - mean_absolute_error: 0.1172 - val_loss: 0.3401 - val_mean_absolute_error: 0.3689 - 123ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.0401 - mean_absolute_error: 0.1079 - val_loss: 0.3569 - val_mean_absolute_error: 0.3771 - 212ms/epoch - 3ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.0408 - mean_absolute_error: 0.1098 - val_loss: 0.3504 - val_mean_absolute_error: 0.3718 - 148ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.0400 - mean_absolute_error: 0.1074 - val_loss: 0.3502 - val_mean_absolute_error: 0.3769 - 164ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.0392 - mean_absolute_error: 0.1060 - val_loss: 0.3449 - val_mean_absolute_error: 0.3646 - 205ms/epoch - 3ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.0379 - mean_absolute_error: 0.1028 - val_loss: 0.3439 - val_mean_absolute_error: 0.3706 - 124ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.0414 - mean_absolute_error: 0.1055 - val_loss: 0.3400 - val_mean_absolute_error: 0.3681 - 123ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.0434 - mean_absolute_error: 0.1140 - val_loss: 0.3565 - val_mean_absolute_error: 0.3756 - 123ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.0444 - mean_absolute_error: 0.1154 - val_loss: 0.3447 - val_mean_absolute_error: 0.3668 - 124ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.0407 - mean_absolute_error: 0.1075 - val_loss: 0.3420 - val_mean_absolute_error: 0.3665 - 124ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.0454 - mean_absolute_error: 0.1160 - val_loss: 0.3425 - val_mean_absolute_error: 0.3737 - 125ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.0492 - mean_absolute_error: 0.1255 - val_loss: 0.3502 - val_mean_absolute_error: 0.3789 - 123ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.0497 - mean_absolute_error: 0.1216 - val_loss: 0.3498 - val_mean_absolute_error: 0.3805 - 125ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.0417 - mean_absolute_error: 0.1121 - val_loss: 0.3403 - val_mean_absolute_error: 0.3690 - 124ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.0430 - mean_absolute_error: 0.1145 - val_loss: 0.3345 - val_mean_absolute_error: 0.3658 - 124ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.0399 - mean_absolute_error: 0.1088 - val_loss: 0.3422 - val_mean_absolute_error: 0.3666 - 123ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.0477 - mean_absolute_error: 0.1221 - val_loss: 0.3373 - val_mean_absolute_error: 0.3663 - 123ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.0419 - mean_absolute_error: 0.1141 - val_loss: 0.3389 - val_mean_absolute_error: 0.3661 - 125ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.0455 - mean_absolute_error: 0.1155 - val_loss: 0.3539 - val_mean_absolute_error: 0.3739 - 123ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.0466 - mean_absolute_error: 0.1175 - val_loss: 0.3383 - val_mean_absolute_error: 0.3662 - 123ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.0406 - mean_absolute_error: 0.1077 - val_loss: 0.3370 - val_mean_absolute_error: 0.3634 - 125ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.0375 - mean_absolute_error: 0.1048 - val_loss: 0.3445 - val_mean_absolute_error: 0.3653 - 124ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.0422 - mean_absolute_error: 0.1059 - val_loss: 0.3468 - val_mean_absolute_error: 0.3700 - 122ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.0465 - mean_absolute_error: 0.1208 - val_loss: 0.3437 - val_mean_absolute_error: 0.3656 - 124ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.0406 - mean_absolute_error: 0.1101 - val_loss: 0.3377 - val_mean_absolute_error: 0.3678 - 125ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.0411 - mean_absolute_error: 0.1093 - val_loss: 0.3445 - val_mean_absolute_error: 0.3760 - 126ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.0390 - mean_absolute_error: 0.1055 - val_loss: 0.3407 - val_mean_absolute_error: 0.3671 - 123ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.0379 - mean_absolute_error: 0.1034 - val_loss: 0.3356 - val_mean_absolute_error: 0.3618 - 123ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.0461 - mean_absolute_error: 0.1144 - val_loss: 0.3595 - val_mean_absolute_error: 0.3841 - 123ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.0439 - mean_absolute_error: 0.1166 - val_loss: 0.3465 - val_mean_absolute_error: 0.3674 - 123ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.0536 - mean_absolute_error: 0.1253 - val_loss: 0.3389 - val_mean_absolute_error: 0.3729 - 123ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.0392 - mean_absolute_error: 0.1065 - val_loss: 0.3579 - val_mean_absolute_error: 0.3708 - 122ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.0410 - mean_absolute_error: 0.1102 - val_loss: 0.3400 - val_mean_absolute_error: 0.3726 - 124ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.0472 - mean_absolute_error: 0.1221 - val_loss: 0.3416 - val_mean_absolute_error: 0.3651 - 125ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.0390 - mean_absolute_error: 0.1057 - val_loss: 0.3481 - val_mean_absolute_error: 0.3723 - 123ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.0395 - mean_absolute_error: 0.1073 - val_loss: 0.3481 - val_mean_absolute_error: 0.3692 - 123ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.0350 - mean_absolute_error: 0.0987 - val_loss: 0.3441 - val_mean_absolute_error: 0.3686 - 123ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.0367 - mean_absolute_error: 0.1000 - val_loss: 0.3649 - val_mean_absolute_error: 0.3829 - 123ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.0425 - mean_absolute_error: 0.1106 - val_loss: 0.3532 - val_mean_absolute_error: 0.3729 - 123ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.0390 - mean_absolute_error: 0.1059 - val_loss: 0.3587 - val_mean_absolute_error: 0.3740 - 123ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.0390 - mean_absolute_error: 0.1039 - val_loss: 0.3461 - val_mean_absolute_error: 0.3718 - 124ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.0364 - mean_absolute_error: 0.0998 - val_loss: 0.3507 - val_mean_absolute_error: 0.3720 - 125ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.0446 - mean_absolute_error: 0.1144 - val_loss: 0.3604 - val_mean_absolute_error: 0.3811 - 124ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.0438 - mean_absolute_error: 0.1173 - val_loss: 0.3476 - val_mean_absolute_error: 0.3698 - 124ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.0404 - mean_absolute_error: 0.1079 - val_loss: 0.3446 - val_mean_absolute_error: 0.3671 - 124ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.0466 - mean_absolute_error: 0.1220 - val_loss: 0.3469 - val_mean_absolute_error: 0.3721 - 125ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.0409 - mean_absolute_error: 0.1082 - val_loss: 0.3447 - val_mean_absolute_error: 0.3697 - 126ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.0532 - mean_absolute_error: 0.1259 - val_loss: 0.3488 - val_mean_absolute_error: 0.3681 - 125ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.0384 - mean_absolute_error: 0.1048 - val_loss: 0.3446 - val_mean_absolute_error: 0.3676 - 125ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.0410 - mean_absolute_error: 0.1086 - val_loss: 0.3512 - val_mean_absolute_error: 0.3687 - 126ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.0360 - mean_absolute_error: 0.1001 - val_loss: 0.3438 - val_mean_absolute_error: 0.3658 - 123ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.0348 - mean_absolute_error: 0.0980 - val_loss: 0.3489 - val_mean_absolute_error: 0.3699 - 123ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.0387 - mean_absolute_error: 0.1027 - val_loss: 0.3399 - val_mean_absolute_error: 0.3666 - 125ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.0383 - mean_absolute_error: 0.1021 - val_loss: 0.3477 - val_mean_absolute_error: 0.3675 - 124ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.0383 - mean_absolute_error: 0.1057 - val_loss: 0.3466 - val_mean_absolute_error: 0.3694 - 123ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.0351 - mean_absolute_error: 0.0948 - val_loss: 0.3426 - val_mean_absolute_error: 0.3647 - 125ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.0380 - mean_absolute_error: 0.1030 - val_loss: 0.3590 - val_mean_absolute_error: 0.3783 - 124ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.0418 - mean_absolute_error: 0.1122 - val_loss: 0.3459 - val_mean_absolute_error: 0.3676 - 124ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.0384 - mean_absolute_error: 0.1031 - val_loss: 0.3506 - val_mean_absolute_error: 0.3736 - 125ms/epoch - 2ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.0431 - mean_absolute_error: 0.1110 - val_loss: 0.3340 - val_mean_absolute_error: 0.3634 - 125ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.0394 - mean_absolute_error: 0.1065 - val_loss: 0.3485 - val_mean_absolute_error: 0.3717 - 124ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.0359 - mean_absolute_error: 0.0995 - val_loss: 0.3415 - val_mean_absolute_error: 0.3664 - 123ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.0373 - mean_absolute_error: 0.1022 - val_loss: 0.3443 - val_mean_absolute_error: 0.3659 - 124ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.0373 - mean_absolute_error: 0.1009 - val_loss: 0.3301 - val_mean_absolute_error: 0.3623 - 123ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.0353 - mean_absolute_error: 0.0972 - val_loss: 0.3412 - val_mean_absolute_error: 0.3651 - 124ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.0364 - mean_absolute_error: 0.0976 - val_loss: 0.3492 - val_mean_absolute_error: 0.3677 - 124ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.0391 - mean_absolute_error: 0.1044 - val_loss: 0.3626 - val_mean_absolute_error: 0.3776 - 123ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.0387 - mean_absolute_error: 0.1076 - val_loss: 0.3367 - val_mean_absolute_error: 0.3652 - 123ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.0379 - mean_absolute_error: 0.1014 - val_loss: 0.3484 - val_mean_absolute_error: 0.3698 - 124ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.0385 - mean_absolute_error: 0.1061 - val_loss: 0.3458 - val_mean_absolute_error: 0.3743 - 145ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.0500 - mean_absolute_error: 0.1189 - val_loss: 0.3654 - val_mean_absolute_error: 0.3873 - 124ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.0481 - mean_absolute_error: 0.1240 - val_loss: 0.3380 - val_mean_absolute_error: 0.3622 - 123ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.0394 - mean_absolute_error: 0.1082 - val_loss: 0.3478 - val_mean_absolute_error: 0.3694 - 126ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.0320 - mean_absolute_error: 0.0943 - val_loss: 0.3478 - val_mean_absolute_error: 0.3688 - 125ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.0349 - mean_absolute_error: 0.0941 - val_loss: 0.3447 - val_mean_absolute_error: 0.3665 - 146ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.0427 - mean_absolute_error: 0.1076 - val_loss: 0.3512 - val_mean_absolute_error: 0.3709 - 125ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.0323 - mean_absolute_error: 0.0943 - val_loss: 0.3464 - val_mean_absolute_error: 0.3634 - 124ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.0373 - mean_absolute_error: 0.0992 - val_loss: 0.3401 - val_mean_absolute_error: 0.3655 - 123ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.0342 - mean_absolute_error: 0.0965 - val_loss: 0.3356 - val_mean_absolute_error: 0.3631 - 124ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.0319 - mean_absolute_error: 0.0946 - val_loss: 0.3475 - val_mean_absolute_error: 0.3674 - 124ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.0366 - mean_absolute_error: 0.1008 - val_loss: 0.3495 - val_mean_absolute_error: 0.3721 - 124ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.0421 - mean_absolute_error: 0.1113 - val_loss: 0.3476 - val_mean_absolute_error: 0.3698 - 127ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.0328 - mean_absolute_error: 0.0977 - val_loss: 0.3441 - val_mean_absolute_error: 0.3659 - 126ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.0327 - mean_absolute_error: 0.0920 - val_loss: 0.3630 - val_mean_absolute_error: 0.3766 - 130ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.0366 - mean_absolute_error: 0.0993 - val_loss: 0.3524 - val_mean_absolute_error: 0.3711 - 125ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.0340 - mean_absolute_error: 0.0960 - val_loss: 0.3400 - val_mean_absolute_error: 0.3641 - 123ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.0323 - mean_absolute_error: 0.0933 - val_loss: 0.3345 - val_mean_absolute_error: 0.3620 - 123ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.0366 - mean_absolute_error: 0.0980 - val_loss: 0.3444 - val_mean_absolute_error: 0.3661 - 124ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.0335 - mean_absolute_error: 0.0982 - val_loss: 0.3422 - val_mean_absolute_error: 0.3643 - 124ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.0417 - mean_absolute_error: 0.1089 - val_loss: 0.3554 - val_mean_absolute_error: 0.3745 - 124ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.0404 - mean_absolute_error: 0.1126 - val_loss: 0.3410 - val_mean_absolute_error: 0.3692 - 123ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.0372 - mean_absolute_error: 0.1008 - val_loss: 0.3410 - val_mean_absolute_error: 0.3634 - 125ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.0325 - mean_absolute_error: 0.0907 - val_loss: 0.3454 - val_mean_absolute_error: 0.3688 - 123ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.0391 - mean_absolute_error: 0.1047 - val_loss: 0.3572 - val_mean_absolute_error: 0.3767 - 126ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.0410 - mean_absolute_error: 0.1103 - val_loss: 0.3451 - val_mean_absolute_error: 0.3679 - 124ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.0448 - mean_absolute_error: 0.1121 - val_loss: 0.3432 - val_mean_absolute_error: 0.3674 - 123ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.0436 - mean_absolute_error: 0.1129 - val_loss: 0.3467 - val_mean_absolute_error: 0.3723 - 125ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.0410 - mean_absolute_error: 0.1111 - val_loss: 0.3410 - val_mean_absolute_error: 0.3692 - 123ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.0310 - mean_absolute_error: 0.0928 - val_loss: 0.3366 - val_mean_absolute_error: 0.3643 - 124ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.0322 - mean_absolute_error: 0.0893 - val_loss: 0.3359 - val_mean_absolute_error: 0.3625 - 123ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.0357 - mean_absolute_error: 0.0988 - val_loss: 0.3485 - val_mean_absolute_error: 0.3728 - 124ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.0316 - mean_absolute_error: 0.0920 - val_loss: 0.3335 - val_mean_absolute_error: 0.3602 - 123ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.0327 - mean_absolute_error: 0.0907 - val_loss: 0.3515 - val_mean_absolute_error: 0.3679 - 125ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.0352 - mean_absolute_error: 0.0952 - val_loss: 0.3590 - val_mean_absolute_error: 0.3721 - 131ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.0322 - mean_absolute_error: 0.0923 - val_loss: 0.3413 - val_mean_absolute_error: 0.3616 - 131ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.0331 - mean_absolute_error: 0.0932 - val_loss: 0.3415 - val_mean_absolute_error: 0.3647 - 131ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.0352 - mean_absolute_error: 0.0966 - val_loss: 0.3417 - val_mean_absolute_error: 0.3675 - 125ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.0361 - mean_absolute_error: 0.1045 - val_loss: 0.3467 - val_mean_absolute_error: 0.3647 - 187ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.0406 - mean_absolute_error: 0.1095 - val_loss: 0.3417 - val_mean_absolute_error: 0.3663 - 124ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.0388 - mean_absolute_error: 0.1056 - val_loss: 0.3400 - val_mean_absolute_error: 0.3643 - 127ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.0339 - mean_absolute_error: 0.0955 - val_loss: 0.3500 - val_mean_absolute_error: 0.3714 - 124ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.0359 - mean_absolute_error: 0.0979 - val_loss: 0.3370 - val_mean_absolute_error: 0.3654 - 126ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.0348 - mean_absolute_error: 0.0971 - val_loss: 0.3371 - val_mean_absolute_error: 0.3628 - 124ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.0328 - mean_absolute_error: 0.0939 - val_loss: 0.3405 - val_mean_absolute_error: 0.3642 - 124ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.0311 - mean_absolute_error: 0.0905 - val_loss: 0.3356 - val_mean_absolute_error: 0.3631 - 123ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.0366 - mean_absolute_error: 0.1004 - val_loss: 0.3388 - val_mean_absolute_error: 0.3683 - 123ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.0328 - mean_absolute_error: 0.0930 - val_loss: 0.3562 - val_mean_absolute_error: 0.3719 - 124ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.0320 - mean_absolute_error: 0.0899 - val_loss: 0.3364 - val_mean_absolute_error: 0.3690 - 127ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.0308 - mean_absolute_error: 0.0932 - val_loss: 0.3448 - val_mean_absolute_error: 0.3676 - 128ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.0333 - mean_absolute_error: 0.0928 - val_loss: 0.3395 - val_mean_absolute_error: 0.3644 - 145ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.0324 - mean_absolute_error: 0.0938 - val_loss: 0.3460 - val_mean_absolute_error: 0.3657 - 125ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.0349 - mean_absolute_error: 0.0999 - val_loss: 0.3591 - val_mean_absolute_error: 0.3830 - 125ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.0322 - mean_absolute_error: 0.0949 - val_loss: 0.3406 - val_mean_absolute_error: 0.3643 - 124ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.0303 - mean_absolute_error: 0.0886 - val_loss: 0.3432 - val_mean_absolute_error: 0.3636 - 130ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.0323 - mean_absolute_error: 0.0894 - val_loss: 0.3360 - val_mean_absolute_error: 0.3654 - 128ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.0318 - mean_absolute_error: 0.0933 - val_loss: 0.3436 - val_mean_absolute_error: 0.3660 - 127ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.0319 - mean_absolute_error: 0.0917 - val_loss: 0.3513 - val_mean_absolute_error: 0.3774 - 124ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.0337 - mean_absolute_error: 0.0963 - val_loss: 0.3435 - val_mean_absolute_error: 0.3668 - 130ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.0335 - mean_absolute_error: 0.0950 - val_loss: 0.3369 - val_mean_absolute_error: 0.3631 - 129ms/epoch - 2ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.0318 - mean_absolute_error: 0.0951 - val_loss: 0.3533 - val_mean_absolute_error: 0.3721 - 128ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.0430 - mean_absolute_error: 0.1142 - val_loss: 0.3377 - val_mean_absolute_error: 0.3661 - 128ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.0420 - mean_absolute_error: 0.1107 - val_loss: 0.3546 - val_mean_absolute_error: 0.3724 - 124ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.0370 - mean_absolute_error: 0.1024 - val_loss: 0.3390 - val_mean_absolute_error: 0.3647 - 124ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.0321 - mean_absolute_error: 0.0925 - val_loss: 0.3377 - val_mean_absolute_error: 0.3654 - 215ms/epoch - 3ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.0441 - mean_absolute_error: 0.1109 - val_loss: 0.3599 - val_mean_absolute_error: 0.3794 - 141ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.0332 - mean_absolute_error: 0.0956 - val_loss: 0.3425 - val_mean_absolute_error: 0.3663 - 131ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.0399 - mean_absolute_error: 0.1050 - val_loss: 0.3694 - val_mean_absolute_error: 0.3808 - 125ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.0459 - mean_absolute_error: 0.1189 - val_loss: 0.3370 - val_mean_absolute_error: 0.3688 - 129ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.0357 - mean_absolute_error: 0.1029 - val_loss: 0.3432 - val_mean_absolute_error: 0.3669 - 125ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.0342 - mean_absolute_error: 0.0969 - val_loss: 0.3554 - val_mean_absolute_error: 0.3728 - 125ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.0326 - mean_absolute_error: 0.0901 - val_loss: 0.3434 - val_mean_absolute_error: 0.3685 - 125ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.0274 - mean_absolute_error: 0.0817 - val_loss: 0.3400 - val_mean_absolute_error: 0.3647 - 124ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.0311 - mean_absolute_error: 0.0872 - val_loss: 0.3380 - val_mean_absolute_error: 0.3660 - 128ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.0286 - mean_absolute_error: 0.0812 - val_loss: 0.3332 - val_mean_absolute_error: 0.3603 - 124ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.0270 - mean_absolute_error: 0.0764 - val_loss: 0.3376 - val_mean_absolute_error: 0.3615 - 122ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.0302 - mean_absolute_error: 0.0836 - val_loss: 0.3415 - val_mean_absolute_error: 0.3661 - 124ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.0338 - mean_absolute_error: 0.0920 - val_loss: 0.3460 - val_mean_absolute_error: 0.3684 - 168ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.0319 - mean_absolute_error: 0.0893 - val_loss: 0.3428 - val_mean_absolute_error: 0.3657 - 157ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.0299 - mean_absolute_error: 0.0870 - val_loss: 0.3523 - val_mean_absolute_error: 0.3685 - 124ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.0342 - mean_absolute_error: 0.0983 - val_loss: 0.3452 - val_mean_absolute_error: 0.3716 - 125ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.0276 - mean_absolute_error: 0.0842 - val_loss: 0.3454 - val_mean_absolute_error: 0.3680 - 125ms/epoch - 2ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.0309 - mean_absolute_error: 0.0865 - val_loss: 0.3448 - val_mean_absolute_error: 0.3706 - 124ms/epoch - 2ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.0325 - mean_absolute_error: 0.0924 - val_loss: 0.3548 - val_mean_absolute_error: 0.3715 - 123ms/epoch - 2ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.0330 - mean_absolute_error: 0.0943 - val_loss: 0.3778 - val_mean_absolute_error: 0.3959 - 124ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.0327 - mean_absolute_error: 0.0942 - val_loss: 0.3393 - val_mean_absolute_error: 0.3617 - 124ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.0307 - mean_absolute_error: 0.0894 - val_loss: 0.3506 - val_mean_absolute_error: 0.3713 - 124ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.0299 - mean_absolute_error: 0.0882 - val_loss: 0.3381 - val_mean_absolute_error: 0.3659 - 127ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.0365 - mean_absolute_error: 0.1011 - val_loss: 0.3403 - val_mean_absolute_error: 0.3707 - 126ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.0291 - mean_absolute_error: 0.0930 - val_loss: 0.3533 - val_mean_absolute_error: 0.3705 - 123ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.0315 - mean_absolute_error: 0.0923 - val_loss: 0.3514 - val_mean_absolute_error: 0.3699 - 123ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.0304 - mean_absolute_error: 0.0888 - val_loss: 0.3349 - val_mean_absolute_error: 0.3662 - 122ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.0349 - mean_absolute_error: 0.0992 - val_loss: 0.3526 - val_mean_absolute_error: 0.3710 - 123ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.0313 - mean_absolute_error: 0.0916 - val_loss: 0.3384 - val_mean_absolute_error: 0.3656 - 123ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.0290 - mean_absolute_error: 0.0855 - val_loss: 0.3324 - val_mean_absolute_error: 0.3657 - 122ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.0261 - mean_absolute_error: 0.0776 - val_loss: 0.3411 - val_mean_absolute_error: 0.3654 - 123ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.0344 - mean_absolute_error: 0.0947 - val_loss: 0.3506 - val_mean_absolute_error: 0.3763 - 127ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.0252 - mean_absolute_error: 0.0812 - val_loss: 0.3461 - val_mean_absolute_error: 0.3643 - 123ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.0257 - mean_absolute_error: 0.0771 - val_loss: 0.3381 - val_mean_absolute_error: 0.3632 - 125ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.0327 - mean_absolute_error: 0.0894 - val_loss: 0.3490 - val_mean_absolute_error: 0.3738 - 123ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.0308 - mean_absolute_error: 0.0929 - val_loss: 0.3453 - val_mean_absolute_error: 0.3682 - 124ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0534 - val_loss: 0.3516 - val_mean_absolute_error: 0.3690 - 124ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.0194 - mean_absolute_error: 0.0705 - val_loss: 0.3501 - val_mean_absolute_error: 0.3690 - 131ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.0217 - mean_absolute_error: 0.0753 - val_loss: 0.3483 - val_mean_absolute_error: 0.3704 - 199ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.0200 - mean_absolute_error: 0.0728 - val_loss: 0.3475 - val_mean_absolute_error: 0.3664 - 124ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.0151 - mean_absolute_error: 0.0581 - val_loss: 0.3438 - val_mean_absolute_error: 0.3677 - 123ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.0162 - mean_absolute_error: 0.0631 - val_loss: 0.3448 - val_mean_absolute_error: 0.3673 - 129ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.0190 - mean_absolute_error: 0.0695 - val_loss: 0.3544 - val_mean_absolute_error: 0.3690 - 124ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.0180 - mean_absolute_error: 0.0677 - val_loss: 0.3523 - val_mean_absolute_error: 0.3695 - 124ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.0185 - mean_absolute_error: 0.0676 - val_loss: 0.3494 - val_mean_absolute_error: 0.3690 - 126ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.0136 - mean_absolute_error: 0.0563 - val_loss: 0.3512 - val_mean_absolute_error: 0.3661 - 124ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0554 - val_loss: 0.3458 - val_mean_absolute_error: 0.3641 - 124ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.0135 - mean_absolute_error: 0.0541 - val_loss: 0.3463 - val_mean_absolute_error: 0.3656 - 123ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.0157 - mean_absolute_error: 0.0578 - val_loss: 0.3781 - val_mean_absolute_error: 0.3841 - 124ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.0181 - mean_absolute_error: 0.0683 - val_loss: 0.3378 - val_mean_absolute_error: 0.3639 - 125ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.0150 - mean_absolute_error: 0.0582 - val_loss: 0.3528 - val_mean_absolute_error: 0.3696 - 125ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.0165 - mean_absolute_error: 0.0638 - val_loss: 0.3467 - val_mean_absolute_error: 0.3669 - 124ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.0163 - mean_absolute_error: 0.0649 - val_loss: 0.3508 - val_mean_absolute_error: 0.3704 - 125ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.0231 - mean_absolute_error: 0.0763 - val_loss: 0.3507 - val_mean_absolute_error: 0.3722 - 124ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.0178 - mean_absolute_error: 0.0706 - val_loss: 0.3464 - val_mean_absolute_error: 0.3650 - 124ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0552 - val_loss: 0.3572 - val_mean_absolute_error: 0.3712 - 124ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.0179 - mean_absolute_error: 0.0633 - val_loss: 0.3468 - val_mean_absolute_error: 0.3661 - 125ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.0164 - mean_absolute_error: 0.0619 - val_loss: 0.3531 - val_mean_absolute_error: 0.3714 - 129ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.0136 - mean_absolute_error: 0.0566 - val_loss: 0.3510 - val_mean_absolute_error: 0.3679 - 124ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.0212 - mean_absolute_error: 0.0721 - val_loss: 0.3464 - val_mean_absolute_error: 0.3685 - 123ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.0154 - mean_absolute_error: 0.0639 - val_loss: 0.3516 - val_mean_absolute_error: 0.3683 - 124ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.0135 - mean_absolute_error: 0.0555 - val_loss: 0.3481 - val_mean_absolute_error: 0.3698 - 123ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.0187 - mean_absolute_error: 0.0655 - val_loss: 0.3560 - val_mean_absolute_error: 0.3766 - 123ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.0338 - mean_absolute_error: 0.1032 - val_loss: 0.3502 - val_mean_absolute_error: 0.3692 - 123ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.0152 - mean_absolute_error: 0.0665 - val_loss: 0.3519 - val_mean_absolute_error: 0.3689 - 124ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.0153 - mean_absolute_error: 0.0598 - val_loss: 0.3542 - val_mean_absolute_error: 0.3742 - 125ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.0225 - mean_absolute_error: 0.0781 - val_loss: 0.3388 - val_mean_absolute_error: 0.3663 - 124ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.0139 - mean_absolute_error: 0.0591 - val_loss: 0.3586 - val_mean_absolute_error: 0.3709 - 124ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.0257 - mean_absolute_error: 0.0767 - val_loss: 0.3618 - val_mean_absolute_error: 0.3778 - 124ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.0217 - mean_absolute_error: 0.0785 - val_loss: 0.3504 - val_mean_absolute_error: 0.3685 - 125ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.0165 - mean_absolute_error: 0.0624 - val_loss: 0.3522 - val_mean_absolute_error: 0.3704 - 124ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0543 - val_loss: 0.3483 - val_mean_absolute_error: 0.3666 - 125ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0545 - val_loss: 0.3476 - val_mean_absolute_error: 0.3681 - 125ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.0137 - mean_absolute_error: 0.0565 - val_loss: 0.3475 - val_mean_absolute_error: 0.3666 - 128ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.0124 - mean_absolute_error: 0.0489 - val_loss: 0.3490 - val_mean_absolute_error: 0.3686 - 124ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.0136 - mean_absolute_error: 0.0542 - val_loss: 0.3508 - val_mean_absolute_error: 0.3673 - 124ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0543 - val_loss: 0.3495 - val_mean_absolute_error: 0.3678 - 125ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.0170 - mean_absolute_error: 0.0586 - val_loss: 0.3636 - val_mean_absolute_error: 0.3732 - 124ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.0204 - mean_absolute_error: 0.0702 - val_loss: 0.3537 - val_mean_absolute_error: 0.3712 - 125ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.0145 - mean_absolute_error: 0.0599 - val_loss: 0.3546 - val_mean_absolute_error: 0.3683 - 126ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.0197 - mean_absolute_error: 0.0665 - val_loss: 0.3512 - val_mean_absolute_error: 0.3736 - 124ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.0207 - mean_absolute_error: 0.0753 - val_loss: 0.3573 - val_mean_absolute_error: 0.3729 - 126ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.0119 - mean_absolute_error: 0.0562 - val_loss: 0.3467 - val_mean_absolute_error: 0.3669 - 125ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.0155 - mean_absolute_error: 0.0593 - val_loss: 0.3522 - val_mean_absolute_error: 0.3693 - 124ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.0141 - mean_absolute_error: 0.0554 - val_loss: 0.3521 - val_mean_absolute_error: 0.3705 - 125ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0531 - val_loss: 0.3596 - val_mean_absolute_error: 0.3774 - 125ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.0263 - mean_absolute_error: 0.0857 - val_loss: 0.3450 - val_mean_absolute_error: 0.3702 - 124ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.0215 - mean_absolute_error: 0.0757 - val_loss: 0.3384 - val_mean_absolute_error: 0.3647 - 123ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.0137 - mean_absolute_error: 0.0586 - val_loss: 0.3413 - val_mean_absolute_error: 0.3651 - 128ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.0146 - mean_absolute_error: 0.0573 - val_loss: 0.3527 - val_mean_absolute_error: 0.3693 - 125ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.0126 - mean_absolute_error: 0.0556 - val_loss: 0.3435 - val_mean_absolute_error: 0.3647 - 127ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.0181 - mean_absolute_error: 0.0604 - val_loss: 0.3600 - val_mean_absolute_error: 0.3788 - 124ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.0165 - mean_absolute_error: 0.0681 - val_loss: 0.3563 - val_mean_absolute_error: 0.3709 - 125ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.0147 - mean_absolute_error: 0.0607 - val_loss: 0.3440 - val_mean_absolute_error: 0.3677 - 124ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.0141 - mean_absolute_error: 0.0545 - val_loss: 0.3454 - val_mean_absolute_error: 0.3654 - 124ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0575 - val_loss: 0.3506 - val_mean_absolute_error: 0.3683 - 123ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.0149 - mean_absolute_error: 0.0581 - val_loss: 0.3407 - val_mean_absolute_error: 0.3666 - 125ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.0186 - mean_absolute_error: 0.0646 - val_loss: 0.3586 - val_mean_absolute_error: 0.3745 - 124ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.0172 - mean_absolute_error: 0.0663 - val_loss: 0.3561 - val_mean_absolute_error: 0.3709 - 124ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.0149 - mean_absolute_error: 0.0564 - val_loss: 0.3479 - val_mean_absolute_error: 0.3672 - 123ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.0163 - mean_absolute_error: 0.0613 - val_loss: 0.3495 - val_mean_absolute_error: 0.3684 - 124ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0568 - val_loss: 0.3391 - val_mean_absolute_error: 0.3645 - 125ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.0261 - mean_absolute_error: 0.0825 - val_loss: 0.3545 - val_mean_absolute_error: 0.3778 - 125ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.0161 - mean_absolute_error: 0.0673 - val_loss: 0.3467 - val_mean_absolute_error: 0.3685 - 128ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.0173 - mean_absolute_error: 0.0652 - val_loss: 0.3448 - val_mean_absolute_error: 0.3665 - 125ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.0157 - mean_absolute_error: 0.0624 - val_loss: 0.3540 - val_mean_absolute_error: 0.3696 - 126ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.0123 - mean_absolute_error: 0.0525 - val_loss: 0.3448 - val_mean_absolute_error: 0.3681 - 124ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.0162 - mean_absolute_error: 0.0607 - val_loss: 0.3496 - val_mean_absolute_error: 0.3694 - 124ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0563 - val_loss: 0.3567 - val_mean_absolute_error: 0.3725 - 126ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.0179 - mean_absolute_error: 0.0679 - val_loss: 0.3445 - val_mean_absolute_error: 0.3647 - 125ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.0163 - mean_absolute_error: 0.0628 - val_loss: 0.3485 - val_mean_absolute_error: 0.3708 - 124ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.0220 - mean_absolute_error: 0.0754 - val_loss: 0.3483 - val_mean_absolute_error: 0.3671 - 123ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.0181 - mean_absolute_error: 0.0701 - val_loss: 0.3442 - val_mean_absolute_error: 0.3651 - 135ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.0144 - mean_absolute_error: 0.0586 - val_loss: 0.3505 - val_mean_absolute_error: 0.3705 - 132ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.0178 - mean_absolute_error: 0.0597 - val_loss: 0.3476 - val_mean_absolute_error: 0.3702 - 124ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.0166 - mean_absolute_error: 0.0612 - val_loss: 0.3450 - val_mean_absolute_error: 0.3679 - 124ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.0160 - mean_absolute_error: 0.0621 - val_loss: 0.3526 - val_mean_absolute_error: 0.3691 - 125ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.0143 - mean_absolute_error: 0.0565 - val_loss: 0.3634 - val_mean_absolute_error: 0.3744 - 124ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.0171 - mean_absolute_error: 0.0643 - val_loss: 0.3576 - val_mean_absolute_error: 0.3729 - 128ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.0122 - mean_absolute_error: 0.0534 - val_loss: 0.3458 - val_mean_absolute_error: 0.3659 - 124ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.0150 - mean_absolute_error: 0.0559 - val_loss: 0.3527 - val_mean_absolute_error: 0.3727 - 124ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.0197 - mean_absolute_error: 0.0715 - val_loss: 0.3527 - val_mean_absolute_error: 0.3728 - 124ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.0192 - mean_absolute_error: 0.0715 - val_loss: 0.3492 - val_mean_absolute_error: 0.3679 - 122ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.0139 - mean_absolute_error: 0.0561 - val_loss: 0.3594 - val_mean_absolute_error: 0.3753 - 124ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.0195 - mean_absolute_error: 0.0646 - val_loss: 0.3455 - val_mean_absolute_error: 0.3702 - 125ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.0174 - mean_absolute_error: 0.0673 - val_loss: 0.3481 - val_mean_absolute_error: 0.3661 - 124ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.0136 - mean_absolute_error: 0.0579 - val_loss: 0.3467 - val_mean_absolute_error: 0.3649 - 123ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.0159 - mean_absolute_error: 0.0601 - val_loss: 0.3448 - val_mean_absolute_error: 0.3641 - 123ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.0132 - mean_absolute_error: 0.0519 - val_loss: 0.3519 - val_mean_absolute_error: 0.3693 - 124ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0541 - val_loss: 0.3480 - val_mean_absolute_error: 0.3673 - 125ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.0195 - mean_absolute_error: 0.0679 - val_loss: 0.3612 - val_mean_absolute_error: 0.3783 - 129ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.0177 - mean_absolute_error: 0.0706 - val_loss: 0.3490 - val_mean_absolute_error: 0.3669 - 127ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0556 - val_loss: 0.3436 - val_mean_absolute_error: 0.3655 - 133ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.0180 - mean_absolute_error: 0.0636 - val_loss: 0.3509 - val_mean_absolute_error: 0.3714 - 131ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0626 - val_loss: 0.3543 - val_mean_absolute_error: 0.3705 - 125ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0533 - val_loss: 0.3430 - val_mean_absolute_error: 0.3642 - 124ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.0115 - mean_absolute_error: 0.0487 - val_loss: 0.3513 - val_mean_absolute_error: 0.3684 - 125ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.0140 - mean_absolute_error: 0.0557 - val_loss: 0.3486 - val_mean_absolute_error: 0.3649 - 125ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.0120 - mean_absolute_error: 0.0507 - val_loss: 0.3524 - val_mean_absolute_error: 0.3671 - 126ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.0127 - mean_absolute_error: 0.0512 - val_loss: 0.3426 - val_mean_absolute_error: 0.3640 - 125ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0539 - val_loss: 0.3541 - val_mean_absolute_error: 0.3699 - 126ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.0130 - mean_absolute_error: 0.0509 - val_loss: 0.3469 - val_mean_absolute_error: 0.3678 - 125ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.0208 - mean_absolute_error: 0.0746 - val_loss: 0.3593 - val_mean_absolute_error: 0.3704 - 125ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_Noise_five(DeltaE-1.02_50%).keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE: 0.3593009412288666
# MAE: 0.3704161047935486
# 32/32 [==============================] - 0s 766us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# ##### Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\kappa$', r'$\gamma$', r'$g$']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(3,1, figsize=(8,15))
fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ##### Curvas Validación VS Predicción
#
# Si jugamos con la función, llegamos a:
#
# $$
# t(\omega)=\frac{-\kappa\left[(\Delta E-\omega)-i\gamma\right]}{\left[(\Omega-\omega)(\Delta E-\omega)-\kappa\gamma-g^2\right]-i\left[(\Omega-\omega)\gamma+(\Delta E-\omega)\kappa\right]}
# $$
#
# Sacamos los polos de la parte real del denominador, obteniendo:
# $$
# \omega_1=\frac{(\Delta E+\Omega)+\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# $$
# \omega_2=\frac{(\Delta E+\Omega)-\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# Si queremos el valor de g:
# $$g=\frac{\sqrt{|\omega_1-\omega_2|^2-(\Omega-\Delta E)^2-4\kappa\gamma}}{2}$$
#
# Ahora, junto a las curvas, dibujaremos líneas verticales correspondientes a esos polos y escribimnos el valor de la resta de sus valores

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
k_pred = y_pred_denorm[:, 0]
k_val = y_val_denorm[:, 0]
gamma_pred = y_pred_denorm[:, 1]
gamma_val = y_val_denorm[:, 1]
g_pred = y_pred_denorm[:, 2]
g_val = y_val_denorm[:, 2]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val_noise = t_values_noise[indices_val]
t_values_val = t_values[indices_val]

for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k_pred[i], Omega, DeltaE, gamma_pred[i], g_pred[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k_val, Omega, DeltaE, gamma_val, g_val)
w2=w_2(k_val, Omega, DeltaE, gamma_val, g_val)

i = 300
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_val_noise[i, :], color="g", label="Curva con ruido")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"κ real = {k_val[i]:.7f}, κ pred = {k_pred[i]:.7f}\n"\
           f"γ real = {gamma_val[i]:.7f}, γ pred = {gamma_pred[i]:.7f}\n"\
           f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [12, 7], 
    "figure.dpi": 300 
})

# %% [markdown]
# #### Define t($\omega$):
# $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    up = -k
    down = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = up / down
    return np.abs(t)

# %% [markdown]
# Si jugamos con la función, llegamos a:
#
# $$
# t(\omega)=\frac{-\kappa\left[(\Delta E-\omega)-i\gamma\right]}{\left[(\Omega-\omega)(\Delta E-\omega)-\kappa\gamma-g^2\right]-i\left[(\Omega-\omega)\gamma+(\Delta E-\omega)\kappa\right]}
# $$
#
# Sacamos los polos de la parte real del denominador, obteniendo:
# $$
# \omega_\pm=\frac{(\Delta E+\Omega)\pm\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
#
# En acoplo fuerte $(\frac{g^2}{\gamma}\gg 1)$, luego:
# $$
# \omega_\pm=\frac{(\Delta E+\Omega)}{2}\pm\sqrt{\left(\frac{\Delta E-\Omega}{2}\right)^2+g^2}
# $$
#
# Junto a las curvas, dibujaremos líneas verticales correspondientes a esos polos.
#
# En resonancia $(\Delta E=\Omega)$, tenemos dos modos, $$\omega_\pm=\Omega\pm g$$

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %% [markdown]
#  # NO noise

# %% [markdown]
# ## Creamos base de datos

# %%
# Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)

    return k, DeltaE, gamma, g

num_datos = 10000

# %%
# #Creamos base de datos y guardamos en .txt
# k, DeltaE, gamma, g = Parameters_generator (num_datos)
# np.savetxt('Parameters_noNoise.txt', np.column_stack((k, DeltaE, gamma, g)),
#             header='\u03BA \u0394E \u213D g', encoding='utf8')

# %%
datos = np.loadtxt('Parameters_noNoise.txt', skiprows=1)
k = datos[:,0]
DeltaE = datos[:,1]
gamma = datos[:,2]
g = datos[:,3]
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.85, 1.15, 300)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))

w1 = w2 = np.zeros(num_datos)
w1=w_1(k, Omega, DeltaE, gamma, g)
w2=w_2(k, Omega, DeltaE, gamma, g)

# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k[i], Omega, DeltaE[i], gamma[i], g[i])

# %% [markdown]
# ### Dibujamos las curvas

# %%
# i=0
# while i<=1000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values[i,:], label='Curva original')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$")
#     plt.ylabel(r"t ($\omega$)")
#     #plt.legend()
#     # plt.ylim(0) 
#     # plt.xlim(0.85, 1.15) 

#     # # Calcula los valores de t(w) en w1 y w2
#     # t_w1 = t_w(w1[i], k[i], Omega, DeltaE[i], gamma[i], g[i])
#     # t_w2 = t_w(w2[i], k[i], Omega, DeltaE[i], gamma[i], g[i])

#     # if w_values.min() <= w1[i] <= w_values.max():
#     #     plt.vlines(w1[i], 0, t_w1, colors='black', linewidth=0.5)
#     # if w_values.min() <= w2[i] <= w_values.max():
#     #     plt.vlines(w2[i], 0, t_w2, colors='black', linewidth=0.5)
    
#     plt.draw()  # Dibuja la figura actual

#     # Muestra los valores como un recuadro dentro de la gráfica
#     text = f"$\kappa$ = {k[i]:.2e}\n"\
#            f"$\Delta$E real = {DeltaE[i]:.3f}\n"\
#            f"$\gamma$ real = {gamma[i]:.2e}\n"\
#            f"g real = {g[i]:.2e}"
#     plt.text(0.011, 0.3, text, transform=plt.gca().transAxes, fontsize=16, verticalalignment='top', 
#              bbox=dict(facecolor='white', alpha=1))

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'):
#         break
#     elif keyboard.is_pressed('right'):
#         i += 1
#         if i >= num_datos:
#             i = num_datos - 1  # Asegura que no exceda el índice máximo
#     elif keyboard.is_pressed('left'):
#         i -= 1
#         if i < 0:
#             i = 0  # Asegura que no baje del índice mínimo

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
x_train, x_post, y_train, y_post = train_test_split(t_values, datos, test_size=0.2, random_state=18)
x_val, x_test, y_val, y_test = train_test_split(x_post, y_post, test_size=0.5, random_state=18)

# Normalizamos los datos
scaler_x = RobustScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)
x_test_norm = scaler_x.transform(x_test)

scaler_y = RobustScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)
y_test_norm = scaler_y.transform(y_test)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'validation samples')
print(x_test.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 250
epochs = 1000
optimizer = Adam()
# Out:
# 8000 train samples
# 1000 validation samples
# 1000 test samples
# x_train shape (8000, 300)
# y_train shape (8000, 4)

# %% [markdown]
# #### Definimos modelo

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm , y_train_norm , batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_noNoise.keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 32/32 - 2s - 56ms/step - loss: 0.3106 - mean_absolute_error: 0.4593 - val_loss: 0.2958 - val_mean_absolute_error: 0.4433
# Epoch 2/1000
# 32/32 - 0s - 4ms/step - loss: 0.2886 - mean_absolute_error: 0.4391 - val_loss: 0.2841 - val_mean_absolute_error: 0.4343
# Epoch 3/1000
# 32/32 - 0s - 3ms/step - loss: 0.2799 - mean_absolute_error: 0.4293 - val_loss: 0.2768 - val_mean_absolute_error: 0.4274
# Epoch 4/1000
# 32/32 - 0s - 3ms/step - loss: 0.2717 - mean_absolute_error: 0.4208 - val_loss: 0.2734 - val_mean_absolute_error: 0.4180
# Epoch 5/1000
# 32/32 - 0s - 3ms/step - loss: 0.2694 - mean_absolute_error: 0.4180 - val_loss: 0.2610 - val_mean_absolute_error: 0.4094
# Epoch 6/1000
# 32/32 - 0s - 3ms/step - loss: 0.2581 - mean_absolute_error: 0.4097 - val_loss: 0.2509 - val_mean_absolute_error: 0.4009
# Epoch 7/1000
# 32/32 - 0s - 3ms/step - loss: 0.2486 - mean_absolute_error: 0.4002 - val_loss: 0.2451 - val_mean_absolute_error: 0.3978
# Epoch 8/1000
# 32/32 - 0s - 3ms/step - loss: 0.2412 - mean_absolute_error: 0.3913 - val_loss: 0.2422 - val_mean_absolute_error: 0.3913
# Epoch 9/1000
# 32/32 - 0s - 3ms/step - loss: 0.2361 - mean_absolute_error: 0.3864 - val_loss: 0.2319 - val_mean_absolute_error: 0.3835
# Epoch 10/1000
# 32/32 - 0s - 3ms/step - loss: 0.2285 - mean_absolute_error: 0.3805 - val_loss: 0.2416 - val_mean_absolute_error: 0.3884
# Epoch 11/1000
# 32/32 - 0s - 3ms/step - loss: 0.2235 - mean_absolute_error: 0.3722 - val_loss: 0.2301 - val_mean_absolute_error: 0.3786
# Epoch 12/1000
# 32/32 - 0s - 3ms/step - loss: 0.2159 - mean_absolute_error: 0.3627 - val_loss: 0.2214 - val_mean_absolute_error: 0.3618
# Epoch 13/1000
# 32/32 - 0s - 3ms/step - loss: 0.2114 - mean_absolute_error: 0.3581 - val_loss: 0.2091 - val_mean_absolute_error: 0.3601
# Epoch 14/1000
# 32/32 - 0s - 3ms/step - loss: 0.2014 - mean_absolute_error: 0.3482 - val_loss: 0.2084 - val_mean_absolute_error: 0.3539
# Epoch 15/1000
# 32/32 - 0s - 3ms/step - loss: 0.2009 - mean_absolute_error: 0.3464 - val_loss: 0.2108 - val_mean_absolute_error: 0.3496
# Epoch 16/1000
# 32/32 - 0s - 3ms/step - loss: 0.1839 - mean_absolute_error: 0.3286 - val_loss: 0.1987 - val_mean_absolute_error: 0.3365
# Epoch 17/1000
# 32/32 - 0s - 3ms/step - loss: 0.1813 - mean_absolute_error: 0.3232 - val_loss: 0.1746 - val_mean_absolute_error: 0.3164
# Epoch 18/1000
# 32/32 - 0s - 3ms/step - loss: 0.1716 - mean_absolute_error: 0.3124 - val_loss: 0.1700 - val_mean_absolute_error: 0.3084
# Epoch 19/1000
# 32/32 - 0s - 3ms/step - loss: 0.1694 - mean_absolute_error: 0.3077 - val_loss: 0.1820 - val_mean_absolute_error: 0.3182
# Epoch 20/1000
# 32/32 - 0s - 3ms/step - loss: 0.1664 - mean_absolute_error: 0.3038 - val_loss: 0.1571 - val_mean_absolute_error: 0.2960
# Epoch 21/1000
# 32/32 - 0s - 3ms/step - loss: 0.1576 - mean_absolute_error: 0.2950 - val_loss: 0.1594 - val_mean_absolute_error: 0.2969
# Epoch 22/1000
# 32/32 - 0s - 3ms/step - loss: 0.1575 - mean_absolute_error: 0.2932 - val_loss: 0.1528 - val_mean_absolute_error: 0.2890
# Epoch 23/1000
# 32/32 - 0s - 3ms/step - loss: 0.1483 - mean_absolute_error: 0.2833 - val_loss: 0.1448 - val_mean_absolute_error: 0.2815
# Epoch 24/1000
# 32/32 - 0s - 3ms/step - loss: 0.1573 - mean_absolute_error: 0.2913 - val_loss: 0.1481 - val_mean_absolute_error: 0.2842
# Epoch 25/1000
# 32/32 - 0s - 3ms/step - loss: 0.1497 - mean_absolute_error: 0.2827 - val_loss: 0.1563 - val_mean_absolute_error: 0.2875
# Epoch 26/1000
# 32/32 - 0s - 3ms/step - loss: 0.1508 - mean_absolute_error: 0.2825 - val_loss: 0.1533 - val_mean_absolute_error: 0.2847
# Epoch 27/1000
# 32/32 - 0s - 3ms/step - loss: 0.1458 - mean_absolute_error: 0.2778 - val_loss: 0.1413 - val_mean_absolute_error: 0.2735
# Epoch 28/1000
# 32/32 - 0s - 3ms/step - loss: 0.1410 - mean_absolute_error: 0.2710 - val_loss: 0.1403 - val_mean_absolute_error: 0.2696
# Epoch 29/1000
# 32/32 - 0s - 3ms/step - loss: 0.1447 - mean_absolute_error: 0.2736 - val_loss: 0.1399 - val_mean_absolute_error: 0.2699
# Epoch 30/1000
# 32/32 - 0s - 3ms/step - loss: 0.1400 - mean_absolute_error: 0.2679 - val_loss: 0.1394 - val_mean_absolute_error: 0.2701
# Epoch 31/1000
# 32/32 - 0s - 3ms/step - loss: 0.1388 - mean_absolute_error: 0.2673 - val_loss: 0.1474 - val_mean_absolute_error: 0.2744
# Epoch 32/1000
# 32/32 - 0s - 3ms/step - loss: 0.1485 - mean_absolute_error: 0.2762 - val_loss: 0.1361 - val_mean_absolute_error: 0.2671
# Epoch 33/1000
# 32/32 - 0s - 3ms/step - loss: 0.1365 - mean_absolute_error: 0.2641 - val_loss: 0.1375 - val_mean_absolute_error: 0.2637
# Epoch 34/1000
# 32/32 - 0s - 3ms/step - loss: 0.1356 - mean_absolute_error: 0.2626 - val_loss: 0.1328 - val_mean_absolute_error: 0.2589
# Epoch 35/1000
# 32/32 - 0s - 3ms/step - loss: 0.1437 - mean_absolute_error: 0.2692 - val_loss: 0.1409 - val_mean_absolute_error: 0.2669
# Epoch 36/1000
# 32/32 - 0s - 3ms/step - loss: 0.1356 - mean_absolute_error: 0.2617 - val_loss: 0.1588 - val_mean_absolute_error: 0.2806
# Epoch 37/1000
# 32/32 - 0s - 3ms/step - loss: 0.1389 - mean_absolute_error: 0.2650 - val_loss: 0.1493 - val_mean_absolute_error: 0.2742
# Epoch 38/1000
# 32/32 - 0s - 3ms/step - loss: 0.1371 - mean_absolute_error: 0.2644 - val_loss: 0.1389 - val_mean_absolute_error: 0.2670
# Epoch 39/1000
# 32/32 - 0s - 3ms/step - loss: 0.1348 - mean_absolute_error: 0.2603 - val_loss: 0.1347 - val_mean_absolute_error: 0.2593
# Epoch 40/1000
# 32/32 - 0s - 3ms/step - loss: 0.1378 - mean_absolute_error: 0.2628 - val_loss: 0.1582 - val_mean_absolute_error: 0.2792
# Epoch 41/1000
# 32/32 - 0s - 3ms/step - loss: 0.1365 - mean_absolute_error: 0.2628 - val_loss: 0.1456 - val_mean_absolute_error: 0.2673
# Epoch 42/1000
# 32/32 - 0s - 3ms/step - loss: 0.1326 - mean_absolute_error: 0.2557 - val_loss: 0.1343 - val_mean_absolute_error: 0.2590
# Epoch 43/1000
# 32/32 - 0s - 3ms/step - loss: 0.1296 - mean_absolute_error: 0.2525 - val_loss: 0.1279 - val_mean_absolute_error: 0.2513
# Epoch 44/1000
# 32/32 - 0s - 3ms/step - loss: 0.1314 - mean_absolute_error: 0.2531 - val_loss: 0.1277 - val_mean_absolute_error: 0.2498
# Epoch 45/1000
# 32/32 - 0s - 3ms/step - loss: 0.1305 - mean_absolute_error: 0.2528 - val_loss: 0.1345 - val_mean_absolute_error: 0.2561
# Epoch 46/1000
# 32/32 - 0s - 3ms/step - loss: 0.1397 - mean_absolute_error: 0.2642 - val_loss: 0.1303 - val_mean_absolute_error: 0.2596
# Epoch 47/1000
# 32/32 - 0s - 3ms/step - loss: 0.1339 - mean_absolute_error: 0.2583 - val_loss: 0.1304 - val_mean_absolute_error: 0.2571
# Epoch 48/1000
# 32/32 - 0s - 3ms/step - loss: 0.1307 - mean_absolute_error: 0.2539 - val_loss: 0.1315 - val_mean_absolute_error: 0.2535
# Epoch 49/1000
# 32/32 - 0s - 3ms/step - loss: 0.1302 - mean_absolute_error: 0.2526 - val_loss: 0.1249 - val_mean_absolute_error: 0.2511
# Epoch 50/1000
# 32/32 - 0s - 3ms/step - loss: 0.1243 - mean_absolute_error: 0.2460 - val_loss: 0.1267 - val_mean_absolute_error: 0.2474
# Epoch 51/1000
# 32/32 - 0s - 3ms/step - loss: 0.1298 - mean_absolute_error: 0.2507 - val_loss: 0.1260 - val_mean_absolute_error: 0.2494
# Epoch 52/1000
# 32/32 - 0s - 3ms/step - loss: 0.1257 - mean_absolute_error: 0.2470 - val_loss: 0.1398 - val_mean_absolute_error: 0.2645
# Epoch 53/1000
# 32/32 - 0s - 3ms/step - loss: 0.1273 - mean_absolute_error: 0.2518 - val_loss: 0.1341 - val_mean_absolute_error: 0.2541
# Epoch 54/1000
# 32/32 - 0s - 3ms/step - loss: 0.1259 - mean_absolute_error: 0.2478 - val_loss: 0.1271 - val_mean_absolute_error: 0.2520
# Epoch 55/1000
# 32/32 - 0s - 3ms/step - loss: 0.1231 - mean_absolute_error: 0.2455 - val_loss: 0.1284 - val_mean_absolute_error: 0.2497
# Epoch 56/1000
# 32/32 - 0s - 3ms/step - loss: 0.1250 - mean_absolute_error: 0.2466 - val_loss: 0.1220 - val_mean_absolute_error: 0.2460
# Epoch 57/1000
# 32/32 - 0s - 3ms/step - loss: 0.1233 - mean_absolute_error: 0.2449 - val_loss: 0.1221 - val_mean_absolute_error: 0.2426
# Epoch 58/1000
# 32/32 - 0s - 3ms/step - loss: 0.1201 - mean_absolute_error: 0.2405 - val_loss: 0.1166 - val_mean_absolute_error: 0.2376
# Epoch 59/1000
# 32/32 - 0s - 3ms/step - loss: 0.1221 - mean_absolute_error: 0.2447 - val_loss: 0.1205 - val_mean_absolute_error: 0.2447
# Epoch 60/1000
# 32/32 - 0s - 3ms/step - loss: 0.1275 - mean_absolute_error: 0.2499 - val_loss: 0.1202 - val_mean_absolute_error: 0.2445
# Epoch 61/1000
# 32/32 - 0s - 3ms/step - loss: 0.1200 - mean_absolute_error: 0.2421 - val_loss: 0.1262 - val_mean_absolute_error: 0.2475
# Epoch 62/1000
# 32/32 - 0s - 3ms/step - loss: 0.1178 - mean_absolute_error: 0.2407 - val_loss: 0.1175 - val_mean_absolute_error: 0.2383
# Epoch 63/1000
# 32/32 - 0s - 3ms/step - loss: 0.1253 - mean_absolute_error: 0.2450 - val_loss: 0.1202 - val_mean_absolute_error: 0.2433
# Epoch 64/1000
# 32/32 - 0s - 3ms/step - loss: 0.1184 - mean_absolute_error: 0.2408 - val_loss: 0.1156 - val_mean_absolute_error: 0.2343
# Epoch 65/1000
# 32/32 - 0s - 3ms/step - loss: 0.1174 - mean_absolute_error: 0.2372 - val_loss: 0.1161 - val_mean_absolute_error: 0.2392
# Epoch 66/1000
# 32/32 - 0s - 3ms/step - loss: 0.1140 - mean_absolute_error: 0.2342 - val_loss: 0.1159 - val_mean_absolute_error: 0.2323
# Epoch 67/1000
# 32/32 - 0s - 3ms/step - loss: 0.1224 - mean_absolute_error: 0.2420 - val_loss: 0.1188 - val_mean_absolute_error: 0.2401
# Epoch 68/1000
# 32/32 - 0s - 3ms/step - loss: 0.1162 - mean_absolute_error: 0.2368 - val_loss: 0.1201 - val_mean_absolute_error: 0.2396
# Epoch 69/1000
# 32/32 - 0s - 3ms/step - loss: 0.1143 - mean_absolute_error: 0.2345 - val_loss: 0.1136 - val_mean_absolute_error: 0.2318
# Epoch 70/1000
# 32/32 - 0s - 3ms/step - loss: 0.1180 - mean_absolute_error: 0.2375 - val_loss: 0.1327 - val_mean_absolute_error: 0.2569
# Epoch 71/1000
# 32/32 - 0s - 3ms/step - loss: 0.1191 - mean_absolute_error: 0.2408 - val_loss: 0.1202 - val_mean_absolute_error: 0.2377
# Epoch 72/1000
# 32/32 - 0s - 3ms/step - loss: 0.1117 - mean_absolute_error: 0.2335 - val_loss: 0.1164 - val_mean_absolute_error: 0.2322
# Epoch 73/1000
# 32/32 - 0s - 3ms/step - loss: 0.1154 - mean_absolute_error: 0.2345 - val_loss: 0.1130 - val_mean_absolute_error: 0.2324
# Epoch 74/1000
# 32/32 - 0s - 3ms/step - loss: 0.1098 - mean_absolute_error: 0.2290 - val_loss: 0.1119 - val_mean_absolute_error: 0.2302
# Epoch 75/1000
# 32/32 - 0s - 3ms/step - loss: 0.1146 - mean_absolute_error: 0.2332 - val_loss: 0.1080 - val_mean_absolute_error: 0.2287
# Epoch 76/1000
# 32/32 - 0s - 3ms/step - loss: 0.1120 - mean_absolute_error: 0.2299 - val_loss: 0.1173 - val_mean_absolute_error: 0.2369
# Epoch 77/1000
# 32/32 - 0s - 3ms/step - loss: 0.1171 - mean_absolute_error: 0.2356 - val_loss: 0.1089 - val_mean_absolute_error: 0.2318
# Epoch 78/1000
# 32/32 - 0s - 3ms/step - loss: 0.1209 - mean_absolute_error: 0.2402 - val_loss: 0.1144 - val_mean_absolute_error: 0.2357
# Epoch 79/1000
# 32/32 - 0s - 3ms/step - loss: 0.1114 - mean_absolute_error: 0.2290 - val_loss: 0.1057 - val_mean_absolute_error: 0.2225
# Epoch 80/1000
# 32/32 - 0s - 3ms/step - loss: 0.1102 - mean_absolute_error: 0.2279 - val_loss: 0.1168 - val_mean_absolute_error: 0.2365
# Epoch 81/1000
# 32/32 - 0s - 3ms/step - loss: 0.1072 - mean_absolute_error: 0.2249 - val_loss: 0.1042 - val_mean_absolute_error: 0.2212
# Epoch 82/1000
# 32/32 - 0s - 3ms/step - loss: 0.1052 - mean_absolute_error: 0.2212 - val_loss: 0.1071 - val_mean_absolute_error: 0.2223
# Epoch 83/1000
# 32/32 - 0s - 3ms/step - loss: 0.1106 - mean_absolute_error: 0.2274 - val_loss: 0.1193 - val_mean_absolute_error: 0.2352
# Epoch 84/1000
# 32/32 - 0s - 3ms/step - loss: 0.1150 - mean_absolute_error: 0.2318 - val_loss: 0.1218 - val_mean_absolute_error: 0.2377
# Epoch 85/1000
# 32/32 - 0s - 3ms/step - loss: 0.1108 - mean_absolute_error: 0.2282 - val_loss: 0.1092 - val_mean_absolute_error: 0.2257
# Epoch 86/1000
# 32/32 - 0s - 3ms/step - loss: 0.1038 - mean_absolute_error: 0.2201 - val_loss: 0.1085 - val_mean_absolute_error: 0.2237
# Epoch 87/1000
# 32/32 - 0s - 3ms/step - loss: 0.1036 - mean_absolute_error: 0.2187 - val_loss: 0.1220 - val_mean_absolute_error: 0.2334
# Epoch 88/1000
# 32/32 - 0s - 3ms/step - loss: 0.1163 - mean_absolute_error: 0.2335 - val_loss: 0.1150 - val_mean_absolute_error: 0.2363
# Epoch 89/1000
# 32/32 - 0s - 3ms/step - loss: 0.1110 - mean_absolute_error: 0.2287 - val_loss: 0.1069 - val_mean_absolute_error: 0.2204
# Epoch 90/1000
# 32/32 - 0s - 3ms/step - loss: 0.1055 - mean_absolute_error: 0.2233 - val_loss: 0.1028 - val_mean_absolute_error: 0.2190
# Epoch 91/1000
# 32/32 - 0s - 3ms/step - loss: 0.1044 - mean_absolute_error: 0.2191 - val_loss: 0.1021 - val_mean_absolute_error: 0.2182
# Epoch 92/1000
# 32/32 - 0s - 3ms/step - loss: 0.1101 - mean_absolute_error: 0.2257 - val_loss: 0.1171 - val_mean_absolute_error: 0.2360
# Epoch 93/1000
# 32/32 - 0s - 3ms/step - loss: 0.1084 - mean_absolute_error: 0.2245 - val_loss: 0.1036 - val_mean_absolute_error: 0.2200
# Epoch 94/1000
# 32/32 - 0s - 3ms/step - loss: 0.1028 - mean_absolute_error: 0.2175 - val_loss: 0.1043 - val_mean_absolute_error: 0.2180
# Epoch 95/1000
# 32/32 - 0s - 3ms/step - loss: 0.1018 - mean_absolute_error: 0.2151 - val_loss: 0.1048 - val_mean_absolute_error: 0.2188
# Epoch 96/1000
# 32/32 - 0s - 3ms/step - loss: 0.0990 - mean_absolute_error: 0.2130 - val_loss: 0.0972 - val_mean_absolute_error: 0.2094
# Epoch 97/1000
# 32/32 - 0s - 3ms/step - loss: 0.1110 - mean_absolute_error: 0.2249 - val_loss: 0.1337 - val_mean_absolute_error: 0.2533
# Epoch 98/1000
# 32/32 - 0s - 3ms/step - loss: 0.1089 - mean_absolute_error: 0.2264 - val_loss: 0.1076 - val_mean_absolute_error: 0.2225
# Epoch 99/1000
# 32/32 - 0s - 3ms/step - loss: 0.1110 - mean_absolute_error: 0.2257 - val_loss: 0.1035 - val_mean_absolute_error: 0.2178
# Epoch 100/1000
# 32/32 - 0s - 4ms/step - loss: 0.1021 - mean_absolute_error: 0.2167 - val_loss: 0.1011 - val_mean_absolute_error: 0.2159
# Epoch 101/1000
# 32/32 - 0s - 3ms/step - loss: 0.1016 - mean_absolute_error: 0.2154 - val_loss: 0.1022 - val_mean_absolute_error: 0.2177
# Epoch 102/1000
# 32/32 - 0s - 3ms/step - loss: 0.1024 - mean_absolute_error: 0.2168 - val_loss: 0.1087 - val_mean_absolute_error: 0.2227
# Epoch 103/1000
# 32/32 - 0s - 3ms/step - loss: 0.1006 - mean_absolute_error: 0.2144 - val_loss: 0.1048 - val_mean_absolute_error: 0.2218
# Epoch 104/1000
# 32/32 - 0s - 3ms/step - loss: 0.1004 - mean_absolute_error: 0.2139 - val_loss: 0.1052 - val_mean_absolute_error: 0.2176
# Epoch 105/1000
# 32/32 - 0s - 3ms/step - loss: 0.1000 - mean_absolute_error: 0.2125 - val_loss: 0.1137 - val_mean_absolute_error: 0.2231
# Epoch 106/1000
# 32/32 - 0s - 3ms/step - loss: 0.1013 - mean_absolute_error: 0.2143 - val_loss: 0.1001 - val_mean_absolute_error: 0.2136
# Epoch 107/1000
# 32/32 - 0s - 3ms/step - loss: 0.1066 - mean_absolute_error: 0.2215 - val_loss: 0.1050 - val_mean_absolute_error: 0.2191
# Epoch 108/1000
# 32/32 - 0s - 3ms/step - loss: 0.1067 - mean_absolute_error: 0.2211 - val_loss: 0.1080 - val_mean_absolute_error: 0.2226
# Epoch 109/1000
# 32/32 - 0s - 3ms/step - loss: 0.0986 - mean_absolute_error: 0.2117 - val_loss: 0.0953 - val_mean_absolute_error: 0.2104
# Epoch 110/1000
# 32/32 - 0s - 3ms/step - loss: 0.1005 - mean_absolute_error: 0.2154 - val_loss: 0.1060 - val_mean_absolute_error: 0.2203
# Epoch 111/1000
# 32/32 - 0s - 3ms/step - loss: 0.1032 - mean_absolute_error: 0.2162 - val_loss: 0.1179 - val_mean_absolute_error: 0.2327
# Epoch 112/1000
# 32/32 - 0s - 3ms/step - loss: 0.1026 - mean_absolute_error: 0.2177 - val_loss: 0.1102 - val_mean_absolute_error: 0.2245
# Epoch 113/1000
# 32/32 - 0s - 3ms/step - loss: 0.1061 - mean_absolute_error: 0.2194 - val_loss: 0.1115 - val_mean_absolute_error: 0.2249
# Epoch 114/1000
# 32/32 - 0s - 3ms/step - loss: 0.1016 - mean_absolute_error: 0.2135 - val_loss: 0.0956 - val_mean_absolute_error: 0.2077
# Epoch 115/1000
# 32/32 - 0s - 3ms/step - loss: 0.0958 - mean_absolute_error: 0.2066 - val_loss: 0.0922 - val_mean_absolute_error: 0.2053
# Epoch 116/1000
# 32/32 - 0s - 3ms/step - loss: 0.1004 - mean_absolute_error: 0.2118 - val_loss: 0.0994 - val_mean_absolute_error: 0.2130
# Epoch 117/1000
# 32/32 - 0s - 3ms/step - loss: 0.0958 - mean_absolute_error: 0.2078 - val_loss: 0.0968 - val_mean_absolute_error: 0.2085
# Epoch 118/1000
# 32/32 - 0s - 3ms/step - loss: 0.1010 - mean_absolute_error: 0.2143 - val_loss: 0.1190 - val_mean_absolute_error: 0.2293
# Epoch 119/1000
# 32/32 - 0s - 3ms/step - loss: 0.1034 - mean_absolute_error: 0.2156 - val_loss: 0.1023 - val_mean_absolute_error: 0.2134
# Epoch 120/1000
# 32/32 - 0s - 3ms/step - loss: 0.0995 - mean_absolute_error: 0.2121 - val_loss: 0.1003 - val_mean_absolute_error: 0.2126
# Epoch 121/1000
# 32/32 - 0s - 3ms/step - loss: 0.1015 - mean_absolute_error: 0.2149 - val_loss: 0.0994 - val_mean_absolute_error: 0.2127
# Epoch 122/1000
# 32/32 - 0s - 3ms/step - loss: 0.0962 - mean_absolute_error: 0.2081 - val_loss: 0.0940 - val_mean_absolute_error: 0.2046
# Epoch 123/1000
# 32/32 - 0s - 3ms/step - loss: 0.0962 - mean_absolute_error: 0.2060 - val_loss: 0.1012 - val_mean_absolute_error: 0.2166
# Epoch 124/1000
# 32/32 - 0s - 3ms/step - loss: 0.0975 - mean_absolute_error: 0.2089 - val_loss: 0.0951 - val_mean_absolute_error: 0.2094
# Epoch 125/1000
# 32/32 - 0s - 3ms/step - loss: 0.0952 - mean_absolute_error: 0.2067 - val_loss: 0.1085 - val_mean_absolute_error: 0.2194
# Epoch 126/1000
# 32/32 - 0s - 3ms/step - loss: 0.0979 - mean_absolute_error: 0.2096 - val_loss: 0.0959 - val_mean_absolute_error: 0.2076
# Epoch 127/1000
# 32/32 - 0s - 3ms/step - loss: 0.0948 - mean_absolute_error: 0.2059 - val_loss: 0.0934 - val_mean_absolute_error: 0.2051
# Epoch 128/1000
# 32/32 - 0s - 3ms/step - loss: 0.1022 - mean_absolute_error: 0.2128 - val_loss: 0.1083 - val_mean_absolute_error: 0.2216
# Epoch 129/1000
# 32/32 - 0s - 3ms/step - loss: 0.0969 - mean_absolute_error: 0.2098 - val_loss: 0.1117 - val_mean_absolute_error: 0.2236
# Epoch 130/1000
# 32/32 - 0s - 3ms/step - loss: 0.0972 - mean_absolute_error: 0.2082 - val_loss: 0.1094 - val_mean_absolute_error: 0.2195
# Epoch 131/1000
# 32/32 - 0s - 3ms/step - loss: 0.1010 - mean_absolute_error: 0.2118 - val_loss: 0.1010 - val_mean_absolute_error: 0.2167
# Epoch 132/1000
# 32/32 - 0s - 3ms/step - loss: 0.0949 - mean_absolute_error: 0.2054 - val_loss: 0.0965 - val_mean_absolute_error: 0.2082
# Epoch 133/1000
# 32/32 - 0s - 3ms/step - loss: 0.0957 - mean_absolute_error: 0.2072 - val_loss: 0.0952 - val_mean_absolute_error: 0.2034
# Epoch 134/1000
# 32/32 - 0s - 3ms/step - loss: 0.0975 - mean_absolute_error: 0.2086 - val_loss: 0.1216 - val_mean_absolute_error: 0.2328
# Epoch 135/1000
# 32/32 - 0s - 4ms/step - loss: 0.0950 - mean_absolute_error: 0.2065 - val_loss: 0.0909 - val_mean_absolute_error: 0.2042
# Epoch 136/1000
# 32/32 - 0s - 3ms/step - loss: 0.0938 - mean_absolute_error: 0.2030 - val_loss: 0.1073 - val_mean_absolute_error: 0.2144
# Epoch 137/1000
# 32/32 - 0s - 3ms/step - loss: 0.0966 - mean_absolute_error: 0.2062 - val_loss: 0.0936 - val_mean_absolute_error: 0.2048
# Epoch 138/1000
# 32/32 - 0s - 3ms/step - loss: 0.0927 - mean_absolute_error: 0.2013 - val_loss: 0.1049 - val_mean_absolute_error: 0.2121
# Epoch 139/1000
# 32/32 - 0s - 3ms/step - loss: 0.0956 - mean_absolute_error: 0.2064 - val_loss: 0.1041 - val_mean_absolute_error: 0.2141
# Epoch 140/1000
# 32/32 - 0s - 3ms/step - loss: 0.0952 - mean_absolute_error: 0.2053 - val_loss: 0.1043 - val_mean_absolute_error: 0.2194
# Epoch 141/1000
# 32/32 - 0s - 3ms/step - loss: 0.0973 - mean_absolute_error: 0.2090 - val_loss: 0.0888 - val_mean_absolute_error: 0.1996
# Epoch 142/1000
# 32/32 - 0s - 3ms/step - loss: 0.0921 - mean_absolute_error: 0.2018 - val_loss: 0.0892 - val_mean_absolute_error: 0.1978
# Epoch 143/1000
# 32/32 - 0s - 3ms/step - loss: 0.0912 - mean_absolute_error: 0.2004 - val_loss: 0.0952 - val_mean_absolute_error: 0.2025
# Epoch 144/1000
# 32/32 - 0s - 3ms/step - loss: 0.0984 - mean_absolute_error: 0.2077 - val_loss: 0.1039 - val_mean_absolute_error: 0.2098
# Epoch 145/1000
# 32/32 - 0s - 3ms/step - loss: 0.0962 - mean_absolute_error: 0.2054 - val_loss: 0.0902 - val_mean_absolute_error: 0.2015
# Epoch 146/1000
# 32/32 - 0s - 3ms/step - loss: 0.0929 - mean_absolute_error: 0.2018 - val_loss: 0.0928 - val_mean_absolute_error: 0.2041
# Epoch 147/1000
# 32/32 - 0s - 3ms/step - loss: 0.0902 - mean_absolute_error: 0.1998 - val_loss: 0.0892 - val_mean_absolute_error: 0.1994
# Epoch 148/1000
# 32/32 - 0s - 3ms/step - loss: 0.0900 - mean_absolute_error: 0.1985 - val_loss: 0.0900 - val_mean_absolute_error: 0.2013
# Epoch 149/1000
# 32/32 - 0s - 3ms/step - loss: 0.0979 - mean_absolute_error: 0.2067 - val_loss: 0.1082 - val_mean_absolute_error: 0.2194
# Epoch 150/1000
# 32/32 - 0s - 3ms/step - loss: 0.0944 - mean_absolute_error: 0.2049 - val_loss: 0.0987 - val_mean_absolute_error: 0.2108
# Epoch 151/1000
# 32/32 - 0s - 3ms/step - loss: 0.0928 - mean_absolute_error: 0.2016 - val_loss: 0.0923 - val_mean_absolute_error: 0.1997
# Epoch 152/1000
# 32/32 - 0s - 3ms/step - loss: 0.0934 - mean_absolute_error: 0.2015 - val_loss: 0.0912 - val_mean_absolute_error: 0.1995
# Epoch 153/1000
# 32/32 - 0s - 3ms/step - loss: 0.0892 - mean_absolute_error: 0.1975 - val_loss: 0.0917 - val_mean_absolute_error: 0.1994
# Epoch 154/1000
# 32/32 - 0s - 3ms/step - loss: 0.0994 - mean_absolute_error: 0.2087 - val_loss: 0.0940 - val_mean_absolute_error: 0.2041
# Epoch 155/1000
# 32/32 - 0s - 3ms/step - loss: 0.0919 - mean_absolute_error: 0.1994 - val_loss: 0.1005 - val_mean_absolute_error: 0.2064
# Epoch 156/1000
# 32/32 - 0s - 3ms/step - loss: 0.0976 - mean_absolute_error: 0.2050 - val_loss: 0.0954 - val_mean_absolute_error: 0.2030
# Epoch 157/1000
# 32/32 - 0s - 4ms/step - loss: 0.0908 - mean_absolute_error: 0.1991 - val_loss: 0.0978 - val_mean_absolute_error: 0.2071
# Epoch 158/1000
# 32/32 - 0s - 3ms/step - loss: 0.0888 - mean_absolute_error: 0.1982 - val_loss: 0.0889 - val_mean_absolute_error: 0.1956
# Epoch 159/1000
# 32/32 - 0s - 3ms/step - loss: 0.0960 - mean_absolute_error: 0.2038 - val_loss: 0.1045 - val_mean_absolute_error: 0.2114
# Epoch 160/1000
# 32/32 - 0s - 3ms/step - loss: 0.0957 - mean_absolute_error: 0.2040 - val_loss: 0.0934 - val_mean_absolute_error: 0.1997
# Epoch 161/1000
# 32/32 - 0s - 3ms/step - loss: 0.0945 - mean_absolute_error: 0.2036 - val_loss: 0.0999 - val_mean_absolute_error: 0.2095
# Epoch 162/1000
# 32/32 - 0s - 3ms/step - loss: 0.0895 - mean_absolute_error: 0.1988 - val_loss: 0.1038 - val_mean_absolute_error: 0.2099
# Epoch 163/1000
# 32/32 - 0s - 3ms/step - loss: 0.0891 - mean_absolute_error: 0.1981 - val_loss: 0.0982 - val_mean_absolute_error: 0.2084
# Epoch 164/1000
# 32/32 - 0s - 3ms/step - loss: 0.0919 - mean_absolute_error: 0.2012 - val_loss: 0.0915 - val_mean_absolute_error: 0.1982
# Epoch 165/1000
# 32/32 - 0s - 3ms/step - loss: 0.0908 - mean_absolute_error: 0.1995 - val_loss: 0.1077 - val_mean_absolute_error: 0.2179
# Epoch 166/1000
# 32/32 - 0s - 3ms/step - loss: 0.0932 - mean_absolute_error: 0.2032 - val_loss: 0.0839 - val_mean_absolute_error: 0.1938
# Epoch 167/1000
# 32/32 - 0s - 3ms/step - loss: 0.0917 - mean_absolute_error: 0.2003 - val_loss: 0.0888 - val_mean_absolute_error: 0.1954
# Epoch 168/1000
# 32/32 - 0s - 3ms/step - loss: 0.0889 - mean_absolute_error: 0.1961 - val_loss: 0.0933 - val_mean_absolute_error: 0.2020
# Epoch 169/1000
# 32/32 - 0s - 3ms/step - loss: 0.0900 - mean_absolute_error: 0.1983 - val_loss: 0.1057 - val_mean_absolute_error: 0.2199
# Epoch 170/1000
# 32/32 - 0s - 3ms/step - loss: 0.0946 - mean_absolute_error: 0.2050 - val_loss: 0.0883 - val_mean_absolute_error: 0.1952
# Epoch 171/1000
# 32/32 - 0s - 3ms/step - loss: 0.0874 - mean_absolute_error: 0.1944 - val_loss: 0.0871 - val_mean_absolute_error: 0.1981
# Epoch 172/1000
# 32/32 - 0s - 3ms/step - loss: 0.0887 - mean_absolute_error: 0.1962 - val_loss: 0.0882 - val_mean_absolute_error: 0.1966
# Epoch 173/1000
# 32/32 - 0s - 3ms/step - loss: 0.0945 - mean_absolute_error: 0.2030 - val_loss: 0.0990 - val_mean_absolute_error: 0.2084
# Epoch 174/1000
# 32/32 - 0s - 3ms/step - loss: 0.0899 - mean_absolute_error: 0.1980 - val_loss: 0.0919 - val_mean_absolute_error: 0.2010
# Epoch 175/1000
# 32/32 - 0s - 3ms/step - loss: 0.0918 - mean_absolute_error: 0.2005 - val_loss: 0.0951 - val_mean_absolute_error: 0.2104
# Epoch 176/1000
# 32/32 - 0s - 3ms/step - loss: 0.0861 - mean_absolute_error: 0.1949 - val_loss: 0.0894 - val_mean_absolute_error: 0.1986
# Epoch 177/1000
# 32/32 - 0s - 3ms/step - loss: 0.0916 - mean_absolute_error: 0.1989 - val_loss: 0.0891 - val_mean_absolute_error: 0.1969
# Epoch 178/1000
# 32/32 - 0s - 3ms/step - loss: 0.0921 - mean_absolute_error: 0.1999 - val_loss: 0.0970 - val_mean_absolute_error: 0.2044
# Epoch 179/1000
# 32/32 - 0s - 3ms/step - loss: 0.0873 - mean_absolute_error: 0.1945 - val_loss: 0.1087 - val_mean_absolute_error: 0.2137
# Epoch 180/1000
# 32/32 - 0s - 3ms/step - loss: 0.0901 - mean_absolute_error: 0.1999 - val_loss: 0.0860 - val_mean_absolute_error: 0.1938
# Epoch 181/1000
# 32/32 - 0s - 3ms/step - loss: 0.0863 - mean_absolute_error: 0.1918 - val_loss: 0.0940 - val_mean_absolute_error: 0.1996
# Epoch 182/1000
# 32/32 - 0s - 3ms/step - loss: 0.0948 - mean_absolute_error: 0.2035 - val_loss: 0.0913 - val_mean_absolute_error: 0.1988
# Epoch 183/1000
# 32/32 - 0s - 3ms/step - loss: 0.0902 - mean_absolute_error: 0.1979 - val_loss: 0.0883 - val_mean_absolute_error: 0.1944
# Epoch 184/1000
# 32/32 - 0s - 3ms/step - loss: 0.0905 - mean_absolute_error: 0.1979 - val_loss: 0.0903 - val_mean_absolute_error: 0.1998
# Epoch 185/1000
# 32/32 - 0s - 3ms/step - loss: 0.0915 - mean_absolute_error: 0.1996 - val_loss: 0.0910 - val_mean_absolute_error: 0.2007
# Epoch 186/1000
# 32/32 - 0s - 3ms/step - loss: 0.0828 - mean_absolute_error: 0.1907 - val_loss: 0.0819 - val_mean_absolute_error: 0.1894
# Epoch 187/1000
# 32/32 - 0s - 3ms/step - loss: 0.0868 - mean_absolute_error: 0.1944 - val_loss: 0.0955 - val_mean_absolute_error: 0.2040
# Epoch 188/1000
# 32/32 - 0s - 3ms/step - loss: 0.0886 - mean_absolute_error: 0.1958 - val_loss: 0.0863 - val_mean_absolute_error: 0.1951
# Epoch 189/1000
# 32/32 - 0s - 4ms/step - loss: 0.0880 - mean_absolute_error: 0.1948 - val_loss: 0.0936 - val_mean_absolute_error: 0.2023
# Epoch 190/1000
# 32/32 - 0s - 3ms/step - loss: 0.0881 - mean_absolute_error: 0.1962 - val_loss: 0.0914 - val_mean_absolute_error: 0.1991
# Epoch 191/1000
# 32/32 - 0s - 3ms/step - loss: 0.0903 - mean_absolute_error: 0.1968 - val_loss: 0.1020 - val_mean_absolute_error: 0.2093
# Epoch 192/1000
# 32/32 - 0s - 3ms/step - loss: 0.0916 - mean_absolute_error: 0.1990 - val_loss: 0.0885 - val_mean_absolute_error: 0.1975
# Epoch 193/1000
# 32/32 - 0s - 3ms/step - loss: 0.1028 - mean_absolute_error: 0.2120 - val_loss: 0.0979 - val_mean_absolute_error: 0.2080
# Epoch 194/1000
# 32/32 - 0s - 3ms/step - loss: 0.0885 - mean_absolute_error: 0.1973 - val_loss: 0.0868 - val_mean_absolute_error: 0.1904
# Epoch 195/1000
# 32/32 - 0s - 3ms/step - loss: 0.0849 - mean_absolute_error: 0.1914 - val_loss: 0.0919 - val_mean_absolute_error: 0.1981
# Epoch 196/1000
# 32/32 - 0s - 3ms/step - loss: 0.0845 - mean_absolute_error: 0.1902 - val_loss: 0.0894 - val_mean_absolute_error: 0.1952
# Epoch 197/1000
# 32/32 - 0s - 3ms/step - loss: 0.0848 - mean_absolute_error: 0.1896 - val_loss: 0.1088 - val_mean_absolute_error: 0.2136
# Epoch 198/1000
# 32/32 - 0s - 3ms/step - loss: 0.0895 - mean_absolute_error: 0.1966 - val_loss: 0.0834 - val_mean_absolute_error: 0.1887
# Epoch 199/1000
# 32/32 - 0s - 3ms/step - loss: 0.0880 - mean_absolute_error: 0.1944 - val_loss: 0.0909 - val_mean_absolute_error: 0.2020
# Epoch 200/1000
# 32/32 - 0s - 3ms/step - loss: 0.0881 - mean_absolute_error: 0.1953 - val_loss: 0.0885 - val_mean_absolute_error: 0.1960
# Epoch 201/1000
# 32/32 - 0s - 3ms/step - loss: 0.0879 - mean_absolute_error: 0.1952 - val_loss: 0.0846 - val_mean_absolute_error: 0.1926
# Epoch 202/1000
# 32/32 - 0s - 3ms/step - loss: 0.0870 - mean_absolute_error: 0.1934 - val_loss: 0.0856 - val_mean_absolute_error: 0.1904
# Epoch 203/1000
# 32/32 - 0s - 3ms/step - loss: 0.0883 - mean_absolute_error: 0.1935 - val_loss: 0.0894 - val_mean_absolute_error: 0.1960
# Epoch 204/1000
# 32/32 - 0s - 3ms/step - loss: 0.0850 - mean_absolute_error: 0.1904 - val_loss: 0.1035 - val_mean_absolute_error: 0.2074
# Epoch 205/1000
# 32/32 - 0s - 3ms/step - loss: 0.0855 - mean_absolute_error: 0.1924 - val_loss: 0.0836 - val_mean_absolute_error: 0.1891
# Epoch 206/1000
# 32/32 - 0s - 3ms/step - loss: 0.0848 - mean_absolute_error: 0.1908 - val_loss: 0.0982 - val_mean_absolute_error: 0.2048
# Epoch 207/1000
# 32/32 - 0s - 3ms/step - loss: 0.0947 - mean_absolute_error: 0.2018 - val_loss: 0.1161 - val_mean_absolute_error: 0.2203
# Epoch 208/1000
# 32/32 - 0s - 3ms/step - loss: 0.0867 - mean_absolute_error: 0.1935 - val_loss: 0.0828 - val_mean_absolute_error: 0.1911
# Epoch 209/1000
# 32/32 - 0s - 3ms/step - loss: 0.0849 - mean_absolute_error: 0.1905 - val_loss: 0.1143 - val_mean_absolute_error: 0.2255
# Epoch 210/1000
# 32/32 - 0s - 3ms/step - loss: 0.0929 - mean_absolute_error: 0.2009 - val_loss: 0.0990 - val_mean_absolute_error: 0.2041
# Epoch 211/1000
# 32/32 - 0s - 3ms/step - loss: 0.0854 - mean_absolute_error: 0.1914 - val_loss: 0.1074 - val_mean_absolute_error: 0.2101
# Epoch 212/1000
# 32/32 - 0s - 3ms/step - loss: 0.0917 - mean_absolute_error: 0.1981 - val_loss: 0.0851 - val_mean_absolute_error: 0.1907
# Epoch 213/1000
# 32/32 - 0s - 3ms/step - loss: 0.0825 - mean_absolute_error: 0.1885 - val_loss: 0.0904 - val_mean_absolute_error: 0.1940
# Epoch 214/1000
# 32/32 - 0s - 3ms/step - loss: 0.0844 - mean_absolute_error: 0.1890 - val_loss: 0.0813 - val_mean_absolute_error: 0.1846
# Epoch 215/1000
# 32/32 - 0s - 3ms/step - loss: 0.0872 - mean_absolute_error: 0.1916 - val_loss: 0.1030 - val_mean_absolute_error: 0.2066
# Epoch 216/1000
# 32/32 - 0s - 3ms/step - loss: 0.0828 - mean_absolute_error: 0.1877 - val_loss: 0.0913 - val_mean_absolute_error: 0.1969
# Epoch 217/1000
# 32/32 - 0s - 3ms/step - loss: 0.0967 - mean_absolute_error: 0.2023 - val_loss: 0.0902 - val_mean_absolute_error: 0.2009
# Epoch 218/1000
# 32/32 - 0s - 3ms/step - loss: 0.0870 - mean_absolute_error: 0.1952 - val_loss: 0.1001 - val_mean_absolute_error: 0.2072
# Epoch 219/1000
# 32/32 - 0s - 3ms/step - loss: 0.0883 - mean_absolute_error: 0.1937 - val_loss: 0.0919 - val_mean_absolute_error: 0.1975
# Epoch 220/1000
# 32/32 - 0s - 4ms/step - loss: 0.0856 - mean_absolute_error: 0.1921 - val_loss: 0.0930 - val_mean_absolute_error: 0.2035
# Epoch 221/1000
# 32/32 - 0s - 3ms/step - loss: 0.0856 - mean_absolute_error: 0.1915 - val_loss: 0.0962 - val_mean_absolute_error: 0.1979
# Epoch 222/1000
# 32/32 - 0s - 3ms/step - loss: 0.0869 - mean_absolute_error: 0.1918 - val_loss: 0.0878 - val_mean_absolute_error: 0.1933
# Epoch 223/1000
# 32/32 - 0s - 3ms/step - loss: 0.0835 - mean_absolute_error: 0.1876 - val_loss: 0.1045 - val_mean_absolute_error: 0.2114
# Epoch 224/1000
# 32/32 - 0s - 3ms/step - loss: 0.0952 - mean_absolute_error: 0.2035 - val_loss: 0.0945 - val_mean_absolute_error: 0.2028
# Epoch 225/1000
# 32/32 - 0s - 3ms/step - loss: 0.0867 - mean_absolute_error: 0.1929 - val_loss: 0.0836 - val_mean_absolute_error: 0.1913
# Epoch 226/1000
# 32/32 - 0s - 3ms/step - loss: 0.0930 - mean_absolute_error: 0.1997 - val_loss: 0.0979 - val_mean_absolute_error: 0.2065
# Epoch 227/1000
# 32/32 - 0s - 3ms/step - loss: 0.0845 - mean_absolute_error: 0.1910 - val_loss: 0.0864 - val_mean_absolute_error: 0.1893
# Epoch 228/1000
# 32/32 - 0s - 3ms/step - loss: 0.0864 - mean_absolute_error: 0.1916 - val_loss: 0.0919 - val_mean_absolute_error: 0.2003
# Epoch 229/1000
# 32/32 - 0s - 3ms/step - loss: 0.0857 - mean_absolute_error: 0.1927 - val_loss: 0.0840 - val_mean_absolute_error: 0.1936
# Epoch 230/1000
# 32/32 - 0s - 3ms/step - loss: 0.0889 - mean_absolute_error: 0.1955 - val_loss: 0.0917 - val_mean_absolute_error: 0.1992
# Epoch 231/1000
# 32/32 - 0s - 3ms/step - loss: 0.0870 - mean_absolute_error: 0.1933 - val_loss: 0.0933 - val_mean_absolute_error: 0.1983
# Epoch 232/1000
# 32/32 - 0s - 3ms/step - loss: 0.0823 - mean_absolute_error: 0.1866 - val_loss: 0.0876 - val_mean_absolute_error: 0.1921
# Epoch 233/1000
# 32/32 - 0s - 3ms/step - loss: 0.0872 - mean_absolute_error: 0.1923 - val_loss: 0.0930 - val_mean_absolute_error: 0.1940
# Epoch 234/1000
# 32/32 - 0s - 3ms/step - loss: 0.0874 - mean_absolute_error: 0.1929 - val_loss: 0.0896 - val_mean_absolute_error: 0.2060
# Epoch 235/1000
# 32/32 - 0s - 3ms/step - loss: 0.0872 - mean_absolute_error: 0.1946 - val_loss: 0.0904 - val_mean_absolute_error: 0.2019
# Epoch 236/1000
# 32/32 - 0s - 3ms/step - loss: 0.0850 - mean_absolute_error: 0.1919 - val_loss: 0.0902 - val_mean_absolute_error: 0.1959
# Epoch 237/1000
# 32/32 - 0s - 3ms/step - loss: 0.0826 - mean_absolute_error: 0.1872 - val_loss: 0.0862 - val_mean_absolute_error: 0.1926
# Epoch 238/1000
# 32/32 - 0s - 3ms/step - loss: 0.0825 - mean_absolute_error: 0.1865 - val_loss: 0.0957 - val_mean_absolute_error: 0.1994
# Epoch 239/1000
# 32/32 - 0s - 3ms/step - loss: 0.0820 - mean_absolute_error: 0.1852 - val_loss: 0.0852 - val_mean_absolute_error: 0.1895
# Epoch 240/1000
# 32/32 - 0s - 3ms/step - loss: 0.0839 - mean_absolute_error: 0.1888 - val_loss: 0.0880 - val_mean_absolute_error: 0.1927
# Epoch 241/1000
# 32/32 - 0s - 3ms/step - loss: 0.0916 - mean_absolute_error: 0.1973 - val_loss: 0.0860 - val_mean_absolute_error: 0.1953
# Epoch 242/1000
# 32/32 - 0s - 3ms/step - loss: 0.0831 - mean_absolute_error: 0.1884 - val_loss: 0.0851 - val_mean_absolute_error: 0.1906
# Epoch 243/1000
# 32/32 - 0s - 3ms/step - loss: 0.0900 - mean_absolute_error: 0.1961 - val_loss: 0.0849 - val_mean_absolute_error: 0.1891
# Epoch 244/1000
# 32/32 - 0s - 3ms/step - loss: 0.0831 - mean_absolute_error: 0.1876 - val_loss: 0.0812 - val_mean_absolute_error: 0.1858
# Epoch 245/1000
# 32/32 - 0s - 3ms/step - loss: 0.0823 - mean_absolute_error: 0.1868 - val_loss: 0.0872 - val_mean_absolute_error: 0.1924
# Epoch 246/1000
# 32/32 - 0s - 3ms/step - loss: 0.0820 - mean_absolute_error: 0.1866 - val_loss: 0.0915 - val_mean_absolute_error: 0.1930
# Epoch 247/1000
# 32/32 - 0s - 3ms/step - loss: 0.0818 - mean_absolute_error: 0.1861 - val_loss: 0.1061 - val_mean_absolute_error: 0.2106
# Epoch 248/1000
# 32/32 - 0s - 3ms/step - loss: 0.0924 - mean_absolute_error: 0.1996 - val_loss: 0.0995 - val_mean_absolute_error: 0.2077
# Epoch 249/1000
# 32/32 - 0s - 3ms/step - loss: 0.0874 - mean_absolute_error: 0.1930 - val_loss: 0.0871 - val_mean_absolute_error: 0.1896
# Epoch 250/1000
# 32/32 - 0s - 3ms/step - loss: 0.0853 - mean_absolute_error: 0.1902 - val_loss: 0.0928 - val_mean_absolute_error: 0.1991
# Epoch 251/1000
# 32/32 - 0s - 3ms/step - loss: 0.0848 - mean_absolute_error: 0.1902 - val_loss: 0.0913 - val_mean_absolute_error: 0.1953
# Epoch 252/1000
# 32/32 - 0s - 3ms/step - loss: 0.0825 - mean_absolute_error: 0.1890 - val_loss: 0.0951 - val_mean_absolute_error: 0.1991
# Epoch 253/1000
# 32/32 - 0s - 3ms/step - loss: 0.0836 - mean_absolute_error: 0.1881 - val_loss: 0.0798 - val_mean_absolute_error: 0.1847
# Epoch 254/1000
# 32/32 - 0s - 3ms/step - loss: 0.0828 - mean_absolute_error: 0.1861 - val_loss: 0.0995 - val_mean_absolute_error: 0.2040
# Epoch 255/1000
# 32/32 - 0s - 3ms/step - loss: 0.0894 - mean_absolute_error: 0.1939 - val_loss: 0.0996 - val_mean_absolute_error: 0.2019
# Epoch 256/1000
# 32/32 - 0s - 4ms/step - loss: 0.0873 - mean_absolute_error: 0.1925 - val_loss: 0.0874 - val_mean_absolute_error: 0.1902
# Epoch 257/1000
# 32/32 - 0s - 3ms/step - loss: 0.0867 - mean_absolute_error: 0.1907 - val_loss: 0.0838 - val_mean_absolute_error: 0.1878
# Epoch 258/1000
# 32/32 - 0s - 3ms/step - loss: 0.0817 - mean_absolute_error: 0.1858 - val_loss: 0.0803 - val_mean_absolute_error: 0.1847
# Epoch 259/1000
# 32/32 - 0s - 3ms/step - loss: 0.0803 - mean_absolute_error: 0.1833 - val_loss: 0.0807 - val_mean_absolute_error: 0.1844
# Epoch 260/1000
# 32/32 - 0s - 3ms/step - loss: 0.0822 - mean_absolute_error: 0.1857 - val_loss: 0.1117 - val_mean_absolute_error: 0.2129
# Epoch 261/1000
# 32/32 - 0s - 3ms/step - loss: 0.0828 - mean_absolute_error: 0.1856 - val_loss: 0.0839 - val_mean_absolute_error: 0.1891
# Epoch 262/1000
# 32/32 - 0s - 3ms/step - loss: 0.0798 - mean_absolute_error: 0.1837 - val_loss: 0.0814 - val_mean_absolute_error: 0.1861
# Epoch 263/1000
# 32/32 - 0s - 3ms/step - loss: 0.0867 - mean_absolute_error: 0.1915 - val_loss: 0.0846 - val_mean_absolute_error: 0.1908
# Epoch 264/1000
# 32/32 - 0s - 3ms/step - loss: 0.0802 - mean_absolute_error: 0.1830 - val_loss: 0.0814 - val_mean_absolute_error: 0.1853
# Epoch 265/1000
# 32/32 - 0s - 3ms/step - loss: 0.0798 - mean_absolute_error: 0.1821 - val_loss: 0.0969 - val_mean_absolute_error: 0.1985
# Epoch 266/1000
# 32/32 - 0s - 3ms/step - loss: 0.0821 - mean_absolute_error: 0.1875 - val_loss: 0.0942 - val_mean_absolute_error: 0.2000
# Epoch 267/1000
# 32/32 - 0s - 3ms/step - loss: 0.0854 - mean_absolute_error: 0.1885 - val_loss: 0.1065 - val_mean_absolute_error: 0.2144
# Epoch 268/1000
# 32/32 - 0s - 3ms/step - loss: 0.0886 - mean_absolute_error: 0.1957 - val_loss: 0.0879 - val_mean_absolute_error: 0.1945
# Epoch 269/1000
# 32/32 - 0s - 3ms/step - loss: 0.0858 - mean_absolute_error: 0.1899 - val_loss: 0.0854 - val_mean_absolute_error: 0.1917
# Epoch 270/1000
# 32/32 - 0s - 3ms/step - loss: 0.0857 - mean_absolute_error: 0.1902 - val_loss: 0.0892 - val_mean_absolute_error: 0.1968
# Epoch 271/1000
# 32/32 - 0s - 3ms/step - loss: 0.0831 - mean_absolute_error: 0.1887 - val_loss: 0.0863 - val_mean_absolute_error: 0.1911
# Epoch 272/1000
# 32/32 - 0s - 3ms/step - loss: 0.0829 - mean_absolute_error: 0.1872 - val_loss: 0.0948 - val_mean_absolute_error: 0.2000
# Epoch 273/1000
# 32/32 - 0s - 3ms/step - loss: 0.0898 - mean_absolute_error: 0.1932 - val_loss: 0.0920 - val_mean_absolute_error: 0.1977
# Epoch 274/1000
# 32/32 - 0s - 3ms/step - loss: 0.0863 - mean_absolute_error: 0.1914 - val_loss: 0.0941 - val_mean_absolute_error: 0.1989
# Epoch 275/1000
# 32/32 - 0s - 3ms/step - loss: 0.0914 - mean_absolute_error: 0.1975 - val_loss: 0.0908 - val_mean_absolute_error: 0.2033
# Epoch 276/1000
# 32/32 - 0s - 3ms/step - loss: 0.0843 - mean_absolute_error: 0.1907 - val_loss: 0.0834 - val_mean_absolute_error: 0.1888
# Epoch 277/1000
# 32/32 - 0s - 3ms/step - loss: 0.0799 - mean_absolute_error: 0.1824 - val_loss: 0.0813 - val_mean_absolute_error: 0.1852
# Epoch 278/1000
# 32/32 - 0s - 3ms/step - loss: 0.0787 - mean_absolute_error: 0.1822 - val_loss: 0.0764 - val_mean_absolute_error: 0.1806
# Epoch 279/1000
# 32/32 - 0s - 3ms/step - loss: 0.0820 - mean_absolute_error: 0.1859 - val_loss: 0.1046 - val_mean_absolute_error: 0.2080
# Epoch 280/1000
# 32/32 - 0s - 3ms/step - loss: 0.0879 - mean_absolute_error: 0.1927 - val_loss: 0.0809 - val_mean_absolute_error: 0.1860
# Epoch 281/1000
# 32/32 - 0s - 3ms/step - loss: 0.0856 - mean_absolute_error: 0.1900 - val_loss: 0.0915 - val_mean_absolute_error: 0.1949
# Epoch 282/1000
# 32/32 - 0s - 3ms/step - loss: 0.0786 - mean_absolute_error: 0.1821 - val_loss: 0.0816 - val_mean_absolute_error: 0.1843
# Epoch 283/1000
# 32/32 - 0s - 3ms/step - loss: 0.0819 - mean_absolute_error: 0.1860 - val_loss: 0.0942 - val_mean_absolute_error: 0.2030
# Epoch 284/1000
# 32/32 - 0s - 3ms/step - loss: 0.0850 - mean_absolute_error: 0.1889 - val_loss: 0.0934 - val_mean_absolute_error: 0.1977
# Epoch 285/1000
# 32/32 - 0s - 3ms/step - loss: 0.0824 - mean_absolute_error: 0.1857 - val_loss: 0.0840 - val_mean_absolute_error: 0.1888
# Epoch 286/1000
# 32/32 - 0s - 3ms/step - loss: 0.0819 - mean_absolute_error: 0.1855 - val_loss: 0.0803 - val_mean_absolute_error: 0.1839
# Epoch 287/1000
# 32/32 - 0s - 3ms/step - loss: 0.0829 - mean_absolute_error: 0.1883 - val_loss: 0.0856 - val_mean_absolute_error: 0.1942
# Epoch 288/1000
# 32/32 - 0s - 3ms/step - loss: 0.0791 - mean_absolute_error: 0.1819 - val_loss: 0.1075 - val_mean_absolute_error: 0.2081
# Epoch 289/1000
# 32/32 - 0s - 3ms/step - loss: 0.0826 - mean_absolute_error: 0.1851 - val_loss: 0.0896 - val_mean_absolute_error: 0.1928
# Epoch 290/1000
# 32/32 - 0s - 3ms/step - loss: 0.0765 - mean_absolute_error: 0.1786 - val_loss: 0.0797 - val_mean_absolute_error: 0.1843
# Epoch 291/1000
# 32/32 - 0s - 3ms/step - loss: 0.0801 - mean_absolute_error: 0.1818 - val_loss: 0.0843 - val_mean_absolute_error: 0.1890
# Epoch 292/1000
# 32/32 - 0s - 3ms/step - loss: 0.0812 - mean_absolute_error: 0.1843 - val_loss: 0.0883 - val_mean_absolute_error: 0.1909
# Epoch 293/1000
# 32/32 - 0s - 3ms/step - loss: 0.0812 - mean_absolute_error: 0.1844 - val_loss: 0.0909 - val_mean_absolute_error: 0.1934
# Epoch 294/1000
# 32/32 - 0s - 3ms/step - loss: 0.0944 - mean_absolute_error: 0.1984 - val_loss: 0.0888 - val_mean_absolute_error: 0.1948
# Epoch 295/1000
# 32/32 - 0s - 3ms/step - loss: 0.0781 - mean_absolute_error: 0.1806 - val_loss: 0.0806 - val_mean_absolute_error: 0.1823
# Epoch 296/1000
# 32/32 - 0s - 3ms/step - loss: 0.0892 - mean_absolute_error: 0.1937 - val_loss: 0.1021 - val_mean_absolute_error: 0.2075
# Epoch 297/1000
# 32/32 - 0s - 4ms/step - loss: 0.0819 - mean_absolute_error: 0.1852 - val_loss: 0.0912 - val_mean_absolute_error: 0.1929
# Epoch 298/1000
# 32/32 - 0s - 3ms/step - loss: 0.0847 - mean_absolute_error: 0.1886 - val_loss: 0.0899 - val_mean_absolute_error: 0.1974
# Epoch 299/1000
# 32/32 - 0s - 3ms/step - loss: 0.0801 - mean_absolute_error: 0.1822 - val_loss: 0.0855 - val_mean_absolute_error: 0.1863
# Epoch 300/1000
# 32/32 - 0s - 3ms/step - loss: 0.0776 - mean_absolute_error: 0.1780 - val_loss: 0.0912 - val_mean_absolute_error: 0.1934
# Epoch 301/1000
# 32/32 - 0s - 3ms/step - loss: 0.0797 - mean_absolute_error: 0.1814 - val_loss: 0.0787 - val_mean_absolute_error: 0.1827
# Epoch 302/1000
# 32/32 - 0s - 3ms/step - loss: 0.0796 - mean_absolute_error: 0.1814 - val_loss: 0.0789 - val_mean_absolute_error: 0.1831
# Epoch 303/1000
# 32/32 - 0s - 3ms/step - loss: 0.0769 - mean_absolute_error: 0.1784 - val_loss: 0.0804 - val_mean_absolute_error: 0.1868
# Epoch 304/1000
# 32/32 - 0s - 3ms/step - loss: 0.0797 - mean_absolute_error: 0.1828 - val_loss: 0.0795 - val_mean_absolute_error: 0.1820
# Epoch 305/1000
# 32/32 - 0s - 3ms/step - loss: 0.0797 - mean_absolute_error: 0.1816 - val_loss: 0.0908 - val_mean_absolute_error: 0.1928
# Epoch 306/1000
# 32/32 - 0s - 3ms/step - loss: 0.0824 - mean_absolute_error: 0.1849 - val_loss: 0.0841 - val_mean_absolute_error: 0.1890
# Epoch 307/1000
# 32/32 - 0s - 3ms/step - loss: 0.0824 - mean_absolute_error: 0.1873 - val_loss: 0.0920 - val_mean_absolute_error: 0.1923
# Epoch 308/1000
# 32/32 - 0s - 3ms/step - loss: 0.0821 - mean_absolute_error: 0.1844 - val_loss: 0.0810 - val_mean_absolute_error: 0.1824
# Epoch 309/1000
# 32/32 - 0s - 3ms/step - loss: 0.0784 - mean_absolute_error: 0.1799 - val_loss: 0.0961 - val_mean_absolute_error: 0.1948
# Epoch 310/1000
# 32/32 - 0s - 3ms/step - loss: 0.0873 - mean_absolute_error: 0.1885 - val_loss: 0.1015 - val_mean_absolute_error: 0.2016
# Epoch 311/1000
# 32/32 - 0s - 3ms/step - loss: 0.0829 - mean_absolute_error: 0.1858 - val_loss: 0.0911 - val_mean_absolute_error: 0.1926
# Epoch 312/1000
# 32/32 - 0s - 3ms/step - loss: 0.0808 - mean_absolute_error: 0.1822 - val_loss: 0.0968 - val_mean_absolute_error: 0.1972
# Epoch 313/1000
# 32/32 - 0s - 3ms/step - loss: 0.0777 - mean_absolute_error: 0.1783 - val_loss: 0.0766 - val_mean_absolute_error: 0.1796
# Epoch 314/1000
# 32/32 - 0s - 3ms/step - loss: 0.0753 - mean_absolute_error: 0.1768 - val_loss: 0.0886 - val_mean_absolute_error: 0.1904
# Epoch 315/1000
# 32/32 - 0s - 3ms/step - loss: 0.0773 - mean_absolute_error: 0.1791 - val_loss: 0.0820 - val_mean_absolute_error: 0.1837
# Epoch 316/1000
# 32/32 - 0s - 3ms/step - loss: 0.0826 - mean_absolute_error: 0.1857 - val_loss: 0.0918 - val_mean_absolute_error: 0.1926
# Epoch 317/1000
# 32/32 - 0s - 3ms/step - loss: 0.0832 - mean_absolute_error: 0.1849 - val_loss: 0.0872 - val_mean_absolute_error: 0.1898
# Epoch 318/1000
# 32/32 - 0s - 3ms/step - loss: 0.0808 - mean_absolute_error: 0.1824 - val_loss: 0.0866 - val_mean_absolute_error: 0.1918
# Epoch 319/1000
# 32/32 - 0s - 3ms/step - loss: 0.0785 - mean_absolute_error: 0.1797 - val_loss: 0.0875 - val_mean_absolute_error: 0.1896
# Epoch 320/1000
# 32/32 - 0s - 3ms/step - loss: 0.0786 - mean_absolute_error: 0.1809 - val_loss: 0.0984 - val_mean_absolute_error: 0.2009
# Epoch 321/1000
# 32/32 - 0s - 3ms/step - loss: 0.0850 - mean_absolute_error: 0.1881 - val_loss: 0.0916 - val_mean_absolute_error: 0.1970
# Epoch 322/1000
# 32/32 - 0s - 3ms/step - loss: 0.0805 - mean_absolute_error: 0.1846 - val_loss: 0.0903 - val_mean_absolute_error: 0.1940
# Epoch 323/1000
# 32/32 - 0s - 3ms/step - loss: 0.0811 - mean_absolute_error: 0.1834 - val_loss: 0.0863 - val_mean_absolute_error: 0.1896
# Epoch 324/1000
# 32/32 - 0s - 3ms/step - loss: 0.0798 - mean_absolute_error: 0.1834 - val_loss: 0.0853 - val_mean_absolute_error: 0.1860
# Epoch 325/1000
# 32/32 - 0s - 3ms/step - loss: 0.0783 - mean_absolute_error: 0.1796 - val_loss: 0.1083 - val_mean_absolute_error: 0.2065
# Epoch 326/1000
# 32/32 - 0s - 3ms/step - loss: 0.0786 - mean_absolute_error: 0.1803 - val_loss: 0.0837 - val_mean_absolute_error: 0.1890
# Epoch 327/1000
# 32/32 - 0s - 3ms/step - loss: 0.0855 - mean_absolute_error: 0.1878 - val_loss: 0.0881 - val_mean_absolute_error: 0.1925
# Epoch 328/1000
# 32/32 - 0s - 3ms/step - loss: 0.0792 - mean_absolute_error: 0.1825 - val_loss: 0.0788 - val_mean_absolute_error: 0.1787
# Epoch 329/1000
# 32/32 - 0s - 3ms/step - loss: 0.0773 - mean_absolute_error: 0.1784 - val_loss: 0.0814 - val_mean_absolute_error: 0.1852
# Epoch 330/1000
# 32/32 - 0s - 3ms/step - loss: 0.0756 - mean_absolute_error: 0.1757 - val_loss: 0.0854 - val_mean_absolute_error: 0.1840
# Epoch 331/1000
# 32/32 - 0s - 3ms/step - loss: 0.0795 - mean_absolute_error: 0.1803 - val_loss: 0.0893 - val_mean_absolute_error: 0.1906
# Epoch 332/1000
# 32/32 - 0s - 3ms/step - loss: 0.0792 - mean_absolute_error: 0.1796 - val_loss: 0.0828 - val_mean_absolute_error: 0.1837
# Epoch 333/1000
# 32/32 - 0s - 3ms/step - loss: 0.0790 - mean_absolute_error: 0.1809 - val_loss: 0.0864 - val_mean_absolute_error: 0.1895
# Epoch 334/1000
# 32/32 - 0s - 3ms/step - loss: 0.0771 - mean_absolute_error: 0.1789 - val_loss: 0.0774 - val_mean_absolute_error: 0.1785
# Epoch 335/1000
# 32/32 - 0s - 4ms/step - loss: 0.0750 - mean_absolute_error: 0.1756 - val_loss: 0.0793 - val_mean_absolute_error: 0.1799
# Epoch 336/1000
# 32/32 - 0s - 3ms/step - loss: 0.0741 - mean_absolute_error: 0.1735 - val_loss: 0.0879 - val_mean_absolute_error: 0.1885
# Epoch 337/1000
# 32/32 - 0s - 3ms/step - loss: 0.0788 - mean_absolute_error: 0.1803 - val_loss: 0.0847 - val_mean_absolute_error: 0.1904
# Epoch 338/1000
# 32/32 - 0s - 3ms/step - loss: 0.0825 - mean_absolute_error: 0.1838 - val_loss: 0.0819 - val_mean_absolute_error: 0.1843
# Epoch 339/1000
# 32/32 - 0s - 3ms/step - loss: 0.0799 - mean_absolute_error: 0.1810 - val_loss: 0.0804 - val_mean_absolute_error: 0.1864
# Epoch 340/1000
# 32/32 - 0s - 3ms/step - loss: 0.0760 - mean_absolute_error: 0.1777 - val_loss: 0.0761 - val_mean_absolute_error: 0.1781
# Epoch 341/1000
# 32/32 - 0s - 3ms/step - loss: 0.0790 - mean_absolute_error: 0.1792 - val_loss: 0.0961 - val_mean_absolute_error: 0.1988
# Epoch 342/1000
# 32/32 - 0s - 3ms/step - loss: 0.0893 - mean_absolute_error: 0.1947 - val_loss: 0.0818 - val_mean_absolute_error: 0.1879
# Epoch 343/1000
# 32/32 - 0s - 3ms/step - loss: 0.0777 - mean_absolute_error: 0.1793 - val_loss: 0.0884 - val_mean_absolute_error: 0.1902
# Epoch 344/1000
# 32/32 - 0s - 3ms/step - loss: 0.0763 - mean_absolute_error: 0.1774 - val_loss: 0.0931 - val_mean_absolute_error: 0.1920
# Epoch 345/1000
# 32/32 - 0s - 3ms/step - loss: 0.0767 - mean_absolute_error: 0.1772 - val_loss: 0.0820 - val_mean_absolute_error: 0.1857
# Epoch 346/1000
# 32/32 - 0s - 3ms/step - loss: 0.0752 - mean_absolute_error: 0.1747 - val_loss: 0.0792 - val_mean_absolute_error: 0.1821
# Epoch 347/1000
# 32/32 - 0s - 3ms/step - loss: 0.0811 - mean_absolute_error: 0.1824 - val_loss: 0.0917 - val_mean_absolute_error: 0.1974
# Epoch 348/1000
# 32/32 - 0s - 3ms/step - loss: 0.0854 - mean_absolute_error: 0.1874 - val_loss: 0.0818 - val_mean_absolute_error: 0.1835
# Epoch 349/1000
# 32/32 - 0s - 3ms/step - loss: 0.0751 - mean_absolute_error: 0.1773 - val_loss: 0.0832 - val_mean_absolute_error: 0.1877
# Epoch 350/1000
# 32/32 - 0s - 3ms/step - loss: 0.0778 - mean_absolute_error: 0.1774 - val_loss: 0.0841 - val_mean_absolute_error: 0.1849
# Epoch 351/1000
# 32/32 - 0s - 3ms/step - loss: 0.0843 - mean_absolute_error: 0.1849 - val_loss: 0.0792 - val_mean_absolute_error: 0.1836
# Epoch 352/1000
# 32/32 - 0s - 3ms/step - loss: 0.0768 - mean_absolute_error: 0.1781 - val_loss: 0.0838 - val_mean_absolute_error: 0.1868
# Epoch 353/1000
# 32/32 - 0s - 3ms/step - loss: 0.0755 - mean_absolute_error: 0.1770 - val_loss: 0.0841 - val_mean_absolute_error: 0.1852
# Epoch 354/1000
# 32/32 - 0s - 3ms/step - loss: 0.0810 - mean_absolute_error: 0.1823 - val_loss: 0.0803 - val_mean_absolute_error: 0.1839
# Epoch 355/1000
# 32/32 - 0s - 3ms/step - loss: 0.0777 - mean_absolute_error: 0.1786 - val_loss: 0.0883 - val_mean_absolute_error: 0.1873
# Epoch 356/1000
# 32/32 - 0s - 3ms/step - loss: 0.0816 - mean_absolute_error: 0.1833 - val_loss: 0.0915 - val_mean_absolute_error: 0.1998
# Epoch 357/1000
# ...
# Epoch 883/1000
# 32/32 - 0s - 3ms/step - loss: 0.0634 - mean_absolute_error: 0.1544 - val_loss: 0.0771 - val_mean_absolute_error: 0.1682
# Epoch 884/1000
# 32/32 - 0s - 3ms/step - loss: 0.0618 - mean_absolute_error: 0.1524 - val_loss: 0.0780 - val_mean_absolute_error: 0.1749
# Epoch 885/1000
# 32/32 - 0s - 3ms/step - loss: 0.0657 - mean_absolute_error: 0.1584 - val_loss: 0.0727 - val_mean_absolute_error: 0.1652
# Epoch 886/1000
# 32/32 - 0s - 3ms/step - loss: 0.0685 - mean_absolute_error: 0.1608 - val_loss: 0.0871 - val_mean_absolute_error: 0.1797
# Epoch 887/1000
# 32/32 - 0s - 3ms/step - loss: 0.0629 - mean_absolute_error: 0.1541 - val_loss: 0.0933 - val_mean_absolute_error: 0.1844
# Epoch 888/1000
# 32/32 - 0s - 3ms/step - loss: 0.0670 - mean_absolute_error: 0.1572 - val_loss: 0.0705 - val_mean_absolute_error: 0.1639
# Epoch 889/1000
# 32/32 - 0s - 3ms/step - loss: 0.0627 - mean_absolute_error: 0.1531 - val_loss: 0.0746 - val_mean_absolute_error: 0.1670
# Epoch 890/1000
# 32/32 - 0s - 3ms/step - loss: 0.0676 - mean_absolute_error: 0.1596 - val_loss: 0.0782 - val_mean_absolute_error: 0.1725
# Epoch 891/1000
# 32/32 - 0s - 3ms/step - loss: 0.0661 - mean_absolute_error: 0.1591 - val_loss: 0.0707 - val_mean_absolute_error: 0.1627
# Epoch 892/1000
# 32/32 - 0s - 3ms/step - loss: 0.0594 - mean_absolute_error: 0.1489 - val_loss: 0.0724 - val_mean_absolute_error: 0.1644
# Epoch 893/1000
# 32/32 - 0s - 3ms/step - loss: 0.0656 - mean_absolute_error: 0.1570 - val_loss: 0.0756 - val_mean_absolute_error: 0.1692
# Epoch 894/1000
# 32/32 - 0s - 3ms/step - loss: 0.0664 - mean_absolute_error: 0.1578 - val_loss: 0.0725 - val_mean_absolute_error: 0.1677
# Epoch 895/1000
# 32/32 - 0s - 3ms/step - loss: 0.0693 - mean_absolute_error: 0.1613 - val_loss: 0.0859 - val_mean_absolute_error: 0.1796
# Epoch 896/1000
# 32/32 - 0s - 3ms/step - loss: 0.0634 - mean_absolute_error: 0.1552 - val_loss: 0.0676 - val_mean_absolute_error: 0.1609
# Epoch 897/1000
# 32/32 - 0s - 3ms/step - loss: 0.0620 - mean_absolute_error: 0.1520 - val_loss: 0.0725 - val_mean_absolute_error: 0.1626
# Epoch 898/1000
# 32/32 - 0s - 3ms/step - loss: 0.0621 - mean_absolute_error: 0.1514 - val_loss: 0.0735 - val_mean_absolute_error: 0.1647
# Epoch 899/1000
# 32/32 - 0s - 3ms/step - loss: 0.0624 - mean_absolute_error: 0.1513 - val_loss: 0.0696 - val_mean_absolute_error: 0.1612
# Epoch 900/1000
# 32/32 - 0s - 3ms/step - loss: 0.0691 - mean_absolute_error: 0.1631 - val_loss: 0.0740 - val_mean_absolute_error: 0.1658
# Epoch 901/1000
# 32/32 - 0s - 3ms/step - loss: 0.0715 - mean_absolute_error: 0.1640 - val_loss: 0.0866 - val_mean_absolute_error: 0.1861
# Epoch 902/1000
# 32/32 - 0s - 3ms/step - loss: 0.0669 - mean_absolute_error: 0.1605 - val_loss: 0.0774 - val_mean_absolute_error: 0.1687
# Epoch 903/1000
# 32/32 - 0s - 3ms/step - loss: 0.0633 - mean_absolute_error: 0.1544 - val_loss: 0.0772 - val_mean_absolute_error: 0.1724
# Epoch 904/1000
# 32/32 - 0s - 3ms/step - loss: 0.0623 - mean_absolute_error: 0.1531 - val_loss: 0.0878 - val_mean_absolute_error: 0.1784
# Epoch 905/1000
# 32/32 - 0s - 3ms/step - loss: 0.0665 - mean_absolute_error: 0.1581 - val_loss: 0.0824 - val_mean_absolute_error: 0.1784
# Epoch 906/1000
# 32/32 - 0s - 3ms/step - loss: 0.0721 - mean_absolute_error: 0.1644 - val_loss: 0.0914 - val_mean_absolute_error: 0.1856
# Epoch 907/1000
# 32/32 - 0s - 3ms/step - loss: 0.0696 - mean_absolute_error: 0.1630 - val_loss: 0.0700 - val_mean_absolute_error: 0.1657
# Epoch 908/1000
# 32/32 - 0s - 3ms/step - loss: 0.0640 - mean_absolute_error: 0.1567 - val_loss: 0.0703 - val_mean_absolute_error: 0.1609
# Epoch 909/1000
# 32/32 - 0s - 3ms/step - loss: 0.0652 - mean_absolute_error: 0.1571 - val_loss: 0.0704 - val_mean_absolute_error: 0.1616
# Epoch 910/1000
# 32/32 - 0s - 3ms/step - loss: 0.0632 - mean_absolute_error: 0.1544 - val_loss: 0.0845 - val_mean_absolute_error: 0.1808
# Epoch 911/1000
# 32/32 - 0s - 3ms/step - loss: 0.0615 - mean_absolute_error: 0.1519 - val_loss: 0.0726 - val_mean_absolute_error: 0.1615
# Epoch 912/1000
# 32/32 - 0s - 4ms/step - loss: 0.0726 - mean_absolute_error: 0.1638 - val_loss: 0.0750 - val_mean_absolute_error: 0.1737
# Epoch 913/1000
# 32/32 - 0s - 3ms/step - loss: 0.0719 - mean_absolute_error: 0.1650 - val_loss: 0.0716 - val_mean_absolute_error: 0.1638
# Epoch 914/1000
# 32/32 - 0s - 3ms/step - loss: 0.0647 - mean_absolute_error: 0.1565 - val_loss: 0.0785 - val_mean_absolute_error: 0.1730
# Epoch 915/1000
# 32/32 - 0s - 3ms/step - loss: 0.0686 - mean_absolute_error: 0.1613 - val_loss: 0.0791 - val_mean_absolute_error: 0.1698
# Epoch 916/1000
# 32/32 - 0s - 3ms/step - loss: 0.0615 - mean_absolute_error: 0.1511 - val_loss: 0.0728 - val_mean_absolute_error: 0.1650
# Epoch 917/1000
# 32/32 - 0s - 3ms/step - loss: 0.0668 - mean_absolute_error: 0.1561 - val_loss: 0.0915 - val_mean_absolute_error: 0.1828
# Epoch 918/1000
# 32/32 - 0s - 3ms/step - loss: 0.0606 - mean_absolute_error: 0.1510 - val_loss: 0.0695 - val_mean_absolute_error: 0.1626
# Epoch 919/1000
# 32/32 - 0s - 3ms/step - loss: 0.0660 - mean_absolute_error: 0.1559 - val_loss: 0.0741 - val_mean_absolute_error: 0.1652
# Epoch 920/1000
# 32/32 - 0s - 3ms/step - loss: 0.0607 - mean_absolute_error: 0.1502 - val_loss: 0.0708 - val_mean_absolute_error: 0.1616
# Epoch 921/1000
# 32/32 - 0s - 3ms/step - loss: 0.0604 - mean_absolute_error: 0.1503 - val_loss: 0.0817 - val_mean_absolute_error: 0.1735
# Epoch 922/1000
# 32/32 - 0s - 3ms/step - loss: 0.0728 - mean_absolute_error: 0.1647 - val_loss: 0.0847 - val_mean_absolute_error: 0.1780
# Epoch 923/1000
# 32/32 - 0s - 3ms/step - loss: 0.0636 - mean_absolute_error: 0.1562 - val_loss: 0.0787 - val_mean_absolute_error: 0.1770
# Epoch 924/1000
# 32/32 - 0s - 4ms/step - loss: 0.0700 - mean_absolute_error: 0.1631 - val_loss: 0.0755 - val_mean_absolute_error: 0.1697
# Epoch 925/1000
# 32/32 - 0s - 3ms/step - loss: 0.0619 - mean_absolute_error: 0.1524 - val_loss: 0.0736 - val_mean_absolute_error: 0.1613
# Epoch 926/1000
# 32/32 - 0s - 3ms/step - loss: 0.0617 - mean_absolute_error: 0.1501 - val_loss: 0.0701 - val_mean_absolute_error: 0.1603
# Epoch 927/1000
# 32/32 - 0s - 3ms/step - loss: 0.0631 - mean_absolute_error: 0.1519 - val_loss: 0.0781 - val_mean_absolute_error: 0.1743
# Epoch 928/1000
# 32/32 - 0s - 3ms/step - loss: 0.0617 - mean_absolute_error: 0.1531 - val_loss: 0.0722 - val_mean_absolute_error: 0.1666
# Epoch 929/1000
# 32/32 - 0s - 3ms/step - loss: 0.0599 - mean_absolute_error: 0.1503 - val_loss: 0.0677 - val_mean_absolute_error: 0.1583
# Epoch 930/1000
# 32/32 - 0s - 3ms/step - loss: 0.0641 - mean_absolute_error: 0.1540 - val_loss: 0.0868 - val_mean_absolute_error: 0.1790
# Epoch 931/1000
# 32/32 - 0s - 3ms/step - loss: 0.0634 - mean_absolute_error: 0.1538 - val_loss: 0.0830 - val_mean_absolute_error: 0.1762
# Epoch 932/1000
# 32/32 - 0s - 3ms/step - loss: 0.0640 - mean_absolute_error: 0.1552 - val_loss: 0.0712 - val_mean_absolute_error: 0.1633
# Epoch 933/1000
# 32/32 - 0s - 3ms/step - loss: 0.0641 - mean_absolute_error: 0.1535 - val_loss: 0.0754 - val_mean_absolute_error: 0.1641
# Epoch 934/1000
# 32/32 - 0s - 3ms/step - loss: 0.0678 - mean_absolute_error: 0.1571 - val_loss: 0.0711 - val_mean_absolute_error: 0.1615
# Epoch 935/1000
# 32/32 - 0s - 3ms/step - loss: 0.0616 - mean_absolute_error: 0.1514 - val_loss: 0.0678 - val_mean_absolute_error: 0.1594
# Epoch 936/1000
# 32/32 - 0s - 3ms/step - loss: 0.0685 - mean_absolute_error: 0.1585 - val_loss: 0.0796 - val_mean_absolute_error: 0.1756
# Epoch 937/1000
# 32/32 - 0s - 3ms/step - loss: 0.0663 - mean_absolute_error: 0.1588 - val_loss: 0.0953 - val_mean_absolute_error: 0.1955
# Epoch 938/1000
# 32/32 - 0s - 3ms/step - loss: 0.0713 - mean_absolute_error: 0.1652 - val_loss: 0.0789 - val_mean_absolute_error: 0.1715
# Epoch 939/1000
# 32/32 - 0s - 4ms/step - loss: 0.0618 - mean_absolute_error: 0.1523 - val_loss: 0.0683 - val_mean_absolute_error: 0.1591
# Epoch 940/1000
# 32/32 - 0s - 3ms/step - loss: 0.0602 - mean_absolute_error: 0.1499 - val_loss: 0.0668 - val_mean_absolute_error: 0.1573
# Epoch 941/1000
# 32/32 - 0s - 3ms/step - loss: 0.0665 - mean_absolute_error: 0.1567 - val_loss: 0.0954 - val_mean_absolute_error: 0.1898
# Epoch 942/1000
# 32/32 - 0s - 3ms/step - loss: 0.0691 - mean_absolute_error: 0.1612 - val_loss: 0.0741 - val_mean_absolute_error: 0.1665
# Epoch 943/1000
# 32/32 - 0s - 3ms/step - loss: 0.0594 - mean_absolute_error: 0.1478 - val_loss: 0.0673 - val_mean_absolute_error: 0.1563
# Epoch 944/1000
# 32/32 - 0s - 3ms/step - loss: 0.0603 - mean_absolute_error: 0.1494 - val_loss: 0.0746 - val_mean_absolute_error: 0.1681
# Epoch 945/1000
# 32/32 - 0s - 4ms/step - loss: 0.0766 - mean_absolute_error: 0.1730 - val_loss: 0.0836 - val_mean_absolute_error: 0.1784
# Epoch 946/1000
# 32/32 - 0s - 3ms/step - loss: 0.0656 - mean_absolute_error: 0.1590 - val_loss: 0.0707 - val_mean_absolute_error: 0.1626
# Epoch 947/1000
# 32/32 - 0s - 3ms/step - loss: 0.0627 - mean_absolute_error: 0.1530 - val_loss: 0.0916 - val_mean_absolute_error: 0.1833
# Epoch 948/1000
# 32/32 - 0s - 3ms/step - loss: 0.0664 - mean_absolute_error: 0.1589 - val_loss: 0.0778 - val_mean_absolute_error: 0.1694
# Epoch 949/1000
# 32/32 - 0s - 3ms/step - loss: 0.0645 - mean_absolute_error: 0.1548 - val_loss: 0.0718 - val_mean_absolute_error: 0.1651
# Epoch 950/1000
# 32/32 - 0s - 3ms/step - loss: 0.0640 - mean_absolute_error: 0.1548 - val_loss: 0.0731 - val_mean_absolute_error: 0.1662
# Epoch 951/1000
# 32/32 - 0s - 3ms/step - loss: 0.0613 - mean_absolute_error: 0.1510 - val_loss: 0.0685 - val_mean_absolute_error: 0.1599
# Epoch 952/1000
# 32/32 - 0s - 3ms/step - loss: 0.0677 - mean_absolute_error: 0.1591 - val_loss: 0.0813 - val_mean_absolute_error: 0.1796
# Epoch 953/1000
# 32/32 - 0s - 3ms/step - loss: 0.0683 - mean_absolute_error: 0.1626 - val_loss: 0.0677 - val_mean_absolute_error: 0.1602
# Epoch 954/1000
# 32/32 - 0s - 3ms/step - loss: 0.0619 - mean_absolute_error: 0.1512 - val_loss: 0.0736 - val_mean_absolute_error: 0.1681
# Epoch 955/1000
# 32/32 - 0s - 3ms/step - loss: 0.0661 - mean_absolute_error: 0.1571 - val_loss: 0.0793 - val_mean_absolute_error: 0.1718
# Epoch 956/1000
# 32/32 - 0s - 3ms/step - loss: 0.0678 - mean_absolute_error: 0.1576 - val_loss: 0.0713 - val_mean_absolute_error: 0.1627
# Epoch 957/1000
# 32/32 - 0s - 3ms/step - loss: 0.0581 - mean_absolute_error: 0.1477 - val_loss: 0.0738 - val_mean_absolute_error: 0.1655
# Epoch 958/1000
# 32/32 - 0s - 3ms/step - loss: 0.0622 - mean_absolute_error: 0.1514 - val_loss: 0.0757 - val_mean_absolute_error: 0.1687
# Epoch 959/1000
# 32/32 - 0s - 3ms/step - loss: 0.0612 - mean_absolute_error: 0.1520 - val_loss: 0.0901 - val_mean_absolute_error: 0.1820
# Epoch 960/1000
# 32/32 - 0s - 3ms/step - loss: 0.0657 - mean_absolute_error: 0.1564 - val_loss: 0.0847 - val_mean_absolute_error: 0.1754
# Epoch 961/1000
# 32/32 - 0s - 3ms/step - loss: 0.0676 - mean_absolute_error: 0.1583 - val_loss: 0.0808 - val_mean_absolute_error: 0.1734
# Epoch 962/1000
# 32/32 - 0s - 3ms/step - loss: 0.0673 - mean_absolute_error: 0.1597 - val_loss: 0.0758 - val_mean_absolute_error: 0.1676
# Epoch 963/1000
# 32/32 - 0s - 3ms/step - loss: 0.0609 - mean_absolute_error: 0.1505 - val_loss: 0.0664 - val_mean_absolute_error: 0.1563
# Epoch 964/1000
# 32/32 - 0s - 3ms/step - loss: 0.0632 - mean_absolute_error: 0.1510 - val_loss: 0.0764 - val_mean_absolute_error: 0.1688
# Epoch 965/1000
# 32/32 - 0s - 4ms/step - loss: 0.0696 - mean_absolute_error: 0.1644 - val_loss: 0.0736 - val_mean_absolute_error: 0.1700
# Epoch 966/1000
# 32/32 - 0s - 3ms/step - loss: 0.0648 - mean_absolute_error: 0.1568 - val_loss: 0.0778 - val_mean_absolute_error: 0.1693
# Epoch 967/1000
# 32/32 - 0s - 3ms/step - loss: 0.0640 - mean_absolute_error: 0.1547 - val_loss: 0.0778 - val_mean_absolute_error: 0.1665
# Epoch 968/1000
# 32/32 - 0s - 3ms/step - loss: 0.0651 - mean_absolute_error: 0.1562 - val_loss: 0.0721 - val_mean_absolute_error: 0.1648
# Epoch 969/1000
# 32/32 - 0s - 3ms/step - loss: 0.0617 - mean_absolute_error: 0.1515 - val_loss: 0.0861 - val_mean_absolute_error: 0.1788
# Epoch 970/1000
# 32/32 - 0s - 3ms/step - loss: 0.0609 - mean_absolute_error: 0.1497 - val_loss: 0.0685 - val_mean_absolute_error: 0.1567
# Epoch 971/1000
# 32/32 - 0s - 3ms/step - loss: 0.0651 - mean_absolute_error: 0.1545 - val_loss: 0.0768 - val_mean_absolute_error: 0.1721
# Epoch 972/1000
# 32/32 - 0s - 3ms/step - loss: 0.0657 - mean_absolute_error: 0.1562 - val_loss: 0.0924 - val_mean_absolute_error: 0.1860
# Epoch 973/1000
# 32/32 - 0s - 3ms/step - loss: 0.0661 - mean_absolute_error: 0.1600 - val_loss: 0.0698 - val_mean_absolute_error: 0.1633
# Epoch 974/1000
# 32/32 - 0s - 3ms/step - loss: 0.0684 - mean_absolute_error: 0.1600 - val_loss: 0.0888 - val_mean_absolute_error: 0.1812
# Epoch 975/1000
# 32/32 - 0s - 3ms/step - loss: 0.0679 - mean_absolute_error: 0.1596 - val_loss: 0.0760 - val_mean_absolute_error: 0.1679
# Epoch 976/1000
# 32/32 - 0s - 3ms/step - loss: 0.0605 - mean_absolute_error: 0.1507 - val_loss: 0.0791 - val_mean_absolute_error: 0.1724
# Epoch 977/1000
# 32/32 - 0s - 3ms/step - loss: 0.0644 - mean_absolute_error: 0.1552 - val_loss: 0.0722 - val_mean_absolute_error: 0.1626
# Epoch 978/1000
# 32/32 - 0s - 3ms/step - loss: 0.0588 - mean_absolute_error: 0.1477 - val_loss: 0.0740 - val_mean_absolute_error: 0.1696
# Epoch 979/1000
# 32/32 - 0s - 3ms/step - loss: 0.0600 - mean_absolute_error: 0.1484 - val_loss: 0.0681 - val_mean_absolute_error: 0.1591
# Epoch 980/1000
# 32/32 - 0s - 3ms/step - loss: 0.0614 - mean_absolute_error: 0.1511 - val_loss: 0.0791 - val_mean_absolute_error: 0.1740
# Epoch 981/1000
# 32/32 - 0s - 4ms/step - loss: 0.0726 - mean_absolute_error: 0.1626 - val_loss: 0.0829 - val_mean_absolute_error: 0.1746
# Epoch 982/1000
# 32/32 - 0s - 3ms/step - loss: 0.0603 - mean_absolute_error: 0.1512 - val_loss: 0.0714 - val_mean_absolute_error: 0.1620
# Epoch 983/1000
# 32/32 - 0s - 3ms/step - loss: 0.0608 - mean_absolute_error: 0.1496 - val_loss: 0.0665 - val_mean_absolute_error: 0.1570
# Epoch 984/1000
# 32/32 - 0s - 3ms/step - loss: 0.0583 - mean_absolute_error: 0.1462 - val_loss: 0.0719 - val_mean_absolute_error: 0.1602
# Epoch 985/1000
# 32/32 - 0s - 3ms/step - loss: 0.0652 - mean_absolute_error: 0.1574 - val_loss: 0.0771 - val_mean_absolute_error: 0.1673
# Epoch 986/1000
# 32/32 - 0s - 3ms/step - loss: 0.0629 - mean_absolute_error: 0.1525 - val_loss: 0.0717 - val_mean_absolute_error: 0.1658
# Epoch 987/1000
# 32/32 - 0s - 3ms/step - loss: 0.0649 - mean_absolute_error: 0.1557 - val_loss: 0.0696 - val_mean_absolute_error: 0.1594
# Epoch 988/1000
# 32/32 - 0s - 3ms/step - loss: 0.0659 - mean_absolute_error: 0.1563 - val_loss: 0.0739 - val_mean_absolute_error: 0.1697
# Epoch 989/1000
# 32/32 - 0s - 3ms/step - loss: 0.0623 - mean_absolute_error: 0.1535 - val_loss: 0.0717 - val_mean_absolute_error: 0.1635
# Epoch 990/1000
# 32/32 - 0s - 3ms/step - loss: 0.0616 - mean_absolute_error: 0.1508 - val_loss: 0.0743 - val_mean_absolute_error: 0.1696
# Epoch 991/1000
# 32/32 - 0s - 3ms/step - loss: 0.0714 - mean_absolute_error: 0.1634 - val_loss: 0.0729 - val_mean_absolute_error: 0.1663
# Epoch 992/1000
# 32/32 - 0s - 3ms/step - loss: 0.0683 - mean_absolute_error: 0.1625 - val_loss: 0.0729 - val_mean_absolute_error: 0.1667
# Epoch 993/1000
# 32/32 - 0s - 3ms/step - loss: 0.0635 - mean_absolute_error: 0.1535 - val_loss: 0.0742 - val_mean_absolute_error: 0.1673
# Epoch 994/1000
# 32/32 - 0s - 3ms/step - loss: 0.0603 - mean_absolute_error: 0.1492 - val_loss: 0.0767 - val_mean_absolute_error: 0.1683
# Epoch 995/1000
# 32/32 - 0s - 3ms/step - loss: 0.0601 - mean_absolute_error: 0.1487 - val_loss: 0.0780 - val_mean_absolute_error: 0.1691
# Epoch 996/1000
# 32/32 - 0s - 3ms/step - loss: 0.0712 - mean_absolute_error: 0.1651 - val_loss: 0.0771 - val_mean_absolute_error: 0.1764
# Epoch 997/1000
# 32/32 - 0s - 3ms/step - loss: 0.0655 - mean_absolute_error: 0.1603 - val_loss: 0.0770 - val_mean_absolute_error: 0.1699
# Epoch 998/1000
# 32/32 - 0s - 4ms/step - loss: 0.0678 - mean_absolute_error: 0.1592 - val_loss: 0.0815 - val_mean_absolute_error: 0.1748
# Epoch 999/1000
# 32/32 - 0s - 3ms/step - loss: 0.0653 - mean_absolute_error: 0.1561 - val_loss: 0.0689 - val_mean_absolute_error: 0.1605
# Epoch 1000/1000
# 32/32 - 0s - 3ms/step - loss: 0.0612 - mean_absolute_error: 0.1509 - val_loss: 0.0667 - val_mean_absolute_error: 0.1561

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_noNoise.keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_test_norm, y_test_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_test_norm)
# Out:
# MSE: 0.06934992223978043
# MAE: 0.16215230524539948
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# ##### Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_test_denorm = scaler_y.inverse_transform(y_test_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

# Dibujamos los datos
symbols = [r'$\kappa$', r'$\Delta E$', r'$\gamma$', r'$g$']

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [10, 7.5], 
    "figure.dpi": 300 
})

# Crear subgráficos para cada variable
fig, axes = plt.subplots(nrows=2, ncols=2, constrained_layout=True)

# Añadir los subgráficos
for i, ax in enumerate(axes.flatten()):
    if i < y_test_denorm.shape[1]:  # Verifica que no exceda el número de columnas en los datos
        ax.plot(y_test_denorm[:, i], y_pred_denorm[:, i], marker='o', linestyle='',
                markersize=3, color='cornflowerblue')
        ax.plot([y_test_denorm[:, i].min(), y_test_denorm[:, i].max()],
                [y_test_denorm[:, i].min(), y_test_denorm[:, i].max()], linestyle='-', color='red', linewidth=2 )
        ax.set_xlabel('Real')
        ax.set_ylabel('NN')
        ax.set_title(symbols[i]) 

        if i == 1:  # Índice 1 corresponde a Delta E
            ticks = [0.5, 1.0, 1.5]
        else:
            ticks = [1e-4, 5e-3, 1e-2]

        ax.set_xticks(ticks)
        ax.set_yticks(ticks)
        
        # Aplicar notación científica a los ejes
        if i != 2:  # Índice 2 corresponde a Delta E
            ax.ticklabel_format(style='sci', axis='both', scilimits=(0, 0))
        else:
            ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
            ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
            ax.ticklabel_format(style='sci', axis='both', scilimits=(0,0))

labels = ["Predicciones", "Valor real"]
fig.legend(labels, loc='upper center', bbox_to_anchor=(0.53, 1.07), ncol=2)

plt.show()

# %% [markdown]
# ##### Curvas Validación VS Predicción

# %%
k_pred = y_pred_denorm[:, 0]
k_test = y_test_denorm[:, 0]
DeltaE_pred = y_pred_denorm[:, 1]
DeltaE_test = y_test_denorm[:, 1]
gamma_pred = y_pred_denorm[:, 2]
gamma_test = y_test_denorm[:, 2]
g_pred = y_pred_denorm[:, 3]
g_test = y_test_denorm[:, 3]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_test = np.zeros((x_val.shape[0], len(w_values)))


for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k_pred[i], Omega, DeltaE_pred[i], gamma_pred[i], g_pred[i])
    t_values_test[i,:] = t_w(w_values, k_test[i],  Omega, DeltaE_test[i], gamma_test[i], g_test[i])

# w1 = w2 = np.zeros(x_val.shape[0])

# w1=w_1(k_test, Omega, DeltaE_test, gamma_test, g_test)
# w2=w_2(k_test, Omega, DeltaE_test, gamma_test, g_test)

plt.rcParams.update({
    "text.usetex": False,
    "figure.figsize": [12, 7], 
})

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_test[i, :], color="b", label="Real")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Network prediction")

    # # Calcula los valores de t(w) en w1 y w2
    # t_w1 = t_w(w1[i], k_test[i], Omega, DeltaE_test[i], gamma_test[i], g_test[i])
    # t_w2 = t_w(w2[i], k_test[i], Omega, DeltaE_test[i], gamma_test[i], g_test[i])
    
    # if w_values.min() <= w1[i] <= w_values.max():
    #     plt.vlines(w1[i], 0, t_w1, colors='black', linewidth=0.5)
    # if w_values.min() <= w2[i] <= w_values.max():
    #     plt.vlines(w2[i], 0, t_w2, colors='black', linewidth=0.5)
   
    plt.title(f"Pred. vs Test. Curve number: {i}")
    plt.xlabel(r"$\omega$")
    plt.ylabel(r"$t (\omega$)")
    plt.legend(framealpha=1, loc='upper right')
    # plt.ylim(,1) 
    plt.xlim(0.85,1.15) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"$\kappa$ real = {k_test[i]:.2e}, $\kappa$ pred = {k_pred[i]:.2e}\n"\
           f"$\Delta$E real = {DeltaE_test[i]:.3f}, $\Delta$E pred = {DeltaE_pred[i]:.3f}\n"\
           f"$\gamma$ real = {gamma_test[i]:.2e}, $\gamma$ pred = {gamma_pred[i]:.2e}\n"\
           f"g real = {g_test[i]:.2e}, g pred = {g_pred[i]:.2e}"
    plt.text(0.011, 0.95, text, transform=plt.gca().transAxes, fontsize=16, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=1))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # Dibujos para Memoria

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['cmr10'], 
    "figure.titlesize": 22,
    "axes.labelsize": 20, 
    "axes.titlesize": 20, 
    "xtick.labelsize": 18, 
    "ytick.labelsize": 18, 
    "legend.fontsize": 18,
    "figure.figsize": [12,7], 
    "figure.dpi": 300 
})


pics = [1,18,37,70,107,165]
labels_subplots = ["a)", "b)", "c)", "d)", "e)", "f)"]

fig, axes = plt.subplots(2, 3, constrained_layout=True)
for idx, (ax, i) in enumerate(zip(axes.flat, pics)):
    ax.plot(w_values, t_values_test[i, :], color="b")
    ax.plot(w_values, t_values_pred[i, :], color="r", linestyle='--')
    ax.set_yticks(np.arange(0, 1.05, 0.25))
    ax.set_xticks(np.linspace(w_values.min(), w_values.max(), 5))
    ax.set_ylim(-0.03, 1.05)

    ax.text(0.03, 0.97, labels_subplots[idx], transform=ax.transAxes, 
        fontsize=15, fontweight='bold', va='top', ha='left')

    # Configurar etiquetas y ticks según la posición del subplot
    if idx % 3 == 0:  # Primera columna
        ax.set_ylabel(r'$t(\omega)$')  # Etiqueta y en la columna izquierda
    else:
        ax.set_yticklabels([])  # Sin etiquetas en el eje y en la columna derecha
        ax.tick_params(axis='y', labelleft=False)

    if idx // 3 == 1:  # Última fila
        ax.set_xlabel(r'$\omega$')  # Etiqueta x en la fila inferior
    else:
        ax.set_xticklabels([])  # Sin etiquetas en el eje x en la fila superior
        ax.tick_params(axis='x', labelbottom=False)

    ax.tick_params(axis='both', direction='in')


labels = ["Real", "NN"]
fig.legend(labels, loc='upper center', bbox_to_anchor=(0.52, 1.09), ncol=2)
plt.show()

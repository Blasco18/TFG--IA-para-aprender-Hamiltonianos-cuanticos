# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos: $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # Sin ruido

# %% [markdown]
# ## Creamos base de datos

# %%
#Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)

    return DeltaE, gamma, g

num_datos = 5000

# %%
# #Creamos base de datos y guardamos en .txt
# DeltaE, gamma, g = Parameters_generator (num_datos)
# np.savetxt('Parameters_noNoise(kappa-fijo).txt', np.column_stack((DeltaE, gamma, g)), header='\u0394E \u213D g')

# %%
datos = np.loadtxt('Parameters_noNoise(kappa-fijo).txt', skiprows=1)
DeltaE = datos[:,0]
gamma = datos[:,1]
g = datos[:,2]
k = 7e-3
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.8, 1.2, 400)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))

# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k, Omega, DeltaE[i], gamma[i], g[i])

# %% [markdown]
# ### Dibujamos alguna curva

# %%
# i=0
# while i<=1000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values[i,:], label='Curva original')
#     plt.plot(w_values, t_sep_values[i,:], linestyle='--', label='Curva separada')
#     plt.plot(w_values, mod_t_values[i,:], linestyle='-.', label='Módulo curva')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
x_train, x_val, y_train, y_val = train_test_split(t_values, datos, test_size=0.2)

# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 400)
# y_train shape (4000, 3)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_noNoise_five(kappa-7e-3).keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 1s - loss: 0.8206 - mean_absolute_error: 0.7542 - val_loss: 0.7079 - val_mean_absolute_error: 0.6881 - 990ms/epoch - 12ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.6607 - mean_absolute_error: 0.6480 - val_loss: 0.6146 - val_mean_absolute_error: 0.6222 - 146ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.5961 - mean_absolute_error: 0.6025 - val_loss: 0.5563 - val_mean_absolute_error: 0.5771 - 160ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.5436 - mean_absolute_error: 0.5630 - val_loss: 0.5107 - val_mean_absolute_error: 0.5410 - 149ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.5038 - mean_absolute_error: 0.5336 - val_loss: 0.4829 - val_mean_absolute_error: 0.5298 - 148ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.4777 - mean_absolute_error: 0.5148 - val_loss: 0.4504 - val_mean_absolute_error: 0.4975 - 149ms/epoch - 2ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.4548 - mean_absolute_error: 0.4969 - val_loss: 0.4409 - val_mean_absolute_error: 0.4997 - 147ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.4350 - mean_absolute_error: 0.4828 - val_loss: 0.4139 - val_mean_absolute_error: 0.4705 - 149ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.4214 - mean_absolute_error: 0.4718 - val_loss: 0.3950 - val_mean_absolute_error: 0.4543 - 147ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.3994 - mean_absolute_error: 0.4543 - val_loss: 0.3712 - val_mean_absolute_error: 0.4356 - 148ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.3784 - mean_absolute_error: 0.4364 - val_loss: 0.3651 - val_mean_absolute_error: 0.4278 - 148ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.3720 - mean_absolute_error: 0.4282 - val_loss: 0.3632 - val_mean_absolute_error: 0.4289 - 147ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.3607 - mean_absolute_error: 0.4203 - val_loss: 0.3480 - val_mean_absolute_error: 0.4100 - 150ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.3462 - mean_absolute_error: 0.4062 - val_loss: 0.3362 - val_mean_absolute_error: 0.4013 - 146ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.3303 - mean_absolute_error: 0.3911 - val_loss: 0.3375 - val_mean_absolute_error: 0.4026 - 159ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.3228 - mean_absolute_error: 0.3854 - val_loss: 0.3153 - val_mean_absolute_error: 0.3761 - 165ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.3103 - mean_absolute_error: 0.3691 - val_loss: 0.3074 - val_mean_absolute_error: 0.3687 - 148ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.3020 - mean_absolute_error: 0.3607 - val_loss: 0.3072 - val_mean_absolute_error: 0.3849 - 148ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.3039 - mean_absolute_error: 0.3669 - val_loss: 0.2960 - val_mean_absolute_error: 0.3609 - 149ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.2933 - mean_absolute_error: 0.3516 - val_loss: 0.2932 - val_mean_absolute_error: 0.3514 - 147ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.2872 - mean_absolute_error: 0.3443 - val_loss: 0.2879 - val_mean_absolute_error: 0.3511 - 150ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.2875 - mean_absolute_error: 0.3458 - val_loss: 0.2746 - val_mean_absolute_error: 0.3337 - 146ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.2793 - mean_absolute_error: 0.3359 - val_loss: 0.2841 - val_mean_absolute_error: 0.3360 - 147ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.2777 - mean_absolute_error: 0.3324 - val_loss: 0.2818 - val_mean_absolute_error: 0.3361 - 145ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.2720 - mean_absolute_error: 0.3236 - val_loss: 0.2695 - val_mean_absolute_error: 0.3305 - 147ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.2730 - mean_absolute_error: 0.3275 - val_loss: 0.2773 - val_mean_absolute_error: 0.3381 - 156ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.2727 - mean_absolute_error: 0.3280 - val_loss: 0.2683 - val_mean_absolute_error: 0.3273 - 150ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.2617 - mean_absolute_error: 0.3126 - val_loss: 0.2564 - val_mean_absolute_error: 0.3074 - 149ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.2592 - mean_absolute_error: 0.3086 - val_loss: 0.2677 - val_mean_absolute_error: 0.3170 - 150ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.2531 - mean_absolute_error: 0.2990 - val_loss: 0.2629 - val_mean_absolute_error: 0.3125 - 150ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.2649 - mean_absolute_error: 0.3104 - val_loss: 0.2640 - val_mean_absolute_error: 0.3174 - 158ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.2622 - mean_absolute_error: 0.3100 - val_loss: 0.2581 - val_mean_absolute_error: 0.3163 - 180ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.2556 - mean_absolute_error: 0.3039 - val_loss: 0.2574 - val_mean_absolute_error: 0.3076 - 163ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.2500 - mean_absolute_error: 0.2951 - val_loss: 0.2571 - val_mean_absolute_error: 0.2973 - 154ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.2516 - mean_absolute_error: 0.2928 - val_loss: 0.2488 - val_mean_absolute_error: 0.2923 - 144ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.2500 - mean_absolute_error: 0.2944 - val_loss: 0.2472 - val_mean_absolute_error: 0.3044 - 143ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.2509 - mean_absolute_error: 0.2963 - val_loss: 0.2448 - val_mean_absolute_error: 0.2932 - 144ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.2442 - mean_absolute_error: 0.2873 - val_loss: 0.2407 - val_mean_absolute_error: 0.2828 - 143ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.2430 - mean_absolute_error: 0.2835 - val_loss: 0.2492 - val_mean_absolute_error: 0.2967 - 146ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.2446 - mean_absolute_error: 0.2849 - val_loss: 0.2339 - val_mean_absolute_error: 0.2773 - 148ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.2512 - mean_absolute_error: 0.2900 - val_loss: 0.2358 - val_mean_absolute_error: 0.2776 - 148ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.2439 - mean_absolute_error: 0.2820 - val_loss: 0.2496 - val_mean_absolute_error: 0.2760 - 147ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.2392 - mean_absolute_error: 0.2740 - val_loss: 0.2400 - val_mean_absolute_error: 0.2787 - 148ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.2388 - mean_absolute_error: 0.2762 - val_loss: 0.2390 - val_mean_absolute_error: 0.2853 - 150ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.2421 - mean_absolute_error: 0.2832 - val_loss: 0.2440 - val_mean_absolute_error: 0.2856 - 147ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.2394 - mean_absolute_error: 0.2742 - val_loss: 0.2432 - val_mean_absolute_error: 0.2847 - 146ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.2363 - mean_absolute_error: 0.2721 - val_loss: 0.2481 - val_mean_absolute_error: 0.3031 - 152ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.2379 - mean_absolute_error: 0.2759 - val_loss: 0.2306 - val_mean_absolute_error: 0.2737 - 163ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.2333 - mean_absolute_error: 0.2681 - val_loss: 0.2265 - val_mean_absolute_error: 0.2694 - 150ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.2340 - mean_absolute_error: 0.2682 - val_loss: 0.2371 - val_mean_absolute_error: 0.2796 - 150ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.2361 - mean_absolute_error: 0.2734 - val_loss: 0.2504 - val_mean_absolute_error: 0.2795 - 149ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.2335 - mean_absolute_error: 0.2667 - val_loss: 0.2353 - val_mean_absolute_error: 0.2884 - 151ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.2430 - mean_absolute_error: 0.2778 - val_loss: 0.2273 - val_mean_absolute_error: 0.2637 - 150ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.2315 - mean_absolute_error: 0.2602 - val_loss: 0.2301 - val_mean_absolute_error: 0.2730 - 154ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.2322 - mean_absolute_error: 0.2616 - val_loss: 0.2357 - val_mean_absolute_error: 0.2732 - 146ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.2297 - mean_absolute_error: 0.2599 - val_loss: 0.2347 - val_mean_absolute_error: 0.2684 - 146ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.2308 - mean_absolute_error: 0.2572 - val_loss: 0.2263 - val_mean_absolute_error: 0.2581 - 150ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.2286 - mean_absolute_error: 0.2552 - val_loss: 0.2314 - val_mean_absolute_error: 0.2701 - 160ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.2302 - mean_absolute_error: 0.2612 - val_loss: 0.2298 - val_mean_absolute_error: 0.2647 - 148ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.2290 - mean_absolute_error: 0.2577 - val_loss: 0.2447 - val_mean_absolute_error: 0.2768 - 146ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.2325 - mean_absolute_error: 0.2598 - val_loss: 0.2285 - val_mean_absolute_error: 0.2587 - 145ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.2285 - mean_absolute_error: 0.2527 - val_loss: 0.2229 - val_mean_absolute_error: 0.2542 - 145ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.2277 - mean_absolute_error: 0.2531 - val_loss: 0.2251 - val_mean_absolute_error: 0.2571 - 144ms/epoch - 2ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.2286 - mean_absolute_error: 0.2558 - val_loss: 0.2283 - val_mean_absolute_error: 0.2525 - 144ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.2306 - mean_absolute_error: 0.2573 - val_loss: 0.2347 - val_mean_absolute_error: 0.2762 - 169ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.2308 - mean_absolute_error: 0.2590 - val_loss: 0.2197 - val_mean_absolute_error: 0.2553 - 149ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.2246 - mean_absolute_error: 0.2520 - val_loss: 0.2307 - val_mean_absolute_error: 0.2591 - 146ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.2254 - mean_absolute_error: 0.2526 - val_loss: 0.2281 - val_mean_absolute_error: 0.2539 - 148ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.2253 - mean_absolute_error: 0.2492 - val_loss: 0.2201 - val_mean_absolute_error: 0.2503 - 146ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.2238 - mean_absolute_error: 0.2480 - val_loss: 0.2178 - val_mean_absolute_error: 0.2522 - 145ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.2258 - mean_absolute_error: 0.2533 - val_loss: 0.2171 - val_mean_absolute_error: 0.2536 - 146ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.2224 - mean_absolute_error: 0.2462 - val_loss: 0.2241 - val_mean_absolute_error: 0.2656 - 144ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.2274 - mean_absolute_error: 0.2531 - val_loss: 0.2222 - val_mean_absolute_error: 0.2634 - 144ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.2252 - mean_absolute_error: 0.2532 - val_loss: 0.2269 - val_mean_absolute_error: 0.2688 - 144ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.2240 - mean_absolute_error: 0.2567 - val_loss: 0.2281 - val_mean_absolute_error: 0.2542 - 159ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.2218 - mean_absolute_error: 0.2475 - val_loss: 0.2176 - val_mean_absolute_error: 0.2468 - 146ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.2275 - mean_absolute_error: 0.2550 - val_loss: 0.2366 - val_mean_absolute_error: 0.2683 - 144ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.2270 - mean_absolute_error: 0.2560 - val_loss: 0.2150 - val_mean_absolute_error: 0.2567 - 147ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.2238 - mean_absolute_error: 0.2492 - val_loss: 0.2221 - val_mean_absolute_error: 0.2548 - 147ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.2238 - mean_absolute_error: 0.2531 - val_loss: 0.2262 - val_mean_absolute_error: 0.2647 - 146ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.2215 - mean_absolute_error: 0.2474 - val_loss: 0.2154 - val_mean_absolute_error: 0.2458 - 144ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.2202 - mean_absolute_error: 0.2418 - val_loss: 0.2156 - val_mean_absolute_error: 0.2447 - 143ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.2264 - mean_absolute_error: 0.2462 - val_loss: 0.2174 - val_mean_absolute_error: 0.2509 - 148ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.2224 - mean_absolute_error: 0.2468 - val_loss: 0.2181 - val_mean_absolute_error: 0.2470 - 148ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.2198 - mean_absolute_error: 0.2440 - val_loss: 0.2234 - val_mean_absolute_error: 0.2582 - 146ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.2209 - mean_absolute_error: 0.2472 - val_loss: 0.2281 - val_mean_absolute_error: 0.2606 - 146ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.2190 - mean_absolute_error: 0.2403 - val_loss: 0.2276 - val_mean_absolute_error: 0.2601 - 149ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.2195 - mean_absolute_error: 0.2415 - val_loss: 0.2219 - val_mean_absolute_error: 0.2557 - 148ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.2188 - mean_absolute_error: 0.2403 - val_loss: 0.2200 - val_mean_absolute_error: 0.2534 - 148ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.2229 - mean_absolute_error: 0.2463 - val_loss: 0.2248 - val_mean_absolute_error: 0.2513 - 145ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.2202 - mean_absolute_error: 0.2407 - val_loss: 0.2264 - val_mean_absolute_error: 0.2510 - 159ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.2207 - mean_absolute_error: 0.2445 - val_loss: 0.2260 - val_mean_absolute_error: 0.2541 - 156ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.2174 - mean_absolute_error: 0.2422 - val_loss: 0.2157 - val_mean_absolute_error: 0.2513 - 150ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.2226 - mean_absolute_error: 0.2433 - val_loss: 0.2264 - val_mean_absolute_error: 0.2498 - 145ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.2190 - mean_absolute_error: 0.2435 - val_loss: 0.2252 - val_mean_absolute_error: 0.2499 - 144ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.2211 - mean_absolute_error: 0.2430 - val_loss: 0.2282 - val_mean_absolute_error: 0.2568 - 151ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.2215 - mean_absolute_error: 0.2438 - val_loss: 0.2302 - val_mean_absolute_error: 0.2467 - 158ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.2182 - mean_absolute_error: 0.2381 - val_loss: 0.2249 - val_mean_absolute_error: 0.2514 - 182ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.2179 - mean_absolute_error: 0.2397 - val_loss: 0.2238 - val_mean_absolute_error: 0.2439 - 152ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.2261 - mean_absolute_error: 0.2467 - val_loss: 0.2238 - val_mean_absolute_error: 0.2545 - 156ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.2171 - mean_absolute_error: 0.2397 - val_loss: 0.2206 - val_mean_absolute_error: 0.2567 - 177ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.2202 - mean_absolute_error: 0.2447 - val_loss: 0.2181 - val_mean_absolute_error: 0.2431 - 205ms/epoch - 3ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.2183 - mean_absolute_error: 0.2390 - val_loss: 0.2224 - val_mean_absolute_error: 0.2513 - 168ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.2154 - mean_absolute_error: 0.2371 - val_loss: 0.2166 - val_mean_absolute_error: 0.2446 - 167ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.2162 - mean_absolute_error: 0.2386 - val_loss: 0.2241 - val_mean_absolute_error: 0.2489 - 155ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.2161 - mean_absolute_error: 0.2374 - val_loss: 0.2195 - val_mean_absolute_error: 0.2526 - 179ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.2147 - mean_absolute_error: 0.2357 - val_loss: 0.2222 - val_mean_absolute_error: 0.2423 - 157ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.2162 - mean_absolute_error: 0.2395 - val_loss: 0.2194 - val_mean_absolute_error: 0.2440 - 149ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.2144 - mean_absolute_error: 0.2362 - val_loss: 0.2163 - val_mean_absolute_error: 0.2500 - 147ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.2176 - mean_absolute_error: 0.2451 - val_loss: 0.2414 - val_mean_absolute_error: 0.2597 - 147ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.2193 - mean_absolute_error: 0.2390 - val_loss: 0.2266 - val_mean_absolute_error: 0.2471 - 150ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.2195 - mean_absolute_error: 0.2453 - val_loss: 0.2333 - val_mean_absolute_error: 0.2611 - 150ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.2180 - mean_absolute_error: 0.2410 - val_loss: 0.2253 - val_mean_absolute_error: 0.2475 - 151ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.2174 - mean_absolute_error: 0.2368 - val_loss: 0.2216 - val_mean_absolute_error: 0.2480 - 161ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.2194 - mean_absolute_error: 0.2388 - val_loss: 0.2170 - val_mean_absolute_error: 0.2382 - 144ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.2155 - mean_absolute_error: 0.2361 - val_loss: 0.2205 - val_mean_absolute_error: 0.2440 - 177ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.2150 - mean_absolute_error: 0.2371 - val_loss: 0.2328 - val_mean_absolute_error: 0.2614 - 150ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.2215 - mean_absolute_error: 0.2420 - val_loss: 0.2185 - val_mean_absolute_error: 0.2378 - 151ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.2149 - mean_absolute_error: 0.2353 - val_loss: 0.2236 - val_mean_absolute_error: 0.2491 - 148ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.2167 - mean_absolute_error: 0.2401 - val_loss: 0.2147 - val_mean_absolute_error: 0.2361 - 146ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.2184 - mean_absolute_error: 0.2372 - val_loss: 0.2268 - val_mean_absolute_error: 0.2511 - 144ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.2210 - mean_absolute_error: 0.2445 - val_loss: 0.2166 - val_mean_absolute_error: 0.2380 - 146ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.2145 - mean_absolute_error: 0.2338 - val_loss: 0.2277 - val_mean_absolute_error: 0.2452 - 145ms/epoch - 2ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.2110 - mean_absolute_error: 0.2286 - val_loss: 0.2161 - val_mean_absolute_error: 0.2407 - 145ms/epoch - 2ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.2116 - mean_absolute_error: 0.2308 - val_loss: 0.2196 - val_mean_absolute_error: 0.2434 - 143ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.2145 - mean_absolute_error: 0.2377 - val_loss: 0.2354 - val_mean_absolute_error: 0.2500 - 143ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.2153 - mean_absolute_error: 0.2368 - val_loss: 0.2212 - val_mean_absolute_error: 0.2531 - 145ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.2128 - mean_absolute_error: 0.2317 - val_loss: 0.2162 - val_mean_absolute_error: 0.2412 - 145ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.2162 - mean_absolute_error: 0.2372 - val_loss: 0.2152 - val_mean_absolute_error: 0.2419 - 145ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.2131 - mean_absolute_error: 0.2336 - val_loss: 0.2275 - val_mean_absolute_error: 0.2648 - 144ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.2143 - mean_absolute_error: 0.2357 - val_loss: 0.2216 - val_mean_absolute_error: 0.2493 - 146ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.2120 - mean_absolute_error: 0.2323 - val_loss: 0.2270 - val_mean_absolute_error: 0.2439 - 143ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.2138 - mean_absolute_error: 0.2341 - val_loss: 0.2186 - val_mean_absolute_error: 0.2424 - 144ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.2124 - mean_absolute_error: 0.2292 - val_loss: 0.2274 - val_mean_absolute_error: 0.2423 - 144ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.2144 - mean_absolute_error: 0.2399 - val_loss: 0.2298 - val_mean_absolute_error: 0.2539 - 144ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.2114 - mean_absolute_error: 0.2311 - val_loss: 0.2231 - val_mean_absolute_error: 0.2372 - 144ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.2143 - mean_absolute_error: 0.2319 - val_loss: 0.2173 - val_mean_absolute_error: 0.2376 - 147ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.2125 - mean_absolute_error: 0.2303 - val_loss: 0.2249 - val_mean_absolute_error: 0.2429 - 150ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.2124 - mean_absolute_error: 0.2300 - val_loss: 0.2249 - val_mean_absolute_error: 0.2439 - 147ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.2104 - mean_absolute_error: 0.2274 - val_loss: 0.2244 - val_mean_absolute_error: 0.2402 - 144ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.2176 - mean_absolute_error: 0.2386 - val_loss: 0.2213 - val_mean_absolute_error: 0.2412 - 145ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.2130 - mean_absolute_error: 0.2307 - val_loss: 0.2190 - val_mean_absolute_error: 0.2391 - 144ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.2137 - mean_absolute_error: 0.2307 - val_loss: 0.2199 - val_mean_absolute_error: 0.2424 - 144ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.2108 - mean_absolute_error: 0.2283 - val_loss: 0.2196 - val_mean_absolute_error: 0.2333 - 144ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.2087 - mean_absolute_error: 0.2233 - val_loss: 0.2203 - val_mean_absolute_error: 0.2442 - 145ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.2144 - mean_absolute_error: 0.2320 - val_loss: 0.2243 - val_mean_absolute_error: 0.2401 - 146ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.2111 - mean_absolute_error: 0.2276 - val_loss: 0.2212 - val_mean_absolute_error: 0.2381 - 145ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.2079 - mean_absolute_error: 0.2257 - val_loss: 0.2267 - val_mean_absolute_error: 0.2480 - 147ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.2150 - mean_absolute_error: 0.2346 - val_loss: 0.2219 - val_mean_absolute_error: 0.2368 - 161ms/epoch - 2ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.2147 - mean_absolute_error: 0.2318 - val_loss: 0.2188 - val_mean_absolute_error: 0.2428 - 157ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.2104 - mean_absolute_error: 0.2292 - val_loss: 0.2175 - val_mean_absolute_error: 0.2374 - 152ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.2105 - mean_absolute_error: 0.2277 - val_loss: 0.2193 - val_mean_absolute_error: 0.2390 - 147ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.2139 - mean_absolute_error: 0.2295 - val_loss: 0.2296 - val_mean_absolute_error: 0.2370 - 143ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.2160 - mean_absolute_error: 0.2345 - val_loss: 0.2145 - val_mean_absolute_error: 0.2371 - 147ms/epoch - 2ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.2076 - mean_absolute_error: 0.2223 - val_loss: 0.2119 - val_mean_absolute_error: 0.2304 - 145ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.2102 - mean_absolute_error: 0.2275 - val_loss: 0.2386 - val_mean_absolute_error: 0.2544 - 149ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.2146 - mean_absolute_error: 0.2315 - val_loss: 0.2123 - val_mean_absolute_error: 0.2341 - 156ms/epoch - 2ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.2086 - mean_absolute_error: 0.2268 - val_loss: 0.2254 - val_mean_absolute_error: 0.2399 - 144ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.2116 - mean_absolute_error: 0.2301 - val_loss: 0.2145 - val_mean_absolute_error: 0.2406 - 148ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.2125 - mean_absolute_error: 0.2320 - val_loss: 0.2295 - val_mean_absolute_error: 0.2455 - 149ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.2124 - mean_absolute_error: 0.2299 - val_loss: 0.2247 - val_mean_absolute_error: 0.2419 - 148ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.2104 - mean_absolute_error: 0.2316 - val_loss: 0.2100 - val_mean_absolute_error: 0.2346 - 146ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.2104 - mean_absolute_error: 0.2300 - val_loss: 0.2222 - val_mean_absolute_error: 0.2464 - 145ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.2068 - mean_absolute_error: 0.2264 - val_loss: 0.2178 - val_mean_absolute_error: 0.2339 - 146ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.2098 - mean_absolute_error: 0.2241 - val_loss: 0.2194 - val_mean_absolute_error: 0.2383 - 151ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.2114 - mean_absolute_error: 0.2305 - val_loss: 0.2144 - val_mean_absolute_error: 0.2378 - 147ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.2116 - mean_absolute_error: 0.2309 - val_loss: 0.2179 - val_mean_absolute_error: 0.2359 - 148ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.2130 - mean_absolute_error: 0.2310 - val_loss: 0.2190 - val_mean_absolute_error: 0.2401 - 153ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.2136 - mean_absolute_error: 0.2308 - val_loss: 0.2203 - val_mean_absolute_error: 0.2466 - 154ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.2110 - mean_absolute_error: 0.2311 - val_loss: 0.2126 - val_mean_absolute_error: 0.2324 - 149ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.2088 - mean_absolute_error: 0.2252 - val_loss: 0.2116 - val_mean_absolute_error: 0.2324 - 149ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.2084 - mean_absolute_error: 0.2253 - val_loss: 0.2140 - val_mean_absolute_error: 0.2354 - 149ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.2095 - mean_absolute_error: 0.2282 - val_loss: 0.2186 - val_mean_absolute_error: 0.2312 - 148ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.2087 - mean_absolute_error: 0.2266 - val_loss: 0.2315 - val_mean_absolute_error: 0.2496 - 149ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.2099 - mean_absolute_error: 0.2305 - val_loss: 0.2170 - val_mean_absolute_error: 0.2313 - 147ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.2059 - mean_absolute_error: 0.2210 - val_loss: 0.2201 - val_mean_absolute_error: 0.2341 - 148ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.2098 - mean_absolute_error: 0.2248 - val_loss: 0.2192 - val_mean_absolute_error: 0.2377 - 147ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.2083 - mean_absolute_error: 0.2250 - val_loss: 0.2209 - val_mean_absolute_error: 0.2355 - 147ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.2056 - mean_absolute_error: 0.2218 - val_loss: 0.2112 - val_mean_absolute_error: 0.2325 - 145ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.2115 - mean_absolute_error: 0.2289 - val_loss: 0.2228 - val_mean_absolute_error: 0.2407 - 145ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.2126 - mean_absolute_error: 0.2329 - val_loss: 0.2129 - val_mean_absolute_error: 0.2297 - 157ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.2143 - mean_absolute_error: 0.2293 - val_loss: 0.2084 - val_mean_absolute_error: 0.2335 - 156ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.2092 - mean_absolute_error: 0.2262 - val_loss: 0.2104 - val_mean_absolute_error: 0.2334 - 151ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.2069 - mean_absolute_error: 0.2211 - val_loss: 0.2126 - val_mean_absolute_error: 0.2313 - 159ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.2057 - mean_absolute_error: 0.2205 - val_loss: 0.2150 - val_mean_absolute_error: 0.2349 - 149ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.2084 - mean_absolute_error: 0.2216 - val_loss: 0.2123 - val_mean_absolute_error: 0.2386 - 144ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.2097 - mean_absolute_error: 0.2262 - val_loss: 0.2192 - val_mean_absolute_error: 0.2396 - 144ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.2081 - mean_absolute_error: 0.2291 - val_loss: 0.2124 - val_mean_absolute_error: 0.2342 - 145ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.2073 - mean_absolute_error: 0.2240 - val_loss: 0.2144 - val_mean_absolute_error: 0.2331 - 144ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.2057 - mean_absolute_error: 0.2220 - val_loss: 0.2131 - val_mean_absolute_error: 0.2329 - 143ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.2066 - mean_absolute_error: 0.2222 - val_loss: 0.2191 - val_mean_absolute_error: 0.2319 - 144ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.2087 - mean_absolute_error: 0.2244 - val_loss: 0.2191 - val_mean_absolute_error: 0.2360 - 145ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.2041 - mean_absolute_error: 0.2185 - val_loss: 0.2068 - val_mean_absolute_error: 0.2288 - 144ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.2034 - mean_absolute_error: 0.2214 - val_loss: 0.2234 - val_mean_absolute_error: 0.2365 - 148ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.2128 - mean_absolute_error: 0.2289 - val_loss: 0.2197 - val_mean_absolute_error: 0.2307 - 143ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.2091 - mean_absolute_error: 0.2277 - val_loss: 0.2176 - val_mean_absolute_error: 0.2385 - 145ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.2038 - mean_absolute_error: 0.2208 - val_loss: 0.2184 - val_mean_absolute_error: 0.2354 - 147ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.2095 - mean_absolute_error: 0.2249 - val_loss: 0.2156 - val_mean_absolute_error: 0.2389 - 145ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.2076 - mean_absolute_error: 0.2260 - val_loss: 0.2171 - val_mean_absolute_error: 0.2387 - 145ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.2083 - mean_absolute_error: 0.2275 - val_loss: 0.2186 - val_mean_absolute_error: 0.2434 - 145ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.2089 - mean_absolute_error: 0.2255 - val_loss: 0.2182 - val_mean_absolute_error: 0.2368 - 144ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.2122 - mean_absolute_error: 0.2279 - val_loss: 0.2234 - val_mean_absolute_error: 0.2422 - 144ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.2083 - mean_absolute_error: 0.2263 - val_loss: 0.2262 - val_mean_absolute_error: 0.2391 - 144ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.2059 - mean_absolute_error: 0.2243 - val_loss: 0.2114 - val_mean_absolute_error: 0.2281 - 144ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.2093 - mean_absolute_error: 0.2272 - val_loss: 0.2137 - val_mean_absolute_error: 0.2333 - 145ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.2068 - mean_absolute_error: 0.2232 - val_loss: 0.2149 - val_mean_absolute_error: 0.2273 - 145ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.2068 - mean_absolute_error: 0.2223 - val_loss: 0.2125 - val_mean_absolute_error: 0.2280 - 144ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.2086 - mean_absolute_error: 0.2247 - val_loss: 0.2182 - val_mean_absolute_error: 0.2418 - 144ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.2055 - mean_absolute_error: 0.2241 - val_loss: 0.2261 - val_mean_absolute_error: 0.2334 - 143ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.2100 - mean_absolute_error: 0.2259 - val_loss: 0.2135 - val_mean_absolute_error: 0.2343 - 143ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.2047 - mean_absolute_error: 0.2226 - val_loss: 0.2199 - val_mean_absolute_error: 0.2363 - 145ms/epoch - 2ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.2058 - mean_absolute_error: 0.2233 - val_loss: 0.2233 - val_mean_absolute_error: 0.2369 - 145ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.2045 - mean_absolute_error: 0.2208 - val_loss: 0.2153 - val_mean_absolute_error: 0.2335 - 145ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.2077 - mean_absolute_error: 0.2248 - val_loss: 0.2144 - val_mean_absolute_error: 0.2286 - 144ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.2047 - mean_absolute_error: 0.2197 - val_loss: 0.2156 - val_mean_absolute_error: 0.2281 - 144ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.2037 - mean_absolute_error: 0.2154 - val_loss: 0.2157 - val_mean_absolute_error: 0.2273 - 144ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.2088 - mean_absolute_error: 0.2222 - val_loss: 0.2235 - val_mean_absolute_error: 0.2352 - 143ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.2047 - mean_absolute_error: 0.2172 - val_loss: 0.2226 - val_mean_absolute_error: 0.2406 - 145ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.2113 - mean_absolute_error: 0.2298 - val_loss: 0.2252 - val_mean_absolute_error: 0.2367 - 144ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.2104 - mean_absolute_error: 0.2251 - val_loss: 0.2229 - val_mean_absolute_error: 0.2378 - 145ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.2035 - mean_absolute_error: 0.2190 - val_loss: 0.2217 - val_mean_absolute_error: 0.2309 - 144ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.2015 - mean_absolute_error: 0.2156 - val_loss: 0.2160 - val_mean_absolute_error: 0.2318 - 144ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.2033 - mean_absolute_error: 0.2198 - val_loss: 0.2224 - val_mean_absolute_error: 0.2363 - 144ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.2041 - mean_absolute_error: 0.2199 - val_loss: 0.2142 - val_mean_absolute_error: 0.2350 - 144ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.2065 - mean_absolute_error: 0.2217 - val_loss: 0.2243 - val_mean_absolute_error: 0.2374 - 145ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.2082 - mean_absolute_error: 0.2235 - val_loss: 0.2270 - val_mean_absolute_error: 0.2450 - 146ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.2021 - mean_absolute_error: 0.2178 - val_loss: 0.2280 - val_mean_absolute_error: 0.2413 - 145ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.2038 - mean_absolute_error: 0.2195 - val_loss: 0.2090 - val_mean_absolute_error: 0.2233 - 145ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.2045 - mean_absolute_error: 0.2179 - val_loss: 0.2199 - val_mean_absolute_error: 0.2314 - 144ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.2031 - mean_absolute_error: 0.2147 - val_loss: 0.2269 - val_mean_absolute_error: 0.2327 - 144ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.2050 - mean_absolute_error: 0.2173 - val_loss: 0.2245 - val_mean_absolute_error: 0.2309 - 144ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.2010 - mean_absolute_error: 0.2165 - val_loss: 0.2112 - val_mean_absolute_error: 0.2280 - 144ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.2001 - mean_absolute_error: 0.2129 - val_loss: 0.2188 - val_mean_absolute_error: 0.2315 - 145ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.2040 - mean_absolute_error: 0.2166 - val_loss: 0.2219 - val_mean_absolute_error: 0.2366 - 145ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.2037 - mean_absolute_error: 0.2214 - val_loss: 0.2248 - val_mean_absolute_error: 0.2392 - 145ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.2042 - mean_absolute_error: 0.2214 - val_loss: 0.2211 - val_mean_absolute_error: 0.2392 - 145ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.2051 - mean_absolute_error: 0.2220 - val_loss: 0.2133 - val_mean_absolute_error: 0.2310 - 144ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.2004 - mean_absolute_error: 0.2160 - val_loss: 0.2101 - val_mean_absolute_error: 0.2310 - 144ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.2085 - mean_absolute_error: 0.2219 - val_loss: 0.2290 - val_mean_absolute_error: 0.2406 - 144ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.2060 - mean_absolute_error: 0.2219 - val_loss: 0.2171 - val_mean_absolute_error: 0.2316 - 162ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.2041 - mean_absolute_error: 0.2192 - val_loss: 0.2187 - val_mean_absolute_error: 0.2362 - 144ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.2021 - mean_absolute_error: 0.2181 - val_loss: 0.2104 - val_mean_absolute_error: 0.2231 - 144ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.2025 - mean_absolute_error: 0.2189 - val_loss: 0.2127 - val_mean_absolute_error: 0.2310 - 144ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.2040 - mean_absolute_error: 0.2154 - val_loss: 0.2183 - val_mean_absolute_error: 0.2320 - 144ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.2029 - mean_absolute_error: 0.2167 - val_loss: 0.2112 - val_mean_absolute_error: 0.2256 - 156ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.2026 - mean_absolute_error: 0.2165 - val_loss: 0.2227 - val_mean_absolute_error: 0.2465 - 144ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.2026 - mean_absolute_error: 0.2204 - val_loss: 0.2208 - val_mean_absolute_error: 0.2385 - 144ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.2058 - mean_absolute_error: 0.2226 - val_loss: 0.2309 - val_mean_absolute_error: 0.2420 - 144ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.2046 - mean_absolute_error: 0.2217 - val_loss: 0.2214 - val_mean_absolute_error: 0.2417 - 159ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.2032 - mean_absolute_error: 0.2218 - val_loss: 0.2150 - val_mean_absolute_error: 0.2303 - 144ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.2083 - mean_absolute_error: 0.2226 - val_loss: 0.2205 - val_mean_absolute_error: 0.2376 - 143ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.2014 - mean_absolute_error: 0.2164 - val_loss: 0.2138 - val_mean_absolute_error: 0.2300 - 145ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.2020 - mean_absolute_error: 0.2190 - val_loss: 0.2167 - val_mean_absolute_error: 0.2339 - 146ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.2063 - mean_absolute_error: 0.2240 - val_loss: 0.2124 - val_mean_absolute_error: 0.2388 - 147ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.2095 - mean_absolute_error: 0.2259 - val_loss: 0.2099 - val_mean_absolute_error: 0.2264 - 146ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.2029 - mean_absolute_error: 0.2186 - val_loss: 0.2196 - val_mean_absolute_error: 0.2303 - 146ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.2012 - mean_absolute_error: 0.2151 - val_loss: 0.2241 - val_mean_absolute_error: 0.2319 - 145ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.2000 - mean_absolute_error: 0.2146 - val_loss: 0.2207 - val_mean_absolute_error: 0.2328 - 144ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.2012 - mean_absolute_error: 0.2153 - val_loss: 0.2103 - val_mean_absolute_error: 0.2277 - 144ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.2039 - mean_absolute_error: 0.2205 - val_loss: 0.2317 - val_mean_absolute_error: 0.2370 - 144ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.2055 - mean_absolute_error: 0.2190 - val_loss: 0.2153 - val_mean_absolute_error: 0.2319 - 144ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.2008 - mean_absolute_error: 0.2142 - val_loss: 0.2306 - val_mean_absolute_error: 0.2360 - 144ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.2036 - mean_absolute_error: 0.2186 - val_loss: 0.2172 - val_mean_absolute_error: 0.2326 - 145ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.1994 - mean_absolute_error: 0.2132 - val_loss: 0.2114 - val_mean_absolute_error: 0.2223 - 144ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.2000 - mean_absolute_error: 0.2142 - val_loss: 0.2210 - val_mean_absolute_error: 0.2352 - 144ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.2025 - mean_absolute_error: 0.2172 - val_loss: 0.2166 - val_mean_absolute_error: 0.2282 - 144ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.2015 - mean_absolute_error: 0.2178 - val_loss: 0.2149 - val_mean_absolute_error: 0.2300 - 146ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.1956 - mean_absolute_error: 0.2095 - val_loss: 0.2107 - val_mean_absolute_error: 0.2238 - 145ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.1992 - mean_absolute_error: 0.2122 - val_loss: 0.2154 - val_mean_absolute_error: 0.2268 - 143ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.1960 - mean_absolute_error: 0.2111 - val_loss: 0.2163 - val_mean_absolute_error: 0.2271 - 142ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.2020 - mean_absolute_error: 0.2219 - val_loss: 0.2160 - val_mean_absolute_error: 0.2313 - 143ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.2031 - mean_absolute_error: 0.2185 - val_loss: 0.2176 - val_mean_absolute_error: 0.2315 - 144ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.1964 - mean_absolute_error: 0.2132 - val_loss: 0.2120 - val_mean_absolute_error: 0.2299 - 144ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.2000 - mean_absolute_error: 0.2166 - val_loss: 0.2148 - val_mean_absolute_error: 0.2325 - 145ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.2012 - mean_absolute_error: 0.2173 - val_loss: 0.2103 - val_mean_absolute_error: 0.2240 - 144ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.2041 - mean_absolute_error: 0.2231 - val_loss: 0.2205 - val_mean_absolute_error: 0.2381 - 142ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.1987 - mean_absolute_error: 0.2154 - val_loss: 0.2308 - val_mean_absolute_error: 0.2363 - 143ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.2017 - mean_absolute_error: 0.2166 - val_loss: 0.2210 - val_mean_absolute_error: 0.2286 - 143ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.2022 - mean_absolute_error: 0.2182 - val_loss: 0.2105 - val_mean_absolute_error: 0.2338 - 142ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.1964 - mean_absolute_error: 0.2154 - val_loss: 0.2176 - val_mean_absolute_error: 0.2282 - 143ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.1955 - mean_absolute_error: 0.2101 - val_loss: 0.2145 - val_mean_absolute_error: 0.2250 - 144ms/epoch - 2ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.2022 - mean_absolute_error: 0.2198 - val_loss: 0.2161 - val_mean_absolute_error: 0.2290 - 144ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.2013 - mean_absolute_error: 0.2155 - val_loss: 0.2169 - val_mean_absolute_error: 0.2322 - 143ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.1990 - mean_absolute_error: 0.2122 - val_loss: 0.2261 - val_mean_absolute_error: 0.2424 - 143ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.2005 - mean_absolute_error: 0.2169 - val_loss: 0.2128 - val_mean_absolute_error: 0.2259 - 143ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.1996 - mean_absolute_error: 0.2139 - val_loss: 0.2314 - val_mean_absolute_error: 0.2447 - 143ms/epoch - 2ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.1998 - mean_absolute_error: 0.2174 - val_loss: 0.2096 - val_mean_absolute_error: 0.2237 - 143ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.1987 - mean_absolute_error: 0.2123 - val_loss: 0.2172 - val_mean_absolute_error: 0.2305 - 147ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.1985 - mean_absolute_error: 0.2139 - val_loss: 0.2100 - val_mean_absolute_error: 0.2284 - 144ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.1957 - mean_absolute_error: 0.2092 - val_loss: 0.2100 - val_mean_absolute_error: 0.2301 - 144ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.1961 - mean_absolute_error: 0.2100 - val_loss: 0.2278 - val_mean_absolute_error: 0.2290 - 145ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.2006 - mean_absolute_error: 0.2147 - val_loss: 0.2170 - val_mean_absolute_error: 0.2278 - 144ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.1965 - mean_absolute_error: 0.2097 - val_loss: 0.2155 - val_mean_absolute_error: 0.2309 - 145ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.2010 - mean_absolute_error: 0.2215 - val_loss: 0.2204 - val_mean_absolute_error: 0.2360 - 144ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.1994 - mean_absolute_error: 0.2177 - val_loss: 0.2155 - val_mean_absolute_error: 0.2320 - 143ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.1958 - mean_absolute_error: 0.2115 - val_loss: 0.2123 - val_mean_absolute_error: 0.2274 - 144ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.2004 - mean_absolute_error: 0.2154 - val_loss: 0.2221 - val_mean_absolute_error: 0.2444 - 144ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.1942 - mean_absolute_error: 0.2127 - val_loss: 0.2090 - val_mean_absolute_error: 0.2200 - 144ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.1988 - mean_absolute_error: 0.2140 - val_loss: 0.2117 - val_mean_absolute_error: 0.2328 - 144ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.2002 - mean_absolute_error: 0.2181 - val_loss: 0.2096 - val_mean_absolute_error: 0.2276 - 143ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.1995 - mean_absolute_error: 0.2160 - val_loss: 0.2090 - val_mean_absolute_error: 0.2229 - 143ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.1980 - mean_absolute_error: 0.2136 - val_loss: 0.2060 - val_mean_absolute_error: 0.2219 - 143ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.1945 - mean_absolute_error: 0.2101 - val_loss: 0.2258 - val_mean_absolute_error: 0.2316 - 146ms/epoch - 2ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.2015 - mean_absolute_error: 0.2209 - val_loss: 0.2096 - val_mean_absolute_error: 0.2338 - 145ms/epoch - 2ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.1991 - mean_absolute_error: 0.2180 - val_loss: 0.2173 - val_mean_absolute_error: 0.2268 - 148ms/epoch - 2ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.1942 - mean_absolute_error: 0.2124 - val_loss: 0.2077 - val_mean_absolute_error: 0.2218 - 147ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.1973 - mean_absolute_error: 0.2120 - val_loss: 0.2210 - val_mean_absolute_error: 0.2347 - 145ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.1951 - mean_absolute_error: 0.2128 - val_loss: 0.2252 - val_mean_absolute_error: 0.2334 - 144ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.1974 - mean_absolute_error: 0.2151 - val_loss: 0.2183 - val_mean_absolute_error: 0.2305 - 145ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.1973 - mean_absolute_error: 0.2131 - val_loss: 0.2096 - val_mean_absolute_error: 0.2255 - 144ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.1932 - mean_absolute_error: 0.2084 - val_loss: 0.2137 - val_mean_absolute_error: 0.2266 - 144ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.1970 - mean_absolute_error: 0.2141 - val_loss: 0.2090 - val_mean_absolute_error: 0.2253 - 144ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.1928 - mean_absolute_error: 0.2086 - val_loss: 0.2144 - val_mean_absolute_error: 0.2259 - 145ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.1967 - mean_absolute_error: 0.2107 - val_loss: 0.2248 - val_mean_absolute_error: 0.2378 - 145ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.2009 - mean_absolute_error: 0.2196 - val_loss: 0.2214 - val_mean_absolute_error: 0.2438 - 143ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.1988 - mean_absolute_error: 0.2165 - val_loss: 0.2305 - val_mean_absolute_error: 0.2330 - 144ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.1960 - mean_absolute_error: 0.2115 - val_loss: 0.2187 - val_mean_absolute_error: 0.2308 - 144ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.1968 - mean_absolute_error: 0.2131 - val_loss: 0.2119 - val_mean_absolute_error: 0.2331 - 144ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.1916 - mean_absolute_error: 0.2072 - val_loss: 0.2070 - val_mean_absolute_error: 0.2318 - 143ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.1964 - mean_absolute_error: 0.2108 - val_loss: 0.2226 - val_mean_absolute_error: 0.2373 - 144ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.1942 - mean_absolute_error: 0.2130 - val_loss: 0.2091 - val_mean_absolute_error: 0.2238 - 144ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.1942 - mean_absolute_error: 0.2115 - val_loss: 0.2105 - val_mean_absolute_error: 0.2238 - 144ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.0498 - mean_absolute_error: 0.0946 - val_loss: 0.0747 - val_mean_absolute_error: 0.1219 - 148ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.0606 - mean_absolute_error: 0.1059 - val_loss: 0.0882 - val_mean_absolute_error: 0.1450 - 148ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.0568 - mean_absolute_error: 0.1012 - val_loss: 0.0877 - val_mean_absolute_error: 0.1361 - 147ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.0597 - mean_absolute_error: 0.1013 - val_loss: 0.0703 - val_mean_absolute_error: 0.1158 - 145ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.0589 - mean_absolute_error: 0.1043 - val_loss: 0.1260 - val_mean_absolute_error: 0.1712 - 148ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.0888 - mean_absolute_error: 0.1328 - val_loss: 0.1077 - val_mean_absolute_error: 0.1531 - 153ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.0688 - mean_absolute_error: 0.1182 - val_loss: 0.0827 - val_mean_absolute_error: 0.1301 - 154ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.0688 - mean_absolute_error: 0.1151 - val_loss: 0.0938 - val_mean_absolute_error: 0.1406 - 154ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.0594 - mean_absolute_error: 0.1069 - val_loss: 0.0762 - val_mean_absolute_error: 0.1330 - 153ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.0672 - mean_absolute_error: 0.1160 - val_loss: 0.1141 - val_mean_absolute_error: 0.1641 - 152ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.0824 - mean_absolute_error: 0.1255 - val_loss: 0.0897 - val_mean_absolute_error: 0.1494 - 152ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.0663 - mean_absolute_error: 0.1157 - val_loss: 0.1020 - val_mean_absolute_error: 0.1505 - 154ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.0753 - mean_absolute_error: 0.1210 - val_loss: 0.0933 - val_mean_absolute_error: 0.1453 - 153ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.0672 - mean_absolute_error: 0.1157 - val_loss: 0.0964 - val_mean_absolute_error: 0.1518 - 152ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.0625 - mean_absolute_error: 0.1068 - val_loss: 0.0635 - val_mean_absolute_error: 0.1146 - 152ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.0548 - mean_absolute_error: 0.1001 - val_loss: 0.0682 - val_mean_absolute_error: 0.1214 - 145ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.0833 - mean_absolute_error: 0.1262 - val_loss: 0.0809 - val_mean_absolute_error: 0.1336 - 145ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.0638 - mean_absolute_error: 0.1115 - val_loss: 0.0647 - val_mean_absolute_error: 0.1131 - 145ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.0447 - mean_absolute_error: 0.0894 - val_loss: 0.0681 - val_mean_absolute_error: 0.1207 - 145ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.0541 - mean_absolute_error: 0.0989 - val_loss: 0.0640 - val_mean_absolute_error: 0.1117 - 145ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.0642 - mean_absolute_error: 0.1079 - val_loss: 0.1048 - val_mean_absolute_error: 0.1583 - 145ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.0761 - mean_absolute_error: 0.1182 - val_loss: 0.1515 - val_mean_absolute_error: 0.1902 - 146ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.0664 - mean_absolute_error: 0.1133 - val_loss: 0.0856 - val_mean_absolute_error: 0.1408 - 144ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.0551 - mean_absolute_error: 0.1010 - val_loss: 0.0920 - val_mean_absolute_error: 0.1377 - 147ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.0934 - mean_absolute_error: 0.1379 - val_loss: 0.0808 - val_mean_absolute_error: 0.1340 - 145ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.0528 - mean_absolute_error: 0.1031 - val_loss: 0.0794 - val_mean_absolute_error: 0.1298 - 146ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.0527 - mean_absolute_error: 0.0980 - val_loss: 0.1016 - val_mean_absolute_error: 0.1550 - 145ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.0614 - mean_absolute_error: 0.1082 - val_loss: 0.0870 - val_mean_absolute_error: 0.1446 - 145ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.0706 - mean_absolute_error: 0.1184 - val_loss: 0.0929 - val_mean_absolute_error: 0.1480 - 145ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.0630 - mean_absolute_error: 0.1089 - val_loss: 0.0815 - val_mean_absolute_error: 0.1222 - 145ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.0848 - mean_absolute_error: 0.1260 - val_loss: 0.0789 - val_mean_absolute_error: 0.1322 - 145ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.0587 - mean_absolute_error: 0.1061 - val_loss: 0.0958 - val_mean_absolute_error: 0.1500 - 145ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.0700 - mean_absolute_error: 0.1158 - val_loss: 0.0809 - val_mean_absolute_error: 0.1354 - 146ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.0517 - mean_absolute_error: 0.0983 - val_loss: 0.0671 - val_mean_absolute_error: 0.1103 - 150ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.0610 - mean_absolute_error: 0.1057 - val_loss: 0.0981 - val_mean_absolute_error: 0.1465 - 144ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.0615 - mean_absolute_error: 0.1077 - val_loss: 0.1030 - val_mean_absolute_error: 0.1557 - 150ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.0582 - mean_absolute_error: 0.1023 - val_loss: 0.0731 - val_mean_absolute_error: 0.1315 - 153ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.0685 - mean_absolute_error: 0.1165 - val_loss: 0.0954 - val_mean_absolute_error: 0.1514 - 165ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.0668 - mean_absolute_error: 0.1156 - val_loss: 0.0794 - val_mean_absolute_error: 0.1281 - 148ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.0596 - mean_absolute_error: 0.1061 - val_loss: 0.0773 - val_mean_absolute_error: 0.1214 - 149ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.0859 - mean_absolute_error: 0.1277 - val_loss: 0.1165 - val_mean_absolute_error: 0.1634 - 145ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.0641 - mean_absolute_error: 0.1091 - val_loss: 0.0776 - val_mean_absolute_error: 0.1255 - 146ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.0521 - mean_absolute_error: 0.0978 - val_loss: 0.0799 - val_mean_absolute_error: 0.1295 - 147ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.0526 - mean_absolute_error: 0.0975 - val_loss: 0.0656 - val_mean_absolute_error: 0.1079 - 147ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.0748 - mean_absolute_error: 0.1168 - val_loss: 0.2177 - val_mean_absolute_error: 0.2315 - 146ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.1018 - mean_absolute_error: 0.1496 - val_loss: 0.0795 - val_mean_absolute_error: 0.1425 - 145ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.0768 - mean_absolute_error: 0.1235 - val_loss: 0.2235 - val_mean_absolute_error: 0.2235 - 145ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.0823 - mean_absolute_error: 0.1305 - val_loss: 0.0971 - val_mean_absolute_error: 0.1468 - 145ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.0595 - mean_absolute_error: 0.1065 - val_loss: 0.0966 - val_mean_absolute_error: 0.1485 - 145ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.0566 - mean_absolute_error: 0.1033 - val_loss: 0.0737 - val_mean_absolute_error: 0.1204 - 151ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.0719 - mean_absolute_error: 0.1182 - val_loss: 0.0955 - val_mean_absolute_error: 0.1467 - 145ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.0551 - mean_absolute_error: 0.1038 - val_loss: 0.0587 - val_mean_absolute_error: 0.1077 - 147ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.0509 - mean_absolute_error: 0.0950 - val_loss: 0.0834 - val_mean_absolute_error: 0.1408 - 147ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.0698 - mean_absolute_error: 0.1134 - val_loss: 0.0903 - val_mean_absolute_error: 0.1393 - 151ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.0640 - mean_absolute_error: 0.1096 - val_loss: 0.0738 - val_mean_absolute_error: 0.1182 - 147ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.0748 - mean_absolute_error: 0.1172 - val_loss: 0.0844 - val_mean_absolute_error: 0.1392 - 149ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.0627 - mean_absolute_error: 0.1079 - val_loss: 0.0747 - val_mean_absolute_error: 0.1275 - 147ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.0729 - mean_absolute_error: 0.1179 - val_loss: 0.0691 - val_mean_absolute_error: 0.1234 - 146ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.0631 - mean_absolute_error: 0.1127 - val_loss: 0.1141 - val_mean_absolute_error: 0.1630 - 146ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.0798 - mean_absolute_error: 0.1278 - val_loss: 0.0892 - val_mean_absolute_error: 0.1468 - 145ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.0704 - mean_absolute_error: 0.1166 - val_loss: 0.0822 - val_mean_absolute_error: 0.1408 - 145ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.0543 - mean_absolute_error: 0.1013 - val_loss: 0.0707 - val_mean_absolute_error: 0.1205 - 145ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.0628 - mean_absolute_error: 0.1099 - val_loss: 0.0676 - val_mean_absolute_error: 0.1150 - 146ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.0508 - mean_absolute_error: 0.0968 - val_loss: 0.0734 - val_mean_absolute_error: 0.1195 - 145ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.0861 - mean_absolute_error: 0.1265 - val_loss: 0.0972 - val_mean_absolute_error: 0.1477 - 145ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.0517 - mean_absolute_error: 0.1006 - val_loss: 0.0774 - val_mean_absolute_error: 0.1278 - 145ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.0609 - mean_absolute_error: 0.1064 - val_loss: 0.0657 - val_mean_absolute_error: 0.1101 - 145ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.0518 - mean_absolute_error: 0.0946 - val_loss: 0.0678 - val_mean_absolute_error: 0.1178 - 145ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.0633 - mean_absolute_error: 0.1055 - val_loss: 0.0986 - val_mean_absolute_error: 0.1479 - 143ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.0564 - mean_absolute_error: 0.1031 - val_loss: 0.0667 - val_mean_absolute_error: 0.1164 - 145ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.0736 - mean_absolute_error: 0.1179 - val_loss: 0.0808 - val_mean_absolute_error: 0.1416 - 149ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.0664 - mean_absolute_error: 0.1155 - val_loss: 0.1148 - val_mean_absolute_error: 0.1660 - 145ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.0678 - mean_absolute_error: 0.1176 - val_loss: 0.0655 - val_mean_absolute_error: 0.1187 - 145ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.0579 - mean_absolute_error: 0.1042 - val_loss: 0.0748 - val_mean_absolute_error: 0.1256 - 145ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.0507 - mean_absolute_error: 0.0949 - val_loss: 0.1200 - val_mean_absolute_error: 0.1721 - 145ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.0862 - mean_absolute_error: 0.1286 - val_loss: 0.0695 - val_mean_absolute_error: 0.1236 - 146ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.0508 - mean_absolute_error: 0.0969 - val_loss: 0.0664 - val_mean_absolute_error: 0.1105 - 145ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.0500 - mean_absolute_error: 0.0945 - val_loss: 0.0683 - val_mean_absolute_error: 0.1186 - 146ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.0775 - mean_absolute_error: 0.1216 - val_loss: 0.0946 - val_mean_absolute_error: 0.1469 - 145ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.0511 - mean_absolute_error: 0.0969 - val_loss: 0.0730 - val_mean_absolute_error: 0.1279 - 145ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.0622 - mean_absolute_error: 0.1054 - val_loss: 0.0973 - val_mean_absolute_error: 0.1461 - 147ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.0491 - mean_absolute_error: 0.0939 - val_loss: 0.0816 - val_mean_absolute_error: 0.1328 - 147ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.0522 - mean_absolute_error: 0.0970 - val_loss: 0.0771 - val_mean_absolute_error: 0.1323 - 147ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.0580 - mean_absolute_error: 0.1038 - val_loss: 0.0916 - val_mean_absolute_error: 0.1392 - 147ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.0482 - mean_absolute_error: 0.0941 - val_loss: 0.0647 - val_mean_absolute_error: 0.1110 - 146ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.0658 - mean_absolute_error: 0.1112 - val_loss: 0.0739 - val_mean_absolute_error: 0.1245 - 150ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.0608 - mean_absolute_error: 0.1068 - val_loss: 0.0836 - val_mean_absolute_error: 0.1381 - 146ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.0573 - mean_absolute_error: 0.1041 - val_loss: 0.0781 - val_mean_absolute_error: 0.1248 - 147ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.0620 - mean_absolute_error: 0.1062 - val_loss: 0.0897 - val_mean_absolute_error: 0.1426 - 146ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.0569 - mean_absolute_error: 0.1022 - val_loss: 0.0705 - val_mean_absolute_error: 0.1179 - 146ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.0581 - mean_absolute_error: 0.1044 - val_loss: 0.0670 - val_mean_absolute_error: 0.1187 - 145ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.0516 - mean_absolute_error: 0.0970 - val_loss: 0.0768 - val_mean_absolute_error: 0.1238 - 145ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.0837 - mean_absolute_error: 0.1258 - val_loss: 0.0921 - val_mean_absolute_error: 0.1548 - 146ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.0700 - mean_absolute_error: 0.1164 - val_loss: 0.0847 - val_mean_absolute_error: 0.1366 - 146ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.0506 - mean_absolute_error: 0.0946 - val_loss: 0.0694 - val_mean_absolute_error: 0.1137 - 146ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.0586 - mean_absolute_error: 0.1019 - val_loss: 0.0905 - val_mean_absolute_error: 0.1332 - 147ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.0532 - mean_absolute_error: 0.0994 - val_loss: 0.0793 - val_mean_absolute_error: 0.1303 - 146ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.0503 - mean_absolute_error: 0.0956 - val_loss: 0.0688 - val_mean_absolute_error: 0.1189 - 146ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.0626 - mean_absolute_error: 0.1092 - val_loss: 0.0805 - val_mean_absolute_error: 0.1313 - 146ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.0506 - mean_absolute_error: 0.0981 - val_loss: 0.0863 - val_mean_absolute_error: 0.1325 - 145ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.0668 - mean_absolute_error: 0.1129 - val_loss: 0.1079 - val_mean_absolute_error: 0.1601 - 148ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.0697 - mean_absolute_error: 0.1186 - val_loss: 0.1054 - val_mean_absolute_error: 0.1535 - 144ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.0497 - mean_absolute_error: 0.0987 - val_loss: 0.0889 - val_mean_absolute_error: 0.1440 - 144ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.0566 - mean_absolute_error: 0.1053 - val_loss: 0.1037 - val_mean_absolute_error: 0.1556 - 146ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.0530 - mean_absolute_error: 0.1014 - val_loss: 0.0661 - val_mean_absolute_error: 0.1110 - 147ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.0866 - mean_absolute_error: 0.1296 - val_loss: 0.0941 - val_mean_absolute_error: 0.1528 - 145ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.0608 - mean_absolute_error: 0.1111 - val_loss: 0.0745 - val_mean_absolute_error: 0.1186 - 145ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_noNoise_five(kappa-7e-3).keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE 0.07449401170015335
# MAE: 0.11863154917955399
# 32/32 [==============================] - 0s 835us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\Delta E$', r'$\gamma$', r'$g$']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(3,1, figsize=(8,15))

fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# Curvas Validación VS Predicción

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
DeltaE_pred = y_pred_denorm[:, 0]
DeltaE_val = y_val_denorm[:, 0]
gamma_pred = y_pred_denorm[:, 1]
gamma_val = y_val_denorm[:, 1]
g_pred = y_pred_denorm[:, 2]
g_val = y_val_denorm[:, 2]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val = np.zeros((x_val.shape[0], len(w_values)))


for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k, Omega, DeltaE_pred[i], gamma_pred[i], g_pred[i])
    t_values_val[i,:] = t_w(w_values, k, Omega, DeltaE_val[i], gamma_val[i], g_val[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k, Omega, DeltaE_val, gamma_val, g_val)
w2=w_2(k, Omega, DeltaE_val, gamma_val, g_val)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"ΔE real = {DeltaE_val[i]:.5f}, ΔE pred = {DeltaE_pred[i]:.5f}\n"\
           f"γ real = {gamma_val[i]:.7f}, γ pred = {gamma_pred[i]:.7f}\n"\
           f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # With noise

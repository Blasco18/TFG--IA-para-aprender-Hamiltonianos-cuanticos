# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos: $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # Sin ruido

# %% [markdown]
# ## Creamos base de datos

# %%
#Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)

    return k, DeltaE, g

num_datos = 5000

# %%
# #Creamos base de datos y guardamos en .txt
# k, DeltaE, g = Parameters_generator (num_datos)
# np.savetxt('Parameters_noNoise(gamma-fijo).txt', np.column_stack((k, DeltaE, g)), header='\u03BA \u0394E g')

# %%
datos = np.loadtxt('Parameters_noNoise(gamma-fijo).txt', skiprows=1)
k = datos[:,0]
DeltaE = datos[:,1]
g = datos[:,2]
gamma = 7e-3
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.8, 1.2, 400)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))

# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k[i], Omega, DeltaE[i], gamma, g[i])

# %% [markdown]
# ### Dibujamos alguna curva

# %%
# i=0
# while i<=1000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values[i,:], label='Curva original')
#     plt.plot(w_values, t_sep_values[i,:], linestyle='--', label='Curva separada')
#     plt.plot(w_values, mod_t_values[i,:], linestyle='-.', label='Módulo curva')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
x_train, x_val, y_train, y_val = train_test_split(t_values, datos, test_size=0.2)

# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 400)
# y_train shape (4000, 3)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_noNoise_five(gamma-7e-3).keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 1s - loss: 0.8457 - mean_absolute_error: 0.7356 - val_loss: 0.8413 - val_mean_absolute_error: 0.7334 - 970ms/epoch - 12ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.8034 - mean_absolute_error: 0.7162 - val_loss: 0.8217 - val_mean_absolute_error: 0.7241 - 149ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.7848 - mean_absolute_error: 0.7020 - val_loss: 0.8124 - val_mean_absolute_error: 0.7426 - 147ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.7704 - mean_absolute_error: 0.6962 - val_loss: 0.7904 - val_mean_absolute_error: 0.7067 - 146ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.7581 - mean_absolute_error: 0.6862 - val_loss: 0.7792 - val_mean_absolute_error: 0.7015 - 146ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.7447 - mean_absolute_error: 0.6758 - val_loss: 0.7682 - val_mean_absolute_error: 0.6971 - 146ms/epoch - 2ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.7339 - mean_absolute_error: 0.6664 - val_loss: 0.7568 - val_mean_absolute_error: 0.6828 - 147ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.7228 - mean_absolute_error: 0.6558 - val_loss: 0.7452 - val_mean_absolute_error: 0.6708 - 145ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.7169 - mean_absolute_error: 0.6570 - val_loss: 0.7402 - val_mean_absolute_error: 0.6693 - 148ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.7092 - mean_absolute_error: 0.6432 - val_loss: 0.7308 - val_mean_absolute_error: 0.6569 - 151ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.7009 - mean_absolute_error: 0.6374 - val_loss: 0.7279 - val_mean_absolute_error: 0.6545 - 158ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.6988 - mean_absolute_error: 0.6348 - val_loss: 0.7201 - val_mean_absolute_error: 0.6530 - 155ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.6911 - mean_absolute_error: 0.6289 - val_loss: 0.7127 - val_mean_absolute_error: 0.6525 - 153ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.6832 - mean_absolute_error: 0.6283 - val_loss: 0.6925 - val_mean_absolute_error: 0.6330 - 156ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.6766 - mean_absolute_error: 0.6241 - val_loss: 0.7080 - val_mean_absolute_error: 0.6424 - 148ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.6770 - mean_absolute_error: 0.6179 - val_loss: 0.6970 - val_mean_absolute_error: 0.6362 - 152ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.6797 - mean_absolute_error: 0.6242 - val_loss: 0.6928 - val_mean_absolute_error: 0.6414 - 150ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.6810 - mean_absolute_error: 0.6320 - val_loss: 0.6946 - val_mean_absolute_error: 0.6320 - 151ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.6678 - mean_absolute_error: 0.6136 - val_loss: 0.6922 - val_mean_absolute_error: 0.6352 - 150ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.6591 - mean_absolute_error: 0.6070 - val_loss: 0.6701 - val_mean_absolute_error: 0.6143 - 149ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.6455 - mean_absolute_error: 0.6017 - val_loss: 0.6672 - val_mean_absolute_error: 0.6136 - 153ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.6320 - mean_absolute_error: 0.5916 - val_loss: 0.6505 - val_mean_absolute_error: 0.6157 - 150ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.6247 - mean_absolute_error: 0.5877 - val_loss: 0.6058 - val_mean_absolute_error: 0.6004 - 151ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.6339 - mean_absolute_error: 0.5939 - val_loss: 0.6123 - val_mean_absolute_error: 0.5871 - 148ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.6156 - mean_absolute_error: 0.5842 - val_loss: 0.5978 - val_mean_absolute_error: 0.5654 - 151ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.5479 - mean_absolute_error: 0.5397 - val_loss: 0.5634 - val_mean_absolute_error: 0.5517 - 149ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.5261 - mean_absolute_error: 0.5294 - val_loss: 0.4978 - val_mean_absolute_error: 0.5217 - 150ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.5278 - mean_absolute_error: 0.5279 - val_loss: 0.6159 - val_mean_absolute_error: 0.5650 - 151ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.4931 - mean_absolute_error: 0.5101 - val_loss: 0.5041 - val_mean_absolute_error: 0.5101 - 152ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.4682 - mean_absolute_error: 0.4935 - val_loss: 0.4899 - val_mean_absolute_error: 0.5237 - 150ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.4515 - mean_absolute_error: 0.4784 - val_loss: 0.4018 - val_mean_absolute_error: 0.4541 - 148ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.4238 - mean_absolute_error: 0.4624 - val_loss: 0.4757 - val_mean_absolute_error: 0.5029 - 153ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.4056 - mean_absolute_error: 0.4482 - val_loss: 0.3840 - val_mean_absolute_error: 0.4368 - 152ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.3881 - mean_absolute_error: 0.4393 - val_loss: 0.5015 - val_mean_absolute_error: 0.5055 - 154ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.3512 - mean_absolute_error: 0.4170 - val_loss: 0.4755 - val_mean_absolute_error: 0.4608 - 151ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.3794 - mean_absolute_error: 0.4315 - val_loss: 0.3437 - val_mean_absolute_error: 0.4298 - 150ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.3223 - mean_absolute_error: 0.3956 - val_loss: 0.3705 - val_mean_absolute_error: 0.4122 - 160ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.3463 - mean_absolute_error: 0.4085 - val_loss: 0.3501 - val_mean_absolute_error: 0.4057 - 164ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.3192 - mean_absolute_error: 0.3898 - val_loss: 0.3045 - val_mean_absolute_error: 0.3846 - 147ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.3358 - mean_absolute_error: 0.4005 - val_loss: 0.3143 - val_mean_absolute_error: 0.3850 - 146ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.3170 - mean_absolute_error: 0.3862 - val_loss: 0.2784 - val_mean_absolute_error: 0.3688 - 146ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.3027 - mean_absolute_error: 0.3849 - val_loss: 0.3025 - val_mean_absolute_error: 0.3830 - 147ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.3085 - mean_absolute_error: 0.3832 - val_loss: 0.3412 - val_mean_absolute_error: 0.3931 - 147ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.2924 - mean_absolute_error: 0.3745 - val_loss: 0.2631 - val_mean_absolute_error: 0.3583 - 147ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.3071 - mean_absolute_error: 0.3766 - val_loss: 0.4083 - val_mean_absolute_error: 0.4325 - 146ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.2933 - mean_absolute_error: 0.3711 - val_loss: 0.2929 - val_mean_absolute_error: 0.3680 - 146ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.3075 - mean_absolute_error: 0.3759 - val_loss: 0.2925 - val_mean_absolute_error: 0.3918 - 146ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.3081 - mean_absolute_error: 0.3793 - val_loss: 0.4497 - val_mean_absolute_error: 0.4407 - 145ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.3018 - mean_absolute_error: 0.3774 - val_loss: 0.2546 - val_mean_absolute_error: 0.3487 - 147ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.2808 - mean_absolute_error: 0.3614 - val_loss: 0.2726 - val_mean_absolute_error: 0.3507 - 147ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.2431 - mean_absolute_error: 0.3412 - val_loss: 0.2586 - val_mean_absolute_error: 0.3449 - 157ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.2865 - mean_absolute_error: 0.3606 - val_loss: 0.3128 - val_mean_absolute_error: 0.3682 - 151ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.2756 - mean_absolute_error: 0.3578 - val_loss: 0.2444 - val_mean_absolute_error: 0.3364 - 175ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.2723 - mean_absolute_error: 0.3528 - val_loss: 0.2465 - val_mean_absolute_error: 0.3359 - 161ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.2784 - mean_absolute_error: 0.3664 - val_loss: 0.2560 - val_mean_absolute_error: 0.3639 - 156ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.2763 - mean_absolute_error: 0.3576 - val_loss: 0.2444 - val_mean_absolute_error: 0.3297 - 147ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.2645 - mean_absolute_error: 0.3518 - val_loss: 0.2722 - val_mean_absolute_error: 0.3436 - 147ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.2646 - mean_absolute_error: 0.3450 - val_loss: 0.2456 - val_mean_absolute_error: 0.3268 - 150ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.2544 - mean_absolute_error: 0.3393 - val_loss: 0.2203 - val_mean_absolute_error: 0.3199 - 145ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.2620 - mean_absolute_error: 0.3442 - val_loss: 0.2191 - val_mean_absolute_error: 0.3148 - 146ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.2709 - mean_absolute_error: 0.3510 - val_loss: 0.2831 - val_mean_absolute_error: 0.3447 - 151ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.2446 - mean_absolute_error: 0.3340 - val_loss: 0.3376 - val_mean_absolute_error: 0.3734 - 157ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.2993 - mean_absolute_error: 0.3696 - val_loss: 0.2402 - val_mean_absolute_error: 0.3565 - 156ms/epoch - 2ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.2374 - mean_absolute_error: 0.3308 - val_loss: 0.3018 - val_mean_absolute_error: 0.3606 - 150ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.2771 - mean_absolute_error: 0.3559 - val_loss: 0.2686 - val_mean_absolute_error: 0.3564 - 145ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.2702 - mean_absolute_error: 0.3534 - val_loss: 0.2273 - val_mean_absolute_error: 0.3242 - 147ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.2521 - mean_absolute_error: 0.3349 - val_loss: 0.3293 - val_mean_absolute_error: 0.3711 - 148ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.2877 - mean_absolute_error: 0.3709 - val_loss: 0.2901 - val_mean_absolute_error: 0.3685 - 147ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.2480 - mean_absolute_error: 0.3385 - val_loss: 0.2092 - val_mean_absolute_error: 0.3131 - 147ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.2505 - mean_absolute_error: 0.3349 - val_loss: 0.2357 - val_mean_absolute_error: 0.3328 - 147ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.2309 - mean_absolute_error: 0.3229 - val_loss: 0.2426 - val_mean_absolute_error: 0.3352 - 148ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.2486 - mean_absolute_error: 0.3342 - val_loss: 0.2529 - val_mean_absolute_error: 0.3319 - 147ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.2594 - mean_absolute_error: 0.3356 - val_loss: 0.3058 - val_mean_absolute_error: 0.3684 - 147ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.2498 - mean_absolute_error: 0.3324 - val_loss: 0.2378 - val_mean_absolute_error: 0.3384 - 152ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.2319 - mean_absolute_error: 0.3234 - val_loss: 0.2138 - val_mean_absolute_error: 0.3225 - 148ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.2319 - mean_absolute_error: 0.3198 - val_loss: 0.2631 - val_mean_absolute_error: 0.3324 - 157ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.2356 - mean_absolute_error: 0.3206 - val_loss: 0.2978 - val_mean_absolute_error: 0.3699 - 148ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.2553 - mean_absolute_error: 0.3359 - val_loss: 0.2493 - val_mean_absolute_error: 0.3361 - 147ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.2645 - mean_absolute_error: 0.3437 - val_loss: 0.3005 - val_mean_absolute_error: 0.3507 - 167ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.2378 - mean_absolute_error: 0.3240 - val_loss: 0.2028 - val_mean_absolute_error: 0.3025 - 165ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.2452 - mean_absolute_error: 0.3321 - val_loss: 0.2339 - val_mean_absolute_error: 0.3257 - 160ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.2168 - mean_absolute_error: 0.3154 - val_loss: 0.1996 - val_mean_absolute_error: 0.3041 - 172ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.2481 - mean_absolute_error: 0.3346 - val_loss: 0.2402 - val_mean_absolute_error: 0.3315 - 165ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.2341 - mean_absolute_error: 0.3206 - val_loss: 0.2276 - val_mean_absolute_error: 0.3213 - 165ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.2391 - mean_absolute_error: 0.3241 - val_loss: 0.2357 - val_mean_absolute_error: 0.3185 - 161ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.2251 - mean_absolute_error: 0.3192 - val_loss: 0.2383 - val_mean_absolute_error: 0.3261 - 161ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.2209 - mean_absolute_error: 0.3094 - val_loss: 0.2236 - val_mean_absolute_error: 0.3123 - 145ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.2302 - mean_absolute_error: 0.3171 - val_loss: 0.2984 - val_mean_absolute_error: 0.3655 - 146ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.2359 - mean_absolute_error: 0.3256 - val_loss: 0.2199 - val_mean_absolute_error: 0.3109 - 148ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.2300 - mean_absolute_error: 0.3178 - val_loss: 0.1946 - val_mean_absolute_error: 0.2930 - 147ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.2135 - mean_absolute_error: 0.3064 - val_loss: 0.2494 - val_mean_absolute_error: 0.3277 - 154ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.2589 - mean_absolute_error: 0.3349 - val_loss: 0.2311 - val_mean_absolute_error: 0.3241 - 146ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.2189 - mean_absolute_error: 0.3096 - val_loss: 0.2612 - val_mean_absolute_error: 0.3249 - 147ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.2437 - mean_absolute_error: 0.3257 - val_loss: 0.2262 - val_mean_absolute_error: 0.3177 - 146ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.2123 - mean_absolute_error: 0.3024 - val_loss: 0.2197 - val_mean_absolute_error: 0.3086 - 151ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.2167 - mean_absolute_error: 0.3043 - val_loss: 0.2205 - val_mean_absolute_error: 0.3161 - 147ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.2364 - mean_absolute_error: 0.3280 - val_loss: 0.3154 - val_mean_absolute_error: 0.3679 - 147ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.2184 - mean_absolute_error: 0.3067 - val_loss: 0.2330 - val_mean_absolute_error: 0.3131 - 147ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.2266 - mean_absolute_error: 0.3139 - val_loss: 0.2186 - val_mean_absolute_error: 0.3069 - 145ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.2152 - mean_absolute_error: 0.3058 - val_loss: 0.2088 - val_mean_absolute_error: 0.2963 - 148ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.2172 - mean_absolute_error: 0.3032 - val_loss: 0.1992 - val_mean_absolute_error: 0.2967 - 146ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.2202 - mean_absolute_error: 0.3098 - val_loss: 0.2298 - val_mean_absolute_error: 0.3087 - 148ms/epoch - 2ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.2155 - mean_absolute_error: 0.3056 - val_loss: 0.2071 - val_mean_absolute_error: 0.3041 - 146ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.2444 - mean_absolute_error: 0.3228 - val_loss: 0.2461 - val_mean_absolute_error: 0.3326 - 145ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.2074 - mean_absolute_error: 0.3029 - val_loss: 0.1946 - val_mean_absolute_error: 0.2920 - 146ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.2249 - mean_absolute_error: 0.3123 - val_loss: 0.2239 - val_mean_absolute_error: 0.3056 - 145ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.2198 - mean_absolute_error: 0.3069 - val_loss: 0.2100 - val_mean_absolute_error: 0.3109 - 147ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.2242 - mean_absolute_error: 0.3137 - val_loss: 0.2115 - val_mean_absolute_error: 0.3115 - 146ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.2208 - mean_absolute_error: 0.3115 - val_loss: 0.2436 - val_mean_absolute_error: 0.3168 - 147ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.2012 - mean_absolute_error: 0.2938 - val_loss: 0.2366 - val_mean_absolute_error: 0.3273 - 146ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.2115 - mean_absolute_error: 0.3031 - val_loss: 0.1943 - val_mean_absolute_error: 0.3017 - 147ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.1981 - mean_absolute_error: 0.2969 - val_loss: 0.2162 - val_mean_absolute_error: 0.3105 - 146ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.2178 - mean_absolute_error: 0.3058 - val_loss: 0.1998 - val_mean_absolute_error: 0.3027 - 146ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.2687 - mean_absolute_error: 0.3468 - val_loss: 0.2641 - val_mean_absolute_error: 0.3362 - 145ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.2064 - mean_absolute_error: 0.3018 - val_loss: 0.1909 - val_mean_absolute_error: 0.2940 - 149ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.2500 - mean_absolute_error: 0.3311 - val_loss: 0.2124 - val_mean_absolute_error: 0.3050 - 146ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.2239 - mean_absolute_error: 0.3097 - val_loss: 0.2404 - val_mean_absolute_error: 0.3203 - 146ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.1950 - mean_absolute_error: 0.2916 - val_loss: 0.1917 - val_mean_absolute_error: 0.2800 - 146ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.2170 - mean_absolute_error: 0.3065 - val_loss: 0.1955 - val_mean_absolute_error: 0.2920 - 146ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.2265 - mean_absolute_error: 0.3121 - val_loss: 0.2297 - val_mean_absolute_error: 0.3123 - 146ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.2280 - mean_absolute_error: 0.3140 - val_loss: 0.2799 - val_mean_absolute_error: 0.3314 - 146ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.2023 - mean_absolute_error: 0.2925 - val_loss: 0.2608 - val_mean_absolute_error: 0.3306 - 155ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.2176 - mean_absolute_error: 0.3061 - val_loss: 0.2038 - val_mean_absolute_error: 0.2989 - 201ms/epoch - 3ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.2025 - mean_absolute_error: 0.2980 - val_loss: 0.1845 - val_mean_absolute_error: 0.2937 - 207ms/epoch - 3ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.2044 - mean_absolute_error: 0.2964 - val_loss: 0.2131 - val_mean_absolute_error: 0.2975 - 161ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.2266 - mean_absolute_error: 0.3091 - val_loss: 0.2148 - val_mean_absolute_error: 0.3056 - 173ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.1980 - mean_absolute_error: 0.2899 - val_loss: 0.4228 - val_mean_absolute_error: 0.3982 - 189ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.2347 - mean_absolute_error: 0.3154 - val_loss: 0.2150 - val_mean_absolute_error: 0.3018 - 172ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.2091 - mean_absolute_error: 0.3006 - val_loss: 0.2048 - val_mean_absolute_error: 0.3124 - 150ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.2047 - mean_absolute_error: 0.2992 - val_loss: 0.2482 - val_mean_absolute_error: 0.3269 - 150ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.2082 - mean_absolute_error: 0.2988 - val_loss: 0.2060 - val_mean_absolute_error: 0.3002 - 148ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.2021 - mean_absolute_error: 0.2911 - val_loss: 0.3120 - val_mean_absolute_error: 0.3522 - 146ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.2177 - mean_absolute_error: 0.3057 - val_loss: 0.3051 - val_mean_absolute_error: 0.3478 - 146ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.2177 - mean_absolute_error: 0.3066 - val_loss: 0.2387 - val_mean_absolute_error: 0.3177 - 147ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.2335 - mean_absolute_error: 0.3141 - val_loss: 0.2063 - val_mean_absolute_error: 0.2980 - 146ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.2228 - mean_absolute_error: 0.3085 - val_loss: 0.3414 - val_mean_absolute_error: 0.3909 - 147ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.2168 - mean_absolute_error: 0.3073 - val_loss: 0.2169 - val_mean_absolute_error: 0.3081 - 148ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.2228 - mean_absolute_error: 0.3130 - val_loss: 0.2452 - val_mean_absolute_error: 0.3263 - 146ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.2346 - mean_absolute_error: 0.3210 - val_loss: 0.2030 - val_mean_absolute_error: 0.3015 - 146ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.2085 - mean_absolute_error: 0.3020 - val_loss: 0.2223 - val_mean_absolute_error: 0.3078 - 147ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.2103 - mean_absolute_error: 0.2963 - val_loss: 0.2477 - val_mean_absolute_error: 0.3210 - 147ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.2109 - mean_absolute_error: 0.3019 - val_loss: 0.1995 - val_mean_absolute_error: 0.2955 - 145ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.2064 - mean_absolute_error: 0.2988 - val_loss: 0.2426 - val_mean_absolute_error: 0.3252 - 145ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.2336 - mean_absolute_error: 0.3219 - val_loss: 0.2164 - val_mean_absolute_error: 0.3020 - 146ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.2197 - mean_absolute_error: 0.3071 - val_loss: 0.2045 - val_mean_absolute_error: 0.2923 - 146ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.2112 - mean_absolute_error: 0.2965 - val_loss: 0.2232 - val_mean_absolute_error: 0.3008 - 146ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.2334 - mean_absolute_error: 0.3152 - val_loss: 0.2060 - val_mean_absolute_error: 0.3006 - 144ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.1948 - mean_absolute_error: 0.2904 - val_loss: 0.2125 - val_mean_absolute_error: 0.3021 - 147ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.2283 - mean_absolute_error: 0.3093 - val_loss: 0.3629 - val_mean_absolute_error: 0.3839 - 147ms/epoch - 2ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.2127 - mean_absolute_error: 0.3048 - val_loss: 0.2357 - val_mean_absolute_error: 0.3363 - 147ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.2011 - mean_absolute_error: 0.2952 - val_loss: 0.2227 - val_mean_absolute_error: 0.3015 - 147ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.2706 - mean_absolute_error: 0.3428 - val_loss: 0.2539 - val_mean_absolute_error: 0.3408 - 147ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.2152 - mean_absolute_error: 0.3057 - val_loss: 0.1956 - val_mean_absolute_error: 0.2928 - 146ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.2531 - mean_absolute_error: 0.3299 - val_loss: 0.2077 - val_mean_absolute_error: 0.3081 - 146ms/epoch - 2ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.2024 - mean_absolute_error: 0.2980 - val_loss: 0.3028 - val_mean_absolute_error: 0.3428 - 147ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.1978 - mean_absolute_error: 0.2902 - val_loss: 0.2488 - val_mean_absolute_error: 0.3203 - 146ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.2295 - mean_absolute_error: 0.3080 - val_loss: 0.2243 - val_mean_absolute_error: 0.3145 - 145ms/epoch - 2ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.2184 - mean_absolute_error: 0.3042 - val_loss: 0.1948 - val_mean_absolute_error: 0.2968 - 146ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.1852 - mean_absolute_error: 0.2827 - val_loss: 0.1842 - val_mean_absolute_error: 0.2818 - 147ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.2033 - mean_absolute_error: 0.2948 - val_loss: 0.2224 - val_mean_absolute_error: 0.3086 - 147ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.2099 - mean_absolute_error: 0.2984 - val_loss: 0.1942 - val_mean_absolute_error: 0.2886 - 146ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.2285 - mean_absolute_error: 0.3142 - val_loss: 0.2108 - val_mean_absolute_error: 0.3051 - 146ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.2002 - mean_absolute_error: 0.2934 - val_loss: 0.1814 - val_mean_absolute_error: 0.2765 - 145ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.2026 - mean_absolute_error: 0.2953 - val_loss: 0.2700 - val_mean_absolute_error: 0.3493 - 147ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.1995 - mean_absolute_error: 0.2960 - val_loss: 0.3500 - val_mean_absolute_error: 0.3829 - 146ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.2299 - mean_absolute_error: 0.3147 - val_loss: 0.2051 - val_mean_absolute_error: 0.3052 - 146ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.2090 - mean_absolute_error: 0.2987 - val_loss: 0.1904 - val_mean_absolute_error: 0.2943 - 146ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.1804 - mean_absolute_error: 0.2796 - val_loss: 0.1872 - val_mean_absolute_error: 0.2832 - 146ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.1944 - mean_absolute_error: 0.2843 - val_loss: 0.2299 - val_mean_absolute_error: 0.3125 - 147ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.2271 - mean_absolute_error: 0.3117 - val_loss: 0.2418 - val_mean_absolute_error: 0.3109 - 146ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.1989 - mean_absolute_error: 0.2931 - val_loss: 0.2122 - val_mean_absolute_error: 0.2908 - 146ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.2135 - mean_absolute_error: 0.3001 - val_loss: 0.2125 - val_mean_absolute_error: 0.2994 - 146ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.1956 - mean_absolute_error: 0.2879 - val_loss: 0.2503 - val_mean_absolute_error: 0.3212 - 147ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.2562 - mean_absolute_error: 0.3299 - val_loss: 0.2166 - val_mean_absolute_error: 0.3056 - 146ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.2166 - mean_absolute_error: 0.3022 - val_loss: 0.2554 - val_mean_absolute_error: 0.3204 - 147ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.2225 - mean_absolute_error: 0.3049 - val_loss: 0.2810 - val_mean_absolute_error: 0.3683 - 147ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.2183 - mean_absolute_error: 0.3123 - val_loss: 0.1846 - val_mean_absolute_error: 0.2884 - 146ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.1866 - mean_absolute_error: 0.2805 - val_loss: 0.1730 - val_mean_absolute_error: 0.2653 - 148ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.1923 - mean_absolute_error: 0.2834 - val_loss: 0.1970 - val_mean_absolute_error: 0.2842 - 145ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.1906 - mean_absolute_error: 0.2863 - val_loss: 0.1746 - val_mean_absolute_error: 0.2755 - 146ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.1839 - mean_absolute_error: 0.2814 - val_loss: 0.1876 - val_mean_absolute_error: 0.2844 - 147ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.1980 - mean_absolute_error: 0.2875 - val_loss: 0.1886 - val_mean_absolute_error: 0.2834 - 148ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.2285 - mean_absolute_error: 0.3154 - val_loss: 0.2446 - val_mean_absolute_error: 0.3169 - 146ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.1857 - mean_absolute_error: 0.2818 - val_loss: 0.2334 - val_mean_absolute_error: 0.3144 - 145ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.2017 - mean_absolute_error: 0.2934 - val_loss: 0.1899 - val_mean_absolute_error: 0.2898 - 146ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.2042 - mean_absolute_error: 0.2967 - val_loss: 0.1801 - val_mean_absolute_error: 0.2700 - 146ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.2328 - mean_absolute_error: 0.3099 - val_loss: 0.2078 - val_mean_absolute_error: 0.2942 - 147ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.1950 - mean_absolute_error: 0.2843 - val_loss: 0.4345 - val_mean_absolute_error: 0.4067 - 146ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.2168 - mean_absolute_error: 0.3058 - val_loss: 0.2181 - val_mean_absolute_error: 0.3096 - 146ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.1863 - mean_absolute_error: 0.2793 - val_loss: 0.1753 - val_mean_absolute_error: 0.2725 - 149ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.2115 - mean_absolute_error: 0.2977 - val_loss: 0.2224 - val_mean_absolute_error: 0.3121 - 147ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.1844 - mean_absolute_error: 0.2796 - val_loss: 0.1977 - val_mean_absolute_error: 0.2909 - 147ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.2023 - mean_absolute_error: 0.2916 - val_loss: 0.2085 - val_mean_absolute_error: 0.2947 - 147ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.1933 - mean_absolute_error: 0.2824 - val_loss: 0.2370 - val_mean_absolute_error: 0.3070 - 147ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.1966 - mean_absolute_error: 0.2893 - val_loss: 0.2352 - val_mean_absolute_error: 0.3246 - 148ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.2056 - mean_absolute_error: 0.2973 - val_loss: 0.1960 - val_mean_absolute_error: 0.2814 - 147ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.2216 - mean_absolute_error: 0.3038 - val_loss: 0.2135 - val_mean_absolute_error: 0.2964 - 147ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.1963 - mean_absolute_error: 0.2868 - val_loss: 0.2536 - val_mean_absolute_error: 0.3458 - 164ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.2302 - mean_absolute_error: 0.3177 - val_loss: 0.2052 - val_mean_absolute_error: 0.3074 - 145ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.1903 - mean_absolute_error: 0.2823 - val_loss: 0.2823 - val_mean_absolute_error: 0.3341 - 148ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.2149 - mean_absolute_error: 0.3015 - val_loss: 0.1926 - val_mean_absolute_error: 0.2933 - 146ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.1875 - mean_absolute_error: 0.2825 - val_loss: 0.2542 - val_mean_absolute_error: 0.3150 - 145ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.2054 - mean_absolute_error: 0.2923 - val_loss: 0.2124 - val_mean_absolute_error: 0.2978 - 146ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.1880 - mean_absolute_error: 0.2767 - val_loss: 0.1877 - val_mean_absolute_error: 0.2792 - 145ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.1911 - mean_absolute_error: 0.2867 - val_loss: 0.1787 - val_mean_absolute_error: 0.2795 - 146ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.1860 - mean_absolute_error: 0.2781 - val_loss: 0.1877 - val_mean_absolute_error: 0.2822 - 145ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.2056 - mean_absolute_error: 0.2976 - val_loss: 0.1763 - val_mean_absolute_error: 0.2825 - 146ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.1900 - mean_absolute_error: 0.2819 - val_loss: 0.2034 - val_mean_absolute_error: 0.2956 - 144ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.1883 - mean_absolute_error: 0.2851 - val_loss: 0.2153 - val_mean_absolute_error: 0.3019 - 155ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.2141 - mean_absolute_error: 0.3002 - val_loss: 0.2530 - val_mean_absolute_error: 0.3230 - 181ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.2078 - mean_absolute_error: 0.2946 - val_loss: 0.1929 - val_mean_absolute_error: 0.2927 - 145ms/epoch - 2ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.2008 - mean_absolute_error: 0.2869 - val_loss: 0.2029 - val_mean_absolute_error: 0.2916 - 146ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.2066 - mean_absolute_error: 0.2948 - val_loss: 0.1841 - val_mean_absolute_error: 0.2842 - 146ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.2133 - mean_absolute_error: 0.2977 - val_loss: 0.1942 - val_mean_absolute_error: 0.2956 - 146ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.1932 - mean_absolute_error: 0.2868 - val_loss: 0.2632 - val_mean_absolute_error: 0.3410 - 146ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.1869 - mean_absolute_error: 0.2809 - val_loss: 0.2143 - val_mean_absolute_error: 0.2911 - 145ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.2141 - mean_absolute_error: 0.3046 - val_loss: 0.2969 - val_mean_absolute_error: 0.3429 - 147ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.1946 - mean_absolute_error: 0.2877 - val_loss: 0.2010 - val_mean_absolute_error: 0.2902 - 147ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.2134 - mean_absolute_error: 0.2974 - val_loss: 0.2243 - val_mean_absolute_error: 0.3181 - 146ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.1944 - mean_absolute_error: 0.2830 - val_loss: 0.2055 - val_mean_absolute_error: 0.2936 - 146ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.1997 - mean_absolute_error: 0.2915 - val_loss: 0.2099 - val_mean_absolute_error: 0.2902 - 145ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.2046 - mean_absolute_error: 0.2927 - val_loss: 0.2281 - val_mean_absolute_error: 0.3113 - 145ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.2102 - mean_absolute_error: 0.2935 - val_loss: 0.1903 - val_mean_absolute_error: 0.2825 - 146ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.2040 - mean_absolute_error: 0.2887 - val_loss: 0.1852 - val_mean_absolute_error: 0.2803 - 146ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.1977 - mean_absolute_error: 0.2861 - val_loss: 0.2661 - val_mean_absolute_error: 0.3253 - 145ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.2073 - mean_absolute_error: 0.2911 - val_loss: 0.2153 - val_mean_absolute_error: 0.3060 - 144ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.1945 - mean_absolute_error: 0.2835 - val_loss: 0.1923 - val_mean_absolute_error: 0.2901 - 144ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.1994 - mean_absolute_error: 0.2892 - val_loss: 0.1887 - val_mean_absolute_error: 0.2828 - 146ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.1755 - mean_absolute_error: 0.2697 - val_loss: 0.2079 - val_mean_absolute_error: 0.2929 - 145ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.1835 - mean_absolute_error: 0.2795 - val_loss: 0.3014 - val_mean_absolute_error: 0.3429 - 151ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.2077 - mean_absolute_error: 0.3011 - val_loss: 0.1836 - val_mean_absolute_error: 0.2844 - 153ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.1757 - mean_absolute_error: 0.2695 - val_loss: 0.3062 - val_mean_absolute_error: 0.3351 - 159ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.2213 - mean_absolute_error: 0.3042 - val_loss: 0.1705 - val_mean_absolute_error: 0.2645 - 150ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.2027 - mean_absolute_error: 0.2884 - val_loss: 0.1803 - val_mean_absolute_error: 0.2932 - 151ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.1919 - mean_absolute_error: 0.2803 - val_loss: 0.1851 - val_mean_absolute_error: 0.2799 - 148ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.1915 - mean_absolute_error: 0.2813 - val_loss: 0.2029 - val_mean_absolute_error: 0.2863 - 146ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.1833 - mean_absolute_error: 0.2728 - val_loss: 0.1761 - val_mean_absolute_error: 0.2782 - 147ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.1894 - mean_absolute_error: 0.2804 - val_loss: 0.2504 - val_mean_absolute_error: 0.3165 - 145ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.1856 - mean_absolute_error: 0.2768 - val_loss: 0.1689 - val_mean_absolute_error: 0.2624 - 146ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.1853 - mean_absolute_error: 0.2795 - val_loss: 0.1956 - val_mean_absolute_error: 0.2816 - 145ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.1753 - mean_absolute_error: 0.2658 - val_loss: 0.2370 - val_mean_absolute_error: 0.3193 - 145ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.1802 - mean_absolute_error: 0.2729 - val_loss: 0.2196 - val_mean_absolute_error: 0.3060 - 147ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.1818 - mean_absolute_error: 0.2769 - val_loss: 0.1869 - val_mean_absolute_error: 0.2750 - 145ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.2074 - mean_absolute_error: 0.2966 - val_loss: 0.2013 - val_mean_absolute_error: 0.2914 - 146ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.1890 - mean_absolute_error: 0.2780 - val_loss: 0.2356 - val_mean_absolute_error: 0.3098 - 143ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.2174 - mean_absolute_error: 0.3000 - val_loss: 0.1987 - val_mean_absolute_error: 0.2924 - 146ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.1817 - mean_absolute_error: 0.2758 - val_loss: 0.1659 - val_mean_absolute_error: 0.2633 - 145ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.1967 - mean_absolute_error: 0.2868 - val_loss: 0.1993 - val_mean_absolute_error: 0.3011 - 146ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.1917 - mean_absolute_error: 0.2825 - val_loss: 0.1954 - val_mean_absolute_error: 0.2878 - 144ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.2213 - mean_absolute_error: 0.3049 - val_loss: 0.2122 - val_mean_absolute_error: 0.3098 - 145ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.2255 - mean_absolute_error: 0.3043 - val_loss: 0.2439 - val_mean_absolute_error: 0.3221 - 147ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.1817 - mean_absolute_error: 0.2805 - val_loss: 0.1782 - val_mean_absolute_error: 0.2743 - 146ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.1830 - mean_absolute_error: 0.2706 - val_loss: 0.1858 - val_mean_absolute_error: 0.2788 - 145ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.1891 - mean_absolute_error: 0.2813 - val_loss: 0.3532 - val_mean_absolute_error: 0.3643 - 144ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.1944 - mean_absolute_error: 0.2846 - val_loss: 0.2100 - val_mean_absolute_error: 0.3015 - 147ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.1908 - mean_absolute_error: 0.2778 - val_loss: 0.1749 - val_mean_absolute_error: 0.2693 - 145ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.1749 - mean_absolute_error: 0.2673 - val_loss: 0.3187 - val_mean_absolute_error: 0.3528 - 145ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.1855 - mean_absolute_error: 0.2744 - val_loss: 0.2522 - val_mean_absolute_error: 0.3206 - 148ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.1949 - mean_absolute_error: 0.2828 - val_loss: 0.2365 - val_mean_absolute_error: 0.3095 - 146ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.1826 - mean_absolute_error: 0.2758 - val_loss: 0.2003 - val_mean_absolute_error: 0.2793 - 145ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.1677 - mean_absolute_error: 0.2626 - val_loss: 0.1743 - val_mean_absolute_error: 0.2752 - 148ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.1834 - mean_absolute_error: 0.2719 - val_loss: 0.2958 - val_mean_absolute_error: 0.3349 - 146ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.1856 - mean_absolute_error: 0.2814 - val_loss: 0.1671 - val_mean_absolute_error: 0.2691 - 144ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.2130 - mean_absolute_error: 0.2932 - val_loss: 0.2389 - val_mean_absolute_error: 0.3365 - 145ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.2020 - mean_absolute_error: 0.2925 - val_loss: 0.1746 - val_mean_absolute_error: 0.2814 - 147ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.1850 - mean_absolute_error: 0.2742 - val_loss: 0.2491 - val_mean_absolute_error: 0.3227 - 144ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.1825 - mean_absolute_error: 0.2765 - val_loss: 0.1707 - val_mean_absolute_error: 0.2700 - 145ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.1732 - mean_absolute_error: 0.2655 - val_loss: 0.1883 - val_mean_absolute_error: 0.2816 - 145ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.1692 - mean_absolute_error: 0.2666 - val_loss: 0.3891 - val_mean_absolute_error: 0.3799 - 144ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.2109 - mean_absolute_error: 0.2911 - val_loss: 0.2200 - val_mean_absolute_error: 0.2979 - 145ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.1901 - mean_absolute_error: 0.2751 - val_loss: 0.2238 - val_mean_absolute_error: 0.3016 - 146ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.1865 - mean_absolute_error: 0.2756 - val_loss: 0.1888 - val_mean_absolute_error: 0.2758 - 145ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.1891 - mean_absolute_error: 0.2799 - val_loss: 0.2049 - val_mean_absolute_error: 0.2906 - 147ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.1830 - mean_absolute_error: 0.2744 - val_loss: 0.1903 - val_mean_absolute_error: 0.2801 - 145ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.1943 - mean_absolute_error: 0.2794 - val_loss: 0.1725 - val_mean_absolute_error: 0.2666 - 146ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.1714 - mean_absolute_error: 0.2655 - val_loss: 0.2456 - val_mean_absolute_error: 0.3102 - 145ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.1758 - mean_absolute_error: 0.2665 - val_loss: 0.2004 - val_mean_absolute_error: 0.2842 - 146ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.1660 - mean_absolute_error: 0.2610 - val_loss: 0.1735 - val_mean_absolute_error: 0.2723 - 146ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.1973 - mean_absolute_error: 0.2806 - val_loss: 0.2398 - val_mean_absolute_error: 0.3044 - 144ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.2001 - mean_absolute_error: 0.2879 - val_loss: 0.2228 - val_mean_absolute_error: 0.2930 - 145ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.1842 - mean_absolute_error: 0.2743 - val_loss: 0.1904 - val_mean_absolute_error: 0.2753 - 146ms/epoch - 2ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.1768 - mean_absolute_error: 0.2683 - val_loss: 0.1688 - val_mean_absolute_error: 0.2649 - 145ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.1722 - mean_absolute_error: 0.2669 - val_loss: 0.2359 - val_mean_absolute_error: 0.3126 - 146ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.1837 - mean_absolute_error: 0.2720 - val_loss: 0.1822 - val_mean_absolute_error: 0.2819 - 145ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.1701 - mean_absolute_error: 0.2653 - val_loss: 0.2111 - val_mean_absolute_error: 0.2898 - 144ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.1877 - mean_absolute_error: 0.2750 - val_loss: 0.1679 - val_mean_absolute_error: 0.2683 - 146ms/epoch - 2ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.1705 - mean_absolute_error: 0.2667 - val_loss: 0.2223 - val_mean_absolute_error: 0.2901 - 147ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.1791 - mean_absolute_error: 0.2664 - val_loss: 0.2173 - val_mean_absolute_error: 0.2816 - 146ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.1757 - mean_absolute_error: 0.2718 - val_loss: 0.2362 - val_mean_absolute_error: 0.2971 - 146ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.1753 - mean_absolute_error: 0.2687 - val_loss: 0.1862 - val_mean_absolute_error: 0.2744 - 147ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.1932 - mean_absolute_error: 0.2826 - val_loss: 0.1718 - val_mean_absolute_error: 0.2632 - 144ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.1702 - mean_absolute_error: 0.2640 - val_loss: 0.2666 - val_mean_absolute_error: 0.3205 - 147ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.1914 - mean_absolute_error: 0.2763 - val_loss: 0.1936 - val_mean_absolute_error: 0.2780 - 146ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.1791 - mean_absolute_error: 0.2717 - val_loss: 0.1687 - val_mean_absolute_error: 0.2678 - 144ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.1652 - mean_absolute_error: 0.2586 - val_loss: 0.1799 - val_mean_absolute_error: 0.2650 - 146ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.1871 - mean_absolute_error: 0.2736 - val_loss: 0.1673 - val_mean_absolute_error: 0.2625 - 144ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.1713 - mean_absolute_error: 0.2622 - val_loss: 0.2112 - val_mean_absolute_error: 0.2933 - 145ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.1889 - mean_absolute_error: 0.2763 - val_loss: 0.2435 - val_mean_absolute_error: 0.3249 - 147ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.1634 - mean_absolute_error: 0.2621 - val_loss: 0.1626 - val_mean_absolute_error: 0.2562 - 147ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.1637 - mean_absolute_error: 0.2571 - val_loss: 0.2149 - val_mean_absolute_error: 0.2989 - 145ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.1802 - mean_absolute_error: 0.2716 - val_loss: 0.1718 - val_mean_absolute_error: 0.2635 - 147ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.2073 - mean_absolute_error: 0.2900 - val_loss: 0.1687 - val_mean_absolute_error: 0.2735 - 146ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.1837 - mean_absolute_error: 0.2743 - val_loss: 0.2004 - val_mean_absolute_error: 0.2813 - 145ms/epoch - 2ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.1778 - mean_absolute_error: 0.2692 - val_loss: 0.1665 - val_mean_absolute_error: 0.2606 - 146ms/epoch - 2ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.1672 - mean_absolute_error: 0.2602 - val_loss: 0.1812 - val_mean_absolute_error: 0.2653 - 146ms/epoch - 2ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.1906 - mean_absolute_error: 0.2705 - val_loss: 0.1892 - val_mean_absolute_error: 0.2797 - 146ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.1715 - mean_absolute_error: 0.2648 - val_loss: 0.1824 - val_mean_absolute_error: 0.2768 - 146ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.1760 - mean_absolute_error: 0.2699 - val_loss: 0.1735 - val_mean_absolute_error: 0.2657 - 145ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.1860 - mean_absolute_error: 0.2792 - val_loss: 0.1749 - val_mean_absolute_error: 0.2616 - 147ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.2071 - mean_absolute_error: 0.2872 - val_loss: 0.1977 - val_mean_absolute_error: 0.2847 - 149ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.1778 - mean_absolute_error: 0.2667 - val_loss: 0.2173 - val_mean_absolute_error: 0.2875 - 146ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.1695 - mean_absolute_error: 0.2603 - val_loss: 0.1752 - val_mean_absolute_error: 0.2698 - 146ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.1929 - mean_absolute_error: 0.2794 - val_loss: 0.2444 - val_mean_absolute_error: 0.3054 - 149ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.1728 - mean_absolute_error: 0.2604 - val_loss: 0.1858 - val_mean_absolute_error: 0.2707 - 147ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.1665 - mean_absolute_error: 0.2587 - val_loss: 0.1786 - val_mean_absolute_error: 0.2610 - 148ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.1696 - mean_absolute_error: 0.2597 - val_loss: 0.1532 - val_mean_absolute_error: 0.2510 - 147ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.1557 - mean_absolute_error: 0.2502 - val_loss: 0.1805 - val_mean_absolute_error: 0.2714 - 146ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.1818 - mean_absolute_error: 0.2667 - val_loss: 0.2154 - val_mean_absolute_error: 0.2932 - 146ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.1804 - mean_absolute_error: 0.2673 - val_loss: 0.2599 - val_mean_absolute_error: 0.3239 - 146ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.1658 - mean_absolute_error: 0.2583 - val_loss: 0.1542 - val_mean_absolute_error: 0.2511 - 147ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.1726 - mean_absolute_error: 0.2627 - val_loss: 0.2204 - val_mean_absolute_error: 0.3049 - 146ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.1712 - mean_absolute_error: 0.2606 - val_loss: 0.2952 - val_mean_absolute_error: 0.3227 - 147ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.1611 - mean_absolute_error: 0.2358 - val_loss: 0.2330 - val_mean_absolute_error: 0.3051 - 145ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.1612 - mean_absolute_error: 0.2513 - val_loss: 0.1480 - val_mean_absolute_error: 0.2448 - 146ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.1353 - mean_absolute_error: 0.2207 - val_loss: 0.1559 - val_mean_absolute_error: 0.2395 - 145ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.1600 - mean_absolute_error: 0.2433 - val_loss: 0.1472 - val_mean_absolute_error: 0.2380 - 146ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.1293 - mean_absolute_error: 0.2158 - val_loss: 0.1465 - val_mean_absolute_error: 0.2349 - 147ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.1343 - mean_absolute_error: 0.2212 - val_loss: 0.1585 - val_mean_absolute_error: 0.2567 - 147ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.1476 - mean_absolute_error: 0.2344 - val_loss: 0.1538 - val_mean_absolute_error: 0.2496 - 147ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.1531 - mean_absolute_error: 0.2395 - val_loss: 0.1391 - val_mean_absolute_error: 0.2320 - 147ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.1349 - mean_absolute_error: 0.2216 - val_loss: 0.1488 - val_mean_absolute_error: 0.2303 - 145ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.1481 - mean_absolute_error: 0.2343 - val_loss: 0.1328 - val_mean_absolute_error: 0.2240 - 145ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.1422 - mean_absolute_error: 0.2255 - val_loss: 0.1336 - val_mean_absolute_error: 0.2268 - 149ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.1282 - mean_absolute_error: 0.2123 - val_loss: 0.1675 - val_mean_absolute_error: 0.2438 - 147ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.1554 - mean_absolute_error: 0.2424 - val_loss: 0.1651 - val_mean_absolute_error: 0.2648 - 160ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.1404 - mean_absolute_error: 0.2305 - val_loss: 0.1469 - val_mean_absolute_error: 0.2317 - 147ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.1319 - mean_absolute_error: 0.2166 - val_loss: 0.1378 - val_mean_absolute_error: 0.2205 - 147ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.1496 - mean_absolute_error: 0.2333 - val_loss: 0.1563 - val_mean_absolute_error: 0.2412 - 145ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.1512 - mean_absolute_error: 0.2392 - val_loss: 0.1665 - val_mean_absolute_error: 0.2617 - 145ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.1291 - mean_absolute_error: 0.2222 - val_loss: 0.1476 - val_mean_absolute_error: 0.2289 - 145ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.1319 - mean_absolute_error: 0.2205 - val_loss: 0.1466 - val_mean_absolute_error: 0.2301 - 146ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.1261 - mean_absolute_error: 0.2131 - val_loss: 0.1596 - val_mean_absolute_error: 0.2356 - 145ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.1524 - mean_absolute_error: 0.2368 - val_loss: 0.1534 - val_mean_absolute_error: 0.2435 - 146ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.1472 - mean_absolute_error: 0.2284 - val_loss: 0.1549 - val_mean_absolute_error: 0.2414 - 145ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.1294 - mean_absolute_error: 0.2150 - val_loss: 0.1417 - val_mean_absolute_error: 0.2272 - 162ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.1311 - mean_absolute_error: 0.2141 - val_loss: 0.1354 - val_mean_absolute_error: 0.2232 - 172ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.1462 - mean_absolute_error: 0.2275 - val_loss: 0.1416 - val_mean_absolute_error: 0.2366 - 163ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.1320 - mean_absolute_error: 0.2161 - val_loss: 0.1451 - val_mean_absolute_error: 0.2340 - 157ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.1311 - mean_absolute_error: 0.2215 - val_loss: 0.2074 - val_mean_absolute_error: 0.2958 - 153ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.1380 - mean_absolute_error: 0.2295 - val_loss: 0.1359 - val_mean_absolute_error: 0.2261 - 154ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.1255 - mean_absolute_error: 0.2120 - val_loss: 0.1976 - val_mean_absolute_error: 0.2550 - 150ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.1319 - mean_absolute_error: 0.2174 - val_loss: 0.1537 - val_mean_absolute_error: 0.2440 - 149ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.1351 - mean_absolute_error: 0.2195 - val_loss: 0.1361 - val_mean_absolute_error: 0.2269 - 166ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.1356 - mean_absolute_error: 0.2201 - val_loss: 0.1277 - val_mean_absolute_error: 0.2193 - 147ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.1324 - mean_absolute_error: 0.2162 - val_loss: 0.2305 - val_mean_absolute_error: 0.2893 - 150ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.1380 - mean_absolute_error: 0.2231 - val_loss: 0.1265 - val_mean_absolute_error: 0.2160 - 157ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.1316 - mean_absolute_error: 0.2231 - val_loss: 0.1518 - val_mean_absolute_error: 0.2381 - 147ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.1356 - mean_absolute_error: 0.2187 - val_loss: 0.2216 - val_mean_absolute_error: 0.2734 - 146ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.1343 - mean_absolute_error: 0.2201 - val_loss: 0.1540 - val_mean_absolute_error: 0.2291 - 146ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.1726 - mean_absolute_error: 0.2599 - val_loss: 0.1460 - val_mean_absolute_error: 0.2415 - 145ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.1316 - mean_absolute_error: 0.2199 - val_loss: 0.1487 - val_mean_absolute_error: 0.2337 - 159ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.1517 - mean_absolute_error: 0.2354 - val_loss: 0.1417 - val_mean_absolute_error: 0.2288 - 149ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.1277 - mean_absolute_error: 0.2134 - val_loss: 0.1794 - val_mean_absolute_error: 0.2495 - 145ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.1370 - mean_absolute_error: 0.2245 - val_loss: 0.1258 - val_mean_absolute_error: 0.2212 - 150ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.1418 - mean_absolute_error: 0.2235 - val_loss: 0.1315 - val_mean_absolute_error: 0.2211 - 146ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.1622 - mean_absolute_error: 0.2369 - val_loss: 0.1399 - val_mean_absolute_error: 0.2324 - 145ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.1588 - mean_absolute_error: 0.2370 - val_loss: 0.1586 - val_mean_absolute_error: 0.2597 - 148ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.1303 - mean_absolute_error: 0.2194 - val_loss: 0.1527 - val_mean_absolute_error: 0.2400 - 145ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.1259 - mean_absolute_error: 0.2077 - val_loss: 0.1332 - val_mean_absolute_error: 0.2225 - 146ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.1439 - mean_absolute_error: 0.2278 - val_loss: 0.1976 - val_mean_absolute_error: 0.2621 - 192ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.1378 - mean_absolute_error: 0.2222 - val_loss: 0.1532 - val_mean_absolute_error: 0.2351 - 144ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.1536 - mean_absolute_error: 0.2416 - val_loss: 0.1341 - val_mean_absolute_error: 0.2333 - 145ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.1375 - mean_absolute_error: 0.2199 - val_loss: 0.1625 - val_mean_absolute_error: 0.2426 - 146ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.1416 - mean_absolute_error: 0.2232 - val_loss: 0.2027 - val_mean_absolute_error: 0.2630 - 145ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.1463 - mean_absolute_error: 0.2255 - val_loss: 0.2020 - val_mean_absolute_error: 0.2649 - 146ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.1376 - mean_absolute_error: 0.2210 - val_loss: 0.2673 - val_mean_absolute_error: 0.3004 - 144ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.1626 - mean_absolute_error: 0.2467 - val_loss: 0.2064 - val_mean_absolute_error: 0.2665 - 145ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.1258 - mean_absolute_error: 0.2146 - val_loss: 0.1515 - val_mean_absolute_error: 0.2404 - 146ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.1251 - mean_absolute_error: 0.2150 - val_loss: 0.1460 - val_mean_absolute_error: 0.2245 - 150ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.1411 - mean_absolute_error: 0.2221 - val_loss: 0.1390 - val_mean_absolute_error: 0.2284 - 146ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.1522 - mean_absolute_error: 0.2319 - val_loss: 0.1602 - val_mean_absolute_error: 0.2498 - 147ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.1376 - mean_absolute_error: 0.2193 - val_loss: 0.1443 - val_mean_absolute_error: 0.2276 - 145ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.1197 - mean_absolute_error: 0.2038 - val_loss: 0.1519 - val_mean_absolute_error: 0.2314 - 145ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.1544 - mean_absolute_error: 0.2320 - val_loss: 0.1448 - val_mean_absolute_error: 0.2318 - 146ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.1451 - mean_absolute_error: 0.2283 - val_loss: 0.1676 - val_mean_absolute_error: 0.2427 - 145ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.1524 - mean_absolute_error: 0.2422 - val_loss: 0.1760 - val_mean_absolute_error: 0.2663 - 146ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.1558 - mean_absolute_error: 0.2388 - val_loss: 0.1577 - val_mean_absolute_error: 0.2499 - 146ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.1327 - mean_absolute_error: 0.2200 - val_loss: 0.1396 - val_mean_absolute_error: 0.2327 - 146ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.1291 - mean_absolute_error: 0.2164 - val_loss: 0.1313 - val_mean_absolute_error: 0.2234 - 147ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.1303 - mean_absolute_error: 0.2150 - val_loss: 0.1283 - val_mean_absolute_error: 0.2204 - 149ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.1304 - mean_absolute_error: 0.2180 - val_loss: 0.1887 - val_mean_absolute_error: 0.2608 - 145ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.1311 - mean_absolute_error: 0.2162 - val_loss: 0.1422 - val_mean_absolute_error: 0.2206 - 145ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.1350 - mean_absolute_error: 0.2186 - val_loss: 0.1513 - val_mean_absolute_error: 0.2316 - 145ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.1444 - mean_absolute_error: 0.2263 - val_loss: 0.1254 - val_mean_absolute_error: 0.2152 - 149ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.1406 - mean_absolute_error: 0.2223 - val_loss: 0.1584 - val_mean_absolute_error: 0.2407 - 145ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.1229 - mean_absolute_error: 0.2101 - val_loss: 0.1313 - val_mean_absolute_error: 0.2185 - 143ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.1461 - mean_absolute_error: 0.2367 - val_loss: 0.1345 - val_mean_absolute_error: 0.2329 - 145ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.1338 - mean_absolute_error: 0.2199 - val_loss: 0.1538 - val_mean_absolute_error: 0.2373 - 145ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.1542 - mean_absolute_error: 0.2366 - val_loss: 0.1811 - val_mean_absolute_error: 0.2673 - 144ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.1589 - mean_absolute_error: 0.2448 - val_loss: 0.1579 - val_mean_absolute_error: 0.2486 - 159ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.1248 - mean_absolute_error: 0.2125 - val_loss: 0.1459 - val_mean_absolute_error: 0.2241 - 145ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.1400 - mean_absolute_error: 0.2230 - val_loss: 0.1978 - val_mean_absolute_error: 0.2683 - 146ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.1564 - mean_absolute_error: 0.2379 - val_loss: 0.1560 - val_mean_absolute_error: 0.2431 - 147ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.1242 - mean_absolute_error: 0.2119 - val_loss: 0.2027 - val_mean_absolute_error: 0.2589 - 146ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.1458 - mean_absolute_error: 0.2283 - val_loss: 0.1715 - val_mean_absolute_error: 0.2458 - 146ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.1418 - mean_absolute_error: 0.2327 - val_loss: 0.1900 - val_mean_absolute_error: 0.2641 - 147ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.1350 - mean_absolute_error: 0.2163 - val_loss: 0.1930 - val_mean_absolute_error: 0.2679 - 146ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.1528 - mean_absolute_error: 0.2377 - val_loss: 0.1638 - val_mean_absolute_error: 0.2441 - 145ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.1249 - mean_absolute_error: 0.2116 - val_loss: 0.1264 - val_mean_absolute_error: 0.2186 - 148ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.1317 - mean_absolute_error: 0.2161 - val_loss: 0.1475 - val_mean_absolute_error: 0.2370 - 144ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.1439 - mean_absolute_error: 0.2250 - val_loss: 0.1552 - val_mean_absolute_error: 0.2460 - 146ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.1417 - mean_absolute_error: 0.2225 - val_loss: 0.2102 - val_mean_absolute_error: 0.2666 - 146ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.1681 - mean_absolute_error: 0.2496 - val_loss: 0.1530 - val_mean_absolute_error: 0.2521 - 145ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.1446 - mean_absolute_error: 0.2290 - val_loss: 0.1415 - val_mean_absolute_error: 0.2266 - 145ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.1344 - mean_absolute_error: 0.2152 - val_loss: 0.1930 - val_mean_absolute_error: 0.2615 - 146ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.1477 - mean_absolute_error: 0.2307 - val_loss: 0.1507 - val_mean_absolute_error: 0.2391 - 146ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.1271 - mean_absolute_error: 0.2147 - val_loss: 0.1299 - val_mean_absolute_error: 0.2251 - 149ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.1584 - mean_absolute_error: 0.2393 - val_loss: 0.1372 - val_mean_absolute_error: 0.2297 - 145ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.1295 - mean_absolute_error: 0.2167 - val_loss: 0.1554 - val_mean_absolute_error: 0.2422 - 145ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.1785 - mean_absolute_error: 0.2556 - val_loss: 0.1486 - val_mean_absolute_error: 0.2377 - 145ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.1371 - mean_absolute_error: 0.2213 - val_loss: 0.2037 - val_mean_absolute_error: 0.2675 - 146ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.1359 - mean_absolute_error: 0.2278 - val_loss: 0.1396 - val_mean_absolute_error: 0.2359 - 146ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.1324 - mean_absolute_error: 0.2206 - val_loss: 0.1954 - val_mean_absolute_error: 0.2585 - 145ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.1340 - mean_absolute_error: 0.2163 - val_loss: 0.3038 - val_mean_absolute_error: 0.3121 - 149ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.1569 - mean_absolute_error: 0.2444 - val_loss: 0.1443 - val_mean_absolute_error: 0.2348 - 145ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.1211 - mean_absolute_error: 0.2070 - val_loss: 0.1284 - val_mean_absolute_error: 0.2179 - 159ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.1483 - mean_absolute_error: 0.2324 - val_loss: 0.1897 - val_mean_absolute_error: 0.2651 - 144ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.1305 - mean_absolute_error: 0.2226 - val_loss: 0.1334 - val_mean_absolute_error: 0.2244 - 146ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.1355 - mean_absolute_error: 0.2204 - val_loss: 0.1324 - val_mean_absolute_error: 0.2312 - 145ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_noNoise_five(gamma-7e-3).keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE 0.13240289688110352
# MAE: 0.23124638199806213
# 32/32 [==============================] - 0s 884us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\kappa$', r'$\Delta E$', r'$g$']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(3,1, figsize=(8,15))

fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# Curvas Validación VS Predicción

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
k_pred = y_pred_denorm[:, 0]
k_val = y_val_denorm[:, 0]
DeltaE_pred = y_pred_denorm[:, 1]
DeltaE_val = y_val_denorm[:, 1]
g_pred = y_pred_denorm[:, 2]
g_val = y_val_denorm[:, 2]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val = np.zeros((x_val.shape[0], len(w_values)))


for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k_pred[i], Omega, DeltaE_pred[i], gamma, g_pred[i])
    t_values_val[i,:] = t_w(w_values, k_val[i], Omega, DeltaE_val[i], gamma, g_val[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k_val, Omega, DeltaE_val, gamma, g_val)
w2=w_2(k_val, Omega, DeltaE_val, gamma, g_val)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"κ real = {k_val[i]:.7f}, κ pred = {k_pred[i]:.7f}\n"\
           f"ΔE real = {DeltaE_val[i]:.5f}, ΔE pred = {DeltaE_pred[i]:.5f}\n"\
           f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # With noise

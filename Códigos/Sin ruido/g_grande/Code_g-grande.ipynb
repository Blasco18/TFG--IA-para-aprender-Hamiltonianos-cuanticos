# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos t($\omega$):
# $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # Sin ruido

# %% [markdown]
# ## Creamos base de datos

# %%
# Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-2, 1e-1, num_datos)

    return k, DeltaE, gamma, g

num_datos = 5000

# %%
# #Creamos base de datos y guardamos en .txt
# k, DeltaE, gamma, g = Parameters_generator (num_datos)
# np.savetxt('Parameters_noNoise(g-grande).txt', np.column_stack((k, DeltaE, gamma, g)), header='\u03BA \u0394E \u213D g')

# %%
datos = np.loadtxt('Parameters_noNoise(g-grande).txt', skiprows=1)
k = datos[:,0]
DeltaE = datos[:,1]
gamma = datos[:,2]
g = datos[:,3]
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.8, 1.2, 400)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))
t_sep_values = np.zeros((num_datos, len(w_values)))
mod_t_values = np.zeros((num_datos, len(w_values)))

# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k[i], Omega, DeltaE[i], gamma[i], g[i])

# %% [markdown]
# ### Dibujamos las curvas

# %%
# i=0
# while i<=1000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values[i,:], label='Curva original')
#     plt.plot(w_values, t_sep_values[i,:], linestyle='--', label='Curva separada')
#     plt.plot(w_values, mod_t_values[i,:], linestyle='-.', label='Módulo curva')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
x_train, x_val, y_train, y_val = train_test_split(t_values, datos, test_size=0.2) # si añades random_state= 
                                                                        # tienes siempre la misma combinación

# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 400)
# y_train shape (4000, 4)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 1 capa oculta

# %%
def Dense_simple ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(output_neurons, activation='linear'))

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_noNoise_five(g-grande).keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 1s - loss: 0.7653 - mean_absolute_error: 0.7081 - val_loss: 0.6792 - val_mean_absolute_error: 0.6480 - 1s/epoch - 15ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.6304 - mean_absolute_error: 0.6189 - val_loss: 0.5927 - val_mean_absolute_error: 0.5928 - 185ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.5752 - mean_absolute_error: 0.5809 - val_loss: 0.5495 - val_mean_absolute_error: 0.5618 - 182ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.5266 - mean_absolute_error: 0.5487 - val_loss: 0.5303 - val_mean_absolute_error: 0.5502 - 162ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.4952 - mean_absolute_error: 0.5271 - val_loss: 0.4949 - val_mean_absolute_error: 0.5254 - 164ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.4661 - mean_absolute_error: 0.5071 - val_loss: 0.4574 - val_mean_absolute_error: 0.4986 - 183ms/epoch - 2ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.4453 - mean_absolute_error: 0.4904 - val_loss: 0.4417 - val_mean_absolute_error: 0.4855 - 154ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.4200 - mean_absolute_error: 0.4716 - val_loss: 0.4184 - val_mean_absolute_error: 0.4646 - 156ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.4008 - mean_absolute_error: 0.4559 - val_loss: 0.3973 - val_mean_absolute_error: 0.4482 - 165ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.3807 - mean_absolute_error: 0.4376 - val_loss: 0.3866 - val_mean_absolute_error: 0.4369 - 170ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.3734 - mean_absolute_error: 0.4336 - val_loss: 0.3764 - val_mean_absolute_error: 0.4342 - 181ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.3528 - mean_absolute_error: 0.4159 - val_loss: 0.3540 - val_mean_absolute_error: 0.4121 - 144ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.3396 - mean_absolute_error: 0.4031 - val_loss: 0.3576 - val_mean_absolute_error: 0.4220 - 143ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.3391 - mean_absolute_error: 0.4042 - val_loss: 0.3383 - val_mean_absolute_error: 0.4028 - 151ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.3217 - mean_absolute_error: 0.3856 - val_loss: 0.3378 - val_mean_absolute_error: 0.4053 - 159ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.3160 - mean_absolute_error: 0.3830 - val_loss: 0.3284 - val_mean_absolute_error: 0.3952 - 157ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.3115 - mean_absolute_error: 0.3819 - val_loss: 0.3136 - val_mean_absolute_error: 0.3836 - 149ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.3025 - mean_absolute_error: 0.3707 - val_loss: 0.3028 - val_mean_absolute_error: 0.3722 - 148ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.2899 - mean_absolute_error: 0.3587 - val_loss: 0.3017 - val_mean_absolute_error: 0.3694 - 146ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.2834 - mean_absolute_error: 0.3511 - val_loss: 0.2889 - val_mean_absolute_error: 0.3479 - 146ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.2753 - mean_absolute_error: 0.3410 - val_loss: 0.2795 - val_mean_absolute_error: 0.3417 - 153ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.2720 - mean_absolute_error: 0.3380 - val_loss: 0.2896 - val_mean_absolute_error: 0.3508 - 159ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.2706 - mean_absolute_error: 0.3389 - val_loss: 0.2791 - val_mean_absolute_error: 0.3393 - 152ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.2592 - mean_absolute_error: 0.3259 - val_loss: 0.2748 - val_mean_absolute_error: 0.3366 - 149ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.2603 - mean_absolute_error: 0.3265 - val_loss: 0.2695 - val_mean_absolute_error: 0.3294 - 150ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.2523 - mean_absolute_error: 0.3160 - val_loss: 0.2623 - val_mean_absolute_error: 0.3230 - 149ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.2468 - mean_absolute_error: 0.3099 - val_loss: 0.2659 - val_mean_absolute_error: 0.3233 - 151ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.2486 - mean_absolute_error: 0.3156 - val_loss: 0.2585 - val_mean_absolute_error: 0.3157 - 149ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.2478 - mean_absolute_error: 0.3148 - val_loss: 0.2660 - val_mean_absolute_error: 0.3296 - 147ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.2504 - mean_absolute_error: 0.3165 - val_loss: 0.2588 - val_mean_absolute_error: 0.3195 - 149ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.2442 - mean_absolute_error: 0.3094 - val_loss: 0.2457 - val_mean_absolute_error: 0.3022 - 147ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.2327 - mean_absolute_error: 0.2956 - val_loss: 0.2692 - val_mean_absolute_error: 0.3245 - 151ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.2331 - mean_absolute_error: 0.2955 - val_loss: 0.2579 - val_mean_absolute_error: 0.3108 - 153ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.2340 - mean_absolute_error: 0.2982 - val_loss: 0.2414 - val_mean_absolute_error: 0.2989 - 151ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.2241 - mean_absolute_error: 0.2885 - val_loss: 0.2409 - val_mean_absolute_error: 0.2989 - 151ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.2336 - mean_absolute_error: 0.2975 - val_loss: 0.2454 - val_mean_absolute_error: 0.3039 - 150ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.2297 - mean_absolute_error: 0.2919 - val_loss: 0.2429 - val_mean_absolute_error: 0.2983 - 146ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.2249 - mean_absolute_error: 0.2890 - val_loss: 0.2496 - val_mean_absolute_error: 0.3049 - 147ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.2245 - mean_absolute_error: 0.2860 - val_loss: 0.2358 - val_mean_absolute_error: 0.2923 - 168ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.2212 - mean_absolute_error: 0.2866 - val_loss: 0.2451 - val_mean_absolute_error: 0.3050 - 152ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.2250 - mean_absolute_error: 0.2901 - val_loss: 0.2423 - val_mean_absolute_error: 0.2958 - 152ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.2171 - mean_absolute_error: 0.2780 - val_loss: 0.2393 - val_mean_absolute_error: 0.2916 - 150ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.2142 - mean_absolute_error: 0.2753 - val_loss: 0.2308 - val_mean_absolute_error: 0.2853 - 146ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.2165 - mean_absolute_error: 0.2812 - val_loss: 0.2472 - val_mean_absolute_error: 0.3043 - 145ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.2149 - mean_absolute_error: 0.2793 - val_loss: 0.2293 - val_mean_absolute_error: 0.2837 - 155ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.2148 - mean_absolute_error: 0.2767 - val_loss: 0.2272 - val_mean_absolute_error: 0.2825 - 174ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.2092 - mean_absolute_error: 0.2697 - val_loss: 0.2224 - val_mean_absolute_error: 0.2821 - 186ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.2097 - mean_absolute_error: 0.2705 - val_loss: 0.2239 - val_mean_absolute_error: 0.2845 - 166ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.2073 - mean_absolute_error: 0.2681 - val_loss: 0.2378 - val_mean_absolute_error: 0.2955 - 152ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.2018 - mean_absolute_error: 0.2645 - val_loss: 0.2290 - val_mean_absolute_error: 0.2831 - 150ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.2027 - mean_absolute_error: 0.2659 - val_loss: 0.2592 - val_mean_absolute_error: 0.3079 - 161ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.2023 - mean_absolute_error: 0.2646 - val_loss: 0.2301 - val_mean_absolute_error: 0.2970 - 149ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.2062 - mean_absolute_error: 0.2684 - val_loss: 0.2353 - val_mean_absolute_error: 0.2902 - 147ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.1985 - mean_absolute_error: 0.2616 - val_loss: 0.2173 - val_mean_absolute_error: 0.2738 - 149ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.1958 - mean_absolute_error: 0.2573 - val_loss: 0.2134 - val_mean_absolute_error: 0.2717 - 145ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.1951 - mean_absolute_error: 0.2597 - val_loss: 0.2075 - val_mean_absolute_error: 0.2614 - 145ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.1929 - mean_absolute_error: 0.2552 - val_loss: 0.2194 - val_mean_absolute_error: 0.2805 - 147ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.1985 - mean_absolute_error: 0.2624 - val_loss: 0.2137 - val_mean_absolute_error: 0.2680 - 149ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.1940 - mean_absolute_error: 0.2557 - val_loss: 0.2233 - val_mean_absolute_error: 0.2793 - 162ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.1887 - mean_absolute_error: 0.2527 - val_loss: 0.2084 - val_mean_absolute_error: 0.2664 - 151ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.1892 - mean_absolute_error: 0.2517 - val_loss: 0.2173 - val_mean_absolute_error: 0.2639 - 154ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.1864 - mean_absolute_error: 0.2484 - val_loss: 0.2189 - val_mean_absolute_error: 0.2618 - 149ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.1824 - mean_absolute_error: 0.2464 - val_loss: 0.2104 - val_mean_absolute_error: 0.2652 - 152ms/epoch - 2ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.1818 - mean_absolute_error: 0.2410 - val_loss: 0.2357 - val_mean_absolute_error: 0.2832 - 149ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.1835 - mean_absolute_error: 0.2464 - val_loss: 0.2196 - val_mean_absolute_error: 0.2705 - 146ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.1831 - mean_absolute_error: 0.2483 - val_loss: 0.2054 - val_mean_absolute_error: 0.2622 - 146ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.1830 - mean_absolute_error: 0.2477 - val_loss: 0.2376 - val_mean_absolute_error: 0.2779 - 150ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.1822 - mean_absolute_error: 0.2474 - val_loss: 0.2050 - val_mean_absolute_error: 0.2646 - 146ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.1730 - mean_absolute_error: 0.2379 - val_loss: 0.2081 - val_mean_absolute_error: 0.2581 - 146ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.1777 - mean_absolute_error: 0.2415 - val_loss: 0.1900 - val_mean_absolute_error: 0.2469 - 145ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.1793 - mean_absolute_error: 0.2418 - val_loss: 0.2172 - val_mean_absolute_error: 0.2641 - 147ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.1721 - mean_absolute_error: 0.2372 - val_loss: 0.1962 - val_mean_absolute_error: 0.2530 - 146ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.1770 - mean_absolute_error: 0.2398 - val_loss: 0.1867 - val_mean_absolute_error: 0.2441 - 146ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.1758 - mean_absolute_error: 0.2378 - val_loss: 0.1857 - val_mean_absolute_error: 0.2449 - 145ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.1656 - mean_absolute_error: 0.2278 - val_loss: 0.1936 - val_mean_absolute_error: 0.2442 - 144ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.1644 - mean_absolute_error: 0.2243 - val_loss: 0.1785 - val_mean_absolute_error: 0.2416 - 144ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.1692 - mean_absolute_error: 0.2295 - val_loss: 0.1892 - val_mean_absolute_error: 0.2507 - 145ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.1697 - mean_absolute_error: 0.2297 - val_loss: 0.2049 - val_mean_absolute_error: 0.2573 - 152ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.1695 - mean_absolute_error: 0.2309 - val_loss: 0.1924 - val_mean_absolute_error: 0.2503 - 158ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.1719 - mean_absolute_error: 0.2373 - val_loss: 0.1905 - val_mean_absolute_error: 0.2482 - 148ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.1665 - mean_absolute_error: 0.2321 - val_loss: 0.1857 - val_mean_absolute_error: 0.2459 - 148ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.1717 - mean_absolute_error: 0.2351 - val_loss: 0.2090 - val_mean_absolute_error: 0.2587 - 167ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.1672 - mean_absolute_error: 0.2317 - val_loss: 0.1784 - val_mean_absolute_error: 0.2394 - 149ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.1571 - mean_absolute_error: 0.2206 - val_loss: 0.1976 - val_mean_absolute_error: 0.2444 - 150ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.1623 - mean_absolute_error: 0.2246 - val_loss: 0.1778 - val_mean_absolute_error: 0.2392 - 146ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.1583 - mean_absolute_error: 0.2214 - val_loss: 0.2073 - val_mean_absolute_error: 0.2600 - 160ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.1556 - mean_absolute_error: 0.2183 - val_loss: 0.1793 - val_mean_absolute_error: 0.2355 - 152ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.1578 - mean_absolute_error: 0.2220 - val_loss: 0.1681 - val_mean_absolute_error: 0.2263 - 146ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.1571 - mean_absolute_error: 0.2187 - val_loss: 0.1862 - val_mean_absolute_error: 0.2431 - 146ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.1610 - mean_absolute_error: 0.2263 - val_loss: 0.1804 - val_mean_absolute_error: 0.2356 - 156ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.1612 - mean_absolute_error: 0.2223 - val_loss: 0.1809 - val_mean_absolute_error: 0.2340 - 148ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.1551 - mean_absolute_error: 0.2196 - val_loss: 0.1799 - val_mean_absolute_error: 0.2360 - 147ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.1526 - mean_absolute_error: 0.2159 - val_loss: 0.1830 - val_mean_absolute_error: 0.2323 - 148ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.1660 - mean_absolute_error: 0.2274 - val_loss: 0.1822 - val_mean_absolute_error: 0.2478 - 148ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.1510 - mean_absolute_error: 0.2148 - val_loss: 0.1681 - val_mean_absolute_error: 0.2305 - 143ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.1477 - mean_absolute_error: 0.2113 - val_loss: 0.1901 - val_mean_absolute_error: 0.2415 - 153ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.1549 - mean_absolute_error: 0.2186 - val_loss: 0.1796 - val_mean_absolute_error: 0.2306 - 148ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.1568 - mean_absolute_error: 0.2198 - val_loss: 0.1841 - val_mean_absolute_error: 0.2389 - 144ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.1551 - mean_absolute_error: 0.2196 - val_loss: 0.1817 - val_mean_absolute_error: 0.2389 - 145ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.1441 - mean_absolute_error: 0.2093 - val_loss: 0.1752 - val_mean_absolute_error: 0.2284 - 159ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.1465 - mean_absolute_error: 0.2088 - val_loss: 0.1683 - val_mean_absolute_error: 0.2206 - 152ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.1365 - mean_absolute_error: 0.2007 - val_loss: 0.1726 - val_mean_absolute_error: 0.2272 - 148ms/epoch - 2ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.1407 - mean_absolute_error: 0.2020 - val_loss: 0.1673 - val_mean_absolute_error: 0.2272 - 147ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.1419 - mean_absolute_error: 0.2059 - val_loss: 0.1708 - val_mean_absolute_error: 0.2310 - 146ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.1439 - mean_absolute_error: 0.2084 - val_loss: 0.1688 - val_mean_absolute_error: 0.2317 - 144ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.1519 - mean_absolute_error: 0.2142 - val_loss: 0.1752 - val_mean_absolute_error: 0.2432 - 146ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.1455 - mean_absolute_error: 0.2113 - val_loss: 0.1605 - val_mean_absolute_error: 0.2200 - 145ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.1479 - mean_absolute_error: 0.2083 - val_loss: 0.1878 - val_mean_absolute_error: 0.2407 - 149ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.1514 - mean_absolute_error: 0.2175 - val_loss: 0.1948 - val_mean_absolute_error: 0.2524 - 158ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.1400 - mean_absolute_error: 0.2038 - val_loss: 0.1822 - val_mean_absolute_error: 0.2406 - 179ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.1408 - mean_absolute_error: 0.2042 - val_loss: 0.1797 - val_mean_absolute_error: 0.2337 - 163ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.1382 - mean_absolute_error: 0.2011 - val_loss: 0.1605 - val_mean_absolute_error: 0.2180 - 178ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.1487 - mean_absolute_error: 0.2128 - val_loss: 0.1801 - val_mean_absolute_error: 0.2348 - 155ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.1375 - mean_absolute_error: 0.2002 - val_loss: 0.1986 - val_mean_absolute_error: 0.2456 - 149ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.1477 - mean_absolute_error: 0.2091 - val_loss: 0.1837 - val_mean_absolute_error: 0.2398 - 148ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.1421 - mean_absolute_error: 0.2045 - val_loss: 0.1802 - val_mean_absolute_error: 0.2355 - 154ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.1381 - mean_absolute_error: 0.2019 - val_loss: 0.1910 - val_mean_absolute_error: 0.2359 - 162ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.1405 - mean_absolute_error: 0.2016 - val_loss: 0.1792 - val_mean_absolute_error: 0.2264 - 158ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.1480 - mean_absolute_error: 0.2101 - val_loss: 0.1550 - val_mean_absolute_error: 0.2217 - 160ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.1366 - mean_absolute_error: 0.2011 - val_loss: 0.1512 - val_mean_absolute_error: 0.2180 - 157ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.1394 - mean_absolute_error: 0.2034 - val_loss: 0.1707 - val_mean_absolute_error: 0.2263 - 155ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.1421 - mean_absolute_error: 0.2057 - val_loss: 0.1505 - val_mean_absolute_error: 0.2115 - 156ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.1326 - mean_absolute_error: 0.1982 - val_loss: 0.1566 - val_mean_absolute_error: 0.2157 - 158ms/epoch - 2ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.1303 - mean_absolute_error: 0.1958 - val_loss: 0.1659 - val_mean_absolute_error: 0.2199 - 160ms/epoch - 2ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.1481 - mean_absolute_error: 0.2115 - val_loss: 0.1870 - val_mean_absolute_error: 0.2413 - 154ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.1425 - mean_absolute_error: 0.2112 - val_loss: 0.1764 - val_mean_absolute_error: 0.2227 - 153ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.1315 - mean_absolute_error: 0.1937 - val_loss: 0.1923 - val_mean_absolute_error: 0.2441 - 148ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.1407 - mean_absolute_error: 0.2077 - val_loss: 0.1600 - val_mean_absolute_error: 0.2223 - 145ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.1325 - mean_absolute_error: 0.1939 - val_loss: 0.1732 - val_mean_absolute_error: 0.2226 - 153ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.1364 - mean_absolute_error: 0.1991 - val_loss: 0.1786 - val_mean_absolute_error: 0.2297 - 148ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.1449 - mean_absolute_error: 0.2080 - val_loss: 0.1585 - val_mean_absolute_error: 0.2137 - 151ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.1418 - mean_absolute_error: 0.2046 - val_loss: 0.1612 - val_mean_absolute_error: 0.2233 - 148ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.1280 - mean_absolute_error: 0.1944 - val_loss: 0.1518 - val_mean_absolute_error: 0.2125 - 147ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.1265 - mean_absolute_error: 0.1923 - val_loss: 0.1515 - val_mean_absolute_error: 0.2085 - 147ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.1261 - mean_absolute_error: 0.1894 - val_loss: 0.1513 - val_mean_absolute_error: 0.2085 - 146ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.1318 - mean_absolute_error: 0.1941 - val_loss: 0.1856 - val_mean_absolute_error: 0.2382 - 151ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.1319 - mean_absolute_error: 0.1949 - val_loss: 0.1609 - val_mean_absolute_error: 0.2223 - 150ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.1250 - mean_absolute_error: 0.1888 - val_loss: 0.1476 - val_mean_absolute_error: 0.2154 - 154ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.1292 - mean_absolute_error: 0.1937 - val_loss: 0.1595 - val_mean_absolute_error: 0.2175 - 147ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.1322 - mean_absolute_error: 0.1957 - val_loss: 0.1614 - val_mean_absolute_error: 0.2157 - 148ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.1318 - mean_absolute_error: 0.1961 - val_loss: 0.1511 - val_mean_absolute_error: 0.2076 - 149ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.1261 - mean_absolute_error: 0.1884 - val_loss: 0.1602 - val_mean_absolute_error: 0.2205 - 146ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.1261 - mean_absolute_error: 0.1904 - val_loss: 0.1697 - val_mean_absolute_error: 0.2215 - 156ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.1285 - mean_absolute_error: 0.1896 - val_loss: 0.1574 - val_mean_absolute_error: 0.2169 - 152ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.1236 - mean_absolute_error: 0.1877 - val_loss: 0.1655 - val_mean_absolute_error: 0.2178 - 156ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.1306 - mean_absolute_error: 0.1948 - val_loss: 0.1696 - val_mean_absolute_error: 0.2253 - 172ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.1295 - mean_absolute_error: 0.1917 - val_loss: 0.1638 - val_mean_absolute_error: 0.2162 - 152ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.1243 - mean_absolute_error: 0.1908 - val_loss: 0.1440 - val_mean_absolute_error: 0.2081 - 150ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.1227 - mean_absolute_error: 0.1854 - val_loss: 0.1570 - val_mean_absolute_error: 0.2263 - 168ms/epoch - 2ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.1250 - mean_absolute_error: 0.1898 - val_loss: 0.1534 - val_mean_absolute_error: 0.2123 - 161ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.1229 - mean_absolute_error: 0.1839 - val_loss: 0.1644 - val_mean_absolute_error: 0.2173 - 149ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.1274 - mean_absolute_error: 0.1899 - val_loss: 0.1563 - val_mean_absolute_error: 0.2124 - 154ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.1278 - mean_absolute_error: 0.1924 - val_loss: 0.1617 - val_mean_absolute_error: 0.2173 - 147ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.1267 - mean_absolute_error: 0.1885 - val_loss: 0.1812 - val_mean_absolute_error: 0.2387 - 146ms/epoch - 2ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.1294 - mean_absolute_error: 0.1941 - val_loss: 0.1588 - val_mean_absolute_error: 0.2260 - 145ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.1276 - mean_absolute_error: 0.1908 - val_loss: 0.1528 - val_mean_absolute_error: 0.2118 - 147ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.1210 - mean_absolute_error: 0.1827 - val_loss: 0.1636 - val_mean_absolute_error: 0.2195 - 145ms/epoch - 2ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.1274 - mean_absolute_error: 0.1923 - val_loss: 0.1622 - val_mean_absolute_error: 0.2263 - 157ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.1181 - mean_absolute_error: 0.1821 - val_loss: 0.1414 - val_mean_absolute_error: 0.2016 - 155ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.1194 - mean_absolute_error: 0.1828 - val_loss: 0.1519 - val_mean_absolute_error: 0.2077 - 145ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.1241 - mean_absolute_error: 0.1875 - val_loss: 0.1616 - val_mean_absolute_error: 0.2174 - 145ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.1214 - mean_absolute_error: 0.1851 - val_loss: 0.1391 - val_mean_absolute_error: 0.1974 - 148ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.1257 - mean_absolute_error: 0.1902 - val_loss: 0.1523 - val_mean_absolute_error: 0.2118 - 148ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.1207 - mean_absolute_error: 0.1864 - val_loss: 0.1481 - val_mean_absolute_error: 0.2058 - 146ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.1279 - mean_absolute_error: 0.1908 - val_loss: 0.1668 - val_mean_absolute_error: 0.2283 - 146ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.1271 - mean_absolute_error: 0.1962 - val_loss: 0.1463 - val_mean_absolute_error: 0.2117 - 145ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.1223 - mean_absolute_error: 0.1840 - val_loss: 0.1575 - val_mean_absolute_error: 0.2100 - 146ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.1217 - mean_absolute_error: 0.1847 - val_loss: 0.1467 - val_mean_absolute_error: 0.2001 - 152ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.1212 - mean_absolute_error: 0.1856 - val_loss: 0.1463 - val_mean_absolute_error: 0.2060 - 145ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.1178 - mean_absolute_error: 0.1801 - val_loss: 0.1351 - val_mean_absolute_error: 0.1952 - 151ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.1164 - mean_absolute_error: 0.1775 - val_loss: 0.1502 - val_mean_absolute_error: 0.2090 - 147ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.1171 - mean_absolute_error: 0.1812 - val_loss: 0.1571 - val_mean_absolute_error: 0.2087 - 159ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.1305 - mean_absolute_error: 0.1942 - val_loss: 0.1530 - val_mean_absolute_error: 0.2054 - 150ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.1209 - mean_absolute_error: 0.1831 - val_loss: 0.1633 - val_mean_absolute_error: 0.2125 - 156ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.1199 - mean_absolute_error: 0.1861 - val_loss: 0.1584 - val_mean_absolute_error: 0.2116 - 146ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.1110 - mean_absolute_error: 0.1785 - val_loss: 0.1533 - val_mean_absolute_error: 0.2098 - 177ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.1219 - mean_absolute_error: 0.1853 - val_loss: 0.1477 - val_mean_absolute_error: 0.2085 - 161ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.1091 - mean_absolute_error: 0.1735 - val_loss: 0.1493 - val_mean_absolute_error: 0.2058 - 161ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.1234 - mean_absolute_error: 0.1843 - val_loss: 0.1646 - val_mean_absolute_error: 0.2234 - 172ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.1233 - mean_absolute_error: 0.1915 - val_loss: 0.1744 - val_mean_absolute_error: 0.2171 - 167ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.1173 - mean_absolute_error: 0.1822 - val_loss: 0.1353 - val_mean_absolute_error: 0.1945 - 157ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.1176 - mean_absolute_error: 0.1784 - val_loss: 0.1332 - val_mean_absolute_error: 0.1926 - 190ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.1156 - mean_absolute_error: 0.1796 - val_loss: 0.1453 - val_mean_absolute_error: 0.2027 - 159ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.1181 - mean_absolute_error: 0.1816 - val_loss: 0.1730 - val_mean_absolute_error: 0.2241 - 156ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.1241 - mean_absolute_error: 0.1883 - val_loss: 0.1632 - val_mean_absolute_error: 0.2136 - 159ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.1232 - mean_absolute_error: 0.1876 - val_loss: 0.1441 - val_mean_absolute_error: 0.2027 - 159ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.1170 - mean_absolute_error: 0.1825 - val_loss: 0.1509 - val_mean_absolute_error: 0.2042 - 156ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.1137 - mean_absolute_error: 0.1769 - val_loss: 0.1565 - val_mean_absolute_error: 0.2106 - 165ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.1181 - mean_absolute_error: 0.1834 - val_loss: 0.1412 - val_mean_absolute_error: 0.2024 - 154ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.1164 - mean_absolute_error: 0.1806 - val_loss: 0.1335 - val_mean_absolute_error: 0.1943 - 148ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.1186 - mean_absolute_error: 0.1824 - val_loss: 0.1456 - val_mean_absolute_error: 0.1983 - 150ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.1140 - mean_absolute_error: 0.1785 - val_loss: 0.1506 - val_mean_absolute_error: 0.2068 - 152ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.1057 - mean_absolute_error: 0.1682 - val_loss: 0.1341 - val_mean_absolute_error: 0.1898 - 149ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.1195 - mean_absolute_error: 0.1807 - val_loss: 0.1427 - val_mean_absolute_error: 0.1991 - 152ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.1159 - mean_absolute_error: 0.1781 - val_loss: 0.1533 - val_mean_absolute_error: 0.2173 - 154ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.1180 - mean_absolute_error: 0.1820 - val_loss: 0.1562 - val_mean_absolute_error: 0.2173 - 150ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.1179 - mean_absolute_error: 0.1813 - val_loss: 0.1747 - val_mean_absolute_error: 0.2326 - 149ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.1219 - mean_absolute_error: 0.1878 - val_loss: 0.1399 - val_mean_absolute_error: 0.1966 - 149ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.1165 - mean_absolute_error: 0.1807 - val_loss: 0.1533 - val_mean_absolute_error: 0.2026 - 178ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.1119 - mean_absolute_error: 0.1755 - val_loss: 0.1418 - val_mean_absolute_error: 0.1994 - 183ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.1159 - mean_absolute_error: 0.1790 - val_loss: 0.1480 - val_mean_absolute_error: 0.2042 - 183ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.1073 - mean_absolute_error: 0.1707 - val_loss: 0.1476 - val_mean_absolute_error: 0.1977 - 168ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.1237 - mean_absolute_error: 0.1871 - val_loss: 0.1396 - val_mean_absolute_error: 0.1964 - 165ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.1220 - mean_absolute_error: 0.1863 - val_loss: 0.1543 - val_mean_absolute_error: 0.2106 - 165ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.1193 - mean_absolute_error: 0.1830 - val_loss: 0.1492 - val_mean_absolute_error: 0.2100 - 158ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.1095 - mean_absolute_error: 0.1738 - val_loss: 0.1547 - val_mean_absolute_error: 0.2090 - 155ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.1054 - mean_absolute_error: 0.1669 - val_loss: 0.1854 - val_mean_absolute_error: 0.2216 - 160ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.1165 - mean_absolute_error: 0.1795 - val_loss: 0.1592 - val_mean_absolute_error: 0.2089 - 159ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.1079 - mean_absolute_error: 0.1715 - val_loss: 0.1331 - val_mean_absolute_error: 0.1919 - 163ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.1187 - mean_absolute_error: 0.1832 - val_loss: 0.1374 - val_mean_absolute_error: 0.1972 - 182ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.1061 - mean_absolute_error: 0.1703 - val_loss: 0.1497 - val_mean_absolute_error: 0.2048 - 206ms/epoch - 3ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.1200 - mean_absolute_error: 0.1847 - val_loss: 0.1430 - val_mean_absolute_error: 0.1979 - 176ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.1049 - mean_absolute_error: 0.1680 - val_loss: 0.1499 - val_mean_absolute_error: 0.2052 - 166ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.1154 - mean_absolute_error: 0.1800 - val_loss: 0.1602 - val_mean_absolute_error: 0.2139 - 151ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.1129 - mean_absolute_error: 0.1774 - val_loss: 0.1865 - val_mean_absolute_error: 0.2190 - 151ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.1170 - mean_absolute_error: 0.1808 - val_loss: 0.1355 - val_mean_absolute_error: 0.1924 - 155ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.1059 - mean_absolute_error: 0.1667 - val_loss: 0.1406 - val_mean_absolute_error: 0.1958 - 160ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.1114 - mean_absolute_error: 0.1758 - val_loss: 0.1375 - val_mean_absolute_error: 0.1977 - 155ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.1106 - mean_absolute_error: 0.1740 - val_loss: 0.1554 - val_mean_absolute_error: 0.2122 - 153ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.1063 - mean_absolute_error: 0.1705 - val_loss: 0.1437 - val_mean_absolute_error: 0.1977 - 154ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.0995 - mean_absolute_error: 0.1636 - val_loss: 0.1291 - val_mean_absolute_error: 0.1890 - 147ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.1130 - mean_absolute_error: 0.1752 - val_loss: 0.1407 - val_mean_absolute_error: 0.1955 - 158ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.1064 - mean_absolute_error: 0.1663 - val_loss: 0.1412 - val_mean_absolute_error: 0.1935 - 159ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.1077 - mean_absolute_error: 0.1702 - val_loss: 0.1475 - val_mean_absolute_error: 0.2062 - 166ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.1101 - mean_absolute_error: 0.1730 - val_loss: 0.1427 - val_mean_absolute_error: 0.1997 - 155ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.1085 - mean_absolute_error: 0.1726 - val_loss: 0.1563 - val_mean_absolute_error: 0.2071 - 155ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.1119 - mean_absolute_error: 0.1761 - val_loss: 0.1710 - val_mean_absolute_error: 0.2270 - 152ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.1150 - mean_absolute_error: 0.1770 - val_loss: 0.1464 - val_mean_absolute_error: 0.2011 - 152ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.1036 - mean_absolute_error: 0.1654 - val_loss: 0.1354 - val_mean_absolute_error: 0.1904 - 167ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.1114 - mean_absolute_error: 0.1745 - val_loss: 0.1677 - val_mean_absolute_error: 0.2165 - 155ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.1056 - mean_absolute_error: 0.1707 - val_loss: 0.1327 - val_mean_absolute_error: 0.1940 - 152ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.1140 - mean_absolute_error: 0.1751 - val_loss: 0.1595 - val_mean_absolute_error: 0.2209 - 152ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.1154 - mean_absolute_error: 0.1795 - val_loss: 0.1595 - val_mean_absolute_error: 0.2194 - 157ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.1169 - mean_absolute_error: 0.1827 - val_loss: 0.1444 - val_mean_absolute_error: 0.2000 - 152ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.1181 - mean_absolute_error: 0.1820 - val_loss: 0.1570 - val_mean_absolute_error: 0.2132 - 151ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.1121 - mean_absolute_error: 0.1767 - val_loss: 0.1530 - val_mean_absolute_error: 0.2146 - 151ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.1095 - mean_absolute_error: 0.1749 - val_loss: 0.1458 - val_mean_absolute_error: 0.2029 - 154ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.0997 - mean_absolute_error: 0.1629 - val_loss: 0.1406 - val_mean_absolute_error: 0.1965 - 157ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.1130 - mean_absolute_error: 0.1750 - val_loss: 0.1509 - val_mean_absolute_error: 0.2103 - 160ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.1217 - mean_absolute_error: 0.1901 - val_loss: 0.1397 - val_mean_absolute_error: 0.2021 - 162ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.1016 - mean_absolute_error: 0.1668 - val_loss: 0.1521 - val_mean_absolute_error: 0.2034 - 152ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.1134 - mean_absolute_error: 0.1768 - val_loss: 0.1464 - val_mean_absolute_error: 0.2164 - 152ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.1049 - mean_absolute_error: 0.1694 - val_loss: 0.1280 - val_mean_absolute_error: 0.1877 - 161ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.1043 - mean_absolute_error: 0.1697 - val_loss: 0.1793 - val_mean_absolute_error: 0.2188 - 168ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.1073 - mean_absolute_error: 0.1709 - val_loss: 0.1502 - val_mean_absolute_error: 0.2128 - 157ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.1052 - mean_absolute_error: 0.1704 - val_loss: 0.1561 - val_mean_absolute_error: 0.2033 - 155ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.1064 - mean_absolute_error: 0.1663 - val_loss: 0.1512 - val_mean_absolute_error: 0.2015 - 153ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.1147 - mean_absolute_error: 0.1786 - val_loss: 0.1754 - val_mean_absolute_error: 0.2186 - 154ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.1055 - mean_absolute_error: 0.1678 - val_loss: 0.1694 - val_mean_absolute_error: 0.2199 - 155ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.1101 - mean_absolute_error: 0.1749 - val_loss: 0.1417 - val_mean_absolute_error: 0.1969 - 157ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.1059 - mean_absolute_error: 0.1660 - val_loss: 0.1366 - val_mean_absolute_error: 0.1924 - 154ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.1063 - mean_absolute_error: 0.1713 - val_loss: 0.1350 - val_mean_absolute_error: 0.1872 - 152ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.0941 - mean_absolute_error: 0.1548 - val_loss: 0.1427 - val_mean_absolute_error: 0.1958 - 152ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.1056 - mean_absolute_error: 0.1675 - val_loss: 0.1687 - val_mean_absolute_error: 0.2127 - 159ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.1189 - mean_absolute_error: 0.1812 - val_loss: 0.1373 - val_mean_absolute_error: 0.1992 - 153ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.1037 - mean_absolute_error: 0.1661 - val_loss: 0.1415 - val_mean_absolute_error: 0.1951 - 166ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.1090 - mean_absolute_error: 0.1687 - val_loss: 0.1435 - val_mean_absolute_error: 0.2019 - 156ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.1039 - mean_absolute_error: 0.1690 - val_loss: 0.1417 - val_mean_absolute_error: 0.2028 - 180ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.1103 - mean_absolute_error: 0.1732 - val_loss: 0.1455 - val_mean_absolute_error: 0.1994 - 186ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.1074 - mean_absolute_error: 0.1694 - val_loss: 0.1393 - val_mean_absolute_error: 0.1975 - 170ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.1069 - mean_absolute_error: 0.1687 - val_loss: 0.1448 - val_mean_absolute_error: 0.2037 - 151ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.1084 - mean_absolute_error: 0.1735 - val_loss: 0.1462 - val_mean_absolute_error: 0.2015 - 154ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.1141 - mean_absolute_error: 0.1761 - val_loss: 0.1332 - val_mean_absolute_error: 0.1889 - 155ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.1040 - mean_absolute_error: 0.1676 - val_loss: 0.1577 - val_mean_absolute_error: 0.2113 - 150ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.1098 - mean_absolute_error: 0.1725 - val_loss: 0.1366 - val_mean_absolute_error: 0.1896 - 156ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.0969 - mean_absolute_error: 0.1616 - val_loss: 0.1398 - val_mean_absolute_error: 0.1989 - 154ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.1037 - mean_absolute_error: 0.1651 - val_loss: 0.1351 - val_mean_absolute_error: 0.1905 - 150ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.1087 - mean_absolute_error: 0.1717 - val_loss: 0.1496 - val_mean_absolute_error: 0.2050 - 150ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.1125 - mean_absolute_error: 0.1764 - val_loss: 0.1511 - val_mean_absolute_error: 0.2007 - 152ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.1021 - mean_absolute_error: 0.1651 - val_loss: 0.1484 - val_mean_absolute_error: 0.2009 - 156ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.1073 - mean_absolute_error: 0.1710 - val_loss: 0.1454 - val_mean_absolute_error: 0.1982 - 158ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.1052 - mean_absolute_error: 0.1672 - val_loss: 0.1584 - val_mean_absolute_error: 0.2104 - 163ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.1026 - mean_absolute_error: 0.1647 - val_loss: 0.1307 - val_mean_absolute_error: 0.1881 - 157ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.1108 - mean_absolute_error: 0.1738 - val_loss: 0.1728 - val_mean_absolute_error: 0.2312 - 160ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.1116 - mean_absolute_error: 0.1793 - val_loss: 0.1438 - val_mean_absolute_error: 0.2015 - 158ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.1023 - mean_absolute_error: 0.1646 - val_loss: 0.1393 - val_mean_absolute_error: 0.1962 - 152ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.0986 - mean_absolute_error: 0.1643 - val_loss: 0.1419 - val_mean_absolute_error: 0.1997 - 152ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.1044 - mean_absolute_error: 0.1691 - val_loss: 0.1433 - val_mean_absolute_error: 0.2053 - 151ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.1020 - mean_absolute_error: 0.1688 - val_loss: 0.1362 - val_mean_absolute_error: 0.1914 - 151ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.1015 - mean_absolute_error: 0.1634 - val_loss: 0.1476 - val_mean_absolute_error: 0.1958 - 165ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.1119 - mean_absolute_error: 0.1723 - val_loss: 0.1467 - val_mean_absolute_error: 0.2014 - 219ms/epoch - 3ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.0975 - mean_absolute_error: 0.1626 - val_loss: 0.1442 - val_mean_absolute_error: 0.1977 - 180ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.1018 - mean_absolute_error: 0.1619 - val_loss: 0.1534 - val_mean_absolute_error: 0.2151 - 159ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.0996 - mean_absolute_error: 0.1648 - val_loss: 0.1472 - val_mean_absolute_error: 0.2034 - 154ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.1040 - mean_absolute_error: 0.1661 - val_loss: 0.1312 - val_mean_absolute_error: 0.1886 - 150ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.0952 - mean_absolute_error: 0.1581 - val_loss: 0.1390 - val_mean_absolute_error: 0.1951 - 151ms/epoch - 2ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.1072 - mean_absolute_error: 0.1699 - val_loss: 0.1467 - val_mean_absolute_error: 0.1912 - 154ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.1072 - mean_absolute_error: 0.1686 - val_loss: 0.1541 - val_mean_absolute_error: 0.2045 - 154ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.0969 - mean_absolute_error: 0.1592 - val_loss: 0.1656 - val_mean_absolute_error: 0.2125 - 152ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.1118 - mean_absolute_error: 0.1728 - val_loss: 0.1519 - val_mean_absolute_error: 0.2069 - 151ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.0937 - mean_absolute_error: 0.1559 - val_loss: 0.1389 - val_mean_absolute_error: 0.1929 - 153ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.0981 - mean_absolute_error: 0.1607 - val_loss: 0.1505 - val_mean_absolute_error: 0.1992 - 153ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.0994 - mean_absolute_error: 0.1632 - val_loss: 0.1466 - val_mean_absolute_error: 0.2049 - 151ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.0919 - mean_absolute_error: 0.1578 - val_loss: 0.1280 - val_mean_absolute_error: 0.1854 - 151ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.1010 - mean_absolute_error: 0.1652 - val_loss: 0.1367 - val_mean_absolute_error: 0.1914 - 154ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.0975 - mean_absolute_error: 0.1622 - val_loss: 0.1363 - val_mean_absolute_error: 0.1947 - 164ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.1031 - mean_absolute_error: 0.1675 - val_loss: 0.1405 - val_mean_absolute_error: 0.1957 - 156ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.0982 - mean_absolute_error: 0.1598 - val_loss: 0.1725 - val_mean_absolute_error: 0.2192 - 197ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.1011 - mean_absolute_error: 0.1647 - val_loss: 0.1257 - val_mean_absolute_error: 0.1829 - 166ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.0952 - mean_absolute_error: 0.1586 - val_loss: 0.1522 - val_mean_absolute_error: 0.1956 - 171ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.0974 - mean_absolute_error: 0.1592 - val_loss: 0.1379 - val_mean_absolute_error: 0.1903 - 187ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.0980 - mean_absolute_error: 0.1610 - val_loss: 0.1393 - val_mean_absolute_error: 0.1927 - 186ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.1012 - mean_absolute_error: 0.1657 - val_loss: 0.1386 - val_mean_absolute_error: 0.1923 - 215ms/epoch - 3ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.1007 - mean_absolute_error: 0.1635 - val_loss: 0.1310 - val_mean_absolute_error: 0.1845 - 203ms/epoch - 3ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.1013 - mean_absolute_error: 0.1638 - val_loss: 0.1288 - val_mean_absolute_error: 0.1862 - 202ms/epoch - 3ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.1018 - mean_absolute_error: 0.1645 - val_loss: 0.1622 - val_mean_absolute_error: 0.2128 - 187ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.0965 - mean_absolute_error: 0.1576 - val_loss: 0.1585 - val_mean_absolute_error: 0.2056 - 153ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.1014 - mean_absolute_error: 0.1640 - val_loss: 0.1730 - val_mean_absolute_error: 0.2218 - 154ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.1004 - mean_absolute_error: 0.1622 - val_loss: 0.1489 - val_mean_absolute_error: 0.1987 - 166ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.0948 - mean_absolute_error: 0.1593 - val_loss: 0.1550 - val_mean_absolute_error: 0.2038 - 156ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.1068 - mean_absolute_error: 0.1694 - val_loss: 0.1819 - val_mean_absolute_error: 0.2187 - 157ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.1147 - mean_absolute_error: 0.1806 - val_loss: 0.1519 - val_mean_absolute_error: 0.2054 - 156ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.1046 - mean_absolute_error: 0.1688 - val_loss: 0.1445 - val_mean_absolute_error: 0.1978 - 166ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.1002 - mean_absolute_error: 0.1619 - val_loss: 0.1306 - val_mean_absolute_error: 0.1873 - 171ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.1012 - mean_absolute_error: 0.1646 - val_loss: 0.1574 - val_mean_absolute_error: 0.2106 - 181ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.1032 - mean_absolute_error: 0.1669 - val_loss: 0.1396 - val_mean_absolute_error: 0.1955 - 189ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.0907 - mean_absolute_error: 0.1520 - val_loss: 0.1303 - val_mean_absolute_error: 0.1856 - 152ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.0956 - mean_absolute_error: 0.1594 - val_loss: 0.1399 - val_mean_absolute_error: 0.1944 - 156ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.1023 - mean_absolute_error: 0.1664 - val_loss: 0.1377 - val_mean_absolute_error: 0.1915 - 150ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.0935 - mean_absolute_error: 0.1564 - val_loss: 0.1502 - val_mean_absolute_error: 0.1965 - 155ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.1048 - mean_absolute_error: 0.1650 - val_loss: 0.1425 - val_mean_absolute_error: 0.1976 - 149ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.0912 - mean_absolute_error: 0.1536 - val_loss: 0.1324 - val_mean_absolute_error: 0.1896 - 151ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.0600 - mean_absolute_error: 0.1222 - val_loss: 0.1295 - val_mean_absolute_error: 0.1817 - 151ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.0635 - mean_absolute_error: 0.1271 - val_loss: 0.1447 - val_mean_absolute_error: 0.1856 - 149ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.0669 - mean_absolute_error: 0.1325 - val_loss: 0.1359 - val_mean_absolute_error: 0.1914 - 148ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.0629 - mean_absolute_error: 0.1283 - val_loss: 0.1381 - val_mean_absolute_error: 0.1858 - 148ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.0646 - mean_absolute_error: 0.1289 - val_loss: 0.1515 - val_mean_absolute_error: 0.1980 - 159ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.0595 - mean_absolute_error: 0.1227 - val_loss: 0.1221 - val_mean_absolute_error: 0.1697 - 146ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.0548 - mean_absolute_error: 0.1162 - val_loss: 0.1441 - val_mean_absolute_error: 0.1824 - 146ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.0629 - mean_absolute_error: 0.1255 - val_loss: 0.1373 - val_mean_absolute_error: 0.1834 - 146ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.0642 - mean_absolute_error: 0.1282 - val_loss: 0.1474 - val_mean_absolute_error: 0.1873 - 147ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.0613 - mean_absolute_error: 0.1237 - val_loss: 0.1425 - val_mean_absolute_error: 0.1872 - 147ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.0533 - mean_absolute_error: 0.1157 - val_loss: 0.1381 - val_mean_absolute_error: 0.1808 - 147ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.0600 - mean_absolute_error: 0.1199 - val_loss: 0.1529 - val_mean_absolute_error: 0.2006 - 148ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.0650 - mean_absolute_error: 0.1313 - val_loss: 0.1418 - val_mean_absolute_error: 0.1856 - 147ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.0677 - mean_absolute_error: 0.1332 - val_loss: 0.1651 - val_mean_absolute_error: 0.2143 - 149ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.0743 - mean_absolute_error: 0.1398 - val_loss: 0.1372 - val_mean_absolute_error: 0.1872 - 148ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.0575 - mean_absolute_error: 0.1192 - val_loss: 0.1404 - val_mean_absolute_error: 0.1863 - 146ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.0623 - mean_absolute_error: 0.1275 - val_loss: 0.1332 - val_mean_absolute_error: 0.1804 - 150ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.0586 - mean_absolute_error: 0.1213 - val_loss: 0.1326 - val_mean_absolute_error: 0.1800 - 151ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.0756 - mean_absolute_error: 0.1355 - val_loss: 0.1834 - val_mean_absolute_error: 0.2246 - 151ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.0896 - mean_absolute_error: 0.1571 - val_loss: 0.1402 - val_mean_absolute_error: 0.1892 - 147ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.0605 - mean_absolute_error: 0.1240 - val_loss: 0.1376 - val_mean_absolute_error: 0.1868 - 147ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.0645 - mean_absolute_error: 0.1272 - val_loss: 0.1414 - val_mean_absolute_error: 0.1909 - 148ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.0798 - mean_absolute_error: 0.1457 - val_loss: 0.1332 - val_mean_absolute_error: 0.1815 - 149ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.0586 - mean_absolute_error: 0.1216 - val_loss: 0.1295 - val_mean_absolute_error: 0.1790 - 146ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.0590 - mean_absolute_error: 0.1213 - val_loss: 0.1293 - val_mean_absolute_error: 0.1793 - 147ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.0620 - mean_absolute_error: 0.1240 - val_loss: 0.1455 - val_mean_absolute_error: 0.1906 - 146ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.0625 - mean_absolute_error: 0.1247 - val_loss: 0.1476 - val_mean_absolute_error: 0.1933 - 148ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.0614 - mean_absolute_error: 0.1239 - val_loss: 0.1413 - val_mean_absolute_error: 0.1878 - 147ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.0639 - mean_absolute_error: 0.1273 - val_loss: 0.1375 - val_mean_absolute_error: 0.1824 - 151ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.0614 - mean_absolute_error: 0.1223 - val_loss: 0.1478 - val_mean_absolute_error: 0.1901 - 151ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.0739 - mean_absolute_error: 0.1372 - val_loss: 0.1324 - val_mean_absolute_error: 0.1809 - 148ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.0569 - mean_absolute_error: 0.1200 - val_loss: 0.1272 - val_mean_absolute_error: 0.1733 - 147ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.0542 - mean_absolute_error: 0.1166 - val_loss: 0.1379 - val_mean_absolute_error: 0.1838 - 147ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.0723 - mean_absolute_error: 0.1352 - val_loss: 0.1469 - val_mean_absolute_error: 0.1904 - 146ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.0713 - mean_absolute_error: 0.1355 - val_loss: 0.1389 - val_mean_absolute_error: 0.1862 - 147ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.0620 - mean_absolute_error: 0.1265 - val_loss: 0.1434 - val_mean_absolute_error: 0.1906 - 145ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.0626 - mean_absolute_error: 0.1261 - val_loss: 0.1374 - val_mean_absolute_error: 0.1846 - 149ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.0568 - mean_absolute_error: 0.1175 - val_loss: 0.1551 - val_mean_absolute_error: 0.2007 - 148ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.0689 - mean_absolute_error: 0.1336 - val_loss: 0.1351 - val_mean_absolute_error: 0.1854 - 149ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.0607 - mean_absolute_error: 0.1262 - val_loss: 0.1332 - val_mean_absolute_error: 0.1855 - 148ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.0670 - mean_absolute_error: 0.1301 - val_loss: 0.1243 - val_mean_absolute_error: 0.1769 - 146ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.0627 - mean_absolute_error: 0.1252 - val_loss: 0.1397 - val_mean_absolute_error: 0.1875 - 147ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.0554 - mean_absolute_error: 0.1186 - val_loss: 0.1403 - val_mean_absolute_error: 0.1840 - 149ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.0557 - mean_absolute_error: 0.1186 - val_loss: 0.1611 - val_mean_absolute_error: 0.2005 - 145ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.0594 - mean_absolute_error: 0.1231 - val_loss: 0.1338 - val_mean_absolute_error: 0.1799 - 150ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.0588 - mean_absolute_error: 0.1200 - val_loss: 0.1477 - val_mean_absolute_error: 0.1825 - 149ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.0675 - mean_absolute_error: 0.1319 - val_loss: 0.1429 - val_mean_absolute_error: 0.1903 - 146ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.0616 - mean_absolute_error: 0.1247 - val_loss: 0.1423 - val_mean_absolute_error: 0.1921 - 148ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.0559 - mean_absolute_error: 0.1203 - val_loss: 0.1353 - val_mean_absolute_error: 0.1889 - 148ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.0711 - mean_absolute_error: 0.1356 - val_loss: 0.1379 - val_mean_absolute_error: 0.1829 - 150ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.0619 - mean_absolute_error: 0.1261 - val_loss: 0.1288 - val_mean_absolute_error: 0.1783 - 147ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.0643 - mean_absolute_error: 0.1258 - val_loss: 0.1485 - val_mean_absolute_error: 0.1920 - 149ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.0564 - mean_absolute_error: 0.1195 - val_loss: 0.1506 - val_mean_absolute_error: 0.1899 - 150ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.0625 - mean_absolute_error: 0.1251 - val_loss: 0.1431 - val_mean_absolute_error: 0.1879 - 148ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.0722 - mean_absolute_error: 0.1349 - val_loss: 0.1425 - val_mean_absolute_error: 0.1836 - 148ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.0569 - mean_absolute_error: 0.1187 - val_loss: 0.1379 - val_mean_absolute_error: 0.1777 - 148ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.0539 - mean_absolute_error: 0.1147 - val_loss: 0.1393 - val_mean_absolute_error: 0.1829 - 152ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.0501 - mean_absolute_error: 0.1109 - val_loss: 0.1421 - val_mean_absolute_error: 0.1837 - 147ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.0561 - mean_absolute_error: 0.1208 - val_loss: 0.1495 - val_mean_absolute_error: 0.1919 - 149ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.0604 - mean_absolute_error: 0.1224 - val_loss: 0.1295 - val_mean_absolute_error: 0.1784 - 153ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.0694 - mean_absolute_error: 0.1338 - val_loss: 0.1381 - val_mean_absolute_error: 0.1943 - 150ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.0594 - mean_absolute_error: 0.1238 - val_loss: 0.1471 - val_mean_absolute_error: 0.1917 - 151ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.0685 - mean_absolute_error: 0.1358 - val_loss: 0.1490 - val_mean_absolute_error: 0.1909 - 150ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.0541 - mean_absolute_error: 0.1156 - val_loss: 0.1448 - val_mean_absolute_error: 0.1864 - 150ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.0577 - mean_absolute_error: 0.1207 - val_loss: 0.1526 - val_mean_absolute_error: 0.1946 - 149ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.0563 - mean_absolute_error: 0.1203 - val_loss: 0.1392 - val_mean_absolute_error: 0.1834 - 148ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.0543 - mean_absolute_error: 0.1156 - val_loss: 0.1393 - val_mean_absolute_error: 0.1808 - 147ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.0600 - mean_absolute_error: 0.1219 - val_loss: 0.1320 - val_mean_absolute_error: 0.1759 - 147ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.0655 - mean_absolute_error: 0.1297 - val_loss: 0.1574 - val_mean_absolute_error: 0.1982 - 150ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.0676 - mean_absolute_error: 0.1312 - val_loss: 0.1390 - val_mean_absolute_error: 0.1866 - 152ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.0623 - mean_absolute_error: 0.1259 - val_loss: 0.1424 - val_mean_absolute_error: 0.1884 - 148ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.0617 - mean_absolute_error: 0.1255 - val_loss: 0.1443 - val_mean_absolute_error: 0.1936 - 151ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.0631 - mean_absolute_error: 0.1277 - val_loss: 0.1412 - val_mean_absolute_error: 0.1894 - 153ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.0548 - mean_absolute_error: 0.1179 - val_loss: 0.1285 - val_mean_absolute_error: 0.1760 - 150ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.0529 - mean_absolute_error: 0.1140 - val_loss: 0.1375 - val_mean_absolute_error: 0.1803 - 150ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.0579 - mean_absolute_error: 0.1217 - val_loss: 0.1354 - val_mean_absolute_error: 0.1837 - 148ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.0582 - mean_absolute_error: 0.1215 - val_loss: 0.1506 - val_mean_absolute_error: 0.2016 - 149ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.0699 - mean_absolute_error: 0.1359 - val_loss: 0.1662 - val_mean_absolute_error: 0.2145 - 149ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.0712 - mean_absolute_error: 0.1377 - val_loss: 0.1377 - val_mean_absolute_error: 0.1843 - 147ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.0578 - mean_absolute_error: 0.1225 - val_loss: 0.1440 - val_mean_absolute_error: 0.1900 - 149ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.0582 - mean_absolute_error: 0.1207 - val_loss: 0.1341 - val_mean_absolute_error: 0.1790 - 150ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.0536 - mean_absolute_error: 0.1159 - val_loss: 0.1316 - val_mean_absolute_error: 0.1805 - 150ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.0605 - mean_absolute_error: 0.1224 - val_loss: 0.1498 - val_mean_absolute_error: 0.1920 - 151ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.0622 - mean_absolute_error: 0.1236 - val_loss: 0.1702 - val_mean_absolute_error: 0.2047 - 149ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.0622 - mean_absolute_error: 0.1263 - val_loss: 0.1352 - val_mean_absolute_error: 0.1798 - 150ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.0564 - mean_absolute_error: 0.1180 - val_loss: 0.1301 - val_mean_absolute_error: 0.1759 - 147ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.0539 - mean_absolute_error: 0.1150 - val_loss: 0.1366 - val_mean_absolute_error: 0.1814 - 150ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.0552 - mean_absolute_error: 0.1146 - val_loss: 0.1348 - val_mean_absolute_error: 0.1767 - 147ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.0546 - mean_absolute_error: 0.1164 - val_loss: 0.1473 - val_mean_absolute_error: 0.1878 - 147ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.0578 - mean_absolute_error: 0.1182 - val_loss: 0.1528 - val_mean_absolute_error: 0.1996 - 148ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.0557 - mean_absolute_error: 0.1194 - val_loss: 0.1548 - val_mean_absolute_error: 0.1949 - 145ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.0599 - mean_absolute_error: 0.1232 - val_loss: 0.1554 - val_mean_absolute_error: 0.1979 - 146ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.0617 - mean_absolute_error: 0.1269 - val_loss: 0.1448 - val_mean_absolute_error: 0.1972 - 146ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.0748 - mean_absolute_error: 0.1378 - val_loss: 0.1721 - val_mean_absolute_error: 0.2089 - 146ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.0798 - mean_absolute_error: 0.1470 - val_loss: 0.1369 - val_mean_absolute_error: 0.1884 - 145ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.0625 - mean_absolute_error: 0.1242 - val_loss: 0.1707 - val_mean_absolute_error: 0.2026 - 145ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.0675 - mean_absolute_error: 0.1311 - val_loss: 0.1568 - val_mean_absolute_error: 0.2002 - 145ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.0545 - mean_absolute_error: 0.1176 - val_loss: 0.1375 - val_mean_absolute_error: 0.1792 - 144ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.0549 - mean_absolute_error: 0.1186 - val_loss: 0.1296 - val_mean_absolute_error: 0.1758 - 145ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.0551 - mean_absolute_error: 0.1167 - val_loss: 0.1305 - val_mean_absolute_error: 0.1809 - 146ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.0567 - mean_absolute_error: 0.1183 - val_loss: 0.1301 - val_mean_absolute_error: 0.1774 - 146ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.0563 - mean_absolute_error: 0.1189 - val_loss: 0.1442 - val_mean_absolute_error: 0.1860 - 143ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.0553 - mean_absolute_error: 0.1165 - val_loss: 0.1430 - val_mean_absolute_error: 0.1845 - 157ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.0575 - mean_absolute_error: 0.1200 - val_loss: 0.1403 - val_mean_absolute_error: 0.1843 - 145ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.0568 - mean_absolute_error: 0.1192 - val_loss: 0.1576 - val_mean_absolute_error: 0.1970 - 153ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.0612 - mean_absolute_error: 0.1234 - val_loss: 0.1316 - val_mean_absolute_error: 0.1807 - 147ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.0644 - mean_absolute_error: 0.1302 - val_loss: 0.1391 - val_mean_absolute_error: 0.1891 - 149ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_noNoise_five(g-grande).keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE: 0.13909316062927246
# MAE: 0.18910586833953857
# 32/32 [==============================] - 0s 816us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\kappa$', r'$\Delta E$', r'$\gamma$', r'$g$']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 9))
fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes.flatten()):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# Curvas Validación VS Predicción

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
k_pred = y_pred_denorm[:, 0]
k_val = y_val_denorm[:, 0]
DeltaE_pred = y_pred_denorm[:, 1]
DeltaE_val = y_val_denorm[:, 1]
gamma_pred = y_pred_denorm[:, 2]
gamma_val = y_val_denorm[:, 2]
g_pred = y_pred_denorm[:, 3]
g_val = y_val_denorm[:, 3]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val = np.zeros((x_val.shape[0], len(w_values)))


for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k_pred[i], Omega, DeltaE_pred[i], gamma_pred[i], g_pred[i])
    t_values_val[i,:] = t_w(w_values, k_val[i], Omega, DeltaE_val[i], gamma_val[i], g_val[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k_val, Omega, DeltaE_val, gamma_val, g_val)
w2=w_2(k_val, Omega, DeltaE_val, gamma_val, g_val)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"κ real = {k_val[i]:.7f}, κ pred = {k_pred[i]:.7f}\n"\
           f"ΔE real = {DeltaE_val[i]:.5f}, ΔE pred = {DeltaE_pred[i]:.5f}\n"\
           f"γ real = {gamma_val[i]:.7f}, γ pred = {gamma_pred[i]:.7f}\n"\
           f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # With noise

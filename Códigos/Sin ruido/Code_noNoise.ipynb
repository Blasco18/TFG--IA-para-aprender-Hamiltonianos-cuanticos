# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos t($\omega$):
# $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # Sin ruido

# %% [markdown]
# ## Creamos base de datos

# %%
# Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)

    return k, DeltaE, gamma, g

num_datos = 5000

# %%
# #Creamos base de datos y guardamos en .txt
# k, DeltaE, gamma, g = Parameters_generator (num_datos)
# np.savetxt('Parameters_noNoise.txt', np.column_stack((k, DeltaE, gamma, g)), header='\u03BA \u0394E \u213D g')

# %%
datos = np.loadtxt('Parameters_noNoise.txt', skiprows=1)
k = datos[:,0]
DeltaE = datos[:,1]
gamma = datos[:,2]
g = datos[:,3]
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.85, 1.15, 300)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))

# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k[i], Omega, DeltaE[i], gamma[i], g[i])

# %% [markdown]
# ### Dibujamos las curvas

# %%
# i=0
# while i<=1000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values[i,:], label='Curva original')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
x_train, x_val, y_train, y_val = train_test_split(t_values, datos, test_size=0.2) # si añades random_state= 
                                                                        # tienes siempre la misma combinación

# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 300)
# y_train shape (4000, 4)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 1 capa oculta

# %%
def Dense_simple ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_noNoise_five(300w).keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 1s - loss: 0.8905 - mean_absolute_error: 0.7674 - val_loss: 0.8842 - val_mean_absolute_error: 0.7661 - 1s/epoch - 15ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.8542 - mean_absolute_error: 0.7491 - val_loss: 0.8700 - val_mean_absolute_error: 0.7574 - 133ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.8388 - mean_absolute_error: 0.7396 - val_loss: 0.8552 - val_mean_absolute_error: 0.7486 - 135ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.8268 - mean_absolute_error: 0.7331 - val_loss: 0.8440 - val_mean_absolute_error: 0.7396 - 133ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.8150 - mean_absolute_error: 0.7237 - val_loss: 0.8348 - val_mean_absolute_error: 0.7365 - 144ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.8066 - mean_absolute_error: 0.7190 - val_loss: 0.8263 - val_mean_absolute_error: 0.7330 - 142ms/epoch - 2ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.7983 - mean_absolute_error: 0.7115 - val_loss: 0.8182 - val_mean_absolute_error: 0.7241 - 142ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.7884 - mean_absolute_error: 0.7073 - val_loss: 0.8054 - val_mean_absolute_error: 0.7145 - 137ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.7762 - mean_absolute_error: 0.7022 - val_loss: 0.8095 - val_mean_absolute_error: 0.7273 - 135ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.7728 - mean_absolute_error: 0.6978 - val_loss: 0.7852 - val_mean_absolute_error: 0.7009 - 135ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.7593 - mean_absolute_error: 0.6893 - val_loss: 0.7533 - val_mean_absolute_error: 0.6874 - 140ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.7554 - mean_absolute_error: 0.6879 - val_loss: 0.7769 - val_mean_absolute_error: 0.6963 - 130ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.7355 - mean_absolute_error: 0.6744 - val_loss: 0.7326 - val_mean_absolute_error: 0.6747 - 130ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.7151 - mean_absolute_error: 0.6676 - val_loss: 0.7351 - val_mean_absolute_error: 0.6807 - 131ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.7064 - mean_absolute_error: 0.6612 - val_loss: 0.7113 - val_mean_absolute_error: 0.6650 - 134ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.6954 - mean_absolute_error: 0.6527 - val_loss: 0.7243 - val_mean_absolute_error: 0.6646 - 134ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.6755 - mean_absolute_error: 0.6394 - val_loss: 0.6406 - val_mean_absolute_error: 0.6241 - 133ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.6509 - mean_absolute_error: 0.6215 - val_loss: 0.6916 - val_mean_absolute_error: 0.6271 - 134ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.6236 - mean_absolute_error: 0.6029 - val_loss: 0.6475 - val_mean_absolute_error: 0.6109 - 131ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.6059 - mean_absolute_error: 0.5914 - val_loss: 0.5963 - val_mean_absolute_error: 0.5829 - 141ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.5817 - mean_absolute_error: 0.5772 - val_loss: 0.6870 - val_mean_absolute_error: 0.6147 - 135ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.5702 - mean_absolute_error: 0.5680 - val_loss: 0.5332 - val_mean_absolute_error: 0.5444 - 136ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.5792 - mean_absolute_error: 0.5766 - val_loss: 0.5507 - val_mean_absolute_error: 0.5613 - 134ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.5242 - mean_absolute_error: 0.5407 - val_loss: 0.4931 - val_mean_absolute_error: 0.5181 - 131ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.5224 - mean_absolute_error: 0.5359 - val_loss: 0.5291 - val_mean_absolute_error: 0.5327 - 134ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.5223 - mean_absolute_error: 0.5346 - val_loss: 0.5365 - val_mean_absolute_error: 0.5372 - 134ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.5069 - mean_absolute_error: 0.5247 - val_loss: 0.4864 - val_mean_absolute_error: 0.5141 - 153ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.5098 - mean_absolute_error: 0.5238 - val_loss: 0.5081 - val_mean_absolute_error: 0.5245 - 147ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.4766 - mean_absolute_error: 0.5048 - val_loss: 0.5709 - val_mean_absolute_error: 0.5588 - 149ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.5100 - mean_absolute_error: 0.5245 - val_loss: 0.5034 - val_mean_absolute_error: 0.5222 - 153ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.4746 - mean_absolute_error: 0.5035 - val_loss: 0.4723 - val_mean_absolute_error: 0.4974 - 136ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.4977 - mean_absolute_error: 0.5135 - val_loss: 0.4765 - val_mean_absolute_error: 0.5004 - 136ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.4849 - mean_absolute_error: 0.5062 - val_loss: 0.5134 - val_mean_absolute_error: 0.5262 - 139ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.4793 - mean_absolute_error: 0.5050 - val_loss: 0.4755 - val_mean_absolute_error: 0.5008 - 146ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.4771 - mean_absolute_error: 0.4983 - val_loss: 0.4584 - val_mean_absolute_error: 0.4854 - 130ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.4645 - mean_absolute_error: 0.4917 - val_loss: 0.4526 - val_mean_absolute_error: 0.4838 - 130ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.5039 - mean_absolute_error: 0.5107 - val_loss: 0.4574 - val_mean_absolute_error: 0.4880 - 131ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.4483 - mean_absolute_error: 0.4803 - val_loss: 0.4379 - val_mean_absolute_error: 0.4719 - 128ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.4662 - mean_absolute_error: 0.4888 - val_loss: 0.4740 - val_mean_absolute_error: 0.4919 - 129ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.4741 - mean_absolute_error: 0.4956 - val_loss: 0.4623 - val_mean_absolute_error: 0.4899 - 132ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.4534 - mean_absolute_error: 0.4809 - val_loss: 0.4357 - val_mean_absolute_error: 0.4729 - 136ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.4561 - mean_absolute_error: 0.4828 - val_loss: 0.4780 - val_mean_absolute_error: 0.4905 - 128ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.4399 - mean_absolute_error: 0.4717 - val_loss: 0.4584 - val_mean_absolute_error: 0.4841 - 129ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.4524 - mean_absolute_error: 0.4803 - val_loss: 0.4432 - val_mean_absolute_error: 0.4733 - 132ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.4337 - mean_absolute_error: 0.4678 - val_loss: 0.4549 - val_mean_absolute_error: 0.4760 - 133ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.4267 - mean_absolute_error: 0.4614 - val_loss: 0.4294 - val_mean_absolute_error: 0.4605 - 132ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.4467 - mean_absolute_error: 0.4746 - val_loss: 0.4323 - val_mean_absolute_error: 0.4628 - 132ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.4309 - mean_absolute_error: 0.4675 - val_loss: 0.4607 - val_mean_absolute_error: 0.4885 - 130ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.4389 - mean_absolute_error: 0.4702 - val_loss: 0.4497 - val_mean_absolute_error: 0.4770 - 130ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.4289 - mean_absolute_error: 0.4655 - val_loss: 0.4923 - val_mean_absolute_error: 0.4942 - 129ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.4796 - mean_absolute_error: 0.4984 - val_loss: 0.4403 - val_mean_absolute_error: 0.4728 - 133ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.4646 - mean_absolute_error: 0.4844 - val_loss: 0.4405 - val_mean_absolute_error: 0.4682 - 138ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.4426 - mean_absolute_error: 0.4697 - val_loss: 0.4283 - val_mean_absolute_error: 0.4627 - 148ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.4331 - mean_absolute_error: 0.4661 - val_loss: 0.4864 - val_mean_absolute_error: 0.4867 - 139ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.4381 - mean_absolute_error: 0.4659 - val_loss: 0.4681 - val_mean_absolute_error: 0.4841 - 130ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.4458 - mean_absolute_error: 0.4717 - val_loss: 0.5206 - val_mean_absolute_error: 0.5251 - 128ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.4433 - mean_absolute_error: 0.4725 - val_loss: 0.5293 - val_mean_absolute_error: 0.5146 - 135ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.4474 - mean_absolute_error: 0.4743 - val_loss: 0.4342 - val_mean_absolute_error: 0.4605 - 142ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.4170 - mean_absolute_error: 0.4545 - val_loss: 0.4687 - val_mean_absolute_error: 0.4872 - 135ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.4258 - mean_absolute_error: 0.4595 - val_loss: 0.4471 - val_mean_absolute_error: 0.4654 - 132ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.4259 - mean_absolute_error: 0.4568 - val_loss: 0.4681 - val_mean_absolute_error: 0.4774 - 127ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.4261 - mean_absolute_error: 0.4575 - val_loss: 0.4828 - val_mean_absolute_error: 0.4921 - 129ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.4414 - mean_absolute_error: 0.4718 - val_loss: 0.4285 - val_mean_absolute_error: 0.4626 - 286ms/epoch - 4ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.4155 - mean_absolute_error: 0.4552 - val_loss: 0.4293 - val_mean_absolute_error: 0.4642 - 138ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.4490 - mean_absolute_error: 0.4761 - val_loss: 0.5004 - val_mean_absolute_error: 0.5035 - 138ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.4386 - mean_absolute_error: 0.4674 - val_loss: 0.4736 - val_mean_absolute_error: 0.4964 - 141ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.4331 - mean_absolute_error: 0.4639 - val_loss: 0.5062 - val_mean_absolute_error: 0.5059 - 139ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.4251 - mean_absolute_error: 0.4589 - val_loss: 0.4838 - val_mean_absolute_error: 0.5005 - 147ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.4703 - mean_absolute_error: 0.4906 - val_loss: 0.4325 - val_mean_absolute_error: 0.4659 - 139ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.4339 - mean_absolute_error: 0.4650 - val_loss: 0.4936 - val_mean_absolute_error: 0.4958 - 149ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.4375 - mean_absolute_error: 0.4672 - val_loss: 0.4973 - val_mean_absolute_error: 0.4922 - 134ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.4283 - mean_absolute_error: 0.4618 - val_loss: 0.4658 - val_mean_absolute_error: 0.4848 - 140ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.4608 - mean_absolute_error: 0.4780 - val_loss: 0.4546 - val_mean_absolute_error: 0.4707 - 136ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.4109 - mean_absolute_error: 0.4504 - val_loss: 0.5038 - val_mean_absolute_error: 0.4993 - 137ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.4183 - mean_absolute_error: 0.4522 - val_loss: 0.4136 - val_mean_absolute_error: 0.4466 - 137ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.4343 - mean_absolute_error: 0.4620 - val_loss: 0.4348 - val_mean_absolute_error: 0.4627 - 144ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.4190 - mean_absolute_error: 0.4561 - val_loss: 0.4155 - val_mean_absolute_error: 0.4559 - 145ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.4140 - mean_absolute_error: 0.4519 - val_loss: 0.4128 - val_mean_absolute_error: 0.4459 - 135ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.4131 - mean_absolute_error: 0.4488 - val_loss: 0.5528 - val_mean_absolute_error: 0.5241 - 161ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.4269 - mean_absolute_error: 0.4596 - val_loss: 0.4118 - val_mean_absolute_error: 0.4498 - 139ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.4129 - mean_absolute_error: 0.4491 - val_loss: 0.4139 - val_mean_absolute_error: 0.4468 - 138ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.4187 - mean_absolute_error: 0.4553 - val_loss: 0.4366 - val_mean_absolute_error: 0.4578 - 143ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.4242 - mean_absolute_error: 0.4573 - val_loss: 0.4173 - val_mean_absolute_error: 0.4545 - 188ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.4144 - mean_absolute_error: 0.4521 - val_loss: 0.4298 - val_mean_absolute_error: 0.4605 - 174ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.4148 - mean_absolute_error: 0.4524 - val_loss: 0.4154 - val_mean_absolute_error: 0.4468 - 148ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.4515 - mean_absolute_error: 0.4750 - val_loss: 0.4207 - val_mean_absolute_error: 0.4555 - 134ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.4252 - mean_absolute_error: 0.4572 - val_loss: 0.5074 - val_mean_absolute_error: 0.4980 - 133ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.4218 - mean_absolute_error: 0.4552 - val_loss: 0.4238 - val_mean_absolute_error: 0.4548 - 134ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.4060 - mean_absolute_error: 0.4452 - val_loss: 0.4139 - val_mean_absolute_error: 0.4464 - 131ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.4465 - mean_absolute_error: 0.4732 - val_loss: 0.4623 - val_mean_absolute_error: 0.4767 - 137ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.4223 - mean_absolute_error: 0.4565 - val_loss: 0.4207 - val_mean_absolute_error: 0.4542 - 132ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.4133 - mean_absolute_error: 0.4469 - val_loss: 0.4547 - val_mean_absolute_error: 0.4733 - 155ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.4245 - mean_absolute_error: 0.4559 - val_loss: 0.5626 - val_mean_absolute_error: 0.5323 - 165ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.4267 - mean_absolute_error: 0.4573 - val_loss: 0.4407 - val_mean_absolute_error: 0.4691 - 143ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.4273 - mean_absolute_error: 0.4596 - val_loss: 0.4417 - val_mean_absolute_error: 0.4660 - 133ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.4138 - mean_absolute_error: 0.4469 - val_loss: 0.4139 - val_mean_absolute_error: 0.4507 - 143ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.4429 - mean_absolute_error: 0.4671 - val_loss: 0.5188 - val_mean_absolute_error: 0.5241 - 145ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.4151 - mean_absolute_error: 0.4605 - val_loss: 0.4558 - val_mean_absolute_error: 0.4682 - 167ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.4113 - mean_absolute_error: 0.4460 - val_loss: 0.4154 - val_mean_absolute_error: 0.4471 - 134ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.4117 - mean_absolute_error: 0.4470 - val_loss: 0.4511 - val_mean_absolute_error: 0.4749 - 147ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.4128 - mean_absolute_error: 0.4491 - val_loss: 0.4157 - val_mean_absolute_error: 0.4545 - 157ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.4128 - mean_absolute_error: 0.4487 - val_loss: 0.4053 - val_mean_absolute_error: 0.4415 - 175ms/epoch - 2ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.4214 - mean_absolute_error: 0.4544 - val_loss: 0.4040 - val_mean_absolute_error: 0.4360 - 163ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.4178 - mean_absolute_error: 0.4531 - val_loss: 0.4240 - val_mean_absolute_error: 0.4648 - 155ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.3963 - mean_absolute_error: 0.4390 - val_loss: 0.4768 - val_mean_absolute_error: 0.4816 - 138ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.4130 - mean_absolute_error: 0.4473 - val_loss: 0.4310 - val_mean_absolute_error: 0.4589 - 166ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.4087 - mean_absolute_error: 0.4452 - val_loss: 0.4214 - val_mean_absolute_error: 0.4473 - 149ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.4331 - mean_absolute_error: 0.4606 - val_loss: 0.4309 - val_mean_absolute_error: 0.4528 - 159ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.4060 - mean_absolute_error: 0.4436 - val_loss: 0.4154 - val_mean_absolute_error: 0.4493 - 152ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.3982 - mean_absolute_error: 0.4381 - val_loss: 0.4281 - val_mean_absolute_error: 0.4530 - 138ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.4190 - mean_absolute_error: 0.4547 - val_loss: 0.4168 - val_mean_absolute_error: 0.4558 - 137ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.4080 - mean_absolute_error: 0.4475 - val_loss: 0.4263 - val_mean_absolute_error: 0.4512 - 140ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.3989 - mean_absolute_error: 0.4383 - val_loss: 0.4361 - val_mean_absolute_error: 0.4570 - 141ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.4201 - mean_absolute_error: 0.4505 - val_loss: 0.4256 - val_mean_absolute_error: 0.4548 - 140ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.3929 - mean_absolute_error: 0.4333 - val_loss: 0.4095 - val_mean_absolute_error: 0.4433 - 141ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.4108 - mean_absolute_error: 0.4470 - val_loss: 0.4017 - val_mean_absolute_error: 0.4362 - 136ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.3977 - mean_absolute_error: 0.4362 - val_loss: 0.4052 - val_mean_absolute_error: 0.4394 - 136ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.4136 - mean_absolute_error: 0.4474 - val_loss: 0.4748 - val_mean_absolute_error: 0.4817 - 143ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.4140 - mean_absolute_error: 0.4503 - val_loss: 0.4356 - val_mean_absolute_error: 0.4594 - 144ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.4099 - mean_absolute_error: 0.4470 - val_loss: 0.4124 - val_mean_absolute_error: 0.4487 - 139ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.3978 - mean_absolute_error: 0.4387 - val_loss: 0.4136 - val_mean_absolute_error: 0.4420 - 161ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.4154 - mean_absolute_error: 0.4470 - val_loss: 0.4262 - val_mean_absolute_error: 0.4546 - 136ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.4028 - mean_absolute_error: 0.4406 - val_loss: 0.4146 - val_mean_absolute_error: 0.4449 - 139ms/epoch - 2ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.4148 - mean_absolute_error: 0.4473 - val_loss: 0.4080 - val_mean_absolute_error: 0.4369 - 136ms/epoch - 2ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.4354 - mean_absolute_error: 0.4621 - val_loss: 0.4159 - val_mean_absolute_error: 0.4525 - 139ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.4248 - mean_absolute_error: 0.4542 - val_loss: 0.4177 - val_mean_absolute_error: 0.4528 - 165ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.4079 - mean_absolute_error: 0.4459 - val_loss: 0.4428 - val_mean_absolute_error: 0.4590 - 147ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.4034 - mean_absolute_error: 0.4421 - val_loss: 0.4538 - val_mean_absolute_error: 0.4690 - 135ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.4180 - mean_absolute_error: 0.4521 - val_loss: 0.4242 - val_mean_absolute_error: 0.4545 - 134ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.4349 - mean_absolute_error: 0.4621 - val_loss: 0.4934 - val_mean_absolute_error: 0.4958 - 139ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.4244 - mean_absolute_error: 0.4541 - val_loss: 0.4158 - val_mean_absolute_error: 0.4507 - 136ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.3926 - mean_absolute_error: 0.4357 - val_loss: 0.3993 - val_mean_absolute_error: 0.4331 - 136ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.3987 - mean_absolute_error: 0.4385 - val_loss: 0.4354 - val_mean_absolute_error: 0.4585 - 135ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.4064 - mean_absolute_error: 0.4421 - val_loss: 0.4180 - val_mean_absolute_error: 0.4434 - 163ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.4419 - mean_absolute_error: 0.4683 - val_loss: 0.4727 - val_mean_absolute_error: 0.4795 - 140ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.4110 - mean_absolute_error: 0.4466 - val_loss: 0.4102 - val_mean_absolute_error: 0.4527 - 134ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.3972 - mean_absolute_error: 0.4382 - val_loss: 0.4140 - val_mean_absolute_error: 0.4469 - 135ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.3963 - mean_absolute_error: 0.4346 - val_loss: 0.4164 - val_mean_absolute_error: 0.4457 - 134ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.4036 - mean_absolute_error: 0.4402 - val_loss: 0.4552 - val_mean_absolute_error: 0.4662 - 136ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.4068 - mean_absolute_error: 0.4414 - val_loss: 0.4156 - val_mean_absolute_error: 0.4468 - 134ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.4080 - mean_absolute_error: 0.4435 - val_loss: 0.4241 - val_mean_absolute_error: 0.4546 - 143ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.3948 - mean_absolute_error: 0.4354 - val_loss: 0.4514 - val_mean_absolute_error: 0.4628 - 156ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.4327 - mean_absolute_error: 0.4602 - val_loss: 0.4112 - val_mean_absolute_error: 0.4438 - 157ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.4151 - mean_absolute_error: 0.4503 - val_loss: 0.4156 - val_mean_absolute_error: 0.4459 - 140ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.3927 - mean_absolute_error: 0.4325 - val_loss: 0.4209 - val_mean_absolute_error: 0.4572 - 139ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.3976 - mean_absolute_error: 0.4379 - val_loss: 0.4397 - val_mean_absolute_error: 0.4577 - 138ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.4077 - mean_absolute_error: 0.4449 - val_loss: 0.4251 - val_mean_absolute_error: 0.4545 - 136ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.4283 - mean_absolute_error: 0.4602 - val_loss: 0.4368 - val_mean_absolute_error: 0.4650 - 136ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.3971 - mean_absolute_error: 0.4362 - val_loss: 0.4616 - val_mean_absolute_error: 0.4704 - 147ms/epoch - 2ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.3979 - mean_absolute_error: 0.4388 - val_loss: 0.4250 - val_mean_absolute_error: 0.4591 - 163ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.4095 - mean_absolute_error: 0.4437 - val_loss: 0.4398 - val_mean_absolute_error: 0.4621 - 150ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.4063 - mean_absolute_error: 0.4435 - val_loss: 0.4226 - val_mean_absolute_error: 0.4511 - 138ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.3957 - mean_absolute_error: 0.4364 - val_loss: 0.4511 - val_mean_absolute_error: 0.4605 - 135ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.4112 - mean_absolute_error: 0.4434 - val_loss: 0.4174 - val_mean_absolute_error: 0.4461 - 144ms/epoch - 2ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.4118 - mean_absolute_error: 0.4464 - val_loss: 0.4218 - val_mean_absolute_error: 0.4497 - 134ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.3969 - mean_absolute_error: 0.4359 - val_loss: 0.4367 - val_mean_absolute_error: 0.4561 - 141ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.4014 - mean_absolute_error: 0.4366 - val_loss: 0.4110 - val_mean_absolute_error: 0.4420 - 152ms/epoch - 2ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.4005 - mean_absolute_error: 0.4376 - val_loss: 0.4176 - val_mean_absolute_error: 0.4469 - 154ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.3919 - mean_absolute_error: 0.4310 - val_loss: 0.4008 - val_mean_absolute_error: 0.4331 - 135ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.3968 - mean_absolute_error: 0.4383 - val_loss: 0.4089 - val_mean_absolute_error: 0.4459 - 131ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.3990 - mean_absolute_error: 0.4401 - val_loss: 0.4117 - val_mean_absolute_error: 0.4466 - 133ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.4036 - mean_absolute_error: 0.4468 - val_loss: 0.3976 - val_mean_absolute_error: 0.4377 - 137ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.4007 - mean_absolute_error: 0.4416 - val_loss: 0.4020 - val_mean_absolute_error: 0.4386 - 140ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.4028 - mean_absolute_error: 0.4372 - val_loss: 0.4111 - val_mean_absolute_error: 0.4473 - 133ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.4104 - mean_absolute_error: 0.4427 - val_loss: 0.4931 - val_mean_absolute_error: 0.4853 - 149ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.4113 - mean_absolute_error: 0.4443 - val_loss: 0.4192 - val_mean_absolute_error: 0.4471 - 136ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.3842 - mean_absolute_error: 0.4275 - val_loss: 0.4048 - val_mean_absolute_error: 0.4409 - 162ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.4001 - mean_absolute_error: 0.4361 - val_loss: 0.4543 - val_mean_absolute_error: 0.4655 - 149ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.3880 - mean_absolute_error: 0.4288 - val_loss: 0.4160 - val_mean_absolute_error: 0.4475 - 134ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.3988 - mean_absolute_error: 0.4397 - val_loss: 0.4103 - val_mean_absolute_error: 0.4522 - 134ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.4092 - mean_absolute_error: 0.4508 - val_loss: 0.4378 - val_mean_absolute_error: 0.4582 - 137ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.3934 - mean_absolute_error: 0.4335 - val_loss: 0.4017 - val_mean_absolute_error: 0.4353 - 148ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.4093 - mean_absolute_error: 0.4412 - val_loss: 0.4155 - val_mean_absolute_error: 0.4454 - 156ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.3921 - mean_absolute_error: 0.4330 - val_loss: 0.4131 - val_mean_absolute_error: 0.4472 - 142ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.3846 - mean_absolute_error: 0.4252 - val_loss: 0.4053 - val_mean_absolute_error: 0.4351 - 134ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.4024 - mean_absolute_error: 0.4426 - val_loss: 0.4034 - val_mean_absolute_error: 0.4391 - 145ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.3945 - mean_absolute_error: 0.4333 - val_loss: 0.3971 - val_mean_absolute_error: 0.4354 - 160ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.4007 - mean_absolute_error: 0.4347 - val_loss: 0.4569 - val_mean_absolute_error: 0.4687 - 148ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.3898 - mean_absolute_error: 0.4315 - val_loss: 0.4404 - val_mean_absolute_error: 0.4601 - 152ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.3935 - mean_absolute_error: 0.4309 - val_loss: 0.4105 - val_mean_absolute_error: 0.4426 - 151ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.4203 - mean_absolute_error: 0.4522 - val_loss: 0.4277 - val_mean_absolute_error: 0.4602 - 156ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.3809 - mean_absolute_error: 0.4255 - val_loss: 0.4195 - val_mean_absolute_error: 0.4469 - 175ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.4063 - mean_absolute_error: 0.4439 - val_loss: 0.4113 - val_mean_absolute_error: 0.4489 - 145ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.4112 - mean_absolute_error: 0.4466 - val_loss: 0.4232 - val_mean_absolute_error: 0.4505 - 132ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.4032 - mean_absolute_error: 0.4381 - val_loss: 0.4499 - val_mean_absolute_error: 0.4668 - 133ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.3974 - mean_absolute_error: 0.4370 - val_loss: 0.4094 - val_mean_absolute_error: 0.4388 - 137ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.3909 - mean_absolute_error: 0.4303 - val_loss: 0.4342 - val_mean_absolute_error: 0.4512 - 140ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.3879 - mean_absolute_error: 0.4292 - val_loss: 0.4010 - val_mean_absolute_error: 0.4378 - 135ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.3975 - mean_absolute_error: 0.4365 - val_loss: 0.4120 - val_mean_absolute_error: 0.4459 - 136ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.4129 - mean_absolute_error: 0.4485 - val_loss: 0.4034 - val_mean_absolute_error: 0.4484 - 131ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.4016 - mean_absolute_error: 0.4362 - val_loss: 0.5075 - val_mean_absolute_error: 0.4929 - 135ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.3964 - mean_absolute_error: 0.4372 - val_loss: 0.4170 - val_mean_absolute_error: 0.4518 - 143ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.3831 - mean_absolute_error: 0.4257 - val_loss: 0.3909 - val_mean_absolute_error: 0.4259 - 143ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.3822 - mean_absolute_error: 0.4244 - val_loss: 0.3918 - val_mean_absolute_error: 0.4264 - 137ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.3913 - mean_absolute_error: 0.4292 - val_loss: 0.4364 - val_mean_absolute_error: 0.4638 - 142ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.3859 - mean_absolute_error: 0.4300 - val_loss: 0.4556 - val_mean_absolute_error: 0.4705 - 154ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.3771 - mean_absolute_error: 0.4221 - val_loss: 0.3940 - val_mean_absolute_error: 0.4320 - 149ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.3872 - mean_absolute_error: 0.4278 - val_loss: 0.4441 - val_mean_absolute_error: 0.4590 - 148ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.3937 - mean_absolute_error: 0.4304 - val_loss: 0.4028 - val_mean_absolute_error: 0.4375 - 135ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.3888 - mean_absolute_error: 0.4301 - val_loss: 0.4038 - val_mean_absolute_error: 0.4347 - 131ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.3844 - mean_absolute_error: 0.4247 - val_loss: 0.4375 - val_mean_absolute_error: 0.4529 - 141ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.3841 - mean_absolute_error: 0.4251 - val_loss: 0.4553 - val_mean_absolute_error: 0.4638 - 151ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.3865 - mean_absolute_error: 0.4264 - val_loss: 0.4755 - val_mean_absolute_error: 0.4707 - 151ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.3936 - mean_absolute_error: 0.4304 - val_loss: 0.4513 - val_mean_absolute_error: 0.4703 - 150ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.3766 - mean_absolute_error: 0.4217 - val_loss: 0.4107 - val_mean_absolute_error: 0.4424 - 132ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.3944 - mean_absolute_error: 0.4305 - val_loss: 0.4146 - val_mean_absolute_error: 0.4490 - 137ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.3813 - mean_absolute_error: 0.4236 - val_loss: 0.3963 - val_mean_absolute_error: 0.4366 - 136ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.3952 - mean_absolute_error: 0.4364 - val_loss: 0.4025 - val_mean_absolute_error: 0.4406 - 139ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.3786 - mean_absolute_error: 0.4225 - val_loss: 0.4209 - val_mean_absolute_error: 0.4439 - 145ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.4031 - mean_absolute_error: 0.4394 - val_loss: 0.4658 - val_mean_absolute_error: 0.4788 - 157ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.3767 - mean_absolute_error: 0.4218 - val_loss: 0.4815 - val_mean_absolute_error: 0.4740 - 145ms/epoch - 2ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.3793 - mean_absolute_error: 0.4240 - val_loss: 0.4176 - val_mean_absolute_error: 0.4437 - 155ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.3998 - mean_absolute_error: 0.4349 - val_loss: 0.4238 - val_mean_absolute_error: 0.4557 - 142ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.3846 - mean_absolute_error: 0.4292 - val_loss: 0.4228 - val_mean_absolute_error: 0.4448 - 139ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.3931 - mean_absolute_error: 0.4288 - val_loss: 0.4957 - val_mean_absolute_error: 0.4870 - 143ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.3975 - mean_absolute_error: 0.4370 - val_loss: 0.4085 - val_mean_absolute_error: 0.4386 - 140ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.3858 - mean_absolute_error: 0.4249 - val_loss: 0.4124 - val_mean_absolute_error: 0.4433 - 135ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.3744 - mean_absolute_error: 0.4191 - val_loss: 0.4294 - val_mean_absolute_error: 0.4551 - 141ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.3877 - mean_absolute_error: 0.4282 - val_loss: 0.4097 - val_mean_absolute_error: 0.4392 - 135ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.3802 - mean_absolute_error: 0.4213 - val_loss: 0.3997 - val_mean_absolute_error: 0.4404 - 136ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.3830 - mean_absolute_error: 0.4261 - val_loss: 0.4139 - val_mean_absolute_error: 0.4415 - 135ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.3764 - mean_absolute_error: 0.4210 - val_loss: 0.3942 - val_mean_absolute_error: 0.4328 - 136ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.3808 - mean_absolute_error: 0.4232 - val_loss: 0.4426 - val_mean_absolute_error: 0.4601 - 135ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.3959 - mean_absolute_error: 0.4361 - val_loss: 0.4035 - val_mean_absolute_error: 0.4365 - 139ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.3771 - mean_absolute_error: 0.4200 - val_loss: 0.4329 - val_mean_absolute_error: 0.4576 - 131ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.3839 - mean_absolute_error: 0.4237 - val_loss: 0.4294 - val_mean_absolute_error: 0.4546 - 136ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.3865 - mean_absolute_error: 0.4266 - val_loss: 0.4005 - val_mean_absolute_error: 0.4342 - 141ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.3966 - mean_absolute_error: 0.4329 - val_loss: 0.3973 - val_mean_absolute_error: 0.4320 - 152ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.3815 - mean_absolute_error: 0.4229 - val_loss: 0.4169 - val_mean_absolute_error: 0.4426 - 134ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.3692 - mean_absolute_error: 0.4149 - val_loss: 0.3905 - val_mean_absolute_error: 0.4235 - 140ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.3768 - mean_absolute_error: 0.4198 - val_loss: 0.3928 - val_mean_absolute_error: 0.4264 - 147ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.4029 - mean_absolute_error: 0.4387 - val_loss: 0.4274 - val_mean_absolute_error: 0.4608 - 140ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.4040 - mean_absolute_error: 0.4369 - val_loss: 0.4543 - val_mean_absolute_error: 0.4689 - 131ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.3903 - mean_absolute_error: 0.4290 - val_loss: 0.4875 - val_mean_absolute_error: 0.4846 - 129ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.3740 - mean_absolute_error: 0.4179 - val_loss: 0.4207 - val_mean_absolute_error: 0.4479 - 132ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.3890 - mean_absolute_error: 0.4265 - val_loss: 0.4592 - val_mean_absolute_error: 0.4651 - 132ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.4064 - mean_absolute_error: 0.4354 - val_loss: 0.5989 - val_mean_absolute_error: 0.5404 - 154ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.3980 - mean_absolute_error: 0.4361 - val_loss: 0.4266 - val_mean_absolute_error: 0.4562 - 133ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.3919 - mean_absolute_error: 0.4339 - val_loss: 0.4006 - val_mean_absolute_error: 0.4355 - 129ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.3635 - mean_absolute_error: 0.4122 - val_loss: 0.4084 - val_mean_absolute_error: 0.4368 - 136ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.3829 - mean_absolute_error: 0.4230 - val_loss: 0.3948 - val_mean_absolute_error: 0.4273 - 133ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.3753 - mean_absolute_error: 0.4169 - val_loss: 0.5115 - val_mean_absolute_error: 0.5027 - 137ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.3952 - mean_absolute_error: 0.4359 - val_loss: 0.4028 - val_mean_absolute_error: 0.4382 - 138ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.3882 - mean_absolute_error: 0.4267 - val_loss: 0.4596 - val_mean_absolute_error: 0.4749 - 133ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.3883 - mean_absolute_error: 0.4296 - val_loss: 0.4184 - val_mean_absolute_error: 0.4424 - 137ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.3808 - mean_absolute_error: 0.4245 - val_loss: 0.4115 - val_mean_absolute_error: 0.4395 - 133ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.3668 - mean_absolute_error: 0.4136 - val_loss: 0.3982 - val_mean_absolute_error: 0.4305 - 134ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.3668 - mean_absolute_error: 0.4140 - val_loss: 0.4069 - val_mean_absolute_error: 0.4386 - 147ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.3706 - mean_absolute_error: 0.4161 - val_loss: 0.3955 - val_mean_absolute_error: 0.4359 - 147ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.3842 - mean_absolute_error: 0.4274 - val_loss: 0.3938 - val_mean_absolute_error: 0.4274 - 161ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.3800 - mean_absolute_error: 0.4226 - val_loss: 0.4774 - val_mean_absolute_error: 0.4835 - 193ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.3819 - mean_absolute_error: 0.4268 - val_loss: 0.3936 - val_mean_absolute_error: 0.4317 - 145ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.3817 - mean_absolute_error: 0.4214 - val_loss: 0.4102 - val_mean_absolute_error: 0.4391 - 139ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.3724 - mean_absolute_error: 0.4171 - val_loss: 0.4107 - val_mean_absolute_error: 0.4414 - 146ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.3704 - mean_absolute_error: 0.4164 - val_loss: 0.4437 - val_mean_absolute_error: 0.4614 - 137ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.3784 - mean_absolute_error: 0.4214 - val_loss: 0.3995 - val_mean_absolute_error: 0.4313 - 147ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.3750 - mean_absolute_error: 0.4196 - val_loss: 0.4634 - val_mean_absolute_error: 0.4708 - 144ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.3801 - mean_absolute_error: 0.4230 - val_loss: 0.3978 - val_mean_absolute_error: 0.4320 - 142ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.3747 - mean_absolute_error: 0.4189 - val_loss: 0.3942 - val_mean_absolute_error: 0.4353 - 139ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.3859 - mean_absolute_error: 0.4277 - val_loss: 0.3964 - val_mean_absolute_error: 0.4302 - 137ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.3941 - mean_absolute_error: 0.4320 - val_loss: 0.4090 - val_mean_absolute_error: 0.4444 - 135ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.3847 - mean_absolute_error: 0.4284 - val_loss: 0.4041 - val_mean_absolute_error: 0.4359 - 139ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.3765 - mean_absolute_error: 0.4225 - val_loss: 0.4246 - val_mean_absolute_error: 0.4515 - 147ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.3687 - mean_absolute_error: 0.4145 - val_loss: 0.3945 - val_mean_absolute_error: 0.4232 - 152ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.3807 - mean_absolute_error: 0.4196 - val_loss: 0.5347 - val_mean_absolute_error: 0.5050 - 159ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.3910 - mean_absolute_error: 0.4328 - val_loss: 0.4236 - val_mean_absolute_error: 0.4463 - 148ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.3752 - mean_absolute_error: 0.4179 - val_loss: 0.3952 - val_mean_absolute_error: 0.4322 - 168ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.3810 - mean_absolute_error: 0.4213 - val_loss: 0.3929 - val_mean_absolute_error: 0.4297 - 164ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.3735 - mean_absolute_error: 0.4149 - val_loss: 0.4334 - val_mean_absolute_error: 0.4593 - 148ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.3796 - mean_absolute_error: 0.4249 - val_loss: 0.4255 - val_mean_absolute_error: 0.4447 - 138ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.3680 - mean_absolute_error: 0.4197 - val_loss: 0.3848 - val_mean_absolute_error: 0.4269 - 139ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.3629 - mean_absolute_error: 0.4126 - val_loss: 0.3822 - val_mean_absolute_error: 0.4202 - 136ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.3820 - mean_absolute_error: 0.4237 - val_loss: 0.4177 - val_mean_absolute_error: 0.4453 - 152ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.3918 - mean_absolute_error: 0.4317 - val_loss: 0.4224 - val_mean_absolute_error: 0.4465 - 145ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.3782 - mean_absolute_error: 0.4189 - val_loss: 0.4574 - val_mean_absolute_error: 0.4659 - 161ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.3734 - mean_absolute_error: 0.4184 - val_loss: 0.3943 - val_mean_absolute_error: 0.4314 - 153ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.3886 - mean_absolute_error: 0.4288 - val_loss: 0.3986 - val_mean_absolute_error: 0.4328 - 146ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.3716 - mean_absolute_error: 0.4204 - val_loss: 0.3933 - val_mean_absolute_error: 0.4271 - 138ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.3585 - mean_absolute_error: 0.4110 - val_loss: 0.3950 - val_mean_absolute_error: 0.4238 - 139ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.3705 - mean_absolute_error: 0.4146 - val_loss: 0.4199 - val_mean_absolute_error: 0.4413 - 159ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.3597 - mean_absolute_error: 0.4077 - val_loss: 0.3862 - val_mean_absolute_error: 0.4207 - 133ms/epoch - 2ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.3611 - mean_absolute_error: 0.4080 - val_loss: 0.4124 - val_mean_absolute_error: 0.4352 - 131ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.3685 - mean_absolute_error: 0.4137 - val_loss: 0.3973 - val_mean_absolute_error: 0.4382 - 137ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.3675 - mean_absolute_error: 0.4127 - val_loss: 0.4169 - val_mean_absolute_error: 0.4431 - 136ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.3768 - mean_absolute_error: 0.4176 - val_loss: 0.4727 - val_mean_absolute_error: 0.4685 - 132ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.3683 - mean_absolute_error: 0.4140 - val_loss: 0.3831 - val_mean_absolute_error: 0.4199 - 131ms/epoch - 2ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.3585 - mean_absolute_error: 0.4075 - val_loss: 0.3969 - val_mean_absolute_error: 0.4307 - 133ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.3884 - mean_absolute_error: 0.4249 - val_loss: 0.4294 - val_mean_absolute_error: 0.4517 - 155ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.3628 - mean_absolute_error: 0.4123 - val_loss: 0.3964 - val_mean_absolute_error: 0.4336 - 157ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.3628 - mean_absolute_error: 0.4098 - val_loss: 0.4112 - val_mean_absolute_error: 0.4329 - 135ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.3612 - mean_absolute_error: 0.4089 - val_loss: 0.5115 - val_mean_absolute_error: 0.4847 - 132ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.3710 - mean_absolute_error: 0.4166 - val_loss: 0.3836 - val_mean_absolute_error: 0.4213 - 132ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.3855 - mean_absolute_error: 0.4242 - val_loss: 0.4172 - val_mean_absolute_error: 0.4432 - 134ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.3706 - mean_absolute_error: 0.4144 - val_loss: 0.4025 - val_mean_absolute_error: 0.4302 - 133ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.3602 - mean_absolute_error: 0.4088 - val_loss: 0.3954 - val_mean_absolute_error: 0.4242 - 134ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.3734 - mean_absolute_error: 0.4156 - val_loss: 0.3936 - val_mean_absolute_error: 0.4279 - 153ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.3833 - mean_absolute_error: 0.4246 - val_loss: 0.4144 - val_mean_absolute_error: 0.4396 - 150ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.3587 - mean_absolute_error: 0.4099 - val_loss: 0.3991 - val_mean_absolute_error: 0.4256 - 176ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.3709 - mean_absolute_error: 0.4142 - val_loss: 0.4217 - val_mean_absolute_error: 0.4429 - 140ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.3636 - mean_absolute_error: 0.4109 - val_loss: 0.3813 - val_mean_absolute_error: 0.4208 - 133ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.3564 - mean_absolute_error: 0.4042 - val_loss: 0.3830 - val_mean_absolute_error: 0.4250 - 144ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.3681 - mean_absolute_error: 0.4119 - val_loss: 0.4202 - val_mean_absolute_error: 0.4426 - 145ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.3789 - mean_absolute_error: 0.4208 - val_loss: 0.3893 - val_mean_absolute_error: 0.4294 - 145ms/epoch - 2ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.3746 - mean_absolute_error: 0.4200 - val_loss: 0.3791 - val_mean_absolute_error: 0.4180 - 140ms/epoch - 2ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.3607 - mean_absolute_error: 0.4087 - val_loss: 0.4341 - val_mean_absolute_error: 0.4552 - 137ms/epoch - 2ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.3647 - mean_absolute_error: 0.4107 - val_loss: 0.5102 - val_mean_absolute_error: 0.4982 - 146ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.3758 - mean_absolute_error: 0.4188 - val_loss: 0.4067 - val_mean_absolute_error: 0.4358 - 134ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.3775 - mean_absolute_error: 0.4188 - val_loss: 0.4822 - val_mean_absolute_error: 0.4818 - 132ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.3753 - mean_absolute_error: 0.4184 - val_loss: 0.4031 - val_mean_absolute_error: 0.4339 - 134ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.3605 - mean_absolute_error: 0.4095 - val_loss: 0.3977 - val_mean_absolute_error: 0.4283 - 132ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.3523 - mean_absolute_error: 0.4022 - val_loss: 0.3838 - val_mean_absolute_error: 0.4214 - 132ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.3761 - mean_absolute_error: 0.4165 - val_loss: 0.4221 - val_mean_absolute_error: 0.4575 - 134ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.3630 - mean_absolute_error: 0.4123 - val_loss: 0.4671 - val_mean_absolute_error: 0.4755 - 152ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.3790 - mean_absolute_error: 0.4223 - val_loss: 0.3863 - val_mean_absolute_error: 0.4221 - 135ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.3669 - mean_absolute_error: 0.4120 - val_loss: 0.3807 - val_mean_absolute_error: 0.4180 - 157ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.3584 - mean_absolute_error: 0.4051 - val_loss: 0.4000 - val_mean_absolute_error: 0.4334 - 131ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.3628 - mean_absolute_error: 0.4067 - val_loss: 0.4172 - val_mean_absolute_error: 0.4404 - 135ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.3577 - mean_absolute_error: 0.4053 - val_loss: 0.3983 - val_mean_absolute_error: 0.4372 - 131ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.3589 - mean_absolute_error: 0.4088 - val_loss: 0.3878 - val_mean_absolute_error: 0.4289 - 133ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.3613 - mean_absolute_error: 0.4094 - val_loss: 0.4022 - val_mean_absolute_error: 0.4332 - 148ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.3709 - mean_absolute_error: 0.4163 - val_loss: 0.3933 - val_mean_absolute_error: 0.4322 - 148ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.3623 - mean_absolute_error: 0.4066 - val_loss: 0.4320 - val_mean_absolute_error: 0.4432 - 144ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.2946 - mean_absolute_error: 0.3525 - val_loss: 0.3691 - val_mean_absolute_error: 0.3975 - 132ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.2841 - mean_absolute_error: 0.3460 - val_loss: 0.3527 - val_mean_absolute_error: 0.3894 - 129ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.2905 - mean_absolute_error: 0.3487 - val_loss: 0.4319 - val_mean_absolute_error: 0.4346 - 133ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.3231 - mean_absolute_error: 0.3715 - val_loss: 0.3828 - val_mean_absolute_error: 0.4114 - 127ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.2977 - mean_absolute_error: 0.3568 - val_loss: 0.3408 - val_mean_absolute_error: 0.3842 - 124ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.2841 - mean_absolute_error: 0.3464 - val_loss: 0.3572 - val_mean_absolute_error: 0.3946 - 126ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.2917 - mean_absolute_error: 0.3519 - val_loss: 0.3728 - val_mean_absolute_error: 0.4067 - 126ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.2914 - mean_absolute_error: 0.3510 - val_loss: 0.3897 - val_mean_absolute_error: 0.4051 - 133ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.2993 - mean_absolute_error: 0.3591 - val_loss: 0.3755 - val_mean_absolute_error: 0.4068 - 127ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.3278 - mean_absolute_error: 0.3748 - val_loss: 0.3436 - val_mean_absolute_error: 0.3877 - 124ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.3185 - mean_absolute_error: 0.3714 - val_loss: 0.3426 - val_mean_absolute_error: 0.3816 - 125ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.3006 - mean_absolute_error: 0.3580 - val_loss: 0.3628 - val_mean_absolute_error: 0.3963 - 126ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.3108 - mean_absolute_error: 0.3669 - val_loss: 0.3403 - val_mean_absolute_error: 0.3813 - 130ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.2824 - mean_absolute_error: 0.3443 - val_loss: 0.3395 - val_mean_absolute_error: 0.3825 - 122ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.2981 - mean_absolute_error: 0.3527 - val_loss: 0.3913 - val_mean_absolute_error: 0.4182 - 125ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.2877 - mean_absolute_error: 0.3484 - val_loss: 0.4002 - val_mean_absolute_error: 0.4165 - 126ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.2921 - mean_absolute_error: 0.3498 - val_loss: 0.3556 - val_mean_absolute_error: 0.3890 - 128ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.3025 - mean_absolute_error: 0.3576 - val_loss: 0.3931 - val_mean_absolute_error: 0.4160 - 127ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.2881 - mean_absolute_error: 0.3477 - val_loss: 0.3574 - val_mean_absolute_error: 0.3878 - 126ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.2808 - mean_absolute_error: 0.3423 - val_loss: 0.3486 - val_mean_absolute_error: 0.3857 - 125ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.3007 - mean_absolute_error: 0.3582 - val_loss: 0.3695 - val_mean_absolute_error: 0.4035 - 126ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.2910 - mean_absolute_error: 0.3521 - val_loss: 0.3926 - val_mean_absolute_error: 0.4190 - 125ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.2854 - mean_absolute_error: 0.3462 - val_loss: 0.3790 - val_mean_absolute_error: 0.4038 - 127ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.2923 - mean_absolute_error: 0.3513 - val_loss: 0.3637 - val_mean_absolute_error: 0.3908 - 125ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.2827 - mean_absolute_error: 0.3432 - val_loss: 0.3420 - val_mean_absolute_error: 0.3935 - 124ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.2959 - mean_absolute_error: 0.3534 - val_loss: 0.4450 - val_mean_absolute_error: 0.4502 - 124ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.3006 - mean_absolute_error: 0.3568 - val_loss: 0.3556 - val_mean_absolute_error: 0.3902 - 125ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.3000 - mean_absolute_error: 0.3556 - val_loss: 0.3529 - val_mean_absolute_error: 0.3899 - 128ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.2941 - mean_absolute_error: 0.3508 - val_loss: 0.3446 - val_mean_absolute_error: 0.3845 - 134ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.2813 - mean_absolute_error: 0.3452 - val_loss: 0.3501 - val_mean_absolute_error: 0.3851 - 131ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.3001 - mean_absolute_error: 0.3544 - val_loss: 0.3582 - val_mean_absolute_error: 0.3853 - 125ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.2902 - mean_absolute_error: 0.3488 - val_loss: 0.3355 - val_mean_absolute_error: 0.3787 - 129ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.2974 - mean_absolute_error: 0.3531 - val_loss: 0.3599 - val_mean_absolute_error: 0.3947 - 128ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.2964 - mean_absolute_error: 0.3578 - val_loss: 0.3860 - val_mean_absolute_error: 0.4108 - 126ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.3094 - mean_absolute_error: 0.3620 - val_loss: 0.3768 - val_mean_absolute_error: 0.4051 - 128ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.2960 - mean_absolute_error: 0.3569 - val_loss: 0.3368 - val_mean_absolute_error: 0.3790 - 129ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.2855 - mean_absolute_error: 0.3469 - val_loss: 0.3616 - val_mean_absolute_error: 0.3909 - 126ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.2921 - mean_absolute_error: 0.3502 - val_loss: 0.3407 - val_mean_absolute_error: 0.3830 - 128ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.2899 - mean_absolute_error: 0.3522 - val_loss: 0.3354 - val_mean_absolute_error: 0.3790 - 129ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.2864 - mean_absolute_error: 0.3460 - val_loss: 0.3357 - val_mean_absolute_error: 0.3747 - 124ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.2874 - mean_absolute_error: 0.3469 - val_loss: 0.3743 - val_mean_absolute_error: 0.4039 - 125ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.2887 - mean_absolute_error: 0.3476 - val_loss: 0.3323 - val_mean_absolute_error: 0.3780 - 130ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.2951 - mean_absolute_error: 0.3531 - val_loss: 0.3768 - val_mean_absolute_error: 0.4053 - 127ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.2997 - mean_absolute_error: 0.3562 - val_loss: 0.3483 - val_mean_absolute_error: 0.3853 - 124ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.2927 - mean_absolute_error: 0.3515 - val_loss: 0.3554 - val_mean_absolute_error: 0.3917 - 132ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.3148 - mean_absolute_error: 0.3693 - val_loss: 0.3728 - val_mean_absolute_error: 0.4083 - 130ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.2934 - mean_absolute_error: 0.3535 - val_loss: 0.3515 - val_mean_absolute_error: 0.3875 - 127ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.2812 - mean_absolute_error: 0.3454 - val_loss: 0.3567 - val_mean_absolute_error: 0.3922 - 126ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.2906 - mean_absolute_error: 0.3500 - val_loss: 0.3693 - val_mean_absolute_error: 0.3998 - 150ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.3212 - mean_absolute_error: 0.3721 - val_loss: 0.4618 - val_mean_absolute_error: 0.4633 - 135ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.3147 - mean_absolute_error: 0.3725 - val_loss: 0.3677 - val_mean_absolute_error: 0.4017 - 129ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.3010 - mean_absolute_error: 0.3560 - val_loss: 0.3938 - val_mean_absolute_error: 0.4119 - 127ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.2925 - mean_absolute_error: 0.3509 - val_loss: 0.3484 - val_mean_absolute_error: 0.3872 - 128ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.2973 - mean_absolute_error: 0.3579 - val_loss: 0.3486 - val_mean_absolute_error: 0.3909 - 126ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.3081 - mean_absolute_error: 0.3597 - val_loss: 0.4052 - val_mean_absolute_error: 0.4309 - 125ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.2972 - mean_absolute_error: 0.3569 - val_loss: 0.3457 - val_mean_absolute_error: 0.3853 - 125ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.3047 - mean_absolute_error: 0.3589 - val_loss: 0.3453 - val_mean_absolute_error: 0.3847 - 125ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.2812 - mean_absolute_error: 0.3423 - val_loss: 0.3307 - val_mean_absolute_error: 0.3727 - 124ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.2911 - mean_absolute_error: 0.3481 - val_loss: 0.3617 - val_mean_absolute_error: 0.3937 - 122ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.2821 - mean_absolute_error: 0.3410 - val_loss: 0.3516 - val_mean_absolute_error: 0.3899 - 124ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.2935 - mean_absolute_error: 0.3533 - val_loss: 0.3421 - val_mean_absolute_error: 0.3822 - 129ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.2868 - mean_absolute_error: 0.3461 - val_loss: 0.3604 - val_mean_absolute_error: 0.3899 - 123ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.2874 - mean_absolute_error: 0.3461 - val_loss: 0.3756 - val_mean_absolute_error: 0.4054 - 123ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.2814 - mean_absolute_error: 0.3455 - val_loss: 0.3369 - val_mean_absolute_error: 0.3810 - 123ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.3122 - mean_absolute_error: 0.3624 - val_loss: 0.3487 - val_mean_absolute_error: 0.3933 - 122ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.2849 - mean_absolute_error: 0.3455 - val_loss: 0.3443 - val_mean_absolute_error: 0.3842 - 124ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.2995 - mean_absolute_error: 0.3585 - val_loss: 0.3872 - val_mean_absolute_error: 0.4081 - 124ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.2882 - mean_absolute_error: 0.3473 - val_loss: 0.3336 - val_mean_absolute_error: 0.3746 - 122ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.2948 - mean_absolute_error: 0.3521 - val_loss: 0.3483 - val_mean_absolute_error: 0.3866 - 125ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.2819 - mean_absolute_error: 0.3434 - val_loss: 0.3483 - val_mean_absolute_error: 0.3852 - 127ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.2755 - mean_absolute_error: 0.3377 - val_loss: 0.3513 - val_mean_absolute_error: 0.3865 - 123ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.3102 - mean_absolute_error: 0.3616 - val_loss: 0.3705 - val_mean_absolute_error: 0.4000 - 123ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.2976 - mean_absolute_error: 0.3572 - val_loss: 0.3505 - val_mean_absolute_error: 0.3890 - 122ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.3104 - mean_absolute_error: 0.3617 - val_loss: 0.4390 - val_mean_absolute_error: 0.4427 - 123ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.2998 - mean_absolute_error: 0.3565 - val_loss: 0.3885 - val_mean_absolute_error: 0.4075 - 123ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.2853 - mean_absolute_error: 0.3460 - val_loss: 0.3450 - val_mean_absolute_error: 0.3812 - 128ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.2826 - mean_absolute_error: 0.3437 - val_loss: 0.3476 - val_mean_absolute_error: 0.3897 - 124ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.2798 - mean_absolute_error: 0.3436 - val_loss: 0.3462 - val_mean_absolute_error: 0.3797 - 123ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.2988 - mean_absolute_error: 0.3559 - val_loss: 0.3519 - val_mean_absolute_error: 0.3870 - 124ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.2801 - mean_absolute_error: 0.3428 - val_loss: 0.4006 - val_mean_absolute_error: 0.4203 - 123ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.3034 - mean_absolute_error: 0.3564 - val_loss: 0.3528 - val_mean_absolute_error: 0.3854 - 123ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.2868 - mean_absolute_error: 0.3467 - val_loss: 0.3591 - val_mean_absolute_error: 0.3914 - 124ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.2881 - mean_absolute_error: 0.3465 - val_loss: 0.3382 - val_mean_absolute_error: 0.3820 - 125ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.2807 - mean_absolute_error: 0.3436 - val_loss: 0.3718 - val_mean_absolute_error: 0.3988 - 124ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.2776 - mean_absolute_error: 0.3389 - val_loss: 0.3669 - val_mean_absolute_error: 0.3928 - 124ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.2847 - mean_absolute_error: 0.3456 - val_loss: 0.3359 - val_mean_absolute_error: 0.3759 - 127ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.3189 - mean_absolute_error: 0.3672 - val_loss: 0.3485 - val_mean_absolute_error: 0.3850 - 126ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.3086 - mean_absolute_error: 0.3637 - val_loss: 0.3711 - val_mean_absolute_error: 0.4046 - 147ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.2822 - mean_absolute_error: 0.3462 - val_loss: 0.3389 - val_mean_absolute_error: 0.3791 - 131ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.3213 - mean_absolute_error: 0.3683 - val_loss: 0.3547 - val_mean_absolute_error: 0.3923 - 127ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.2842 - mean_absolute_error: 0.3485 - val_loss: 0.3352 - val_mean_absolute_error: 0.3784 - 131ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.2961 - mean_absolute_error: 0.3510 - val_loss: 0.3596 - val_mean_absolute_error: 0.4006 - 126ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.3011 - mean_absolute_error: 0.3577 - val_loss: 0.3920 - val_mean_absolute_error: 0.4151 - 130ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.3028 - mean_absolute_error: 0.3592 - val_loss: 0.3412 - val_mean_absolute_error: 0.3785 - 136ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.2999 - mean_absolute_error: 0.3546 - val_loss: 0.3469 - val_mean_absolute_error: 0.3861 - 142ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.2913 - mean_absolute_error: 0.3530 - val_loss: 0.3592 - val_mean_absolute_error: 0.3938 - 127ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.2833 - mean_absolute_error: 0.3433 - val_loss: 0.3514 - val_mean_absolute_error: 0.3876 - 126ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.2945 - mean_absolute_error: 0.3520 - val_loss: 0.3568 - val_mean_absolute_error: 0.3941 - 127ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.2830 - mean_absolute_error: 0.3431 - val_loss: 0.3447 - val_mean_absolute_error: 0.3791 - 130ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.2806 - mean_absolute_error: 0.3403 - val_loss: 0.3594 - val_mean_absolute_error: 0.3876 - 134ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.2865 - mean_absolute_error: 0.3449 - val_loss: 0.3443 - val_mean_absolute_error: 0.3842 - 123ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.3009 - mean_absolute_error: 0.3548 - val_loss: 0.3412 - val_mean_absolute_error: 0.3864 - 124ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.2816 - mean_absolute_error: 0.3424 - val_loss: 0.3412 - val_mean_absolute_error: 0.3854 - 131ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.2815 - mean_absolute_error: 0.3425 - val_loss: 0.3871 - val_mean_absolute_error: 0.4046 - 127ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.2829 - mean_absolute_error: 0.3426 - val_loss: 0.3387 - val_mean_absolute_error: 0.3762 - 126ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.2824 - mean_absolute_error: 0.3438 - val_loss: 0.3991 - val_mean_absolute_error: 0.4136 - 129ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.2830 - mean_absolute_error: 0.3453 - val_loss: 0.3660 - val_mean_absolute_error: 0.3993 - 130ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_noNoise_five(300w).keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE: 0.36604002118110657
# MAE: 0.3992936313152313
# 32/32 [==============================] - 0s 757us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# ##### Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\kappa$', r'$\Delta E$', r'$\gamma$', r'$g$']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 9))
fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes.flatten()):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ##### Curvas Validación VS Predicción
#
# Si jugamos con la función, llegamos a:
#
# $$
# t(\omega)=\frac{-\kappa\left[(\Delta E-\omega)-i\gamma\right]}{\left[(\Omega-\omega)(\Delta E-\omega)-\kappa\gamma-g^2\right]-i\left[(\Omega-\omega)\gamma+(\Delta E-\omega)\kappa\right]}
# $$
#
# Sacamos los polos de la parte real del denominador, obteniendo:
# $$
# \omega_1=\frac{(\Delta E+\Omega)+\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# $$
# \omega_2=\frac{(\Delta E+\Omega)-\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# Si queremos el valor de g:
# $$g=\frac{\sqrt{|\omega_1-\omega_2|^2-(\Omega-\Delta E)^2-4\kappa\gamma}}{2}$$
#
# Ahora, junto a las curvas, dibujaremos líneas verticales correspondientes a esos polos y escribimnos el valor de la resta de sus valores

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
k_pred = y_pred_denorm[:, 0]
k_val = y_val_denorm[:, 0]
DeltaE_pred = y_pred_denorm[:, 1]
DeltaE_val = y_val_denorm[:, 1]
gamma_pred = y_pred_denorm[:, 2]
gamma_val = y_val_denorm[:, 2]
g_pred = y_pred_denorm[:, 3]
g_val = y_val_denorm[:, 3]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val = np.zeros((x_val.shape[0], len(w_values)))


for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k_pred[i], Omega, DeltaE_pred[i], gamma_pred[i], g_pred[i])
    t_values_val[i,:] = t_w(w_values, k_val[i], Omega, DeltaE_val[i], gamma_val[i], g_val[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k_val, Omega, DeltaE_val, gamma_val, g_val)
w2=w_2(k_val, Omega, DeltaE_val, gamma_val, g_val)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"κ real = {k_val[i]:.7f}, κ pred = {k_pred[i]:.7f}\n"\
           f"ΔE real = {DeltaE_val[i]:.5f}, ΔE pred = {DeltaE_pred[i]:.5f}\n"\
           f"γ real = {gamma_val[i]:.7f}, γ pred = {gamma_pred[i]:.7f}\n"\
           f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # With noise

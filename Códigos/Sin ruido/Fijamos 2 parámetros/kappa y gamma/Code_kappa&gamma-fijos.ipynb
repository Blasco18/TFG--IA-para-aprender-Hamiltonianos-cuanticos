# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos: $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # Sin ruido

# %% [markdown]
# ## Creamos base de datos

# %%
#Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)


    return DeltaE, g

num_datos = 5000

# %%
# #Creamos base de datos y guardamos en .txt
# DeltaE, g = Parameters_generator (num_datos)
# np.savetxt('Parameters_noNoise(kappa&gamma-fijos).txt', np.column_stack((DeltaE, g)), header='\u0394E g')

# %%
datos = np.loadtxt('Parameters_noNoise(kappa&gamma-fijos).txt', skiprows=1)
DeltaE = datos[:,0]
g = datos[:,1]
k = 1e-3
gamma = 1e-3
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.8, 1.2, 400)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))

# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k, Omega, DeltaE[i], gamma, g[i])

# %% [markdown]
# ### Dibujamos alguna curva

# %%
# i=0
# while i<=1000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values[i,:], label='Curva original')
#     plt.plot(w_values, t_sep_values[i,:], linestyle='--', label='Curva separada')
#     plt.plot(w_values, mod_t_values[i,:], linestyle='-.', label='Módulo curva')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
x_train, x_val, y_train, y_val = train_test_split(t_values, datos, test_size=0.2)

# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 400)
# y_train shape (4000, 2)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_noNoise_five(k-1e-3&gamma-1e-3).keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 1s - loss: 0.6899 - mean_absolute_error: 0.6748 - val_loss: 0.5708 - val_mean_absolute_error: 0.6023 - 1s/epoch - 13ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.5143 - mean_absolute_error: 0.5443 - val_loss: 0.4464 - val_mean_absolute_error: 0.4935 - 164ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.4203 - mean_absolute_error: 0.4694 - val_loss: 0.3734 - val_mean_absolute_error: 0.4498 - 147ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.3563 - mean_absolute_error: 0.4208 - val_loss: 0.3269 - val_mean_absolute_error: 0.4062 - 151ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.3133 - mean_absolute_error: 0.3889 - val_loss: 0.2807 - val_mean_absolute_error: 0.3731 - 150ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.2714 - mean_absolute_error: 0.3547 - val_loss: 0.2441 - val_mean_absolute_error: 0.3423 - 147ms/epoch - 2ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.2421 - mean_absolute_error: 0.3305 - val_loss: 0.2207 - val_mean_absolute_error: 0.3202 - 146ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.2119 - mean_absolute_error: 0.3062 - val_loss: 0.1930 - val_mean_absolute_error: 0.3019 - 148ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.1909 - mean_absolute_error: 0.2871 - val_loss: 0.1723 - val_mean_absolute_error: 0.2839 - 148ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.1721 - mean_absolute_error: 0.2676 - val_loss: 0.1594 - val_mean_absolute_error: 0.2558 - 153ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.1472 - mean_absolute_error: 0.2406 - val_loss: 0.1435 - val_mean_absolute_error: 0.2414 - 150ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.1337 - mean_absolute_error: 0.2276 - val_loss: 0.1327 - val_mean_absolute_error: 0.2270 - 149ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.1261 - mean_absolute_error: 0.2287 - val_loss: 0.1096 - val_mean_absolute_error: 0.2186 - 147ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.1122 - mean_absolute_error: 0.2111 - val_loss: 0.1132 - val_mean_absolute_error: 0.2314 - 146ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.1037 - mean_absolute_error: 0.2042 - val_loss: 0.0874 - val_mean_absolute_error: 0.1922 - 147ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.0853 - mean_absolute_error: 0.1785 - val_loss: 0.0781 - val_mean_absolute_error: 0.1714 - 147ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.0794 - mean_absolute_error: 0.1674 - val_loss: 0.0854 - val_mean_absolute_error: 0.1761 - 149ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.0706 - mean_absolute_error: 0.1606 - val_loss: 0.0656 - val_mean_absolute_error: 0.1638 - 146ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.0740 - mean_absolute_error: 0.1645 - val_loss: 0.0583 - val_mean_absolute_error: 0.1546 - 144ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.0671 - mean_absolute_error: 0.1516 - val_loss: 0.0587 - val_mean_absolute_error: 0.1509 - 147ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.0573 - mean_absolute_error: 0.1413 - val_loss: 0.0655 - val_mean_absolute_error: 0.1544 - 146ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.0594 - mean_absolute_error: 0.1406 - val_loss: 0.0483 - val_mean_absolute_error: 0.1370 - 146ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.0509 - mean_absolute_error: 0.1297 - val_loss: 0.0527 - val_mean_absolute_error: 0.1420 - 145ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.0481 - mean_absolute_error: 0.1240 - val_loss: 0.0414 - val_mean_absolute_error: 0.1262 - 146ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.0474 - mean_absolute_error: 0.1198 - val_loss: 0.0383 - val_mean_absolute_error: 0.1188 - 145ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.0505 - mean_absolute_error: 0.1303 - val_loss: 0.0381 - val_mean_absolute_error: 0.1144 - 147ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.0426 - mean_absolute_error: 0.1139 - val_loss: 0.0399 - val_mean_absolute_error: 0.1199 - 144ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.0391 - mean_absolute_error: 0.1116 - val_loss: 0.0388 - val_mean_absolute_error: 0.1041 - 150ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.0327 - mean_absolute_error: 0.0954 - val_loss: 0.0312 - val_mean_absolute_error: 0.1056 - 146ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.0401 - mean_absolute_error: 0.1048 - val_loss: 0.0386 - val_mean_absolute_error: 0.1049 - 146ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.0400 - mean_absolute_error: 0.1078 - val_loss: 0.0330 - val_mean_absolute_error: 0.0964 - 149ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.0347 - mean_absolute_error: 0.0965 - val_loss: 0.0328 - val_mean_absolute_error: 0.1027 - 141ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.0307 - mean_absolute_error: 0.0885 - val_loss: 0.0294 - val_mean_absolute_error: 0.0937 - 144ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.0387 - mean_absolute_error: 0.1020 - val_loss: 0.0372 - val_mean_absolute_error: 0.1169 - 146ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.0405 - mean_absolute_error: 0.1050 - val_loss: 0.0276 - val_mean_absolute_error: 0.0960 - 147ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.0382 - mean_absolute_error: 0.1031 - val_loss: 0.0348 - val_mean_absolute_error: 0.1067 - 146ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.0290 - mean_absolute_error: 0.0889 - val_loss: 0.0231 - val_mean_absolute_error: 0.0864 - 146ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.0270 - mean_absolute_error: 0.0776 - val_loss: 0.0255 - val_mean_absolute_error: 0.0901 - 143ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.0305 - mean_absolute_error: 0.0862 - val_loss: 0.0244 - val_mean_absolute_error: 0.0841 - 150ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.0241 - mean_absolute_error: 0.0736 - val_loss: 0.0200 - val_mean_absolute_error: 0.0715 - 145ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.0280 - mean_absolute_error: 0.0795 - val_loss: 0.0276 - val_mean_absolute_error: 0.1019 - 143ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.0281 - mean_absolute_error: 0.0795 - val_loss: 0.0311 - val_mean_absolute_error: 0.0966 - 144ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.0239 - mean_absolute_error: 0.0686 - val_loss: 0.0346 - val_mean_absolute_error: 0.0800 - 151ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.0269 - mean_absolute_error: 0.0784 - val_loss: 0.0187 - val_mean_absolute_error: 0.0680 - 148ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.0248 - mean_absolute_error: 0.0728 - val_loss: 0.0209 - val_mean_absolute_error: 0.0787 - 146ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.0187 - mean_absolute_error: 0.0634 - val_loss: 0.0246 - val_mean_absolute_error: 0.0651 - 146ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.0233 - mean_absolute_error: 0.0712 - val_loss: 0.0204 - val_mean_absolute_error: 0.0698 - 147ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.0254 - mean_absolute_error: 0.0726 - val_loss: 0.0210 - val_mean_absolute_error: 0.0721 - 148ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.0262 - mean_absolute_error: 0.0744 - val_loss: 0.0193 - val_mean_absolute_error: 0.0706 - 146ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.0256 - mean_absolute_error: 0.0684 - val_loss: 0.0230 - val_mean_absolute_error: 0.0740 - 148ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.0308 - mean_absolute_error: 0.0784 - val_loss: 0.0311 - val_mean_absolute_error: 0.0899 - 150ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.0271 - mean_absolute_error: 0.0812 - val_loss: 0.0221 - val_mean_absolute_error: 0.0774 - 147ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.0221 - mean_absolute_error: 0.0652 - val_loss: 0.0279 - val_mean_absolute_error: 0.0844 - 147ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.0237 - mean_absolute_error: 0.0685 - val_loss: 0.0185 - val_mean_absolute_error: 0.0611 - 146ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.0216 - mean_absolute_error: 0.0586 - val_loss: 0.0379 - val_mean_absolute_error: 0.0820 - 146ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.0247 - mean_absolute_error: 0.0682 - val_loss: 0.0172 - val_mean_absolute_error: 0.0590 - 151ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.0203 - mean_absolute_error: 0.0582 - val_loss: 0.0175 - val_mean_absolute_error: 0.0682 - 155ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.0222 - mean_absolute_error: 0.0630 - val_loss: 0.0176 - val_mean_absolute_error: 0.0605 - 148ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.0243 - mean_absolute_error: 0.0640 - val_loss: 0.0183 - val_mean_absolute_error: 0.0682 - 152ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.0202 - mean_absolute_error: 0.0593 - val_loss: 0.0169 - val_mean_absolute_error: 0.0690 - 154ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.0243 - mean_absolute_error: 0.0695 - val_loss: 0.0409 - val_mean_absolute_error: 0.1045 - 156ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.0234 - mean_absolute_error: 0.0708 - val_loss: 0.0165 - val_mean_absolute_error: 0.0655 - 150ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.0206 - mean_absolute_error: 0.0623 - val_loss: 0.0482 - val_mean_absolute_error: 0.0710 - 143ms/epoch - 2ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.0166 - mean_absolute_error: 0.0522 - val_loss: 0.0207 - val_mean_absolute_error: 0.0596 - 148ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.0200 - mean_absolute_error: 0.0575 - val_loss: 0.0147 - val_mean_absolute_error: 0.0541 - 153ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.0185 - mean_absolute_error: 0.0539 - val_loss: 0.0243 - val_mean_absolute_error: 0.0786 - 143ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.0172 - mean_absolute_error: 0.0529 - val_loss: 0.0155 - val_mean_absolute_error: 0.0555 - 142ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.0194 - mean_absolute_error: 0.0504 - val_loss: 0.0238 - val_mean_absolute_error: 0.0764 - 149ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.0178 - mean_absolute_error: 0.0608 - val_loss: 0.0142 - val_mean_absolute_error: 0.0552 - 142ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.0197 - mean_absolute_error: 0.0503 - val_loss: 0.0143 - val_mean_absolute_error: 0.0521 - 141ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.0195 - mean_absolute_error: 0.0547 - val_loss: 0.0177 - val_mean_absolute_error: 0.0652 - 150ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.0192 - mean_absolute_error: 0.0582 - val_loss: 0.0189 - val_mean_absolute_error: 0.0645 - 144ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.0168 - mean_absolute_error: 0.0522 - val_loss: 0.0244 - val_mean_absolute_error: 0.0589 - 146ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.0145 - mean_absolute_error: 0.0479 - val_loss: 0.0153 - val_mean_absolute_error: 0.0543 - 148ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.0204 - mean_absolute_error: 0.0596 - val_loss: 0.0186 - val_mean_absolute_error: 0.0598 - 150ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.0203 - mean_absolute_error: 0.0573 - val_loss: 0.0180 - val_mean_absolute_error: 0.0536 - 148ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.0216 - mean_absolute_error: 0.0580 - val_loss: 0.0175 - val_mean_absolute_error: 0.0544 - 149ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.0195 - mean_absolute_error: 0.0550 - val_loss: 0.0226 - val_mean_absolute_error: 0.0553 - 147ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.0138 - mean_absolute_error: 0.0467 - val_loss: 0.0142 - val_mean_absolute_error: 0.0558 - 151ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.0219 - mean_absolute_error: 0.0605 - val_loss: 0.0172 - val_mean_absolute_error: 0.0665 - 149ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.0251 - mean_absolute_error: 0.0662 - val_loss: 0.0241 - val_mean_absolute_error: 0.0796 - 146ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.0225 - mean_absolute_error: 0.0642 - val_loss: 0.0190 - val_mean_absolute_error: 0.0640 - 148ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.0172 - mean_absolute_error: 0.0549 - val_loss: 0.0204 - val_mean_absolute_error: 0.0536 - 146ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.0190 - mean_absolute_error: 0.0523 - val_loss: 0.0173 - val_mean_absolute_error: 0.0560 - 145ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.0192 - mean_absolute_error: 0.0542 - val_loss: 0.0243 - val_mean_absolute_error: 0.0743 - 148ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.0170 - mean_absolute_error: 0.0556 - val_loss: 0.0170 - val_mean_absolute_error: 0.0516 - 151ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.0218 - mean_absolute_error: 0.0520 - val_loss: 0.0174 - val_mean_absolute_error: 0.0501 - 144ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.0197 - mean_absolute_error: 0.0582 - val_loss: 0.0161 - val_mean_absolute_error: 0.0653 - 146ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.0201 - mean_absolute_error: 0.0566 - val_loss: 0.0198 - val_mean_absolute_error: 0.0635 - 149ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.0163 - mean_absolute_error: 0.0515 - val_loss: 0.0198 - val_mean_absolute_error: 0.0580 - 148ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.0239 - mean_absolute_error: 0.0626 - val_loss: 0.0190 - val_mean_absolute_error: 0.0674 - 148ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.0153 - mean_absolute_error: 0.0488 - val_loss: 0.0136 - val_mean_absolute_error: 0.0500 - 146ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.0244 - mean_absolute_error: 0.0625 - val_loss: 0.0232 - val_mean_absolute_error: 0.0679 - 146ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.0153 - mean_absolute_error: 0.0506 - val_loss: 0.0254 - val_mean_absolute_error: 0.0570 - 144ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.0196 - mean_absolute_error: 0.0499 - val_loss: 0.0173 - val_mean_absolute_error: 0.0529 - 146ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.0201 - mean_absolute_error: 0.0555 - val_loss: 0.0135 - val_mean_absolute_error: 0.0512 - 155ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.0152 - mean_absolute_error: 0.0430 - val_loss: 0.0195 - val_mean_absolute_error: 0.0539 - 146ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.0151 - mean_absolute_error: 0.0454 - val_loss: 0.0149 - val_mean_absolute_error: 0.0471 - 147ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.0145 - mean_absolute_error: 0.0424 - val_loss: 0.0174 - val_mean_absolute_error: 0.0472 - 146ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.0146 - mean_absolute_error: 0.0457 - val_loss: 0.0147 - val_mean_absolute_error: 0.0591 - 146ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.0221 - mean_absolute_error: 0.0615 - val_loss: 0.0141 - val_mean_absolute_error: 0.0579 - 145ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.0214 - mean_absolute_error: 0.0643 - val_loss: 0.0172 - val_mean_absolute_error: 0.0668 - 149ms/epoch - 2ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.0169 - mean_absolute_error: 0.0558 - val_loss: 0.0162 - val_mean_absolute_error: 0.0506 - 145ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.0162 - mean_absolute_error: 0.0456 - val_loss: 0.0126 - val_mean_absolute_error: 0.0475 - 155ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.0195 - mean_absolute_error: 0.0533 - val_loss: 0.0209 - val_mean_absolute_error: 0.0651 - 146ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.0186 - mean_absolute_error: 0.0533 - val_loss: 0.0188 - val_mean_absolute_error: 0.0581 - 151ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.0190 - mean_absolute_error: 0.0506 - val_loss: 0.0191 - val_mean_absolute_error: 0.0523 - 156ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.0132 - mean_absolute_error: 0.0405 - val_loss: 0.0118 - val_mean_absolute_error: 0.0431 - 156ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.0140 - mean_absolute_error: 0.0403 - val_loss: 0.0147 - val_mean_absolute_error: 0.0474 - 163ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.0143 - mean_absolute_error: 0.0439 - val_loss: 0.0128 - val_mean_absolute_error: 0.0467 - 156ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.0194 - mean_absolute_error: 0.0543 - val_loss: 0.0234 - val_mean_absolute_error: 0.0668 - 152ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.0154 - mean_absolute_error: 0.0521 - val_loss: 0.0136 - val_mean_absolute_error: 0.0520 - 148ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.0151 - mean_absolute_error: 0.0492 - val_loss: 0.0135 - val_mean_absolute_error: 0.0450 - 154ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.0147 - mean_absolute_error: 0.0426 - val_loss: 0.0127 - val_mean_absolute_error: 0.0424 - 146ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.0153 - mean_absolute_error: 0.0410 - val_loss: 0.0208 - val_mean_absolute_error: 0.0503 - 147ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.0169 - mean_absolute_error: 0.0435 - val_loss: 0.0125 - val_mean_absolute_error: 0.0420 - 146ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.0142 - mean_absolute_error: 0.0427 - val_loss: 0.0146 - val_mean_absolute_error: 0.0460 - 147ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0464 - val_loss: 0.0135 - val_mean_absolute_error: 0.0439 - 144ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.0126 - mean_absolute_error: 0.0377 - val_loss: 0.0130 - val_mean_absolute_error: 0.0382 - 144ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.0160 - mean_absolute_error: 0.0401 - val_loss: 0.0135 - val_mean_absolute_error: 0.0505 - 146ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.0162 - mean_absolute_error: 0.0475 - val_loss: 0.0177 - val_mean_absolute_error: 0.0478 - 150ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.0167 - mean_absolute_error: 0.0474 - val_loss: 0.0137 - val_mean_absolute_error: 0.0556 - 145ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0448 - val_loss: 0.0133 - val_mean_absolute_error: 0.0489 - 149ms/epoch - 2ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0447 - val_loss: 0.0151 - val_mean_absolute_error: 0.0490 - 150ms/epoch - 2ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.0153 - mean_absolute_error: 0.0447 - val_loss: 0.0179 - val_mean_absolute_error: 0.0608 - 145ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.0129 - mean_absolute_error: 0.0423 - val_loss: 0.0340 - val_mean_absolute_error: 0.0610 - 146ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.0228 - mean_absolute_error: 0.0591 - val_loss: 0.0243 - val_mean_absolute_error: 0.0650 - 150ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.0197 - mean_absolute_error: 0.0526 - val_loss: 0.0149 - val_mean_absolute_error: 0.0481 - 154ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.0196 - mean_absolute_error: 0.0569 - val_loss: 0.0177 - val_mean_absolute_error: 0.0577 - 154ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.0163 - mean_absolute_error: 0.0466 - val_loss: 0.0382 - val_mean_absolute_error: 0.0644 - 153ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.0182 - mean_absolute_error: 0.0483 - val_loss: 0.0130 - val_mean_absolute_error: 0.0429 - 148ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.0176 - mean_absolute_error: 0.0487 - val_loss: 0.0173 - val_mean_absolute_error: 0.0582 - 147ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.0147 - mean_absolute_error: 0.0411 - val_loss: 0.0143 - val_mean_absolute_error: 0.0432 - 147ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0378 - val_loss: 0.0137 - val_mean_absolute_error: 0.0438 - 144ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.0172 - mean_absolute_error: 0.0471 - val_loss: 0.0229 - val_mean_absolute_error: 0.0564 - 146ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.0186 - mean_absolute_error: 0.0536 - val_loss: 0.0348 - val_mean_absolute_error: 0.0562 - 147ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.0160 - mean_absolute_error: 0.0467 - val_loss: 0.0185 - val_mean_absolute_error: 0.0643 - 145ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0478 - val_loss: 0.0251 - val_mean_absolute_error: 0.0549 - 145ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.0138 - mean_absolute_error: 0.0406 - val_loss: 0.0153 - val_mean_absolute_error: 0.0520 - 147ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.0171 - mean_absolute_error: 0.0445 - val_loss: 0.0126 - val_mean_absolute_error: 0.0431 - 144ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.0145 - mean_absolute_error: 0.0433 - val_loss: 0.0242 - val_mean_absolute_error: 0.0549 - 143ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.0125 - mean_absolute_error: 0.0394 - val_loss: 0.0143 - val_mean_absolute_error: 0.0506 - 146ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.0142 - mean_absolute_error: 0.0395 - val_loss: 0.0125 - val_mean_absolute_error: 0.0441 - 146ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0378 - val_loss: 0.0161 - val_mean_absolute_error: 0.0513 - 144ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.0144 - mean_absolute_error: 0.0424 - val_loss: 0.0283 - val_mean_absolute_error: 0.0550 - 145ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.0141 - mean_absolute_error: 0.0416 - val_loss: 0.0162 - val_mean_absolute_error: 0.0453 - 143ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.0151 - mean_absolute_error: 0.0439 - val_loss: 0.0140 - val_mean_absolute_error: 0.0479 - 142ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.0163 - mean_absolute_error: 0.0465 - val_loss: 0.0221 - val_mean_absolute_error: 0.0522 - 147ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.0142 - mean_absolute_error: 0.0413 - val_loss: 0.0222 - val_mean_absolute_error: 0.0489 - 154ms/epoch - 2ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.0188 - mean_absolute_error: 0.0490 - val_loss: 0.0174 - val_mean_absolute_error: 0.0561 - 149ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0464 - val_loss: 0.0116 - val_mean_absolute_error: 0.0400 - 148ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0403 - val_loss: 0.0180 - val_mean_absolute_error: 0.0532 - 147ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0402 - val_loss: 0.0112 - val_mean_absolute_error: 0.0418 - 145ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.0132 - mean_absolute_error: 0.0395 - val_loss: 0.0162 - val_mean_absolute_error: 0.0501 - 143ms/epoch - 2ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.0201 - mean_absolute_error: 0.0515 - val_loss: 0.0250 - val_mean_absolute_error: 0.0786 - 142ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.0171 - mean_absolute_error: 0.0508 - val_loss: 0.0178 - val_mean_absolute_error: 0.0577 - 145ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.0113 - mean_absolute_error: 0.0415 - val_loss: 0.0128 - val_mean_absolute_error: 0.0421 - 145ms/epoch - 2ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.0122 - mean_absolute_error: 0.0355 - val_loss: 0.0214 - val_mean_absolute_error: 0.0500 - 147ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.0160 - mean_absolute_error: 0.0416 - val_loss: 0.0197 - val_mean_absolute_error: 0.0461 - 146ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.0159 - mean_absolute_error: 0.0438 - val_loss: 0.0122 - val_mean_absolute_error: 0.0431 - 146ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.0139 - mean_absolute_error: 0.0404 - val_loss: 0.0252 - val_mean_absolute_error: 0.0490 - 147ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.0161 - mean_absolute_error: 0.0430 - val_loss: 0.0194 - val_mean_absolute_error: 0.0571 - 144ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.0175 - mean_absolute_error: 0.0475 - val_loss: 0.0138 - val_mean_absolute_error: 0.0399 - 144ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.0169 - mean_absolute_error: 0.0413 - val_loss: 0.0164 - val_mean_absolute_error: 0.0557 - 148ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.0115 - mean_absolute_error: 0.0367 - val_loss: 0.0130 - val_mean_absolute_error: 0.0378 - 145ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0417 - val_loss: 0.0121 - val_mean_absolute_error: 0.0428 - 145ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.0132 - mean_absolute_error: 0.0391 - val_loss: 0.0117 - val_mean_absolute_error: 0.0404 - 150ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.0152 - mean_absolute_error: 0.0394 - val_loss: 0.0215 - val_mean_absolute_error: 0.0531 - 151ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.0153 - mean_absolute_error: 0.0446 - val_loss: 0.0116 - val_mean_absolute_error: 0.0409 - 144ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0368 - val_loss: 0.0151 - val_mean_absolute_error: 0.0402 - 147ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.0156 - mean_absolute_error: 0.0447 - val_loss: 0.0129 - val_mean_absolute_error: 0.0470 - 147ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.0161 - mean_absolute_error: 0.0469 - val_loss: 0.0183 - val_mean_absolute_error: 0.0460 - 151ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.0155 - mean_absolute_error: 0.0397 - val_loss: 0.0193 - val_mean_absolute_error: 0.0475 - 147ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.0103 - mean_absolute_error: 0.0342 - val_loss: 0.0125 - val_mean_absolute_error: 0.0437 - 147ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.0154 - mean_absolute_error: 0.0447 - val_loss: 0.0231 - val_mean_absolute_error: 0.0655 - 145ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.0142 - mean_absolute_error: 0.0457 - val_loss: 0.0182 - val_mean_absolute_error: 0.0415 - 144ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.0138 - mean_absolute_error: 0.0374 - val_loss: 0.0122 - val_mean_absolute_error: 0.0402 - 144ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.0125 - mean_absolute_error: 0.0386 - val_loss: 0.0216 - val_mean_absolute_error: 0.0499 - 142ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.0160 - mean_absolute_error: 0.0441 - val_loss: 0.0131 - val_mean_absolute_error: 0.0394 - 144ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.0155 - mean_absolute_error: 0.0412 - val_loss: 0.0181 - val_mean_absolute_error: 0.0516 - 145ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.0169 - mean_absolute_error: 0.0477 - val_loss: 0.0137 - val_mean_absolute_error: 0.0418 - 145ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0435 - val_loss: 0.0284 - val_mean_absolute_error: 0.0530 - 153ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.0114 - mean_absolute_error: 0.0359 - val_loss: 0.0160 - val_mean_absolute_error: 0.0433 - 145ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.0130 - mean_absolute_error: 0.0370 - val_loss: 0.0193 - val_mean_absolute_error: 0.0516 - 144ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.0123 - mean_absolute_error: 0.0367 - val_loss: 0.0107 - val_mean_absolute_error: 0.0365 - 145ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.0145 - mean_absolute_error: 0.0394 - val_loss: 0.0261 - val_mean_absolute_error: 0.0435 - 143ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.0179 - mean_absolute_error: 0.0492 - val_loss: 0.0120 - val_mean_absolute_error: 0.0429 - 145ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.0106 - mean_absolute_error: 0.0339 - val_loss: 0.0221 - val_mean_absolute_error: 0.0602 - 149ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.0172 - mean_absolute_error: 0.0548 - val_loss: 0.0155 - val_mean_absolute_error: 0.0530 - 147ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0412 - val_loss: 0.0127 - val_mean_absolute_error: 0.0413 - 148ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.0161 - mean_absolute_error: 0.0460 - val_loss: 0.0218 - val_mean_absolute_error: 0.0613 - 148ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.0192 - mean_absolute_error: 0.0480 - val_loss: 0.0200 - val_mean_absolute_error: 0.0566 - 147ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.0205 - mean_absolute_error: 0.0561 - val_loss: 0.0184 - val_mean_absolute_error: 0.0478 - 146ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.0129 - mean_absolute_error: 0.0392 - val_loss: 0.0135 - val_mean_absolute_error: 0.0449 - 154ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.0119 - mean_absolute_error: 0.0374 - val_loss: 0.0113 - val_mean_absolute_error: 0.0375 - 150ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.0135 - mean_absolute_error: 0.0368 - val_loss: 0.0119 - val_mean_absolute_error: 0.0398 - 149ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.0145 - mean_absolute_error: 0.0383 - val_loss: 0.0155 - val_mean_absolute_error: 0.0438 - 148ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.0118 - mean_absolute_error: 0.0370 - val_loss: 0.0118 - val_mean_absolute_error: 0.0416 - 146ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.0154 - mean_absolute_error: 0.0463 - val_loss: 0.0167 - val_mean_absolute_error: 0.0409 - 155ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.0145 - mean_absolute_error: 0.0440 - val_loss: 0.0139 - val_mean_absolute_error: 0.0476 - 149ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.0179 - mean_absolute_error: 0.0476 - val_loss: 0.0208 - val_mean_absolute_error: 0.0578 - 149ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.0156 - mean_absolute_error: 0.0434 - val_loss: 0.0131 - val_mean_absolute_error: 0.0398 - 145ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.0110 - mean_absolute_error: 0.0304 - val_loss: 0.0413 - val_mean_absolute_error: 0.0517 - 156ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.0209 - mean_absolute_error: 0.0494 - val_loss: 0.0177 - val_mean_absolute_error: 0.0639 - 149ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.0159 - mean_absolute_error: 0.0461 - val_loss: 0.0176 - val_mean_absolute_error: 0.0454 - 147ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.0129 - mean_absolute_error: 0.0342 - val_loss: 0.0173 - val_mean_absolute_error: 0.0385 - 150ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.0100 - mean_absolute_error: 0.0291 - val_loss: 0.0109 - val_mean_absolute_error: 0.0417 - 149ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.0142 - mean_absolute_error: 0.0358 - val_loss: 0.0169 - val_mean_absolute_error: 0.0422 - 147ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.0101 - mean_absolute_error: 0.0322 - val_loss: 0.0113 - val_mean_absolute_error: 0.0342 - 145ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0326 - val_loss: 0.0152 - val_mean_absolute_error: 0.0496 - 145ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.0135 - mean_absolute_error: 0.0426 - val_loss: 0.0154 - val_mean_absolute_error: 0.0458 - 146ms/epoch - 2ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.0103 - mean_absolute_error: 0.0322 - val_loss: 0.0119 - val_mean_absolute_error: 0.0404 - 145ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.0142 - mean_absolute_error: 0.0434 - val_loss: 0.0124 - val_mean_absolute_error: 0.0421 - 144ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.0101 - mean_absolute_error: 0.0320 - val_loss: 0.0113 - val_mean_absolute_error: 0.0388 - 144ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.0126 - mean_absolute_error: 0.0359 - val_loss: 0.0248 - val_mean_absolute_error: 0.0435 - 144ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.0127 - mean_absolute_error: 0.0357 - val_loss: 0.0133 - val_mean_absolute_error: 0.0371 - 147ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.0126 - mean_absolute_error: 0.0351 - val_loss: 0.0134 - val_mean_absolute_error: 0.0452 - 145ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.0152 - mean_absolute_error: 0.0414 - val_loss: 0.0123 - val_mean_absolute_error: 0.0473 - 147ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.0154 - mean_absolute_error: 0.0455 - val_loss: 0.0145 - val_mean_absolute_error: 0.0455 - 150ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.0117 - mean_absolute_error: 0.0326 - val_loss: 0.0221 - val_mean_absolute_error: 0.0426 - 147ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.0168 - mean_absolute_error: 0.0431 - val_loss: 0.0205 - val_mean_absolute_error: 0.0601 - 144ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.0153 - mean_absolute_error: 0.0430 - val_loss: 0.0227 - val_mean_absolute_error: 0.0511 - 146ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.0182 - mean_absolute_error: 0.0485 - val_loss: 0.0146 - val_mean_absolute_error: 0.0482 - 146ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.0151 - mean_absolute_error: 0.0430 - val_loss: 0.0145 - val_mean_absolute_error: 0.0478 - 144ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.0158 - mean_absolute_error: 0.0451 - val_loss: 0.0154 - val_mean_absolute_error: 0.0446 - 150ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.0164 - mean_absolute_error: 0.0438 - val_loss: 0.0121 - val_mean_absolute_error: 0.0385 - 145ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0335 - val_loss: 0.0201 - val_mean_absolute_error: 0.0437 - 143ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0403 - val_loss: 0.0126 - val_mean_absolute_error: 0.0406 - 144ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.0106 - mean_absolute_error: 0.0301 - val_loss: 0.0144 - val_mean_absolute_error: 0.0374 - 144ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.0140 - mean_absolute_error: 0.0362 - val_loss: 0.0285 - val_mean_absolute_error: 0.0470 - 151ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.0104 - mean_absolute_error: 0.0333 - val_loss: 0.0116 - val_mean_absolute_error: 0.0359 - 148ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.0141 - mean_absolute_error: 0.0407 - val_loss: 0.0121 - val_mean_absolute_error: 0.0381 - 144ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.0147 - mean_absolute_error: 0.0387 - val_loss: 0.0271 - val_mean_absolute_error: 0.0410 - 145ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0368 - val_loss: 0.0185 - val_mean_absolute_error: 0.0473 - 143ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.0182 - mean_absolute_error: 0.0460 - val_loss: 0.0193 - val_mean_absolute_error: 0.0563 - 141ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.0144 - mean_absolute_error: 0.0421 - val_loss: 0.0137 - val_mean_absolute_error: 0.0409 - 147ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.0135 - mean_absolute_error: 0.0367 - val_loss: 0.0117 - val_mean_absolute_error: 0.0421 - 144ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.0127 - mean_absolute_error: 0.0367 - val_loss: 0.0111 - val_mean_absolute_error: 0.0362 - 143ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.0094 - mean_absolute_error: 0.0278 - val_loss: 0.0095 - val_mean_absolute_error: 0.0309 - 144ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.0124 - mean_absolute_error: 0.0351 - val_loss: 0.0221 - val_mean_absolute_error: 0.0465 - 146ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.0104 - mean_absolute_error: 0.0327 - val_loss: 0.0099 - val_mean_absolute_error: 0.0384 - 144ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.0108 - mean_absolute_error: 0.0334 - val_loss: 0.0232 - val_mean_absolute_error: 0.0525 - 144ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.0155 - mean_absolute_error: 0.0442 - val_loss: 0.0267 - val_mean_absolute_error: 0.0443 - 144ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.0116 - mean_absolute_error: 0.0332 - val_loss: 0.0209 - val_mean_absolute_error: 0.0379 - 146ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.0106 - mean_absolute_error: 0.0294 - val_loss: 0.0146 - val_mean_absolute_error: 0.0407 - 145ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0408 - val_loss: 0.0277 - val_mean_absolute_error: 0.0492 - 146ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.0200 - mean_absolute_error: 0.0532 - val_loss: 0.0155 - val_mean_absolute_error: 0.0535 - 145ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.0130 - mean_absolute_error: 0.0415 - val_loss: 0.0206 - val_mean_absolute_error: 0.0466 - 146ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0346 - val_loss: 0.0389 - val_mean_absolute_error: 0.0669 - 146ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.0177 - mean_absolute_error: 0.0451 - val_loss: 0.0103 - val_mean_absolute_error: 0.0355 - 146ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.0108 - mean_absolute_error: 0.0345 - val_loss: 0.0151 - val_mean_absolute_error: 0.0377 - 149ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.0144 - mean_absolute_error: 0.0378 - val_loss: 0.0145 - val_mean_absolute_error: 0.0485 - 146ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.0094 - mean_absolute_error: 0.0330 - val_loss: 0.0250 - val_mean_absolute_error: 0.0412 - 146ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.0156 - mean_absolute_error: 0.0403 - val_loss: 0.0115 - val_mean_absolute_error: 0.0468 - 147ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.0164 - mean_absolute_error: 0.0422 - val_loss: 0.0154 - val_mean_absolute_error: 0.0373 - 150ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.0110 - mean_absolute_error: 0.0318 - val_loss: 0.0112 - val_mean_absolute_error: 0.0375 - 145ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.0127 - mean_absolute_error: 0.0340 - val_loss: 0.0158 - val_mean_absolute_error: 0.0426 - 148ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.0106 - mean_absolute_error: 0.0310 - val_loss: 0.0149 - val_mean_absolute_error: 0.0377 - 149ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.0124 - mean_absolute_error: 0.0352 - val_loss: 0.0104 - val_mean_absolute_error: 0.0391 - 146ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0381 - val_loss: 0.0161 - val_mean_absolute_error: 0.0367 - 148ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.0155 - mean_absolute_error: 0.0399 - val_loss: 0.0136 - val_mean_absolute_error: 0.0426 - 147ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.0126 - mean_absolute_error: 0.0345 - val_loss: 0.0103 - val_mean_absolute_error: 0.0336 - 145ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.0127 - mean_absolute_error: 0.0346 - val_loss: 0.0164 - val_mean_absolute_error: 0.0422 - 146ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.0129 - mean_absolute_error: 0.0329 - val_loss: 0.0172 - val_mean_absolute_error: 0.0426 - 159ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.0150 - mean_absolute_error: 0.0390 - val_loss: 0.0149 - val_mean_absolute_error: 0.0525 - 148ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.0160 - mean_absolute_error: 0.0430 - val_loss: 0.0126 - val_mean_absolute_error: 0.0403 - 153ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.0112 - mean_absolute_error: 0.0337 - val_loss: 0.0117 - val_mean_absolute_error: 0.0438 - 149ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0396 - val_loss: 0.0114 - val_mean_absolute_error: 0.0408 - 146ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.0088 - mean_absolute_error: 0.0327 - val_loss: 0.0202 - val_mean_absolute_error: 0.0454 - 148ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.0136 - mean_absolute_error: 0.0383 - val_loss: 0.0135 - val_mean_absolute_error: 0.0398 - 147ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.0103 - mean_absolute_error: 0.0308 - val_loss: 0.0130 - val_mean_absolute_error: 0.0408 - 147ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.0137 - mean_absolute_error: 0.0355 - val_loss: 0.0126 - val_mean_absolute_error: 0.0400 - 145ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.0137 - mean_absolute_error: 0.0361 - val_loss: 0.0126 - val_mean_absolute_error: 0.0406 - 145ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.0137 - mean_absolute_error: 0.0368 - val_loss: 0.0136 - val_mean_absolute_error: 0.0397 - 144ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.0107 - mean_absolute_error: 0.0309 - val_loss: 0.0228 - val_mean_absolute_error: 0.0438 - 143ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.0136 - mean_absolute_error: 0.0340 - val_loss: 0.0307 - val_mean_absolute_error: 0.0490 - 143ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.0114 - mean_absolute_error: 0.0333 - val_loss: 0.0255 - val_mean_absolute_error: 0.0442 - 145ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.0116 - mean_absolute_error: 0.0360 - val_loss: 0.0131 - val_mean_absolute_error: 0.0459 - 146ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.0140 - mean_absolute_error: 0.0407 - val_loss: 0.0110 - val_mean_absolute_error: 0.0371 - 148ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.0144 - mean_absolute_error: 0.0359 - val_loss: 0.0210 - val_mean_absolute_error: 0.0635 - 146ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.0126 - mean_absolute_error: 0.0382 - val_loss: 0.0117 - val_mean_absolute_error: 0.0444 - 148ms/epoch - 2ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.0129 - mean_absolute_error: 0.0417 - val_loss: 0.0117 - val_mean_absolute_error: 0.0399 - 145ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.0135 - mean_absolute_error: 0.0364 - val_loss: 0.0151 - val_mean_absolute_error: 0.0401 - 145ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.0114 - mean_absolute_error: 0.0318 - val_loss: 0.0185 - val_mean_absolute_error: 0.0523 - 149ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.0135 - mean_absolute_error: 0.0443 - val_loss: 0.0121 - val_mean_absolute_error: 0.0493 - 148ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.0132 - mean_absolute_error: 0.0400 - val_loss: 0.0177 - val_mean_absolute_error: 0.0470 - 144ms/epoch - 2ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.0109 - mean_absolute_error: 0.0324 - val_loss: 0.0124 - val_mean_absolute_error: 0.0364 - 146ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.0132 - mean_absolute_error: 0.0375 - val_loss: 0.0230 - val_mean_absolute_error: 0.0454 - 146ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.0141 - mean_absolute_error: 0.0409 - val_loss: 0.0137 - val_mean_absolute_error: 0.0421 - 148ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.0190 - mean_absolute_error: 0.0495 - val_loss: 0.0303 - val_mean_absolute_error: 0.0585 - 149ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.0166 - mean_absolute_error: 0.0418 - val_loss: 0.0127 - val_mean_absolute_error: 0.0413 - 152ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.0114 - mean_absolute_error: 0.0311 - val_loss: 0.0121 - val_mean_absolute_error: 0.0354 - 148ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0336 - val_loss: 0.0125 - val_mean_absolute_error: 0.0448 - 148ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.0110 - mean_absolute_error: 0.0329 - val_loss: 0.0166 - val_mean_absolute_error: 0.0453 - 145ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.0096 - mean_absolute_error: 0.0289 - val_loss: 0.0126 - val_mean_absolute_error: 0.0326 - 145ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0323 - val_loss: 0.0120 - val_mean_absolute_error: 0.0401 - 142ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.0162 - mean_absolute_error: 0.0402 - val_loss: 0.0229 - val_mean_absolute_error: 0.0499 - 146ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.0140 - mean_absolute_error: 0.0411 - val_loss: 0.0125 - val_mean_absolute_error: 0.0460 - 145ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.0210 - mean_absolute_error: 0.0496 - val_loss: 0.0211 - val_mean_absolute_error: 0.0535 - 144ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.0172 - mean_absolute_error: 0.0479 - val_loss: 0.0117 - val_mean_absolute_error: 0.0453 - 145ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.0141 - mean_absolute_error: 0.0394 - val_loss: 0.0208 - val_mean_absolute_error: 0.0586 - 147ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.0120 - mean_absolute_error: 0.0368 - val_loss: 0.0165 - val_mean_absolute_error: 0.0442 - 144ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.0104 - mean_absolute_error: 0.0304 - val_loss: 0.0167 - val_mean_absolute_error: 0.0363 - 144ms/epoch - 2ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.0132 - mean_absolute_error: 0.0353 - val_loss: 0.0139 - val_mean_absolute_error: 0.0418 - 142ms/epoch - 2ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.0125 - mean_absolute_error: 0.0360 - val_loss: 0.0100 - val_mean_absolute_error: 0.0332 - 145ms/epoch - 2ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.0129 - mean_absolute_error: 0.0320 - val_loss: 0.0141 - val_mean_absolute_error: 0.0375 - 145ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0354 - val_loss: 0.0168 - val_mean_absolute_error: 0.0384 - 145ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.0146 - mean_absolute_error: 0.0390 - val_loss: 0.0154 - val_mean_absolute_error: 0.0507 - 146ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0368 - val_loss: 0.0167 - val_mean_absolute_error: 0.0412 - 145ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.0098 - mean_absolute_error: 0.0301 - val_loss: 0.0123 - val_mean_absolute_error: 0.0357 - 146ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.0141 - mean_absolute_error: 0.0366 - val_loss: 0.0128 - val_mean_absolute_error: 0.0398 - 144ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0355 - val_loss: 0.0175 - val_mean_absolute_error: 0.0394 - 144ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.0111 - mean_absolute_error: 0.0334 - val_loss: 0.0115 - val_mean_absolute_error: 0.0373 - 147ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.0139 - mean_absolute_error: 0.0325 - val_loss: 0.0135 - val_mean_absolute_error: 0.0382 - 144ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.0189 - mean_absolute_error: 0.0420 - val_loss: 0.0243 - val_mean_absolute_error: 0.0738 - 146ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.0159 - mean_absolute_error: 0.0476 - val_loss: 0.0135 - val_mean_absolute_error: 0.0427 - 151ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.0185 - mean_absolute_error: 0.0472 - val_loss: 0.0123 - val_mean_absolute_error: 0.0422 - 148ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.0133 - mean_absolute_error: 0.0369 - val_loss: 0.0137 - val_mean_absolute_error: 0.0464 - 151ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.0174 - mean_absolute_error: 0.0411 - val_loss: 0.0188 - val_mean_absolute_error: 0.0540 - 150ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.0109 - mean_absolute_error: 0.0362 - val_loss: 0.0182 - val_mean_absolute_error: 0.0455 - 147ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.0130 - mean_absolute_error: 0.0366 - val_loss: 0.0137 - val_mean_absolute_error: 0.0432 - 143ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.0105 - mean_absolute_error: 0.0344 - val_loss: 0.0118 - val_mean_absolute_error: 0.0368 - 144ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.0096 - mean_absolute_error: 0.0296 - val_loss: 0.0364 - val_mean_absolute_error: 0.0397 - 145ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.0079 - mean_absolute_error: 0.0274 - val_loss: 0.0458 - val_mean_absolute_error: 0.0424 - 145ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.0054 - mean_absolute_error: 0.0238 - val_loss: 0.0482 - val_mean_absolute_error: 0.0396 - 146ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.0067 - mean_absolute_error: 0.0241 - val_loss: 0.0418 - val_mean_absolute_error: 0.0461 - 146ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.0113 - mean_absolute_error: 0.0323 - val_loss: 0.0336 - val_mean_absolute_error: 0.0436 - 146ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.0076 - mean_absolute_error: 0.0289 - val_loss: 0.0272 - val_mean_absolute_error: 0.0459 - 146ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0369 - val_loss: 0.0514 - val_mean_absolute_error: 0.0404 - 146ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.0130 - mean_absolute_error: 0.0316 - val_loss: 0.1926 - val_mean_absolute_error: 0.0543 - 145ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.0089 - mean_absolute_error: 0.0281 - val_loss: 0.0130 - val_mean_absolute_error: 0.0344 - 148ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.0071 - mean_absolute_error: 0.0247 - val_loss: 0.0196 - val_mean_absolute_error: 0.0347 - 146ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.0130 - mean_absolute_error: 0.0318 - val_loss: 0.0104 - val_mean_absolute_error: 0.0330 - 145ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.0062 - mean_absolute_error: 0.0217 - val_loss: 0.0101 - val_mean_absolute_error: 0.0313 - 146ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.0075 - mean_absolute_error: 0.0247 - val_loss: 0.0124 - val_mean_absolute_error: 0.0331 - 145ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.0107 - mean_absolute_error: 0.0276 - val_loss: 0.0179 - val_mean_absolute_error: 0.0457 - 146ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.0097 - mean_absolute_error: 0.0314 - val_loss: 0.0139 - val_mean_absolute_error: 0.0343 - 149ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.0105 - mean_absolute_error: 0.0279 - val_loss: 0.0106 - val_mean_absolute_error: 0.0334 - 149ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0311 - val_loss: 0.0159 - val_mean_absolute_error: 0.0489 - 148ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.0092 - mean_absolute_error: 0.0296 - val_loss: 0.0143 - val_mean_absolute_error: 0.0320 - 151ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.0094 - mean_absolute_error: 0.0265 - val_loss: 0.0156 - val_mean_absolute_error: 0.0357 - 150ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.0067 - mean_absolute_error: 0.0230 - val_loss: 0.0184 - val_mean_absolute_error: 0.0329 - 148ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.0085 - mean_absolute_error: 0.0257 - val_loss: 0.0210 - val_mean_absolute_error: 0.0480 - 148ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.0115 - mean_absolute_error: 0.0325 - val_loss: 0.0431 - val_mean_absolute_error: 0.0579 - 156ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.0163 - mean_absolute_error: 0.0445 - val_loss: 0.0106 - val_mean_absolute_error: 0.0423 - 147ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.0148 - mean_absolute_error: 0.0453 - val_loss: 0.0125 - val_mean_absolute_error: 0.0409 - 146ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.0098 - mean_absolute_error: 0.0336 - val_loss: 0.0214 - val_mean_absolute_error: 0.0423 - 148ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.0127 - mean_absolute_error: 0.0337 - val_loss: 0.0125 - val_mean_absolute_error: 0.0365 - 146ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.0091 - mean_absolute_error: 0.0282 - val_loss: 0.0157 - val_mean_absolute_error: 0.0390 - 148ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.0093 - mean_absolute_error: 0.0306 - val_loss: 0.0294 - val_mean_absolute_error: 0.0523 - 148ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.0127 - mean_absolute_error: 0.0351 - val_loss: 0.0310 - val_mean_absolute_error: 0.0548 - 146ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0370 - val_loss: 0.0118 - val_mean_absolute_error: 0.0416 - 146ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.0103 - mean_absolute_error: 0.0312 - val_loss: 0.0281 - val_mean_absolute_error: 0.0453 - 146ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.0120 - mean_absolute_error: 0.0300 - val_loss: 0.0249 - val_mean_absolute_error: 0.0499 - 146ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.0097 - mean_absolute_error: 0.0304 - val_loss: 0.0204 - val_mean_absolute_error: 0.0379 - 146ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.0079 - mean_absolute_error: 0.0252 - val_loss: 0.0242 - val_mean_absolute_error: 0.0361 - 146ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.0103 - mean_absolute_error: 0.0292 - val_loss: 0.0291 - val_mean_absolute_error: 0.0402 - 144ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.0071 - mean_absolute_error: 0.0242 - val_loss: 0.0205 - val_mean_absolute_error: 0.0369 - 146ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.0142 - mean_absolute_error: 0.0374 - val_loss: 0.0267 - val_mean_absolute_error: 0.0385 - 144ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.0085 - mean_absolute_error: 0.0271 - val_loss: 0.0312 - val_mean_absolute_error: 0.0349 - 145ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.0102 - mean_absolute_error: 0.0260 - val_loss: 0.0401 - val_mean_absolute_error: 0.0408 - 147ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.0106 - mean_absolute_error: 0.0274 - val_loss: 0.0512 - val_mean_absolute_error: 0.0441 - 145ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.0078 - mean_absolute_error: 0.0248 - val_loss: 0.0575 - val_mean_absolute_error: 0.0436 - 148ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.0101 - mean_absolute_error: 0.0294 - val_loss: 0.0487 - val_mean_absolute_error: 0.0384 - 145ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.0079 - mean_absolute_error: 0.0256 - val_loss: 0.0706 - val_mean_absolute_error: 0.0409 - 145ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.0082 - mean_absolute_error: 0.0256 - val_loss: 0.0552 - val_mean_absolute_error: 0.0404 - 146ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.0108 - mean_absolute_error: 0.0303 - val_loss: 0.0566 - val_mean_absolute_error: 0.0467 - 146ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.0097 - mean_absolute_error: 0.0281 - val_loss: 0.0731 - val_mean_absolute_error: 0.0479 - 146ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.0111 - mean_absolute_error: 0.0327 - val_loss: 0.0650 - val_mean_absolute_error: 0.0401 - 147ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.0091 - mean_absolute_error: 0.0303 - val_loss: 0.0798 - val_mean_absolute_error: 0.0447 - 147ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.0070 - mean_absolute_error: 0.0261 - val_loss: 0.0670 - val_mean_absolute_error: 0.0407 - 170ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.0104 - mean_absolute_error: 0.0285 - val_loss: 0.0764 - val_mean_absolute_error: 0.0575 - 147ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0369 - val_loss: 0.0434 - val_mean_absolute_error: 0.0478 - 148ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.0102 - mean_absolute_error: 0.0291 - val_loss: 0.0504 - val_mean_absolute_error: 0.0474 - 148ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.0106 - mean_absolute_error: 0.0304 - val_loss: 0.0503 - val_mean_absolute_error: 0.0445 - 146ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.0082 - mean_absolute_error: 0.0288 - val_loss: 0.0691 - val_mean_absolute_error: 0.0484 - 148ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.0098 - mean_absolute_error: 0.0278 - val_loss: 0.0274 - val_mean_absolute_error: 0.0396 - 149ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.0106 - mean_absolute_error: 0.0294 - val_loss: 0.0246 - val_mean_absolute_error: 0.0387 - 148ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.0100 - mean_absolute_error: 0.0288 - val_loss: 0.0368 - val_mean_absolute_error: 0.0404 - 151ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.0093 - mean_absolute_error: 0.0295 - val_loss: 0.0276 - val_mean_absolute_error: 0.0401 - 147ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.0092 - mean_absolute_error: 0.0255 - val_loss: 0.0271 - val_mean_absolute_error: 0.0433 - 149ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.0094 - mean_absolute_error: 0.0302 - val_loss: 0.0611 - val_mean_absolute_error: 0.0452 - 147ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.0085 - mean_absolute_error: 0.0294 - val_loss: 0.0747 - val_mean_absolute_error: 0.0523 - 157ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.0071 - mean_absolute_error: 0.0289 - val_loss: 0.0638 - val_mean_absolute_error: 0.0424 - 151ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.0123 - mean_absolute_error: 0.0369 - val_loss: 0.0514 - val_mean_absolute_error: 0.0432 - 148ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0312 - val_loss: 0.0642 - val_mean_absolute_error: 0.0447 - 147ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.0067 - mean_absolute_error: 0.0248 - val_loss: 0.1008 - val_mean_absolute_error: 0.0470 - 148ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.0072 - mean_absolute_error: 0.0248 - val_loss: 0.0912 - val_mean_absolute_error: 0.0534 - 148ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.0123 - mean_absolute_error: 0.0327 - val_loss: 0.0614 - val_mean_absolute_error: 0.0414 - 147ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.0134 - mean_absolute_error: 0.0330 - val_loss: 0.0939 - val_mean_absolute_error: 0.0463 - 147ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.0073 - mean_absolute_error: 0.0251 - val_loss: 0.0989 - val_mean_absolute_error: 0.0441 - 149ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.0149 - mean_absolute_error: 0.0392 - val_loss: 0.0491 - val_mean_absolute_error: 0.0457 - 147ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.0115 - mean_absolute_error: 0.0314 - val_loss: 0.0441 - val_mean_absolute_error: 0.0505 - 145ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.0090 - mean_absolute_error: 0.0297 - val_loss: 0.0233 - val_mean_absolute_error: 0.0402 - 148ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.0090 - mean_absolute_error: 0.0288 - val_loss: 0.0506 - val_mean_absolute_error: 0.0458 - 145ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.0098 - mean_absolute_error: 0.0302 - val_loss: 0.0561 - val_mean_absolute_error: 0.0478 - 147ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.0125 - mean_absolute_error: 0.0336 - val_loss: 0.0694 - val_mean_absolute_error: 0.0461 - 167ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.0105 - mean_absolute_error: 0.0311 - val_loss: 0.0803 - val_mean_absolute_error: 0.0467 - 152ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.0074 - mean_absolute_error: 0.0263 - val_loss: 0.0879 - val_mean_absolute_error: 0.0445 - 149ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.0097 - mean_absolute_error: 0.0267 - val_loss: 0.0728 - val_mean_absolute_error: 0.0434 - 146ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.0116 - mean_absolute_error: 0.0292 - val_loss: 0.0900 - val_mean_absolute_error: 0.0456 - 150ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.0121 - mean_absolute_error: 0.0369 - val_loss: 0.0943 - val_mean_absolute_error: 0.0525 - 149ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.0098 - mean_absolute_error: 0.0295 - val_loss: 0.0698 - val_mean_absolute_error: 0.0491 - 160ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.0092 - mean_absolute_error: 0.0283 - val_loss: 0.0978 - val_mean_absolute_error: 0.0415 - 145ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.0075 - mean_absolute_error: 0.0259 - val_loss: 0.0912 - val_mean_absolute_error: 0.0449 - 145ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.0114 - mean_absolute_error: 0.0317 - val_loss: 0.1000 - val_mean_absolute_error: 0.0506 - 146ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.0115 - mean_absolute_error: 0.0311 - val_loss: 0.0846 - val_mean_absolute_error: 0.0474 - 150ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.0068 - mean_absolute_error: 0.0243 - val_loss: 0.1052 - val_mean_absolute_error: 0.0449 - 150ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.0103 - mean_absolute_error: 0.0293 - val_loss: 0.0808 - val_mean_absolute_error: 0.0495 - 148ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.0131 - mean_absolute_error: 0.0383 - val_loss: 0.0215 - val_mean_absolute_error: 0.0370 - 147ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.0099 - mean_absolute_error: 0.0301 - val_loss: 0.0278 - val_mean_absolute_error: 0.0403 - 156ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.0115 - mean_absolute_error: 0.0296 - val_loss: 0.0318 - val_mean_absolute_error: 0.0444 - 145ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.0075 - mean_absolute_error: 0.0243 - val_loss: 0.0358 - val_mean_absolute_error: 0.0395 - 147ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.0119 - mean_absolute_error: 0.0320 - val_loss: 0.0350 - val_mean_absolute_error: 0.0537 - 147ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.0113 - mean_absolute_error: 0.0323 - val_loss: 0.0448 - val_mean_absolute_error: 0.0401 - 148ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.0128 - mean_absolute_error: 0.0301 - val_loss: 0.0525 - val_mean_absolute_error: 0.0522 - 164ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.0093 - mean_absolute_error: 0.0314 - val_loss: 0.0409 - val_mean_absolute_error: 0.0390 - 146ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.0096 - mean_absolute_error: 0.0290 - val_loss: 0.0524 - val_mean_absolute_error: 0.0441 - 151ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.0099 - mean_absolute_error: 0.0284 - val_loss: 0.0701 - val_mean_absolute_error: 0.0390 - 146ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.0094 - mean_absolute_error: 0.0254 - val_loss: 0.0857 - val_mean_absolute_error: 0.0416 - 148ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.0090 - mean_absolute_error: 0.0255 - val_loss: 0.0935 - val_mean_absolute_error: 0.0416 - 148ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.0089 - mean_absolute_error: 0.0244 - val_loss: 0.0647 - val_mean_absolute_error: 0.0586 - 147ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.0130 - mean_absolute_error: 0.0372 - val_loss: 0.0519 - val_mean_absolute_error: 0.0434 - 150ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.0088 - mean_absolute_error: 0.0298 - val_loss: 0.0455 - val_mean_absolute_error: 0.0390 - 153ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.0075 - mean_absolute_error: 0.0250 - val_loss: 0.0297 - val_mean_absolute_error: 0.0394 - 149ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.0095 - mean_absolute_error: 0.0261 - val_loss: 0.0263 - val_mean_absolute_error: 0.0403 - 148ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.0077 - mean_absolute_error: 0.0283 - val_loss: 0.0386 - val_mean_absolute_error: 0.0353 - 150ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.0118 - mean_absolute_error: 0.0292 - val_loss: 0.0469 - val_mean_absolute_error: 0.0429 - 148ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.0081 - mean_absolute_error: 0.0262 - val_loss: 0.0466 - val_mean_absolute_error: 0.0435 - 145ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_noNoise_five(k-1e-3&gamma-1e-3).keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE 0.04657711461186409
# MAE: 0.04354993253946304
# 32/32 [==============================] - 0s 793us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\Delta E$', r'g']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(2,1, figsize=(9,15))

fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
DeltaE_pred = y_pred_denorm[:, 0]
DeltaE_val = y_val_denorm[:, 0]
g_pred = y_pred_denorm[:, 1]
g_val = y_val_denorm[:, 1]


t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val = np.zeros((x_val.shape[0], len(w_values)))


for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k, Omega, DeltaE_pred[i], gamma, g_pred[i])
    t_values_val[i,:] = t_w(w_values, k, Omega, DeltaE_val[i], gamma, g_val[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k, Omega, DeltaE_val, gamma, g_val)
w2=w_2(k, Omega, DeltaE_val, gamma, g_val)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"ΔE real = {DeltaE_val[i]:.7f}, ΔE pred = {DeltaE_pred[i]:.7f}\n"\
            f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %% [markdown]
# # With noise

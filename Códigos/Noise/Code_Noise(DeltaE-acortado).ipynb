# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos t($\omega$):
# $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # With noise

# %% [markdown]
# ## Creamos base de datos

# %%
# Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    DeltaE = np.random.uniform(0.9, 1.1, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)

    return k, DeltaE, gamma, g

def add_noise (data, sig):
    return data + np.random.normal(0,sig)

num_datos = 5000

# %%
#Creamos base de datos y guardamos en .txt
k, DeltaE, gamma, g = Parameters_generator (num_datos)

np.savetxt('Parameters_Noise(DeltaE-acortado).txt', np.column_stack((k, DeltaE, gamma, g)), header='\u03BA \u0394E \u213D g')

# %%
datos = np.loadtxt('Parameters_Noise(DeltaE-acortado).txt', skiprows=1)
k = datos[:,0]
DeltaE = datos[:,1]
gamma = datos[:,2]
g = datos[:,3]
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.85, 1.15, 300)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))
t_values_noise = np.zeros((num_datos, len(w_values)))


# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k[i], Omega, DeltaE[i], gamma[i], g[i]) 

for i in range (num_datos):
    t_values_noise[i,:] = [add_noise(t_values[i,j], 0.1*t_values[i,j]*np.random.rand())
                            for j in range(len(w_values))]

# %% [markdown]
# ### Dibujamos las curvas

# %%
# i=4000
# while i<=5000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values_noise[i,:], label='Con ruido', color='blue')
#     plt.plot(w_values, t_values[i,:], label='Original', linewidth=0.75, linestyle='--', color='red')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
indices = np.arange(num_datos)
indices_train, indices_val = train_test_split(indices, test_size=0.2)

x_train = t_values_noise[indices_train]
x_val = t_values_noise[indices_val]
y_train = datos[indices_train]
y_val = datos[indices_val]


# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 300)
# y_train shape (4000, 4)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
model =  Dense_five()

#Fiteamos el modelo
history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
                     epochs=epochs, verbose=2)

# # Definir EarlyStopping
# early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

#Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
model.save('model_Noise_five(DeltaE-acortado).keras') 

# Visualiza la pérdida y la métrica de entrenamiento
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 2s - loss: 0.8846 - mean_absolute_error: 0.7721 - val_loss: 0.8820 - val_mean_absolute_error: 0.7643 - 2s/epoch - 22ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.8248 - mean_absolute_error: 0.7360 - val_loss: 0.8632 - val_mean_absolute_error: 0.7569 - 188ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.7863 - mean_absolute_error: 0.7122 - val_loss: 0.7860 - val_mean_absolute_error: 0.7134 - 163ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.7242 - mean_absolute_error: 0.6754 - val_loss: 0.7344 - val_mean_absolute_error: 0.6862 - 164ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.6399 - mean_absolute_error: 0.6246 - val_loss: 0.6549 - val_mean_absolute_error: 0.6360 - 175ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.5827 - mean_absolute_error: 0.5836 - val_loss: 0.5948 - val_mean_absolute_error: 0.5881 - 204ms/epoch - 3ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.5417 - mean_absolute_error: 0.5571 - val_loss: 0.5886 - val_mean_absolute_error: 0.5900 - 166ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.5176 - mean_absolute_error: 0.5402 - val_loss: 0.5364 - val_mean_absolute_error: 0.5502 - 176ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.4978 - mean_absolute_error: 0.5264 - val_loss: 0.5238 - val_mean_absolute_error: 0.5386 - 144ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.4854 - mean_absolute_error: 0.5152 - val_loss: 0.5203 - val_mean_absolute_error: 0.5388 - 155ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.4650 - mean_absolute_error: 0.5002 - val_loss: 0.4838 - val_mean_absolute_error: 0.5086 - 137ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.4484 - mean_absolute_error: 0.4871 - val_loss: 0.4824 - val_mean_absolute_error: 0.5086 - 149ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.4417 - mean_absolute_error: 0.4846 - val_loss: 0.4656 - val_mean_absolute_error: 0.4958 - 138ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.4342 - mean_absolute_error: 0.4733 - val_loss: 0.4860 - val_mean_absolute_error: 0.5243 - 132ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.4271 - mean_absolute_error: 0.4704 - val_loss: 0.4635 - val_mean_absolute_error: 0.4898 - 134ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.4178 - mean_absolute_error: 0.4618 - val_loss: 0.4507 - val_mean_absolute_error: 0.4797 - 149ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.4186 - mean_absolute_error: 0.4601 - val_loss: 0.4756 - val_mean_absolute_error: 0.4909 - 127ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.4176 - mean_absolute_error: 0.4585 - val_loss: 0.4520 - val_mean_absolute_error: 0.4807 - 128ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.3997 - mean_absolute_error: 0.4430 - val_loss: 0.5107 - val_mean_absolute_error: 0.5049 - 129ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.4056 - mean_absolute_error: 0.4479 - val_loss: 0.4437 - val_mean_absolute_error: 0.4697 - 129ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.3990 - mean_absolute_error: 0.4420 - val_loss: 0.4518 - val_mean_absolute_error: 0.4694 - 127ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.3999 - mean_absolute_error: 0.4404 - val_loss: 0.4274 - val_mean_absolute_error: 0.4565 - 130ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.3900 - mean_absolute_error: 0.4326 - val_loss: 0.4512 - val_mean_absolute_error: 0.4787 - 127ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.3889 - mean_absolute_error: 0.4347 - val_loss: 0.4191 - val_mean_absolute_error: 0.4533 - 150ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.3821 - mean_absolute_error: 0.4265 - val_loss: 0.4266 - val_mean_absolute_error: 0.4553 - 139ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.3764 - mean_absolute_error: 0.4183 - val_loss: 0.4357 - val_mean_absolute_error: 0.4573 - 128ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.3860 - mean_absolute_error: 0.4276 - val_loss: 0.4182 - val_mean_absolute_error: 0.4445 - 137ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.3801 - mean_absolute_error: 0.4221 - val_loss: 0.4260 - val_mean_absolute_error: 0.4482 - 137ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.3883 - mean_absolute_error: 0.4291 - val_loss: 0.4361 - val_mean_absolute_error: 0.4598 - 142ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.3765 - mean_absolute_error: 0.4164 - val_loss: 0.4297 - val_mean_absolute_error: 0.4576 - 151ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.3744 - mean_absolute_error: 0.4161 - val_loss: 0.4334 - val_mean_absolute_error: 0.4522 - 145ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.3701 - mean_absolute_error: 0.4107 - val_loss: 0.4278 - val_mean_absolute_error: 0.4484 - 150ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.3799 - mean_absolute_error: 0.4215 - val_loss: 0.4240 - val_mean_absolute_error: 0.4423 - 148ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.3646 - mean_absolute_error: 0.4061 - val_loss: 0.4217 - val_mean_absolute_error: 0.4418 - 140ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.3679 - mean_absolute_error: 0.4078 - val_loss: 0.4211 - val_mean_absolute_error: 0.4457 - 127ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.3689 - mean_absolute_error: 0.4118 - val_loss: 0.4164 - val_mean_absolute_error: 0.4413 - 128ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.3586 - mean_absolute_error: 0.3990 - val_loss: 0.4631 - val_mean_absolute_error: 0.4591 - 139ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.3779 - mean_absolute_error: 0.4170 - val_loss: 0.4262 - val_mean_absolute_error: 0.4427 - 129ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.3650 - mean_absolute_error: 0.4039 - val_loss: 0.4146 - val_mean_absolute_error: 0.4420 - 127ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.3685 - mean_absolute_error: 0.4077 - val_loss: 0.4138 - val_mean_absolute_error: 0.4361 - 137ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.3492 - mean_absolute_error: 0.3905 - val_loss: 0.4053 - val_mean_absolute_error: 0.4248 - 136ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.3609 - mean_absolute_error: 0.4010 - val_loss: 0.4323 - val_mean_absolute_error: 0.4444 - 132ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.3633 - mean_absolute_error: 0.4004 - val_loss: 0.4111 - val_mean_absolute_error: 0.4331 - 127ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.3560 - mean_absolute_error: 0.3987 - val_loss: 0.4095 - val_mean_absolute_error: 0.4246 - 128ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.3525 - mean_absolute_error: 0.3931 - val_loss: 0.4217 - val_mean_absolute_error: 0.4357 - 127ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.3543 - mean_absolute_error: 0.3940 - val_loss: 0.4299 - val_mean_absolute_error: 0.4453 - 129ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.3515 - mean_absolute_error: 0.3907 - val_loss: 0.4221 - val_mean_absolute_error: 0.4383 - 141ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.3467 - mean_absolute_error: 0.3874 - val_loss: 0.4144 - val_mean_absolute_error: 0.4336 - 142ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.3440 - mean_absolute_error: 0.3849 - val_loss: 0.4225 - val_mean_absolute_error: 0.4376 - 155ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.3422 - mean_absolute_error: 0.3861 - val_loss: 0.4160 - val_mean_absolute_error: 0.4333 - 135ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.3542 - mean_absolute_error: 0.3964 - val_loss: 0.4114 - val_mean_absolute_error: 0.4273 - 141ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.3482 - mean_absolute_error: 0.3935 - val_loss: 0.4176 - val_mean_absolute_error: 0.4340 - 139ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.3421 - mean_absolute_error: 0.3845 - val_loss: 0.4244 - val_mean_absolute_error: 0.4371 - 132ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.3546 - mean_absolute_error: 0.3967 - val_loss: 0.4740 - val_mean_absolute_error: 0.4774 - 138ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.3497 - mean_absolute_error: 0.3956 - val_loss: 0.4234 - val_mean_absolute_error: 0.4364 - 132ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.3420 - mean_absolute_error: 0.3856 - val_loss: 0.4075 - val_mean_absolute_error: 0.4246 - 146ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.3452 - mean_absolute_error: 0.3901 - val_loss: 0.4390 - val_mean_absolute_error: 0.4505 - 165ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.3390 - mean_absolute_error: 0.3851 - val_loss: 0.4035 - val_mean_absolute_error: 0.4185 - 128ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.3367 - mean_absolute_error: 0.3880 - val_loss: 0.4170 - val_mean_absolute_error: 0.4366 - 127ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.3265 - mean_absolute_error: 0.3752 - val_loss: 0.4225 - val_mean_absolute_error: 0.4410 - 129ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.3415 - mean_absolute_error: 0.3890 - val_loss: 0.4327 - val_mean_absolute_error: 0.4522 - 130ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.3247 - mean_absolute_error: 0.3742 - val_loss: 0.4058 - val_mean_absolute_error: 0.4270 - 141ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.3252 - mean_absolute_error: 0.3758 - val_loss: 0.4229 - val_mean_absolute_error: 0.4315 - 129ms/epoch - 2ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.3286 - mean_absolute_error: 0.3797 - val_loss: 0.4156 - val_mean_absolute_error: 0.4256 - 132ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.3193 - mean_absolute_error: 0.3670 - val_loss: 0.4016 - val_mean_absolute_error: 0.4224 - 131ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.3191 - mean_absolute_error: 0.3712 - val_loss: 0.4181 - val_mean_absolute_error: 0.4285 - 127ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.3157 - mean_absolute_error: 0.3672 - val_loss: 0.4145 - val_mean_absolute_error: 0.4277 - 126ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.3138 - mean_absolute_error: 0.3651 - val_loss: 0.4280 - val_mean_absolute_error: 0.4402 - 126ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.3155 - mean_absolute_error: 0.3687 - val_loss: 0.4057 - val_mean_absolute_error: 0.4238 - 125ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.3180 - mean_absolute_error: 0.3721 - val_loss: 0.3983 - val_mean_absolute_error: 0.4166 - 131ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.3063 - mean_absolute_error: 0.3593 - val_loss: 0.4087 - val_mean_absolute_error: 0.4204 - 141ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.3060 - mean_absolute_error: 0.3597 - val_loss: 0.4022 - val_mean_absolute_error: 0.4190 - 133ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.3213 - mean_absolute_error: 0.3732 - val_loss: 0.4047 - val_mean_absolute_error: 0.4187 - 130ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.3046 - mean_absolute_error: 0.3604 - val_loss: 0.4037 - val_mean_absolute_error: 0.4182 - 127ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.3040 - mean_absolute_error: 0.3603 - val_loss: 0.4058 - val_mean_absolute_error: 0.4281 - 126ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.3104 - mean_absolute_error: 0.3684 - val_loss: 0.4275 - val_mean_absolute_error: 0.4343 - 125ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.3042 - mean_absolute_error: 0.3599 - val_loss: 0.4043 - val_mean_absolute_error: 0.4220 - 126ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.2960 - mean_absolute_error: 0.3541 - val_loss: 0.3909 - val_mean_absolute_error: 0.4132 - 127ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.2907 - mean_absolute_error: 0.3495 - val_loss: 0.4158 - val_mean_absolute_error: 0.4212 - 151ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.2837 - mean_absolute_error: 0.3454 - val_loss: 0.4294 - val_mean_absolute_error: 0.4381 - 156ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.2897 - mean_absolute_error: 0.3505 - val_loss: 0.3966 - val_mean_absolute_error: 0.4157 - 130ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.2835 - mean_absolute_error: 0.3477 - val_loss: 0.3869 - val_mean_absolute_error: 0.4085 - 127ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.2791 - mean_absolute_error: 0.3427 - val_loss: 0.4034 - val_mean_absolute_error: 0.4150 - 130ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.2783 - mean_absolute_error: 0.3418 - val_loss: 0.4049 - val_mean_absolute_error: 0.4158 - 131ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.2761 - mean_absolute_error: 0.3394 - val_loss: 0.4091 - val_mean_absolute_error: 0.4168 - 129ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.2797 - mean_absolute_error: 0.3432 - val_loss: 0.4039 - val_mean_absolute_error: 0.4181 - 126ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.2729 - mean_absolute_error: 0.3414 - val_loss: 0.4086 - val_mean_absolute_error: 0.4226 - 127ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.2743 - mean_absolute_error: 0.3404 - val_loss: 0.4128 - val_mean_absolute_error: 0.4247 - 138ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.2626 - mean_absolute_error: 0.3304 - val_loss: 0.4030 - val_mean_absolute_error: 0.4131 - 141ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.2678 - mean_absolute_error: 0.3364 - val_loss: 0.4044 - val_mean_absolute_error: 0.4158 - 127ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.2603 - mean_absolute_error: 0.3305 - val_loss: 0.4149 - val_mean_absolute_error: 0.4175 - 126ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.2579 - mean_absolute_error: 0.3278 - val_loss: 0.4087 - val_mean_absolute_error: 0.4152 - 126ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.2760 - mean_absolute_error: 0.3410 - val_loss: 0.3942 - val_mean_absolute_error: 0.4141 - 126ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.2530 - mean_absolute_error: 0.3244 - val_loss: 0.4034 - val_mean_absolute_error: 0.4132 - 129ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.2555 - mean_absolute_error: 0.3250 - val_loss: 0.4206 - val_mean_absolute_error: 0.4256 - 129ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.2561 - mean_absolute_error: 0.3287 - val_loss: 0.4168 - val_mean_absolute_error: 0.4207 - 132ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.2526 - mean_absolute_error: 0.3259 - val_loss: 0.3984 - val_mean_absolute_error: 0.4075 - 152ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.2417 - mean_absolute_error: 0.3157 - val_loss: 0.3952 - val_mean_absolute_error: 0.4111 - 132ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.2480 - mean_absolute_error: 0.3235 - val_loss: 0.4045 - val_mean_absolute_error: 0.4122 - 130ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.2434 - mean_absolute_error: 0.3194 - val_loss: 0.3995 - val_mean_absolute_error: 0.4104 - 127ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.2431 - mean_absolute_error: 0.3201 - val_loss: 0.3975 - val_mean_absolute_error: 0.4134 - 128ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.2404 - mean_absolute_error: 0.3190 - val_loss: 0.3948 - val_mean_absolute_error: 0.4068 - 138ms/epoch - 2ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.2373 - mean_absolute_error: 0.3146 - val_loss: 0.4097 - val_mean_absolute_error: 0.4097 - 136ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.2377 - mean_absolute_error: 0.3160 - val_loss: 0.3916 - val_mean_absolute_error: 0.4048 - 145ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.2307 - mean_absolute_error: 0.3110 - val_loss: 0.3981 - val_mean_absolute_error: 0.4087 - 127ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.2426 - mean_absolute_error: 0.3170 - val_loss: 0.4073 - val_mean_absolute_error: 0.4139 - 131ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.2278 - mean_absolute_error: 0.3056 - val_loss: 0.4184 - val_mean_absolute_error: 0.4171 - 131ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.2311 - mean_absolute_error: 0.3120 - val_loss: 0.4147 - val_mean_absolute_error: 0.4185 - 126ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.2256 - mean_absolute_error: 0.3051 - val_loss: 0.4058 - val_mean_absolute_error: 0.4041 - 128ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.2191 - mean_absolute_error: 0.2993 - val_loss: 0.4027 - val_mean_absolute_error: 0.4065 - 132ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.2291 - mean_absolute_error: 0.3098 - val_loss: 0.4010 - val_mean_absolute_error: 0.4127 - 127ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.2148 - mean_absolute_error: 0.2985 - val_loss: 0.4043 - val_mean_absolute_error: 0.4063 - 126ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.2193 - mean_absolute_error: 0.3029 - val_loss: 0.4025 - val_mean_absolute_error: 0.4078 - 126ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.2210 - mean_absolute_error: 0.3035 - val_loss: 0.4101 - val_mean_absolute_error: 0.4179 - 127ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.2124 - mean_absolute_error: 0.2995 - val_loss: 0.3972 - val_mean_absolute_error: 0.4071 - 152ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.2068 - mean_absolute_error: 0.2908 - val_loss: 0.3945 - val_mean_absolute_error: 0.4076 - 124ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.2295 - mean_absolute_error: 0.3107 - val_loss: 0.4214 - val_mean_absolute_error: 0.4143 - 133ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.2056 - mean_absolute_error: 0.2895 - val_loss: 0.4147 - val_mean_absolute_error: 0.4163 - 142ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.2103 - mean_absolute_error: 0.2947 - val_loss: 0.3978 - val_mean_absolute_error: 0.4033 - 131ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.2083 - mean_absolute_error: 0.2931 - val_loss: 0.4040 - val_mean_absolute_error: 0.4176 - 126ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.2050 - mean_absolute_error: 0.2915 - val_loss: 0.4489 - val_mean_absolute_error: 0.4311 - 128ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.2017 - mean_absolute_error: 0.2899 - val_loss: 0.4149 - val_mean_absolute_error: 0.4104 - 140ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.2149 - mean_absolute_error: 0.2969 - val_loss: 0.4136 - val_mean_absolute_error: 0.4219 - 138ms/epoch - 2ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.2033 - mean_absolute_error: 0.2904 - val_loss: 0.4168 - val_mean_absolute_error: 0.4134 - 140ms/epoch - 2ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.1976 - mean_absolute_error: 0.2821 - val_loss: 0.4117 - val_mean_absolute_error: 0.4133 - 138ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.2024 - mean_absolute_error: 0.2877 - val_loss: 0.4149 - val_mean_absolute_error: 0.4095 - 142ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.1916 - mean_absolute_error: 0.2784 - val_loss: 0.4221 - val_mean_absolute_error: 0.4140 - 147ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.1974 - mean_absolute_error: 0.2836 - val_loss: 0.4297 - val_mean_absolute_error: 0.4230 - 146ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.1998 - mean_absolute_error: 0.2859 - val_loss: 0.4456 - val_mean_absolute_error: 0.4251 - 134ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.1925 - mean_absolute_error: 0.2790 - val_loss: 0.4127 - val_mean_absolute_error: 0.4059 - 124ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.1938 - mean_absolute_error: 0.2808 - val_loss: 0.4219 - val_mean_absolute_error: 0.4147 - 125ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.1865 - mean_absolute_error: 0.2749 - val_loss: 0.4270 - val_mean_absolute_error: 0.4132 - 126ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.1971 - mean_absolute_error: 0.2840 - val_loss: 0.4670 - val_mean_absolute_error: 0.4267 - 126ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.1875 - mean_absolute_error: 0.2747 - val_loss: 0.4161 - val_mean_absolute_error: 0.4096 - 127ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.1853 - mean_absolute_error: 0.2763 - val_loss: 0.4095 - val_mean_absolute_error: 0.4069 - 127ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.1824 - mean_absolute_error: 0.2736 - val_loss: 0.4042 - val_mean_absolute_error: 0.4001 - 125ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.1796 - mean_absolute_error: 0.2709 - val_loss: 0.4299 - val_mean_absolute_error: 0.4128 - 126ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.1858 - mean_absolute_error: 0.2727 - val_loss: 0.4177 - val_mean_absolute_error: 0.4042 - 128ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.1711 - mean_absolute_error: 0.2616 - val_loss: 0.3996 - val_mean_absolute_error: 0.3957 - 130ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.1769 - mean_absolute_error: 0.2681 - val_loss: 0.4280 - val_mean_absolute_error: 0.4172 - 127ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.1835 - mean_absolute_error: 0.2743 - val_loss: 0.4202 - val_mean_absolute_error: 0.4126 - 129ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.1869 - mean_absolute_error: 0.2789 - val_loss: 0.4119 - val_mean_absolute_error: 0.4080 - 126ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.1854 - mean_absolute_error: 0.2749 - val_loss: 0.4267 - val_mean_absolute_error: 0.4137 - 126ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.1766 - mean_absolute_error: 0.2656 - val_loss: 0.4093 - val_mean_absolute_error: 0.4039 - 128ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.1688 - mean_absolute_error: 0.2595 - val_loss: 0.4216 - val_mean_absolute_error: 0.4146 - 143ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.1741 - mean_absolute_error: 0.2637 - val_loss: 0.4220 - val_mean_absolute_error: 0.4099 - 128ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.1705 - mean_absolute_error: 0.2613 - val_loss: 0.4080 - val_mean_absolute_error: 0.4013 - 153ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.1707 - mean_absolute_error: 0.2612 - val_loss: 0.4342 - val_mean_absolute_error: 0.4152 - 176ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.1755 - mean_absolute_error: 0.2648 - val_loss: 0.4458 - val_mean_absolute_error: 0.4361 - 129ms/epoch - 2ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.1787 - mean_absolute_error: 0.2713 - val_loss: 0.4241 - val_mean_absolute_error: 0.4086 - 128ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.1672 - mean_absolute_error: 0.2585 - val_loss: 0.4171 - val_mean_absolute_error: 0.4130 - 128ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.1647 - mean_absolute_error: 0.2569 - val_loss: 0.4136 - val_mean_absolute_error: 0.4015 - 126ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.1579 - mean_absolute_error: 0.2492 - val_loss: 0.4105 - val_mean_absolute_error: 0.3997 - 128ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.1621 - mean_absolute_error: 0.2531 - val_loss: 0.4521 - val_mean_absolute_error: 0.4280 - 126ms/epoch - 2ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.1732 - mean_absolute_error: 0.2633 - val_loss: 0.4251 - val_mean_absolute_error: 0.4091 - 143ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.1597 - mean_absolute_error: 0.2525 - val_loss: 0.4164 - val_mean_absolute_error: 0.4016 - 155ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.1608 - mean_absolute_error: 0.2525 - val_loss: 0.4178 - val_mean_absolute_error: 0.4002 - 166ms/epoch - 2ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.1666 - mean_absolute_error: 0.2585 - val_loss: 0.4053 - val_mean_absolute_error: 0.4045 - 154ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.1605 - mean_absolute_error: 0.2524 - val_loss: 0.4215 - val_mean_absolute_error: 0.4039 - 140ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.1612 - mean_absolute_error: 0.2537 - val_loss: 0.4298 - val_mean_absolute_error: 0.4100 - 142ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.1558 - mean_absolute_error: 0.2487 - val_loss: 0.4397 - val_mean_absolute_error: 0.4204 - 128ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.1595 - mean_absolute_error: 0.2537 - val_loss: 0.4361 - val_mean_absolute_error: 0.4135 - 126ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.1610 - mean_absolute_error: 0.2557 - val_loss: 0.4085 - val_mean_absolute_error: 0.4019 - 133ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.1581 - mean_absolute_error: 0.2518 - val_loss: 0.4212 - val_mean_absolute_error: 0.4024 - 126ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.1489 - mean_absolute_error: 0.2416 - val_loss: 0.4064 - val_mean_absolute_error: 0.3935 - 126ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.1483 - mean_absolute_error: 0.2397 - val_loss: 0.4127 - val_mean_absolute_error: 0.4044 - 126ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.1489 - mean_absolute_error: 0.2429 - val_loss: 0.4450 - val_mean_absolute_error: 0.4161 - 129ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.1555 - mean_absolute_error: 0.2476 - val_loss: 0.4247 - val_mean_absolute_error: 0.4142 - 142ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.1606 - mean_absolute_error: 0.2540 - val_loss: 0.4310 - val_mean_absolute_error: 0.4205 - 152ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.1579 - mean_absolute_error: 0.2517 - val_loss: 0.4146 - val_mean_absolute_error: 0.4065 - 138ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.1504 - mean_absolute_error: 0.2440 - val_loss: 0.4607 - val_mean_absolute_error: 0.4276 - 134ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.1467 - mean_absolute_error: 0.2414 - val_loss: 0.4009 - val_mean_absolute_error: 0.3925 - 158ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.1525 - mean_absolute_error: 0.2453 - val_loss: 0.4377 - val_mean_absolute_error: 0.4198 - 129ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.1505 - mean_absolute_error: 0.2433 - val_loss: 0.4388 - val_mean_absolute_error: 0.4286 - 132ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.1528 - mean_absolute_error: 0.2473 - val_loss: 0.4443 - val_mean_absolute_error: 0.4303 - 149ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.1549 - mean_absolute_error: 0.2502 - val_loss: 0.4227 - val_mean_absolute_error: 0.4035 - 170ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.1411 - mean_absolute_error: 0.2349 - val_loss: 0.4439 - val_mean_absolute_error: 0.4160 - 134ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.1547 - mean_absolute_error: 0.2479 - val_loss: 0.4305 - val_mean_absolute_error: 0.4146 - 126ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.1432 - mean_absolute_error: 0.2353 - val_loss: 0.4183 - val_mean_absolute_error: 0.4080 - 124ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.1505 - mean_absolute_error: 0.2443 - val_loss: 0.4098 - val_mean_absolute_error: 0.3978 - 126ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.1382 - mean_absolute_error: 0.2328 - val_loss: 0.4244 - val_mean_absolute_error: 0.4032 - 142ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.1563 - mean_absolute_error: 0.2494 - val_loss: 0.4262 - val_mean_absolute_error: 0.4089 - 126ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.1494 - mean_absolute_error: 0.2429 - val_loss: 0.4373 - val_mean_absolute_error: 0.4124 - 138ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.1487 - mean_absolute_error: 0.2413 - val_loss: 0.4226 - val_mean_absolute_error: 0.4039 - 160ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.1391 - mean_absolute_error: 0.2337 - val_loss: 0.4259 - val_mean_absolute_error: 0.4042 - 132ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.1364 - mean_absolute_error: 0.2284 - val_loss: 0.4356 - val_mean_absolute_error: 0.4128 - 133ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.1378 - mean_absolute_error: 0.2330 - val_loss: 0.4111 - val_mean_absolute_error: 0.3957 - 127ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.1335 - mean_absolute_error: 0.2270 - val_loss: 0.4074 - val_mean_absolute_error: 0.3971 - 125ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.1343 - mean_absolute_error: 0.2270 - val_loss: 0.4453 - val_mean_absolute_error: 0.4113 - 125ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.1381 - mean_absolute_error: 0.2342 - val_loss: 0.4267 - val_mean_absolute_error: 0.4065 - 131ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.1432 - mean_absolute_error: 0.2368 - val_loss: 0.4282 - val_mean_absolute_error: 0.4041 - 129ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.1259 - mean_absolute_error: 0.2210 - val_loss: 0.4202 - val_mean_absolute_error: 0.3977 - 139ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.1461 - mean_absolute_error: 0.2397 - val_loss: 0.4361 - val_mean_absolute_error: 0.4223 - 142ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.1347 - mean_absolute_error: 0.2297 - val_loss: 0.4348 - val_mean_absolute_error: 0.4060 - 137ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.1287 - mean_absolute_error: 0.2223 - val_loss: 0.4266 - val_mean_absolute_error: 0.4044 - 139ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.1278 - mean_absolute_error: 0.2232 - val_loss: 0.4342 - val_mean_absolute_error: 0.4047 - 148ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.1298 - mean_absolute_error: 0.2226 - val_loss: 0.4275 - val_mean_absolute_error: 0.4025 - 140ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.1407 - mean_absolute_error: 0.2357 - val_loss: 0.4337 - val_mean_absolute_error: 0.4059 - 154ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.1374 - mean_absolute_error: 0.2300 - val_loss: 0.4272 - val_mean_absolute_error: 0.4025 - 147ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.1231 - mean_absolute_error: 0.2183 - val_loss: 0.4249 - val_mean_absolute_error: 0.4039 - 153ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.1265 - mean_absolute_error: 0.2209 - val_loss: 0.4228 - val_mean_absolute_error: 0.4005 - 146ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.1287 - mean_absolute_error: 0.2228 - val_loss: 0.4404 - val_mean_absolute_error: 0.4169 - 127ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.1345 - mean_absolute_error: 0.2292 - val_loss: 0.4339 - val_mean_absolute_error: 0.4100 - 127ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.1364 - mean_absolute_error: 0.2326 - val_loss: 0.4532 - val_mean_absolute_error: 0.4209 - 131ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.1380 - mean_absolute_error: 0.2323 - val_loss: 0.4198 - val_mean_absolute_error: 0.3971 - 133ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.1348 - mean_absolute_error: 0.2314 - val_loss: 0.4219 - val_mean_absolute_error: 0.3999 - 127ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.1279 - mean_absolute_error: 0.2222 - val_loss: 0.4329 - val_mean_absolute_error: 0.4065 - 127ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.1372 - mean_absolute_error: 0.2308 - val_loss: 0.4255 - val_mean_absolute_error: 0.4003 - 141ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.1296 - mean_absolute_error: 0.2244 - val_loss: 0.4257 - val_mean_absolute_error: 0.4088 - 140ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.1233 - mean_absolute_error: 0.2168 - val_loss: 0.4169 - val_mean_absolute_error: 0.3971 - 127ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.1361 - mean_absolute_error: 0.2290 - val_loss: 0.4368 - val_mean_absolute_error: 0.4122 - 129ms/epoch - 2ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.1354 - mean_absolute_error: 0.2322 - val_loss: 0.4243 - val_mean_absolute_error: 0.4067 - 128ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.1200 - mean_absolute_error: 0.2140 - val_loss: 0.4290 - val_mean_absolute_error: 0.4014 - 136ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.1342 - mean_absolute_error: 0.2287 - val_loss: 0.4291 - val_mean_absolute_error: 0.3958 - 132ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.1222 - mean_absolute_error: 0.2164 - val_loss: 0.4198 - val_mean_absolute_error: 0.3939 - 127ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.1261 - mean_absolute_error: 0.2166 - val_loss: 0.4250 - val_mean_absolute_error: 0.4080 - 135ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.1266 - mean_absolute_error: 0.2232 - val_loss: 0.4398 - val_mean_absolute_error: 0.4083 - 151ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.1242 - mean_absolute_error: 0.2185 - val_loss: 0.4284 - val_mean_absolute_error: 0.4046 - 133ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.1363 - mean_absolute_error: 0.2298 - val_loss: 0.4084 - val_mean_absolute_error: 0.3946 - 127ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.1166 - mean_absolute_error: 0.2099 - val_loss: 0.4109 - val_mean_absolute_error: 0.3971 - 129ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.1276 - mean_absolute_error: 0.2199 - val_loss: 0.4451 - val_mean_absolute_error: 0.4096 - 132ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.1260 - mean_absolute_error: 0.2221 - val_loss: 0.4160 - val_mean_absolute_error: 0.3984 - 130ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.1157 - mean_absolute_error: 0.2104 - val_loss: 0.4369 - val_mean_absolute_error: 0.4060 - 127ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.1190 - mean_absolute_error: 0.2120 - val_loss: 0.4253 - val_mean_absolute_error: 0.4010 - 126ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.1154 - mean_absolute_error: 0.2092 - val_loss: 0.4187 - val_mean_absolute_error: 0.3977 - 148ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.1205 - mean_absolute_error: 0.2131 - val_loss: 0.4215 - val_mean_absolute_error: 0.4024 - 151ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.1323 - mean_absolute_error: 0.2284 - val_loss: 0.4111 - val_mean_absolute_error: 0.3957 - 171ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.1219 - mean_absolute_error: 0.2154 - val_loss: 0.4275 - val_mean_absolute_error: 0.4043 - 126ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.1132 - mean_absolute_error: 0.2065 - val_loss: 0.4338 - val_mean_absolute_error: 0.4039 - 128ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.1112 - mean_absolute_error: 0.2052 - val_loss: 0.4188 - val_mean_absolute_error: 0.3956 - 129ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.1124 - mean_absolute_error: 0.2047 - val_loss: 0.4231 - val_mean_absolute_error: 0.4038 - 128ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.1167 - mean_absolute_error: 0.2121 - val_loss: 0.4216 - val_mean_absolute_error: 0.3944 - 128ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.1135 - mean_absolute_error: 0.2078 - val_loss: 0.4200 - val_mean_absolute_error: 0.4042 - 136ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.1137 - mean_absolute_error: 0.2074 - val_loss: 0.4274 - val_mean_absolute_error: 0.4018 - 141ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.1139 - mean_absolute_error: 0.2101 - val_loss: 0.4313 - val_mean_absolute_error: 0.4073 - 129ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.1288 - mean_absolute_error: 0.2226 - val_loss: 0.4448 - val_mean_absolute_error: 0.4161 - 130ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.1318 - mean_absolute_error: 0.2275 - val_loss: 0.4295 - val_mean_absolute_error: 0.3999 - 128ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.1150 - mean_absolute_error: 0.2074 - val_loss: 0.4301 - val_mean_absolute_error: 0.4096 - 130ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.1210 - mean_absolute_error: 0.2175 - val_loss: 0.4271 - val_mean_absolute_error: 0.4001 - 129ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.1154 - mean_absolute_error: 0.2112 - val_loss: 0.4372 - val_mean_absolute_error: 0.4101 - 160ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.1209 - mean_absolute_error: 0.2157 - val_loss: 0.4329 - val_mean_absolute_error: 0.4063 - 140ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.1094 - mean_absolute_error: 0.2042 - val_loss: 0.4153 - val_mean_absolute_error: 0.4017 - 142ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.1106 - mean_absolute_error: 0.2051 - val_loss: 0.4223 - val_mean_absolute_error: 0.3975 - 142ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.1013 - mean_absolute_error: 0.1932 - val_loss: 0.4097 - val_mean_absolute_error: 0.3915 - 126ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.1164 - mean_absolute_error: 0.2089 - val_loss: 0.4430 - val_mean_absolute_error: 0.4096 - 125ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.1324 - mean_absolute_error: 0.2269 - val_loss: 0.4423 - val_mean_absolute_error: 0.4330 - 126ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.1336 - mean_absolute_error: 0.2292 - val_loss: 0.4404 - val_mean_absolute_error: 0.4081 - 125ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.1164 - mean_absolute_error: 0.2102 - val_loss: 0.4217 - val_mean_absolute_error: 0.3985 - 125ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.1167 - mean_absolute_error: 0.2115 - val_loss: 0.4312 - val_mean_absolute_error: 0.3990 - 124ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.1152 - mean_absolute_error: 0.2090 - val_loss: 0.4162 - val_mean_absolute_error: 0.3939 - 140ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.1063 - mean_absolute_error: 0.1993 - val_loss: 0.4347 - val_mean_absolute_error: 0.4086 - 127ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.1091 - mean_absolute_error: 0.2027 - val_loss: 0.4241 - val_mean_absolute_error: 0.3953 - 128ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.1090 - mean_absolute_error: 0.2016 - val_loss: 0.4133 - val_mean_absolute_error: 0.3932 - 139ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.1135 - mean_absolute_error: 0.2064 - val_loss: 0.4342 - val_mean_absolute_error: 0.4043 - 136ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.1146 - mean_absolute_error: 0.2101 - val_loss: 0.4296 - val_mean_absolute_error: 0.4043 - 126ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.1129 - mean_absolute_error: 0.2061 - val_loss: 0.4253 - val_mean_absolute_error: 0.3960 - 125ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.1064 - mean_absolute_error: 0.1995 - val_loss: 0.4223 - val_mean_absolute_error: 0.3958 - 134ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.1153 - mean_absolute_error: 0.2112 - val_loss: 0.4276 - val_mean_absolute_error: 0.4022 - 145ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.1148 - mean_absolute_error: 0.2069 - val_loss: 0.4206 - val_mean_absolute_error: 0.3993 - 131ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.1023 - mean_absolute_error: 0.1942 - val_loss: 0.4191 - val_mean_absolute_error: 0.3919 - 134ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.1050 - mean_absolute_error: 0.1983 - val_loss: 0.4383 - val_mean_absolute_error: 0.4048 - 141ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.1063 - mean_absolute_error: 0.1989 - val_loss: 0.4268 - val_mean_absolute_error: 0.3976 - 140ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.1113 - mean_absolute_error: 0.2042 - val_loss: 0.4243 - val_mean_absolute_error: 0.4016 - 129ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.1250 - mean_absolute_error: 0.2203 - val_loss: 0.4247 - val_mean_absolute_error: 0.3995 - 137ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.1062 - mean_absolute_error: 0.1972 - val_loss: 0.4530 - val_mean_absolute_error: 0.4070 - 143ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.1009 - mean_absolute_error: 0.1930 - val_loss: 0.4181 - val_mean_absolute_error: 0.3934 - 137ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.1020 - mean_absolute_error: 0.1928 - val_loss: 0.4170 - val_mean_absolute_error: 0.4016 - 132ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.1155 - mean_absolute_error: 0.2100 - val_loss: 0.4294 - val_mean_absolute_error: 0.4053 - 146ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.1075 - mean_absolute_error: 0.2017 - val_loss: 0.4441 - val_mean_absolute_error: 0.4158 - 145ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.1064 - mean_absolute_error: 0.1991 - val_loss: 0.4203 - val_mean_absolute_error: 0.3941 - 133ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.1028 - mean_absolute_error: 0.1941 - val_loss: 0.4258 - val_mean_absolute_error: 0.4009 - 126ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.1081 - mean_absolute_error: 0.2016 - val_loss: 0.4165 - val_mean_absolute_error: 0.3940 - 129ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.0969 - mean_absolute_error: 0.1876 - val_loss: 0.4433 - val_mean_absolute_error: 0.4023 - 143ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.1268 - mean_absolute_error: 0.2209 - val_loss: 0.4378 - val_mean_absolute_error: 0.4097 - 128ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.1092 - mean_absolute_error: 0.2039 - val_loss: 0.4200 - val_mean_absolute_error: 0.3929 - 127ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.1090 - mean_absolute_error: 0.2010 - val_loss: 0.4188 - val_mean_absolute_error: 0.3984 - 128ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.0993 - mean_absolute_error: 0.1907 - val_loss: 0.4234 - val_mean_absolute_error: 0.3944 - 150ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.1040 - mean_absolute_error: 0.1955 - val_loss: 0.4068 - val_mean_absolute_error: 0.3946 - 129ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.1066 - mean_absolute_error: 0.1976 - val_loss: 0.4588 - val_mean_absolute_error: 0.4226 - 133ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.1110 - mean_absolute_error: 0.2060 - val_loss: 0.4160 - val_mean_absolute_error: 0.3986 - 131ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.1068 - mean_absolute_error: 0.2002 - val_loss: 0.4247 - val_mean_absolute_error: 0.3977 - 129ms/epoch - 2ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.1184 - mean_absolute_error: 0.2138 - val_loss: 0.4386 - val_mean_absolute_error: 0.4089 - 130ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.1009 - mean_absolute_error: 0.1951 - val_loss: 0.4247 - val_mean_absolute_error: 0.3968 - 127ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.0979 - mean_absolute_error: 0.1900 - val_loss: 0.4180 - val_mean_absolute_error: 0.3970 - 129ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.0951 - mean_absolute_error: 0.1859 - val_loss: 0.4351 - val_mean_absolute_error: 0.4027 - 143ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.1019 - mean_absolute_error: 0.1915 - val_loss: 0.4453 - val_mean_absolute_error: 0.4058 - 127ms/epoch - 2ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.1006 - mean_absolute_error: 0.1911 - val_loss: 0.4255 - val_mean_absolute_error: 0.3964 - 162ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.1030 - mean_absolute_error: 0.1976 - val_loss: 0.4362 - val_mean_absolute_error: 0.4086 - 167ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.0989 - mean_absolute_error: 0.1920 - val_loss: 0.4336 - val_mean_absolute_error: 0.4015 - 145ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.0959 - mean_absolute_error: 0.1885 - val_loss: 0.4250 - val_mean_absolute_error: 0.3981 - 131ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.1256 - mean_absolute_error: 0.2193 - val_loss: 0.4139 - val_mean_absolute_error: 0.3993 - 127ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.1093 - mean_absolute_error: 0.2032 - val_loss: 0.4452 - val_mean_absolute_error: 0.4122 - 134ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.1133 - mean_absolute_error: 0.2084 - val_loss: 0.4264 - val_mean_absolute_error: 0.4027 - 133ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.0972 - mean_absolute_error: 0.1901 - val_loss: 0.4142 - val_mean_absolute_error: 0.3982 - 127ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.1036 - mean_absolute_error: 0.1955 - val_loss: 0.4126 - val_mean_absolute_error: 0.3952 - 124ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.0986 - mean_absolute_error: 0.1886 - val_loss: 0.4302 - val_mean_absolute_error: 0.4048 - 126ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.0985 - mean_absolute_error: 0.1920 - val_loss: 0.4239 - val_mean_absolute_error: 0.4020 - 143ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.1096 - mean_absolute_error: 0.2011 - val_loss: 0.4190 - val_mean_absolute_error: 0.4001 - 139ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.0952 - mean_absolute_error: 0.1871 - val_loss: 0.4322 - val_mean_absolute_error: 0.4070 - 130ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.0927 - mean_absolute_error: 0.1834 - val_loss: 0.4417 - val_mean_absolute_error: 0.4080 - 127ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.1009 - mean_absolute_error: 0.1949 - val_loss: 0.4274 - val_mean_absolute_error: 0.4003 - 125ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.0972 - mean_absolute_error: 0.1894 - val_loss: 0.4074 - val_mean_absolute_error: 0.3938 - 129ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.1018 - mean_absolute_error: 0.1958 - val_loss: 0.4216 - val_mean_absolute_error: 0.3973 - 128ms/epoch - 2ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.0990 - mean_absolute_error: 0.1907 - val_loss: 0.4332 - val_mean_absolute_error: 0.4004 - 138ms/epoch - 2ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.1038 - mean_absolute_error: 0.1962 - val_loss: 0.4274 - val_mean_absolute_error: 0.4005 - 138ms/epoch - 2ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.0972 - mean_absolute_error: 0.1880 - val_loss: 0.4200 - val_mean_absolute_error: 0.3918 - 130ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.1016 - mean_absolute_error: 0.1949 - val_loss: 0.4211 - val_mean_absolute_error: 0.3931 - 148ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.0989 - mean_absolute_error: 0.1919 - val_loss: 0.4233 - val_mean_absolute_error: 0.3979 - 145ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.1026 - mean_absolute_error: 0.1939 - val_loss: 0.4382 - val_mean_absolute_error: 0.4108 - 133ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.1043 - mean_absolute_error: 0.1965 - val_loss: 0.4222 - val_mean_absolute_error: 0.3989 - 138ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.0940 - mean_absolute_error: 0.1855 - val_loss: 0.4328 - val_mean_absolute_error: 0.4024 - 129ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.1090 - mean_absolute_error: 0.2006 - val_loss: 0.4365 - val_mean_absolute_error: 0.4060 - 127ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.0977 - mean_absolute_error: 0.1891 - val_loss: 0.4275 - val_mean_absolute_error: 0.3999 - 126ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.0926 - mean_absolute_error: 0.1832 - val_loss: 0.4254 - val_mean_absolute_error: 0.3979 - 128ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.0947 - mean_absolute_error: 0.1852 - val_loss: 0.4416 - val_mean_absolute_error: 0.4102 - 136ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.0949 - mean_absolute_error: 0.1851 - val_loss: 0.4600 - val_mean_absolute_error: 0.4230 - 142ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.1179 - mean_absolute_error: 0.2115 - val_loss: 0.4182 - val_mean_absolute_error: 0.3979 - 133ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.1009 - mean_absolute_error: 0.1948 - val_loss: 0.4346 - val_mean_absolute_error: 0.4072 - 125ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.0972 - mean_absolute_error: 0.1898 - val_loss: 0.4202 - val_mean_absolute_error: 0.3953 - 134ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.0966 - mean_absolute_error: 0.1865 - val_loss: 0.4181 - val_mean_absolute_error: 0.3918 - 149ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.0892 - mean_absolute_error: 0.1768 - val_loss: 0.4257 - val_mean_absolute_error: 0.4019 - 136ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.0981 - mean_absolute_error: 0.1896 - val_loss: 0.4274 - val_mean_absolute_error: 0.3967 - 150ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.0466 - mean_absolute_error: 0.1247 - val_loss: 0.4241 - val_mean_absolute_error: 0.3895 - 133ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.0504 - mean_absolute_error: 0.1262 - val_loss: 0.4197 - val_mean_absolute_error: 0.3898 - 129ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.0508 - mean_absolute_error: 0.1266 - val_loss: 0.4225 - val_mean_absolute_error: 0.3893 - 130ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.0481 - mean_absolute_error: 0.1251 - val_loss: 0.4180 - val_mean_absolute_error: 0.3866 - 128ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.0478 - mean_absolute_error: 0.1247 - val_loss: 0.4200 - val_mean_absolute_error: 0.3896 - 126ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.0510 - mean_absolute_error: 0.1262 - val_loss: 0.4207 - val_mean_absolute_error: 0.3923 - 129ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.0560 - mean_absolute_error: 0.1362 - val_loss: 0.4273 - val_mean_absolute_error: 0.3914 - 131ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.0517 - mean_absolute_error: 0.1309 - val_loss: 0.4180 - val_mean_absolute_error: 0.3910 - 130ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.0532 - mean_absolute_error: 0.1334 - val_loss: 0.4235 - val_mean_absolute_error: 0.3939 - 131ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.0458 - mean_absolute_error: 0.1210 - val_loss: 0.4185 - val_mean_absolute_error: 0.3893 - 131ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.0597 - mean_absolute_error: 0.1396 - val_loss: 0.4363 - val_mean_absolute_error: 0.3982 - 129ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.0616 - mean_absolute_error: 0.1445 - val_loss: 0.4215 - val_mean_absolute_error: 0.3925 - 139ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.0443 - mean_absolute_error: 0.1189 - val_loss: 0.4120 - val_mean_absolute_error: 0.3855 - 137ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.0510 - mean_absolute_error: 0.1250 - val_loss: 0.4367 - val_mean_absolute_error: 0.4016 - 129ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.0577 - mean_absolute_error: 0.1412 - val_loss: 0.4158 - val_mean_absolute_error: 0.3879 - 128ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.0532 - mean_absolute_error: 0.1341 - val_loss: 0.4208 - val_mean_absolute_error: 0.3873 - 130ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.0528 - mean_absolute_error: 0.1269 - val_loss: 0.4358 - val_mean_absolute_error: 0.3957 - 128ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.0597 - mean_absolute_error: 0.1439 - val_loss: 0.4129 - val_mean_absolute_error: 0.3902 - 127ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.0468 - mean_absolute_error: 0.1220 - val_loss: 0.4184 - val_mean_absolute_error: 0.3880 - 127ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.0457 - mean_absolute_error: 0.1210 - val_loss: 0.4108 - val_mean_absolute_error: 0.3845 - 129ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.0482 - mean_absolute_error: 0.1215 - val_loss: 0.4224 - val_mean_absolute_error: 0.3911 - 126ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.0533 - mean_absolute_error: 0.1322 - val_loss: 0.4247 - val_mean_absolute_error: 0.3889 - 125ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.0447 - mean_absolute_error: 0.1186 - val_loss: 0.4199 - val_mean_absolute_error: 0.3897 - 132ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.0504 - mean_absolute_error: 0.1269 - val_loss: 0.4212 - val_mean_absolute_error: 0.3876 - 128ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.0463 - mean_absolute_error: 0.1207 - val_loss: 0.4111 - val_mean_absolute_error: 0.3846 - 129ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.0416 - mean_absolute_error: 0.1122 - val_loss: 0.4124 - val_mean_absolute_error: 0.3853 - 129ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.0462 - mean_absolute_error: 0.1198 - val_loss: 0.4174 - val_mean_absolute_error: 0.3874 - 125ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.0476 - mean_absolute_error: 0.1220 - val_loss: 0.4305 - val_mean_absolute_error: 0.3952 - 127ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.0513 - mean_absolute_error: 0.1297 - val_loss: 0.4156 - val_mean_absolute_error: 0.3890 - 128ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.0468 - mean_absolute_error: 0.1240 - val_loss: 0.4204 - val_mean_absolute_error: 0.3875 - 126ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.0532 - mean_absolute_error: 0.1325 - val_loss: 0.4385 - val_mean_absolute_error: 0.4006 - 126ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.0569 - mean_absolute_error: 0.1381 - val_loss: 0.4173 - val_mean_absolute_error: 0.3925 - 126ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.0470 - mean_absolute_error: 0.1223 - val_loss: 0.4071 - val_mean_absolute_error: 0.3830 - 127ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.0466 - mean_absolute_error: 0.1223 - val_loss: 0.4177 - val_mean_absolute_error: 0.3851 - 126ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.0471 - mean_absolute_error: 0.1229 - val_loss: 0.4195 - val_mean_absolute_error: 0.3881 - 140ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.0535 - mean_absolute_error: 0.1328 - val_loss: 0.4250 - val_mean_absolute_error: 0.3953 - 126ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.0439 - mean_absolute_error: 0.1168 - val_loss: 0.4113 - val_mean_absolute_error: 0.3868 - 127ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.0567 - mean_absolute_error: 0.1362 - val_loss: 0.4223 - val_mean_absolute_error: 0.3898 - 126ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.0458 - mean_absolute_error: 0.1231 - val_loss: 0.4183 - val_mean_absolute_error: 0.3871 - 132ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.0451 - mean_absolute_error: 0.1179 - val_loss: 0.4250 - val_mean_absolute_error: 0.3900 - 130ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.0478 - mean_absolute_error: 0.1245 - val_loss: 0.4142 - val_mean_absolute_error: 0.3884 - 130ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.0519 - mean_absolute_error: 0.1295 - val_loss: 0.4215 - val_mean_absolute_error: 0.3903 - 127ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.0463 - mean_absolute_error: 0.1218 - val_loss: 0.4035 - val_mean_absolute_error: 0.3870 - 131ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.0455 - mean_absolute_error: 0.1205 - val_loss: 0.4253 - val_mean_absolute_error: 0.3915 - 130ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.0517 - mean_absolute_error: 0.1285 - val_loss: 0.4109 - val_mean_absolute_error: 0.3905 - 132ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.0444 - mean_absolute_error: 0.1198 - val_loss: 0.4179 - val_mean_absolute_error: 0.3915 - 128ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.0509 - mean_absolute_error: 0.1284 - val_loss: 0.4191 - val_mean_absolute_error: 0.3938 - 126ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.0492 - mean_absolute_error: 0.1259 - val_loss: 0.4205 - val_mean_absolute_error: 0.3902 - 127ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.0488 - mean_absolute_error: 0.1259 - val_loss: 0.4103 - val_mean_absolute_error: 0.3891 - 126ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.0553 - mean_absolute_error: 0.1319 - val_loss: 0.4333 - val_mean_absolute_error: 0.4065 - 125ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.0510 - mean_absolute_error: 0.1319 - val_loss: 0.4269 - val_mean_absolute_error: 0.3927 - 126ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.0474 - mean_absolute_error: 0.1242 - val_loss: 0.4248 - val_mean_absolute_error: 0.3956 - 126ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.0470 - mean_absolute_error: 0.1229 - val_loss: 0.4316 - val_mean_absolute_error: 0.3927 - 127ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.0474 - mean_absolute_error: 0.1221 - val_loss: 0.4169 - val_mean_absolute_error: 0.3892 - 130ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.0473 - mean_absolute_error: 0.1252 - val_loss: 0.4258 - val_mean_absolute_error: 0.3925 - 131ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.0450 - mean_absolute_error: 0.1199 - val_loss: 0.4104 - val_mean_absolute_error: 0.3856 - 126ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.0645 - mean_absolute_error: 0.1446 - val_loss: 0.4394 - val_mean_absolute_error: 0.4061 - 127ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.0641 - mean_absolute_error: 0.1512 - val_loss: 0.4237 - val_mean_absolute_error: 0.3919 - 125ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.0434 - mean_absolute_error: 0.1182 - val_loss: 0.4264 - val_mean_absolute_error: 0.3927 - 128ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.0468 - mean_absolute_error: 0.1216 - val_loss: 0.3983 - val_mean_absolute_error: 0.3828 - 127ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.0457 - mean_absolute_error: 0.1214 - val_loss: 0.4225 - val_mean_absolute_error: 0.3876 - 127ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.0474 - mean_absolute_error: 0.1232 - val_loss: 0.4190 - val_mean_absolute_error: 0.3882 - 127ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.0418 - mean_absolute_error: 0.1143 - val_loss: 0.4268 - val_mean_absolute_error: 0.3932 - 127ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.0480 - mean_absolute_error: 0.1228 - val_loss: 0.4197 - val_mean_absolute_error: 0.3892 - 126ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.0431 - mean_absolute_error: 0.1171 - val_loss: 0.4143 - val_mean_absolute_error: 0.3882 - 127ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.0430 - mean_absolute_error: 0.1163 - val_loss: 0.4114 - val_mean_absolute_error: 0.3861 - 127ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.0431 - mean_absolute_error: 0.1144 - val_loss: 0.4131 - val_mean_absolute_error: 0.3932 - 127ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.0523 - mean_absolute_error: 0.1326 - val_loss: 0.4157 - val_mean_absolute_error: 0.3917 - 126ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.0433 - mean_absolute_error: 0.1196 - val_loss: 0.4181 - val_mean_absolute_error: 0.3894 - 126ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.0456 - mean_absolute_error: 0.1192 - val_loss: 0.4295 - val_mean_absolute_error: 0.3977 - 129ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.0598 - mean_absolute_error: 0.1428 - val_loss: 0.4156 - val_mean_absolute_error: 0.3913 - 126ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.0534 - mean_absolute_error: 0.1362 - val_loss: 0.4157 - val_mean_absolute_error: 0.3875 - 126ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.0490 - mean_absolute_error: 0.1264 - val_loss: 0.4151 - val_mean_absolute_error: 0.3894 - 125ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.0434 - mean_absolute_error: 0.1180 - val_loss: 0.4378 - val_mean_absolute_error: 0.3944 - 125ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.0470 - mean_absolute_error: 0.1231 - val_loss: 0.4271 - val_mean_absolute_error: 0.3937 - 125ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.0494 - mean_absolute_error: 0.1230 - val_loss: 0.4305 - val_mean_absolute_error: 0.3951 - 125ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.0471 - mean_absolute_error: 0.1228 - val_loss: 0.4334 - val_mean_absolute_error: 0.3916 - 128ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.0511 - mean_absolute_error: 0.1277 - val_loss: 0.4247 - val_mean_absolute_error: 0.3921 - 125ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.0539 - mean_absolute_error: 0.1345 - val_loss: 0.4312 - val_mean_absolute_error: 0.3955 - 125ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.0523 - mean_absolute_error: 0.1312 - val_loss: 0.4173 - val_mean_absolute_error: 0.3895 - 127ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.0460 - mean_absolute_error: 0.1205 - val_loss: 0.4126 - val_mean_absolute_error: 0.3852 - 127ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.0563 - mean_absolute_error: 0.1380 - val_loss: 0.4309 - val_mean_absolute_error: 0.3962 - 126ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.0538 - mean_absolute_error: 0.1309 - val_loss: 0.4311 - val_mean_absolute_error: 0.4005 - 128ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.0496 - mean_absolute_error: 0.1267 - val_loss: 0.4231 - val_mean_absolute_error: 0.3939 - 127ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.0395 - mean_absolute_error: 0.1114 - val_loss: 0.4122 - val_mean_absolute_error: 0.3827 - 131ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.0473 - mean_absolute_error: 0.1203 - val_loss: 0.4173 - val_mean_absolute_error: 0.3859 - 126ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.0431 - mean_absolute_error: 0.1153 - val_loss: 0.4124 - val_mean_absolute_error: 0.3882 - 126ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.0472 - mean_absolute_error: 0.1245 - val_loss: 0.4158 - val_mean_absolute_error: 0.3874 - 126ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.0440 - mean_absolute_error: 0.1191 - val_loss: 0.4183 - val_mean_absolute_error: 0.3878 - 125ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.0535 - mean_absolute_error: 0.1310 - val_loss: 0.4297 - val_mean_absolute_error: 0.3954 - 127ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.0436 - mean_absolute_error: 0.1168 - val_loss: 0.4136 - val_mean_absolute_error: 0.3867 - 125ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.0412 - mean_absolute_error: 0.1149 - val_loss: 0.4145 - val_mean_absolute_error: 0.3854 - 126ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.0637 - mean_absolute_error: 0.1432 - val_loss: 0.4127 - val_mean_absolute_error: 0.3887 - 126ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.0488 - mean_absolute_error: 0.1282 - val_loss: 0.4324 - val_mean_absolute_error: 0.3977 - 126ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.0644 - mean_absolute_error: 0.1470 - val_loss: 0.4183 - val_mean_absolute_error: 0.3946 - 126ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.0479 - mean_absolute_error: 0.1270 - val_loss: 0.4199 - val_mean_absolute_error: 0.3876 - 126ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.0497 - mean_absolute_error: 0.1262 - val_loss: 0.4191 - val_mean_absolute_error: 0.3929 - 125ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.0437 - mean_absolute_error: 0.1194 - val_loss: 0.4177 - val_mean_absolute_error: 0.3842 - 128ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.0451 - mean_absolute_error: 0.1192 - val_loss: 0.4183 - val_mean_absolute_error: 0.3911 - 126ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.0482 - mean_absolute_error: 0.1234 - val_loss: 0.4139 - val_mean_absolute_error: 0.3852 - 131ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.0502 - mean_absolute_error: 0.1272 - val_loss: 0.4266 - val_mean_absolute_error: 0.3935 - 125ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.0604 - mean_absolute_error: 0.1406 - val_loss: 0.4246 - val_mean_absolute_error: 0.3926 - 125ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.0593 - mean_absolute_error: 0.1409 - val_loss: 0.4200 - val_mean_absolute_error: 0.3907 - 126ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.0444 - mean_absolute_error: 0.1176 - val_loss: 0.4063 - val_mean_absolute_error: 0.3851 - 127ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.0393 - mean_absolute_error: 0.1094 - val_loss: 0.4239 - val_mean_absolute_error: 0.3892 - 125ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.0503 - mean_absolute_error: 0.1222 - val_loss: 0.4284 - val_mean_absolute_error: 0.3941 - 127ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.0463 - mean_absolute_error: 0.1233 - val_loss: 0.4194 - val_mean_absolute_error: 0.3878 - 126ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_Noise_five(DeltaE-acortado).keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE: 0.41935786604881287
# MAE: 0.3877657353878021
# 32/32 [==============================] - 0s 780us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# ##### Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\kappa$', r'$\Delta E$', r'$\gamma$', r'$g$']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 9))
fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes.flatten()):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ##### Curvas Validación VS Predicción
#
# Si jugamos con la función, llegamos a:
#
# $$
# t(\omega)=\frac{-\kappa\left[(\Delta E-\omega)-i\gamma\right]}{\left[(\Omega-\omega)(\Delta E-\omega)-\kappa\gamma-g^2\right]-i\left[(\Omega-\omega)\gamma+(\Delta E-\omega)\kappa\right]}
# $$
#
# Sacamos los polos de la parte real del denominador, obteniendo:
# $$
# \omega_1=\frac{(\Delta E+\Omega)+\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# $$
# \omega_2=\frac{(\Delta E+\Omega)-\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# Si queremos el valor de g:
# $$g=\frac{\sqrt{|\omega_1-\omega_2|^2-(\Omega-\Delta E)^2-4\kappa\gamma}}{2}$$
#
# Ahora, junto a las curvas, dibujaremos líneas verticales correspondientes a esos polos y escribimnos el valor de la resta de sus valores

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
k_pred = y_pred_denorm[:, 0]
k_val = y_val_denorm[:, 0]
DeltaE_pred = y_pred_denorm[:, 1]
DeltaE_val = y_val_denorm[:, 1]
gamma_pred = y_pred_denorm[:, 2]
gamma_val = y_val_denorm[:, 2]
g_pred = y_pred_denorm[:, 3]
g_val = y_val_denorm[:, 3]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val_noise = t_values_noise[indices_val]
t_values_val = t_values[indices_val]

for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k_pred[i], Omega, DeltaE_pred[i], gamma_pred[i], g_pred[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k_val, Omega, DeltaE_val, gamma_val, g_val)
w2=w_2(k_val, Omega, DeltaE_val, gamma_val, g_val)

i = 800
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_val_noise[i, :], color="g", label="Curva con ruido")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"κ real = {k_val[i]:.7f}, κ pred = {k_pred[i]:.7f}\n"\
           f"ΔE real = {DeltaE_val[i]:.5f}, ΔE pred = {DeltaE_pred[i]:.5f}\n"\
           f"γ real = {gamma_val[i]:.7f}, γ pred = {gamma_pred[i]:.7f}\n"\
           f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1

# %%
from IPython.display import display, clear_output
import keyboard
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = [9, 5]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# #### Definimos t($\omega$):
# $$t(\omega)=\frac{-\kappa}{(\Omega-\omega)-i\kappa-i\frac{g^2}{i(\Delta E-\omega)+\gamma}}$$

# %%
def t_w (w, k, Omega, DeltaE, gamma, g):
    numerador = -k
    denominador = (Omega-w) - 1j * k - 1j * g**2 / (1j * (DeltaE - w) + gamma)
    t = numerador / denominador
    return abs(t)

# %% [markdown]
#  # With noise

# %% [markdown]
# ## Creamos base de datos

# %%
# Definimos una función que genere la base de datos
def Parameters_generator (num_datos):
    k = np.random.uniform(1e-4, 1e-2, num_datos)
    DeltaE = np.random.uniform(0.5, 1.5, num_datos)
    gamma = np.random.uniform(1e-4, 1e-2, num_datos)
    g = np.random.uniform(1e-4, 1e-2, num_datos)

    return k, DeltaE, gamma, g

def add_noise (data, sig):
    return data + np.random.normal(0,sig)

num_datos = 5000

# %%
# #Creamos base de datos y guardamos en .txt
# k, DeltaE, gamma, g = Parameters_generator (num_datos)

# np.savetxt('Parameters_Noise.txt', np.column_stack((k, DeltaE, gamma, g)), header='\u03BA \u0394E \u213D g')

# %%
datos = np.loadtxt('Parameters_Noise.txt', skiprows=1)
k = datos[:,0]
DeltaE = datos[:,1]
gamma = datos[:,2]
g = datos[:,3]
Omega = 1

#Creamos los valores de y (la función t(w)) con nuestra base de datos
w_values = np.linspace(0.85, 1.15, 300)

# Crear una matriz para almacenar los t(w)
t_values = np.zeros((num_datos, len(w_values)))
t_values_noise = np.zeros((num_datos, len(w_values)))


# Almacenar los resultados en la matriz 
# (elemento [i,j] fila i es el número de combinación de [k, DeltaE, gamma, g] 
# y la comluna j el elemento de w_values)
for i in range (num_datos):
    t_values[i,:] = t_w(w_values, k[i], Omega, DeltaE[i], gamma[i], g[i]) 

for i in range (num_datos):
    t_values_noise[i,:] = [add_noise(t_values[i,j], 0.1*t_values[i,j]*np.random.rand())
                            for j in range(len(w_values))]

# %% [markdown]
# ### Dibujamos las curvas

# %%
# i=0
# while i<=5000:
#     plt.clf()  # Limpia la figura antes de cada iteración
#     plt.plot(w_values, t_values_noise[i,:], label='Con ruido', color='blue')
#     plt.plot(w_values, t_values[i,:], label='Original', linewidth=0.75, linestyle='--', color='red')
#     plt.title(f"Curva número: {i}")
#     plt.xlabel(r"$\omega$ (Hz)")
#     plt.ylabel(r"t ($\omega$)")
#     plt.legend()

#     plt.draw()  # Dibuja la figura actual

#     # Muestra la figura y espera a que el usuario presione Enter
#     display(plt.gcf())
#     clear_output(wait=True)
    
#     if keyboard.is_pressed('esc'): break
#     if keyboard.is_pressed('right'): i += 1
#     if keyboard.is_pressed('left'): 
#         i -= 1       
#         if i < 0:
#             i += 1

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# ### Tensorflow/Keras

# %%
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from keras.constraints import NonNeg
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Preparamos datos e hiperparámetros

# %%
#Seleccionamos los datos de entrenamiento y de validación
indices = np.arange(num_datos)
indices_train, indices_val = train_test_split(indices, test_size=0.2)

x_train = t_values_noise[indices_train]
x_val = t_values_noise[indices_val]
y_train = datos[indices_train]
y_val = datos[indices_val]


# Normalizamos los datos
scaler_x = StandardScaler()
x_train_norm = scaler_x.fit_transform(x_train)
x_val_norm = scaler_x.transform(x_val)

scaler_y = StandardScaler()
y_train_norm = scaler_y.fit_transform(y_train)
y_val_norm = scaler_y.transform(y_val)

# Comprobamos las dimensiones de nuestros datos
print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'test samples')
print("x_train shape",x_train.shape)
print("y_train shape",y_train.shape)

#Número de neuronas de entrada y salida, y de la capa oculta
input_neurons  = x_train.shape[1]
output_neurons = y_train.shape[1]

#Elegimos los hiperparámetros
batch_size = 50
epochs = 1000
optimizer = Adam(learning_rate=0.001)
# Out:
# 4000 train samples
# 1000 test samples
# x_train shape (4000, 300)
# y_train shape (4000, 4)

# %% [markdown]
# #### Definimos modelos

# %% [markdown]
# ##### 5 capas ocultas

# %%
def Dense_five ():
    model = Sequential()
    model.add(Input(shape=(input_neurons,)))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32 , activation='relu'))
    model.add(Dense(16 , activation='relu'))
    model.add(Dense(output_neurons, activation='linear', kernel_constraint=NonNeg())) 

    #Compila el modelo
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %% [markdown]
#  #### Entrenamos y guardamos

# %%
# model =  Dense_five()

# #Fiteamos el modelo
# history = model.fit(x_train_norm, y_train_norm, batch_size=batch_size, validation_data=(x_val_norm, y_val_norm),
#                      epochs=epochs, verbose=2)

# # # Definir EarlyStopping
# # early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# #Guardamos el modelo y así no necesitamos entrenarlo cada vez que lo queramos usar
# model.save('model_Noise_five.keras') 

# # Visualiza la pérdida y la métrica de entrenamiento
# plt.plot(history.history['loss'], label='Train Loss')
# plt.plot(history.history['mean_absolute_error'], label='Train MAE')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
# plt.xlabel('Epoch')
# plt.legend()
# plt.show()
# Out:
# Epoch 1/1000
# 80/80 - 1s - loss: 0.9175 - mean_absolute_error: 0.7992 - val_loss: 0.8992 - val_mean_absolute_error: 0.7947 - 1s/epoch - 13ms/step
# Epoch 2/1000
# 80/80 - 0s - loss: 0.8735 - mean_absolute_error: 0.7717 - val_loss: 0.8695 - val_mean_absolute_error: 0.7752 - 141ms/epoch - 2ms/step
# Epoch 3/1000
# 80/80 - 0s - loss: 0.8474 - mean_absolute_error: 0.7505 - val_loss: 0.8383 - val_mean_absolute_error: 0.7403 - 124ms/epoch - 2ms/step
# Epoch 4/1000
# 80/80 - 0s - loss: 0.8267 - mean_absolute_error: 0.7360 - val_loss: 0.8275 - val_mean_absolute_error: 0.7439 - 124ms/epoch - 2ms/step
# Epoch 5/1000
# 80/80 - 0s - loss: 0.8156 - mean_absolute_error: 0.7313 - val_loss: 0.8186 - val_mean_absolute_error: 0.7334 - 125ms/epoch - 2ms/step
# Epoch 6/1000
# 80/80 - 0s - loss: 0.8059 - mean_absolute_error: 0.7231 - val_loss: 0.8065 - val_mean_absolute_error: 0.7213 - 123ms/epoch - 2ms/step
# Epoch 7/1000
# 80/80 - 0s - loss: 0.7976 - mean_absolute_error: 0.7177 - val_loss: 0.7991 - val_mean_absolute_error: 0.7177 - 133ms/epoch - 2ms/step
# Epoch 8/1000
# 80/80 - 0s - loss: 0.7907 - mean_absolute_error: 0.7150 - val_loss: 0.7971 - val_mean_absolute_error: 0.7319 - 131ms/epoch - 2ms/step
# Epoch 9/1000
# 80/80 - 0s - loss: 0.7853 - mean_absolute_error: 0.7139 - val_loss: 0.7866 - val_mean_absolute_error: 0.7148 - 129ms/epoch - 2ms/step
# Epoch 10/1000
# 80/80 - 0s - loss: 0.7750 - mean_absolute_error: 0.7033 - val_loss: 0.7750 - val_mean_absolute_error: 0.7040 - 127ms/epoch - 2ms/step
# Epoch 11/1000
# 80/80 - 0s - loss: 0.7759 - mean_absolute_error: 0.7060 - val_loss: 0.7840 - val_mean_absolute_error: 0.7109 - 127ms/epoch - 2ms/step
# Epoch 12/1000
# 80/80 - 0s - loss: 0.7726 - mean_absolute_error: 0.7014 - val_loss: 0.7754 - val_mean_absolute_error: 0.7073 - 131ms/epoch - 2ms/step
# Epoch 13/1000
# 80/80 - 0s - loss: 0.7650 - mean_absolute_error: 0.6972 - val_loss: 0.7749 - val_mean_absolute_error: 0.7116 - 127ms/epoch - 2ms/step
# Epoch 14/1000
# 80/80 - 0s - loss: 0.7567 - mean_absolute_error: 0.6903 - val_loss: 0.7661 - val_mean_absolute_error: 0.6995 - 126ms/epoch - 2ms/step
# Epoch 15/1000
# 80/80 - 0s - loss: 0.7535 - mean_absolute_error: 0.6902 - val_loss: 0.7695 - val_mean_absolute_error: 0.6900 - 124ms/epoch - 2ms/step
# Epoch 16/1000
# 80/80 - 0s - loss: 0.7409 - mean_absolute_error: 0.6786 - val_loss: 0.7395 - val_mean_absolute_error: 0.6761 - 126ms/epoch - 2ms/step
# Epoch 17/1000
# 80/80 - 0s - loss: 0.7345 - mean_absolute_error: 0.6742 - val_loss: 0.7510 - val_mean_absolute_error: 0.6791 - 123ms/epoch - 2ms/step
# Epoch 18/1000
# 80/80 - 0s - loss: 0.7227 - mean_absolute_error: 0.6620 - val_loss: 0.7539 - val_mean_absolute_error: 0.6865 - 125ms/epoch - 2ms/step
# Epoch 19/1000
# 80/80 - 0s - loss: 0.7265 - mean_absolute_error: 0.6686 - val_loss: 0.7343 - val_mean_absolute_error: 0.6715 - 130ms/epoch - 2ms/step
# Epoch 20/1000
# 80/80 - 0s - loss: 0.7206 - mean_absolute_error: 0.6602 - val_loss: 0.7579 - val_mean_absolute_error: 0.6749 - 124ms/epoch - 2ms/step
# Epoch 21/1000
# 80/80 - 0s - loss: 0.7135 - mean_absolute_error: 0.6534 - val_loss: 0.7374 - val_mean_absolute_error: 0.6666 - 123ms/epoch - 2ms/step
# Epoch 22/1000
# 80/80 - 0s - loss: 0.7001 - mean_absolute_error: 0.6474 - val_loss: 0.7373 - val_mean_absolute_error: 0.6683 - 124ms/epoch - 2ms/step
# Epoch 23/1000
# 80/80 - 0s - loss: 0.6908 - mean_absolute_error: 0.6417 - val_loss: 0.7382 - val_mean_absolute_error: 0.6581 - 125ms/epoch - 2ms/step
# Epoch 24/1000
# 80/80 - 0s - loss: 0.6759 - mean_absolute_error: 0.6312 - val_loss: 0.7018 - val_mean_absolute_error: 0.6361 - 124ms/epoch - 2ms/step
# Epoch 25/1000
# 80/80 - 0s - loss: 0.6694 - mean_absolute_error: 0.6251 - val_loss: 0.7443 - val_mean_absolute_error: 0.6624 - 124ms/epoch - 2ms/step
# Epoch 26/1000
# 80/80 - 0s - loss: 0.6684 - mean_absolute_error: 0.6239 - val_loss: 0.6709 - val_mean_absolute_error: 0.6219 - 124ms/epoch - 2ms/step
# Epoch 27/1000
# 80/80 - 0s - loss: 0.6426 - mean_absolute_error: 0.6091 - val_loss: 0.6673 - val_mean_absolute_error: 0.6233 - 123ms/epoch - 2ms/step
# Epoch 28/1000
# 80/80 - 0s - loss: 0.6380 - mean_absolute_error: 0.6027 - val_loss: 0.6644 - val_mean_absolute_error: 0.6118 - 124ms/epoch - 2ms/step
# Epoch 29/1000
# 80/80 - 0s - loss: 0.6246 - mean_absolute_error: 0.5938 - val_loss: 0.6427 - val_mean_absolute_error: 0.6044 - 125ms/epoch - 2ms/step
# Epoch 30/1000
# 80/80 - 0s - loss: 0.6282 - mean_absolute_error: 0.5933 - val_loss: 0.6558 - val_mean_absolute_error: 0.6068 - 123ms/epoch - 2ms/step
# Epoch 31/1000
# 80/80 - 0s - loss: 0.6243 - mean_absolute_error: 0.5926 - val_loss: 0.6782 - val_mean_absolute_error: 0.6217 - 125ms/epoch - 2ms/step
# Epoch 32/1000
# 80/80 - 0s - loss: 0.6113 - mean_absolute_error: 0.5847 - val_loss: 0.6554 - val_mean_absolute_error: 0.6040 - 123ms/epoch - 2ms/step
# Epoch 33/1000
# 80/80 - 0s - loss: 0.6156 - mean_absolute_error: 0.5839 - val_loss: 0.6527 - val_mean_absolute_error: 0.6009 - 122ms/epoch - 2ms/step
# Epoch 34/1000
# 80/80 - 0s - loss: 0.5984 - mean_absolute_error: 0.5750 - val_loss: 0.6322 - val_mean_absolute_error: 0.5963 - 123ms/epoch - 2ms/step
# Epoch 35/1000
# 80/80 - 0s - loss: 0.6057 - mean_absolute_error: 0.5778 - val_loss: 0.6394 - val_mean_absolute_error: 0.5940 - 123ms/epoch - 2ms/step
# Epoch 36/1000
# 80/80 - 0s - loss: 0.5888 - mean_absolute_error: 0.5662 - val_loss: 0.6349 - val_mean_absolute_error: 0.5901 - 124ms/epoch - 2ms/step
# Epoch 37/1000
# 80/80 - 0s - loss: 0.5985 - mean_absolute_error: 0.5734 - val_loss: 0.6594 - val_mean_absolute_error: 0.6013 - 124ms/epoch - 2ms/step
# Epoch 38/1000
# 80/80 - 0s - loss: 0.5944 - mean_absolute_error: 0.5659 - val_loss: 0.6469 - val_mean_absolute_error: 0.5913 - 123ms/epoch - 2ms/step
# Epoch 39/1000
# 80/80 - 0s - loss: 0.5846 - mean_absolute_error: 0.5616 - val_loss: 0.6630 - val_mean_absolute_error: 0.6035 - 124ms/epoch - 2ms/step
# Epoch 40/1000
# 80/80 - 0s - loss: 0.5824 - mean_absolute_error: 0.5603 - val_loss: 0.6420 - val_mean_absolute_error: 0.5928 - 122ms/epoch - 2ms/step
# Epoch 41/1000
# 80/80 - 0s - loss: 0.5849 - mean_absolute_error: 0.5631 - val_loss: 0.6277 - val_mean_absolute_error: 0.5831 - 123ms/epoch - 2ms/step
# Epoch 42/1000
# 80/80 - 0s - loss: 0.5659 - mean_absolute_error: 0.5509 - val_loss: 0.6496 - val_mean_absolute_error: 0.5892 - 123ms/epoch - 2ms/step
# Epoch 43/1000
# 80/80 - 0s - loss: 0.5813 - mean_absolute_error: 0.5589 - val_loss: 0.6328 - val_mean_absolute_error: 0.5843 - 123ms/epoch - 2ms/step
# Epoch 44/1000
# 80/80 - 0s - loss: 0.5665 - mean_absolute_error: 0.5489 - val_loss: 0.6403 - val_mean_absolute_error: 0.5951 - 123ms/epoch - 2ms/step
# Epoch 45/1000
# 80/80 - 0s - loss: 0.5658 - mean_absolute_error: 0.5484 - val_loss: 0.6370 - val_mean_absolute_error: 0.5859 - 124ms/epoch - 2ms/step
# Epoch 46/1000
# 80/80 - 0s - loss: 0.5706 - mean_absolute_error: 0.5512 - val_loss: 0.6377 - val_mean_absolute_error: 0.5917 - 121ms/epoch - 2ms/step
# Epoch 47/1000
# 80/80 - 0s - loss: 0.5561 - mean_absolute_error: 0.5447 - val_loss: 0.6544 - val_mean_absolute_error: 0.5932 - 124ms/epoch - 2ms/step
# Epoch 48/1000
# 80/80 - 0s - loss: 0.5724 - mean_absolute_error: 0.5534 - val_loss: 0.6316 - val_mean_absolute_error: 0.5834 - 124ms/epoch - 2ms/step
# Epoch 49/1000
# 80/80 - 0s - loss: 0.5593 - mean_absolute_error: 0.5433 - val_loss: 0.6294 - val_mean_absolute_error: 0.5844 - 125ms/epoch - 2ms/step
# Epoch 50/1000
# 80/80 - 0s - loss: 0.5540 - mean_absolute_error: 0.5445 - val_loss: 0.6242 - val_mean_absolute_error: 0.5802 - 129ms/epoch - 2ms/step
# Epoch 51/1000
# 80/80 - 0s - loss: 0.5552 - mean_absolute_error: 0.5407 - val_loss: 0.6576 - val_mean_absolute_error: 0.5946 - 123ms/epoch - 2ms/step
# Epoch 52/1000
# 80/80 - 0s - loss: 0.5624 - mean_absolute_error: 0.5452 - val_loss: 0.6179 - val_mean_absolute_error: 0.5734 - 124ms/epoch - 2ms/step
# Epoch 53/1000
# 80/80 - 0s - loss: 0.5421 - mean_absolute_error: 0.5321 - val_loss: 0.6863 - val_mean_absolute_error: 0.6014 - 126ms/epoch - 2ms/step
# Epoch 54/1000
# 80/80 - 0s - loss: 0.5468 - mean_absolute_error: 0.5344 - val_loss: 0.6439 - val_mean_absolute_error: 0.5794 - 124ms/epoch - 2ms/step
# Epoch 55/1000
# 80/80 - 0s - loss: 0.5433 - mean_absolute_error: 0.5325 - val_loss: 0.6322 - val_mean_absolute_error: 0.5809 - 126ms/epoch - 2ms/step
# Epoch 56/1000
# 80/80 - 0s - loss: 0.5335 - mean_absolute_error: 0.5260 - val_loss: 0.6407 - val_mean_absolute_error: 0.5831 - 123ms/epoch - 2ms/step
# Epoch 57/1000
# 80/80 - 0s - loss: 0.5467 - mean_absolute_error: 0.5332 - val_loss: 0.6419 - val_mean_absolute_error: 0.5825 - 122ms/epoch - 2ms/step
# Epoch 58/1000
# 80/80 - 0s - loss: 0.5370 - mean_absolute_error: 0.5314 - val_loss: 0.6380 - val_mean_absolute_error: 0.5795 - 124ms/epoch - 2ms/step
# Epoch 59/1000
# 80/80 - 0s - loss: 0.5346 - mean_absolute_error: 0.5280 - val_loss: 0.6489 - val_mean_absolute_error: 0.5857 - 124ms/epoch - 2ms/step
# Epoch 60/1000
# 80/80 - 0s - loss: 0.5231 - mean_absolute_error: 0.5213 - val_loss: 0.6445 - val_mean_absolute_error: 0.5793 - 125ms/epoch - 2ms/step
# Epoch 61/1000
# 80/80 - 0s - loss: 0.5227 - mean_absolute_error: 0.5178 - val_loss: 0.6409 - val_mean_absolute_error: 0.5820 - 123ms/epoch - 2ms/step
# Epoch 62/1000
# 80/80 - 0s - loss: 0.5175 - mean_absolute_error: 0.5127 - val_loss: 0.6282 - val_mean_absolute_error: 0.5746 - 123ms/epoch - 2ms/step
# Epoch 63/1000
# 80/80 - 0s - loss: 0.5186 - mean_absolute_error: 0.5162 - val_loss: 0.6502 - val_mean_absolute_error: 0.5836 - 124ms/epoch - 2ms/step
# Epoch 64/1000
# 80/80 - 0s - loss: 0.5217 - mean_absolute_error: 0.5161 - val_loss: 0.6447 - val_mean_absolute_error: 0.5817 - 124ms/epoch - 2ms/step
# Epoch 65/1000
# 80/80 - 0s - loss: 0.5142 - mean_absolute_error: 0.5123 - val_loss: 0.6953 - val_mean_absolute_error: 0.5935 - 124ms/epoch - 2ms/step
# Epoch 66/1000
# 80/80 - 0s - loss: 0.5310 - mean_absolute_error: 0.5220 - val_loss: 0.6540 - val_mean_absolute_error: 0.5895 - 124ms/epoch - 2ms/step
# Epoch 67/1000
# 80/80 - 0s - loss: 0.5193 - mean_absolute_error: 0.5159 - val_loss: 0.6926 - val_mean_absolute_error: 0.6013 - 124ms/epoch - 2ms/step
# Epoch 68/1000
# 80/80 - 0s - loss: 0.5150 - mean_absolute_error: 0.5130 - val_loss: 0.6432 - val_mean_absolute_error: 0.5810 - 126ms/epoch - 2ms/step
# Epoch 69/1000
# 80/80 - 0s - loss: 0.5075 - mean_absolute_error: 0.5061 - val_loss: 0.6536 - val_mean_absolute_error: 0.5836 - 123ms/epoch - 2ms/step
# Epoch 70/1000
# 80/80 - 0s - loss: 0.5092 - mean_absolute_error: 0.5091 - val_loss: 0.6650 - val_mean_absolute_error: 0.5949 - 122ms/epoch - 2ms/step
# Epoch 71/1000
# 80/80 - 0s - loss: 0.5067 - mean_absolute_error: 0.5051 - val_loss: 0.6631 - val_mean_absolute_error: 0.5849 - 125ms/epoch - 2ms/step
# Epoch 72/1000
# 80/80 - 0s - loss: 0.5075 - mean_absolute_error: 0.5083 - val_loss: 0.6506 - val_mean_absolute_error: 0.5892 - 124ms/epoch - 2ms/step
# Epoch 73/1000
# 80/80 - 0s - loss: 0.5020 - mean_absolute_error: 0.5070 - val_loss: 0.6695 - val_mean_absolute_error: 0.6003 - 123ms/epoch - 2ms/step
# Epoch 74/1000
# 80/80 - 0s - loss: 0.4987 - mean_absolute_error: 0.5029 - val_loss: 0.6659 - val_mean_absolute_error: 0.5865 - 125ms/epoch - 2ms/step
# Epoch 75/1000
# 80/80 - 0s - loss: 0.5087 - mean_absolute_error: 0.5078 - val_loss: 0.6530 - val_mean_absolute_error: 0.5852 - 124ms/epoch - 2ms/step
# Epoch 76/1000
# 80/80 - 0s - loss: 0.4984 - mean_absolute_error: 0.5045 - val_loss: 0.6678 - val_mean_absolute_error: 0.5831 - 124ms/epoch - 2ms/step
# Epoch 77/1000
# 80/80 - 0s - loss: 0.5001 - mean_absolute_error: 0.5025 - val_loss: 0.6821 - val_mean_absolute_error: 0.5828 - 126ms/epoch - 2ms/step
# Epoch 78/1000
# 80/80 - 0s - loss: 0.4901 - mean_absolute_error: 0.4957 - val_loss: 0.6490 - val_mean_absolute_error: 0.5818 - 124ms/epoch - 2ms/step
# Epoch 79/1000
# 80/80 - 0s - loss: 0.4834 - mean_absolute_error: 0.4915 - val_loss: 0.6888 - val_mean_absolute_error: 0.5954 - 125ms/epoch - 2ms/step
# Epoch 80/1000
# 80/80 - 0s - loss: 0.4772 - mean_absolute_error: 0.4890 - val_loss: 0.6721 - val_mean_absolute_error: 0.5828 - 123ms/epoch - 2ms/step
# Epoch 81/1000
# 80/80 - 0s - loss: 0.4833 - mean_absolute_error: 0.4930 - val_loss: 0.6818 - val_mean_absolute_error: 0.5956 - 123ms/epoch - 2ms/step
# Epoch 82/1000
# 80/80 - 0s - loss: 0.4880 - mean_absolute_error: 0.4942 - val_loss: 0.7110 - val_mean_absolute_error: 0.6017 - 124ms/epoch - 2ms/step
# Epoch 83/1000
# 80/80 - 0s - loss: 0.4791 - mean_absolute_error: 0.4909 - val_loss: 0.6565 - val_mean_absolute_error: 0.5848 - 124ms/epoch - 2ms/step
# Epoch 84/1000
# 80/80 - 0s - loss: 0.4710 - mean_absolute_error: 0.4858 - val_loss: 0.6686 - val_mean_absolute_error: 0.5830 - 139ms/epoch - 2ms/step
# Epoch 85/1000
# 80/80 - 0s - loss: 0.4805 - mean_absolute_error: 0.4919 - val_loss: 0.6657 - val_mean_absolute_error: 0.5841 - 124ms/epoch - 2ms/step
# Epoch 86/1000
# 80/80 - 0s - loss: 0.4832 - mean_absolute_error: 0.4912 - val_loss: 0.6892 - val_mean_absolute_error: 0.5995 - 125ms/epoch - 2ms/step
# Epoch 87/1000
# 80/80 - 0s - loss: 0.4894 - mean_absolute_error: 0.4969 - val_loss: 0.6824 - val_mean_absolute_error: 0.6024 - 124ms/epoch - 2ms/step
# Epoch 88/1000
# 80/80 - 0s - loss: 0.4758 - mean_absolute_error: 0.4898 - val_loss: 0.6636 - val_mean_absolute_error: 0.5798 - 123ms/epoch - 2ms/step
# Epoch 89/1000
# 80/80 - 0s - loss: 0.4684 - mean_absolute_error: 0.4815 - val_loss: 0.6539 - val_mean_absolute_error: 0.5740 - 123ms/epoch - 2ms/step
# Epoch 90/1000
# 80/80 - 0s - loss: 0.4625 - mean_absolute_error: 0.4796 - val_loss: 0.6717 - val_mean_absolute_error: 0.5905 - 123ms/epoch - 2ms/step
# Epoch 91/1000
# 80/80 - 0s - loss: 0.4600 - mean_absolute_error: 0.4773 - val_loss: 0.6939 - val_mean_absolute_error: 0.5998 - 124ms/epoch - 2ms/step
# Epoch 92/1000
# 80/80 - 0s - loss: 0.4533 - mean_absolute_error: 0.4714 - val_loss: 0.6868 - val_mean_absolute_error: 0.5897 - 123ms/epoch - 2ms/step
# Epoch 93/1000
# 80/80 - 0s - loss: 0.4620 - mean_absolute_error: 0.4776 - val_loss: 0.6773 - val_mean_absolute_error: 0.5849 - 124ms/epoch - 2ms/step
# Epoch 94/1000
# 80/80 - 0s - loss: 0.4646 - mean_absolute_error: 0.4793 - val_loss: 0.6618 - val_mean_absolute_error: 0.5820 - 123ms/epoch - 2ms/step
# Epoch 95/1000
# 80/80 - 0s - loss: 0.4594 - mean_absolute_error: 0.4774 - val_loss: 0.6759 - val_mean_absolute_error: 0.5898 - 124ms/epoch - 2ms/step
# Epoch 96/1000
# 80/80 - 0s - loss: 0.4572 - mean_absolute_error: 0.4768 - val_loss: 0.7034 - val_mean_absolute_error: 0.5977 - 124ms/epoch - 2ms/step
# Epoch 97/1000
# 80/80 - 0s - loss: 0.4738 - mean_absolute_error: 0.4872 - val_loss: 0.6942 - val_mean_absolute_error: 0.5938 - 122ms/epoch - 2ms/step
# Epoch 98/1000
# 80/80 - 0s - loss: 0.4699 - mean_absolute_error: 0.4840 - val_loss: 0.6761 - val_mean_absolute_error: 0.5920 - 122ms/epoch - 2ms/step
# Epoch 99/1000
# 80/80 - 0s - loss: 0.4496 - mean_absolute_error: 0.4726 - val_loss: 0.6764 - val_mean_absolute_error: 0.5876 - 123ms/epoch - 2ms/step
# Epoch 100/1000
# 80/80 - 0s - loss: 0.4539 - mean_absolute_error: 0.4725 - val_loss: 0.7003 - val_mean_absolute_error: 0.5983 - 125ms/epoch - 2ms/step
# Epoch 101/1000
# 80/80 - 0s - loss: 0.4613 - mean_absolute_error: 0.4756 - val_loss: 0.6891 - val_mean_absolute_error: 0.5937 - 125ms/epoch - 2ms/step
# Epoch 102/1000
# 80/80 - 0s - loss: 0.4425 - mean_absolute_error: 0.4653 - val_loss: 0.6880 - val_mean_absolute_error: 0.5911 - 123ms/epoch - 2ms/step
# Epoch 103/1000
# 80/80 - 0s - loss: 0.4388 - mean_absolute_error: 0.4628 - val_loss: 0.6872 - val_mean_absolute_error: 0.5891 - 125ms/epoch - 2ms/step
# Epoch 104/1000
# 80/80 - 0s - loss: 0.4372 - mean_absolute_error: 0.4615 - val_loss: 0.6931 - val_mean_absolute_error: 0.5898 - 123ms/epoch - 2ms/step
# Epoch 105/1000
# 80/80 - 0s - loss: 0.4497 - mean_absolute_error: 0.4689 - val_loss: 0.6937 - val_mean_absolute_error: 0.5933 - 123ms/epoch - 2ms/step
# Epoch 106/1000
# 80/80 - 0s - loss: 0.4317 - mean_absolute_error: 0.4603 - val_loss: 0.7102 - val_mean_absolute_error: 0.5962 - 122ms/epoch - 2ms/step
# Epoch 107/1000
# 80/80 - 0s - loss: 0.4441 - mean_absolute_error: 0.4642 - val_loss: 0.6788 - val_mean_absolute_error: 0.5875 - 124ms/epoch - 2ms/step
# Epoch 108/1000
# 80/80 - 0s - loss: 0.4318 - mean_absolute_error: 0.4587 - val_loss: 0.6891 - val_mean_absolute_error: 0.5865 - 124ms/epoch - 2ms/step
# Epoch 109/1000
# 80/80 - 0s - loss: 0.4338 - mean_absolute_error: 0.4592 - val_loss: 0.6977 - val_mean_absolute_error: 0.5926 - 123ms/epoch - 2ms/step
# Epoch 110/1000
# 80/80 - 0s - loss: 0.4291 - mean_absolute_error: 0.4573 - val_loss: 0.7279 - val_mean_absolute_error: 0.6074 - 124ms/epoch - 2ms/step
# Epoch 111/1000
# 80/80 - 0s - loss: 0.4245 - mean_absolute_error: 0.4534 - val_loss: 0.7077 - val_mean_absolute_error: 0.5907 - 124ms/epoch - 2ms/step
# Epoch 112/1000
# 80/80 - 0s - loss: 0.4282 - mean_absolute_error: 0.4555 - val_loss: 0.6987 - val_mean_absolute_error: 0.5910 - 123ms/epoch - 2ms/step
# Epoch 113/1000
# 80/80 - 0s - loss: 0.4327 - mean_absolute_error: 0.4578 - val_loss: 0.6888 - val_mean_absolute_error: 0.5912 - 123ms/epoch - 2ms/step
# Epoch 114/1000
# 80/80 - 0s - loss: 0.4328 - mean_absolute_error: 0.4594 - val_loss: 0.7166 - val_mean_absolute_error: 0.6054 - 123ms/epoch - 2ms/step
# Epoch 115/1000
# 80/80 - 0s - loss: 0.4284 - mean_absolute_error: 0.4563 - val_loss: 0.7388 - val_mean_absolute_error: 0.5996 - 123ms/epoch - 2ms/step
# Epoch 116/1000
# 80/80 - 0s - loss: 0.4186 - mean_absolute_error: 0.4498 - val_loss: 0.7068 - val_mean_absolute_error: 0.5953 - 123ms/epoch - 2ms/step
# Epoch 117/1000
# 80/80 - 0s - loss: 0.4111 - mean_absolute_error: 0.4453 - val_loss: 0.7166 - val_mean_absolute_error: 0.6023 - 122ms/epoch - 2ms/step
# Epoch 118/1000
# 80/80 - 0s - loss: 0.4145 - mean_absolute_error: 0.4461 - val_loss: 0.6979 - val_mean_absolute_error: 0.5971 - 123ms/epoch - 2ms/step
# Epoch 119/1000
# 80/80 - 0s - loss: 0.4136 - mean_absolute_error: 0.4455 - val_loss: 0.7262 - val_mean_absolute_error: 0.5979 - 127ms/epoch - 2ms/step
# Epoch 120/1000
# 80/80 - 0s - loss: 0.4255 - mean_absolute_error: 0.4539 - val_loss: 0.6995 - val_mean_absolute_error: 0.5932 - 124ms/epoch - 2ms/step
# Epoch 121/1000
# 80/80 - 0s - loss: 0.4209 - mean_absolute_error: 0.4494 - val_loss: 0.6977 - val_mean_absolute_error: 0.5889 - 129ms/epoch - 2ms/step
# Epoch 122/1000
# 80/80 - 0s - loss: 0.4038 - mean_absolute_error: 0.4402 - val_loss: 0.6805 - val_mean_absolute_error: 0.5840 - 124ms/epoch - 2ms/step
# Epoch 123/1000
# 80/80 - 0s - loss: 0.4178 - mean_absolute_error: 0.4504 - val_loss: 0.7217 - val_mean_absolute_error: 0.5992 - 123ms/epoch - 2ms/step
# Epoch 124/1000
# 80/80 - 0s - loss: 0.3981 - mean_absolute_error: 0.4356 - val_loss: 0.7170 - val_mean_absolute_error: 0.6004 - 125ms/epoch - 2ms/step
# Epoch 125/1000
# 80/80 - 0s - loss: 0.4325 - mean_absolute_error: 0.4582 - val_loss: 0.7635 - val_mean_absolute_error: 0.6171 - 128ms/epoch - 2ms/step
# Epoch 126/1000
# 80/80 - 0s - loss: 0.4049 - mean_absolute_error: 0.4402 - val_loss: 0.7232 - val_mean_absolute_error: 0.5973 - 125ms/epoch - 2ms/step
# Epoch 127/1000
# 80/80 - 0s - loss: 0.3997 - mean_absolute_error: 0.4377 - val_loss: 0.7458 - val_mean_absolute_error: 0.6054 - 124ms/epoch - 2ms/step
# Epoch 128/1000
# 80/80 - 0s - loss: 0.4024 - mean_absolute_error: 0.4379 - val_loss: 0.7425 - val_mean_absolute_error: 0.6025 - 123ms/epoch - 2ms/step
# Epoch 129/1000
# 80/80 - 0s - loss: 0.4042 - mean_absolute_error: 0.4382 - val_loss: 0.7248 - val_mean_absolute_error: 0.5956 - 124ms/epoch - 2ms/step
# Epoch 130/1000
# 80/80 - 0s - loss: 0.3925 - mean_absolute_error: 0.4320 - val_loss: 0.7113 - val_mean_absolute_error: 0.5957 - 124ms/epoch - 2ms/step
# Epoch 131/1000
# 80/80 - 0s - loss: 0.3983 - mean_absolute_error: 0.4375 - val_loss: 0.7206 - val_mean_absolute_error: 0.5981 - 123ms/epoch - 2ms/step
# Epoch 132/1000
# 80/80 - 0s - loss: 0.4137 - mean_absolute_error: 0.4430 - val_loss: 0.6970 - val_mean_absolute_error: 0.5902 - 123ms/epoch - 2ms/step
# Epoch 133/1000
# 80/80 - 0s - loss: 0.3839 - mean_absolute_error: 0.4250 - val_loss: 0.7288 - val_mean_absolute_error: 0.6028 - 124ms/epoch - 2ms/step
# Epoch 134/1000
# 80/80 - 0s - loss: 0.3869 - mean_absolute_error: 0.4248 - val_loss: 0.7085 - val_mean_absolute_error: 0.5953 - 123ms/epoch - 2ms/step
# Epoch 135/1000
# 80/80 - 0s - loss: 0.3817 - mean_absolute_error: 0.4274 - val_loss: 0.7326 - val_mean_absolute_error: 0.6088 - 125ms/epoch - 2ms/step
# Epoch 136/1000
# 80/80 - 0s - loss: 0.3808 - mean_absolute_error: 0.4223 - val_loss: 0.7138 - val_mean_absolute_error: 0.5913 - 123ms/epoch - 2ms/step
# Epoch 137/1000
# 80/80 - 0s - loss: 0.3981 - mean_absolute_error: 0.4338 - val_loss: 0.7160 - val_mean_absolute_error: 0.5951 - 123ms/epoch - 2ms/step
# Epoch 138/1000
# 80/80 - 0s - loss: 0.3777 - mean_absolute_error: 0.4202 - val_loss: 0.7365 - val_mean_absolute_error: 0.6068 - 123ms/epoch - 2ms/step
# Epoch 139/1000
# 80/80 - 0s - loss: 0.3821 - mean_absolute_error: 0.4254 - val_loss: 0.7221 - val_mean_absolute_error: 0.5985 - 124ms/epoch - 2ms/step
# Epoch 140/1000
# 80/80 - 0s - loss: 0.3830 - mean_absolute_error: 0.4246 - val_loss: 0.7365 - val_mean_absolute_error: 0.5989 - 123ms/epoch - 2ms/step
# Epoch 141/1000
# 80/80 - 0s - loss: 0.3805 - mean_absolute_error: 0.4205 - val_loss: 0.7527 - val_mean_absolute_error: 0.6097 - 124ms/epoch - 2ms/step
# Epoch 142/1000
# 80/80 - 0s - loss: 0.3787 - mean_absolute_error: 0.4206 - val_loss: 0.7241 - val_mean_absolute_error: 0.6012 - 124ms/epoch - 2ms/step
# Epoch 143/1000
# 80/80 - 0s - loss: 0.3884 - mean_absolute_error: 0.4302 - val_loss: 0.7200 - val_mean_absolute_error: 0.6024 - 123ms/epoch - 2ms/step
# Epoch 144/1000
# 80/80 - 0s - loss: 0.3710 - mean_absolute_error: 0.4156 - val_loss: 0.7293 - val_mean_absolute_error: 0.6021 - 123ms/epoch - 2ms/step
# Epoch 145/1000
# 80/80 - 0s - loss: 0.3736 - mean_absolute_error: 0.4186 - val_loss: 0.7376 - val_mean_absolute_error: 0.6009 - 124ms/epoch - 2ms/step
# Epoch 146/1000
# 80/80 - 0s - loss: 0.3678 - mean_absolute_error: 0.4135 - val_loss: 0.7340 - val_mean_absolute_error: 0.5980 - 123ms/epoch - 2ms/step
# Epoch 147/1000
# 80/80 - 0s - loss: 0.3684 - mean_absolute_error: 0.4141 - val_loss: 0.7355 - val_mean_absolute_error: 0.6009 - 123ms/epoch - 2ms/step
# Epoch 148/1000
# 80/80 - 0s - loss: 0.3647 - mean_absolute_error: 0.4121 - val_loss: 0.7267 - val_mean_absolute_error: 0.6040 - 124ms/epoch - 2ms/step
# Epoch 149/1000
# 80/80 - 0s - loss: 0.3720 - mean_absolute_error: 0.4162 - val_loss: 0.7376 - val_mean_absolute_error: 0.6071 - 125ms/epoch - 2ms/step
# Epoch 150/1000
# 80/80 - 0s - loss: 0.3740 - mean_absolute_error: 0.4197 - val_loss: 0.7197 - val_mean_absolute_error: 0.6001 - 124ms/epoch - 2ms/step
# Epoch 151/1000
# 80/80 - 0s - loss: 0.3810 - mean_absolute_error: 0.4238 - val_loss: 0.7622 - val_mean_absolute_error: 0.6099 - 124ms/epoch - 2ms/step
# Epoch 152/1000
# 80/80 - 0s - loss: 0.3702 - mean_absolute_error: 0.4151 - val_loss: 0.7294 - val_mean_absolute_error: 0.6008 - 122ms/epoch - 2ms/step
# Epoch 153/1000
# 80/80 - 0s - loss: 0.3532 - mean_absolute_error: 0.4036 - val_loss: 0.7329 - val_mean_absolute_error: 0.6039 - 123ms/epoch - 2ms/step
# Epoch 154/1000
# 80/80 - 0s - loss: 0.3599 - mean_absolute_error: 0.4056 - val_loss: 0.7295 - val_mean_absolute_error: 0.6056 - 122ms/epoch - 2ms/step
# Epoch 155/1000
# 80/80 - 0s - loss: 0.3561 - mean_absolute_error: 0.4061 - val_loss: 0.7310 - val_mean_absolute_error: 0.6022 - 124ms/epoch - 2ms/step
# Epoch 156/1000
# 80/80 - 0s - loss: 0.3760 - mean_absolute_error: 0.4186 - val_loss: 0.7343 - val_mean_absolute_error: 0.6034 - 125ms/epoch - 2ms/step
# Epoch 157/1000
# 80/80 - 0s - loss: 0.3523 - mean_absolute_error: 0.4048 - val_loss: 0.7367 - val_mean_absolute_error: 0.6055 - 126ms/epoch - 2ms/step
# Epoch 158/1000
# 80/80 - 0s - loss: 0.3664 - mean_absolute_error: 0.4134 - val_loss: 0.7416 - val_mean_absolute_error: 0.6062 - 123ms/epoch - 2ms/step
# Epoch 159/1000
# 80/80 - 0s - loss: 0.3708 - mean_absolute_error: 0.4157 - val_loss: 0.7316 - val_mean_absolute_error: 0.5988 - 123ms/epoch - 2ms/step
# Epoch 160/1000
# 80/80 - 0s - loss: 0.3555 - mean_absolute_error: 0.4069 - val_loss: 0.7391 - val_mean_absolute_error: 0.6048 - 123ms/epoch - 2ms/step
# Epoch 161/1000
# 80/80 - 0s - loss: 0.3511 - mean_absolute_error: 0.4034 - val_loss: 0.7517 - val_mean_absolute_error: 0.6100 - 124ms/epoch - 2ms/step
# Epoch 162/1000
# 80/80 - 0s - loss: 0.3534 - mean_absolute_error: 0.4035 - val_loss: 0.7351 - val_mean_absolute_error: 0.6016 - 123ms/epoch - 2ms/step
# Epoch 163/1000
# 80/80 - 0s - loss: 0.3468 - mean_absolute_error: 0.3996 - val_loss: 0.7415 - val_mean_absolute_error: 0.6036 - 124ms/epoch - 2ms/step
# Epoch 164/1000
# 80/80 - 0s - loss: 0.3409 - mean_absolute_error: 0.3945 - val_loss: 0.7298 - val_mean_absolute_error: 0.5967 - 124ms/epoch - 2ms/step
# Epoch 165/1000
# 80/80 - 0s - loss: 0.3554 - mean_absolute_error: 0.4056 - val_loss: 0.7431 - val_mean_absolute_error: 0.6048 - 125ms/epoch - 2ms/step
# Epoch 166/1000
# 80/80 - 0s - loss: 0.3600 - mean_absolute_error: 0.4107 - val_loss: 0.7632 - val_mean_absolute_error: 0.6094 - 123ms/epoch - 2ms/step
# Epoch 167/1000
# 80/80 - 0s - loss: 0.3478 - mean_absolute_error: 0.4022 - val_loss: 0.7382 - val_mean_absolute_error: 0.6076 - 125ms/epoch - 2ms/step
# Epoch 168/1000
# 80/80 - 0s - loss: 0.3409 - mean_absolute_error: 0.3970 - val_loss: 0.7828 - val_mean_absolute_error: 0.6145 - 125ms/epoch - 2ms/step
# Epoch 169/1000
# 80/80 - 0s - loss: 0.3431 - mean_absolute_error: 0.3967 - val_loss: 0.7360 - val_mean_absolute_error: 0.6081 - 124ms/epoch - 2ms/step
# Epoch 170/1000
# 80/80 - 0s - loss: 0.3342 - mean_absolute_error: 0.3885 - val_loss: 0.7691 - val_mean_absolute_error: 0.6113 - 125ms/epoch - 2ms/step
# Epoch 171/1000
# 80/80 - 0s - loss: 0.3415 - mean_absolute_error: 0.3948 - val_loss: 0.7673 - val_mean_absolute_error: 0.6131 - 125ms/epoch - 2ms/step
# Epoch 172/1000
# 80/80 - 0s - loss: 0.3399 - mean_absolute_error: 0.3930 - val_loss: 0.7389 - val_mean_absolute_error: 0.6002 - 124ms/epoch - 2ms/step
# Epoch 173/1000
# 80/80 - 0s - loss: 0.3447 - mean_absolute_error: 0.3946 - val_loss: 0.7432 - val_mean_absolute_error: 0.6026 - 125ms/epoch - 2ms/step
# Epoch 174/1000
# 80/80 - 0s - loss: 0.3309 - mean_absolute_error: 0.3879 - val_loss: 0.7583 - val_mean_absolute_error: 0.6164 - 125ms/epoch - 2ms/step
# Epoch 175/1000
# 80/80 - 0s - loss: 0.3415 - mean_absolute_error: 0.3967 - val_loss: 0.7380 - val_mean_absolute_error: 0.6026 - 124ms/epoch - 2ms/step
# Epoch 176/1000
# 80/80 - 0s - loss: 0.3379 - mean_absolute_error: 0.3924 - val_loss: 0.7907 - val_mean_absolute_error: 0.6219 - 124ms/epoch - 2ms/step
# Epoch 177/1000
# 80/80 - 0s - loss: 0.3415 - mean_absolute_error: 0.3946 - val_loss: 0.7697 - val_mean_absolute_error: 0.6130 - 134ms/epoch - 2ms/step
# Epoch 178/1000
# 80/80 - 0s - loss: 0.3445 - mean_absolute_error: 0.3980 - val_loss: 0.7568 - val_mean_absolute_error: 0.6061 - 127ms/epoch - 2ms/step
# Epoch 179/1000
# 80/80 - 0s - loss: 0.3218 - mean_absolute_error: 0.3825 - val_loss: 0.8026 - val_mean_absolute_error: 0.6247 - 123ms/epoch - 2ms/step
# Epoch 180/1000
# 80/80 - 0s - loss: 0.3405 - mean_absolute_error: 0.3933 - val_loss: 0.7437 - val_mean_absolute_error: 0.6106 - 125ms/epoch - 2ms/step
# Epoch 181/1000
# 80/80 - 0s - loss: 0.3383 - mean_absolute_error: 0.3909 - val_loss: 0.7794 - val_mean_absolute_error: 0.6113 - 125ms/epoch - 2ms/step
# Epoch 182/1000
# 80/80 - 0s - loss: 0.3204 - mean_absolute_error: 0.3802 - val_loss: 0.7452 - val_mean_absolute_error: 0.6053 - 124ms/epoch - 2ms/step
# Epoch 183/1000
# 80/80 - 0s - loss: 0.3168 - mean_absolute_error: 0.3787 - val_loss: 0.7595 - val_mean_absolute_error: 0.6123 - 124ms/epoch - 2ms/step
# Epoch 184/1000
# 80/80 - 0s - loss: 0.3474 - mean_absolute_error: 0.3970 - val_loss: 0.7885 - val_mean_absolute_error: 0.6220 - 126ms/epoch - 2ms/step
# Epoch 185/1000
# 80/80 - 0s - loss: 0.3307 - mean_absolute_error: 0.3877 - val_loss: 0.7492 - val_mean_absolute_error: 0.6064 - 124ms/epoch - 2ms/step
# Epoch 186/1000
# 80/80 - 0s - loss: 0.3160 - mean_absolute_error: 0.3767 - val_loss: 0.7621 - val_mean_absolute_error: 0.6095 - 124ms/epoch - 2ms/step
# Epoch 187/1000
# 80/80 - 0s - loss: 0.3364 - mean_absolute_error: 0.3929 - val_loss: 0.7444 - val_mean_absolute_error: 0.6095 - 123ms/epoch - 2ms/step
# Epoch 188/1000
# 80/80 - 0s - loss: 0.3156 - mean_absolute_error: 0.3786 - val_loss: 0.7600 - val_mean_absolute_error: 0.6042 - 124ms/epoch - 2ms/step
# Epoch 189/1000
# 80/80 - 0s - loss: 0.3096 - mean_absolute_error: 0.3736 - val_loss: 0.7646 - val_mean_absolute_error: 0.6141 - 124ms/epoch - 2ms/step
# Epoch 190/1000
# 80/80 - 0s - loss: 0.3179 - mean_absolute_error: 0.3826 - val_loss: 0.7598 - val_mean_absolute_error: 0.6074 - 125ms/epoch - 2ms/step
# Epoch 191/1000
# 80/80 - 0s - loss: 0.3115 - mean_absolute_error: 0.3734 - val_loss: 0.7732 - val_mean_absolute_error: 0.6189 - 125ms/epoch - 2ms/step
# Epoch 192/1000
# 80/80 - 0s - loss: 0.3183 - mean_absolute_error: 0.3832 - val_loss: 0.7899 - val_mean_absolute_error: 0.6144 - 129ms/epoch - 2ms/step
# Epoch 193/1000
# 80/80 - 0s - loss: 0.3146 - mean_absolute_error: 0.3776 - val_loss: 0.7808 - val_mean_absolute_error: 0.6148 - 123ms/epoch - 2ms/step
# Epoch 194/1000
# 80/80 - 0s - loss: 0.3107 - mean_absolute_error: 0.3747 - val_loss: 0.7656 - val_mean_absolute_error: 0.6058 - 124ms/epoch - 2ms/step
# Epoch 195/1000
# 80/80 - 0s - loss: 0.3130 - mean_absolute_error: 0.3735 - val_loss: 0.8082 - val_mean_absolute_error: 0.6275 - 125ms/epoch - 2ms/step
# Epoch 196/1000
# 80/80 - 0s - loss: 0.3349 - mean_absolute_error: 0.3917 - val_loss: 0.7587 - val_mean_absolute_error: 0.6063 - 126ms/epoch - 2ms/step
# Epoch 197/1000
# 80/80 - 0s - loss: 0.2992 - mean_absolute_error: 0.3651 - val_loss: 0.8112 - val_mean_absolute_error: 0.6208 - 123ms/epoch - 2ms/step
# Epoch 198/1000
# 80/80 - 0s - loss: 0.3048 - mean_absolute_error: 0.3702 - val_loss: 0.7771 - val_mean_absolute_error: 0.6113 - 125ms/epoch - 2ms/step
# Epoch 199/1000
# 80/80 - 0s - loss: 0.3086 - mean_absolute_error: 0.3701 - val_loss: 0.7644 - val_mean_absolute_error: 0.6081 - 123ms/epoch - 2ms/step
# Epoch 200/1000
# 80/80 - 0s - loss: 0.3069 - mean_absolute_error: 0.3721 - val_loss: 0.7773 - val_mean_absolute_error: 0.6090 - 124ms/epoch - 2ms/step
# Epoch 201/1000
# 80/80 - 0s - loss: 0.2929 - mean_absolute_error: 0.3582 - val_loss: 0.7707 - val_mean_absolute_error: 0.6103 - 127ms/epoch - 2ms/step
# Epoch 202/1000
# 80/80 - 0s - loss: 0.2957 - mean_absolute_error: 0.3622 - val_loss: 0.7687 - val_mean_absolute_error: 0.6104 - 124ms/epoch - 2ms/step
# Epoch 203/1000
# 80/80 - 0s - loss: 0.3166 - mean_absolute_error: 0.3751 - val_loss: 0.7612 - val_mean_absolute_error: 0.6091 - 125ms/epoch - 2ms/step
# Epoch 204/1000
# 80/80 - 0s - loss: 0.2830 - mean_absolute_error: 0.3539 - val_loss: 0.8057 - val_mean_absolute_error: 0.6217 - 124ms/epoch - 2ms/step
# Epoch 205/1000
# 80/80 - 0s - loss: 0.3015 - mean_absolute_error: 0.3662 - val_loss: 0.7743 - val_mean_absolute_error: 0.6073 - 123ms/epoch - 2ms/step
# Epoch 206/1000
# 80/80 - 0s - loss: 0.3129 - mean_absolute_error: 0.3718 - val_loss: 0.7510 - val_mean_absolute_error: 0.6001 - 124ms/epoch - 2ms/step
# Epoch 207/1000
# 80/80 - 0s - loss: 0.2865 - mean_absolute_error: 0.3567 - val_loss: 0.7662 - val_mean_absolute_error: 0.6143 - 124ms/epoch - 2ms/step
# Epoch 208/1000
# 80/80 - 0s - loss: 0.2989 - mean_absolute_error: 0.3680 - val_loss: 0.7737 - val_mean_absolute_error: 0.6136 - 123ms/epoch - 2ms/step
# Epoch 209/1000
# 80/80 - 0s - loss: 0.2914 - mean_absolute_error: 0.3607 - val_loss: 0.7784 - val_mean_absolute_error: 0.6057 - 123ms/epoch - 2ms/step
# Epoch 210/1000
# 80/80 - 0s - loss: 0.2910 - mean_absolute_error: 0.3604 - val_loss: 0.7662 - val_mean_absolute_error: 0.6066 - 124ms/epoch - 2ms/step
# Epoch 211/1000
# 80/80 - 0s - loss: 0.2931 - mean_absolute_error: 0.3609 - val_loss: 0.7862 - val_mean_absolute_error: 0.6125 - 125ms/epoch - 2ms/step
# Epoch 212/1000
# 80/80 - 0s - loss: 0.2910 - mean_absolute_error: 0.3590 - val_loss: 0.7733 - val_mean_absolute_error: 0.6119 - 126ms/epoch - 2ms/step
# Epoch 213/1000
# 80/80 - 0s - loss: 0.2954 - mean_absolute_error: 0.3636 - val_loss: 0.7694 - val_mean_absolute_error: 0.6067 - 126ms/epoch - 2ms/step
# Epoch 214/1000
# 80/80 - 0s - loss: 0.2947 - mean_absolute_error: 0.3617 - val_loss: 0.7900 - val_mean_absolute_error: 0.6161 - 123ms/epoch - 2ms/step
# Epoch 215/1000
# 80/80 - 0s - loss: 0.2806 - mean_absolute_error: 0.3512 - val_loss: 0.7836 - val_mean_absolute_error: 0.6143 - 125ms/epoch - 2ms/step
# Epoch 216/1000
# 80/80 - 0s - loss: 0.2903 - mean_absolute_error: 0.3593 - val_loss: 0.7754 - val_mean_absolute_error: 0.6167 - 125ms/epoch - 2ms/step
# Epoch 217/1000
# 80/80 - 0s - loss: 0.2828 - mean_absolute_error: 0.3555 - val_loss: 0.7784 - val_mean_absolute_error: 0.6111 - 124ms/epoch - 2ms/step
# Epoch 218/1000
# 80/80 - 0s - loss: 0.2869 - mean_absolute_error: 0.3565 - val_loss: 0.7809 - val_mean_absolute_error: 0.6240 - 125ms/epoch - 2ms/step
# Epoch 219/1000
# 80/80 - 0s - loss: 0.2834 - mean_absolute_error: 0.3552 - val_loss: 0.7636 - val_mean_absolute_error: 0.6037 - 124ms/epoch - 2ms/step
# Epoch 220/1000
# 80/80 - 0s - loss: 0.2794 - mean_absolute_error: 0.3522 - val_loss: 0.7383 - val_mean_absolute_error: 0.5981 - 125ms/epoch - 2ms/step
# Epoch 221/1000
# 80/80 - 0s - loss: 0.2860 - mean_absolute_error: 0.3557 - val_loss: 0.7875 - val_mean_absolute_error: 0.6139 - 123ms/epoch - 2ms/step
# Epoch 222/1000
# 80/80 - 0s - loss: 0.2828 - mean_absolute_error: 0.3560 - val_loss: 0.7863 - val_mean_absolute_error: 0.6163 - 124ms/epoch - 2ms/step
# Epoch 223/1000
# 80/80 - 0s - loss: 0.2880 - mean_absolute_error: 0.3571 - val_loss: 0.8393 - val_mean_absolute_error: 0.6367 - 123ms/epoch - 2ms/step
# Epoch 224/1000
# 80/80 - 0s - loss: 0.2951 - mean_absolute_error: 0.3649 - val_loss: 0.8073 - val_mean_absolute_error: 0.6218 - 124ms/epoch - 2ms/step
# Epoch 225/1000
# 80/80 - 0s - loss: 0.2828 - mean_absolute_error: 0.3532 - val_loss: 0.7910 - val_mean_absolute_error: 0.6129 - 125ms/epoch - 2ms/step
# Epoch 226/1000
# 80/80 - 0s - loss: 0.2676 - mean_absolute_error: 0.3453 - val_loss: 0.8038 - val_mean_absolute_error: 0.6201 - 145ms/epoch - 2ms/step
# Epoch 227/1000
# 80/80 - 0s - loss: 0.2770 - mean_absolute_error: 0.3516 - val_loss: 0.7792 - val_mean_absolute_error: 0.6138 - 132ms/epoch - 2ms/step
# Epoch 228/1000
# 80/80 - 0s - loss: 0.2761 - mean_absolute_error: 0.3495 - val_loss: 0.7679 - val_mean_absolute_error: 0.6055 - 138ms/epoch - 2ms/step
# Epoch 229/1000
# 80/80 - 0s - loss: 0.2610 - mean_absolute_error: 0.3373 - val_loss: 0.7977 - val_mean_absolute_error: 0.6203 - 126ms/epoch - 2ms/step
# Epoch 230/1000
# 80/80 - 0s - loss: 0.2760 - mean_absolute_error: 0.3517 - val_loss: 0.8053 - val_mean_absolute_error: 0.6187 - 127ms/epoch - 2ms/step
# Epoch 231/1000
# 80/80 - 0s - loss: 0.2626 - mean_absolute_error: 0.3369 - val_loss: 0.7884 - val_mean_absolute_error: 0.6145 - 123ms/epoch - 2ms/step
# Epoch 232/1000
# 80/80 - 0s - loss: 0.2739 - mean_absolute_error: 0.3462 - val_loss: 0.7969 - val_mean_absolute_error: 0.6249 - 125ms/epoch - 2ms/step
# Epoch 233/1000
# 80/80 - 0s - loss: 0.2666 - mean_absolute_error: 0.3419 - val_loss: 0.7831 - val_mean_absolute_error: 0.6177 - 125ms/epoch - 2ms/step
# Epoch 234/1000
# 80/80 - 0s - loss: 0.2831 - mean_absolute_error: 0.3556 - val_loss: 0.8003 - val_mean_absolute_error: 0.6176 - 124ms/epoch - 2ms/step
# Epoch 235/1000
# 80/80 - 0s - loss: 0.2716 - mean_absolute_error: 0.3453 - val_loss: 0.7791 - val_mean_absolute_error: 0.6117 - 124ms/epoch - 2ms/step
# Epoch 236/1000
# 80/80 - 0s - loss: 0.2529 - mean_absolute_error: 0.3318 - val_loss: 0.7866 - val_mean_absolute_error: 0.6182 - 125ms/epoch - 2ms/step
# Epoch 237/1000
# 80/80 - 0s - loss: 0.2641 - mean_absolute_error: 0.3423 - val_loss: 0.7963 - val_mean_absolute_error: 0.6177 - 125ms/epoch - 2ms/step
# Epoch 238/1000
# 80/80 - 0s - loss: 0.2550 - mean_absolute_error: 0.3339 - val_loss: 0.8008 - val_mean_absolute_error: 0.6176 - 126ms/epoch - 2ms/step
# Epoch 239/1000
# 80/80 - 0s - loss: 0.2443 - mean_absolute_error: 0.3245 - val_loss: 0.7859 - val_mean_absolute_error: 0.6126 - 126ms/epoch - 2ms/step
# Epoch 240/1000
# 80/80 - 0s - loss: 0.2493 - mean_absolute_error: 0.3287 - val_loss: 0.8161 - val_mean_absolute_error: 0.6260 - 125ms/epoch - 2ms/step
# Epoch 241/1000
# 80/80 - 0s - loss: 0.2570 - mean_absolute_error: 0.3336 - val_loss: 0.8070 - val_mean_absolute_error: 0.6316 - 123ms/epoch - 2ms/step
# Epoch 242/1000
# 80/80 - 0s - loss: 0.2693 - mean_absolute_error: 0.3456 - val_loss: 0.7992 - val_mean_absolute_error: 0.6211 - 126ms/epoch - 2ms/step
# Epoch 243/1000
# 80/80 - 0s - loss: 0.2616 - mean_absolute_error: 0.3341 - val_loss: 0.8229 - val_mean_absolute_error: 0.6270 - 124ms/epoch - 2ms/step
# Epoch 244/1000
# 80/80 - 0s - loss: 0.2775 - mean_absolute_error: 0.3519 - val_loss: 0.7930 - val_mean_absolute_error: 0.6221 - 126ms/epoch - 2ms/step
# Epoch 245/1000
# 80/80 - 0s - loss: 0.2732 - mean_absolute_error: 0.3470 - val_loss: 0.7885 - val_mean_absolute_error: 0.6179 - 124ms/epoch - 2ms/step
# Epoch 246/1000
# 80/80 - 0s - loss: 0.2589 - mean_absolute_error: 0.3384 - val_loss: 0.7824 - val_mean_absolute_error: 0.6202 - 122ms/epoch - 2ms/step
# Epoch 247/1000
# 80/80 - 0s - loss: 0.2485 - mean_absolute_error: 0.3302 - val_loss: 0.7976 - val_mean_absolute_error: 0.6207 - 124ms/epoch - 2ms/step
# Epoch 248/1000
# 80/80 - 0s - loss: 0.2483 - mean_absolute_error: 0.3272 - val_loss: 0.8353 - val_mean_absolute_error: 0.6283 - 126ms/epoch - 2ms/step
# Epoch 249/1000
# 80/80 - 0s - loss: 0.2816 - mean_absolute_error: 0.3487 - val_loss: 0.8084 - val_mean_absolute_error: 0.6232 - 124ms/epoch - 2ms/step
# Epoch 250/1000
# 80/80 - 0s - loss: 0.2583 - mean_absolute_error: 0.3358 - val_loss: 0.7775 - val_mean_absolute_error: 0.6129 - 123ms/epoch - 2ms/step
# Epoch 251/1000
# 80/80 - 0s - loss: 0.2508 - mean_absolute_error: 0.3298 - val_loss: 0.7949 - val_mean_absolute_error: 0.6238 - 124ms/epoch - 2ms/step
# Epoch 252/1000
# 80/80 - 0s - loss: 0.2376 - mean_absolute_error: 0.3211 - val_loss: 0.8061 - val_mean_absolute_error: 0.6207 - 124ms/epoch - 2ms/step
# Epoch 253/1000
# 80/80 - 0s - loss: 0.2383 - mean_absolute_error: 0.3183 - val_loss: 0.8317 - val_mean_absolute_error: 0.6293 - 124ms/epoch - 2ms/step
# Epoch 254/1000
# 80/80 - 0s - loss: 0.2459 - mean_absolute_error: 0.3243 - val_loss: 0.7768 - val_mean_absolute_error: 0.6090 - 125ms/epoch - 2ms/step
# Epoch 255/1000
# 80/80 - 0s - loss: 0.2341 - mean_absolute_error: 0.3156 - val_loss: 0.8027 - val_mean_absolute_error: 0.6164 - 125ms/epoch - 2ms/step
# Epoch 256/1000
# 80/80 - 0s - loss: 0.2362 - mean_absolute_error: 0.3149 - val_loss: 0.8069 - val_mean_absolute_error: 0.6188 - 125ms/epoch - 2ms/step
# Epoch 257/1000
# 80/80 - 0s - loss: 0.2527 - mean_absolute_error: 0.3312 - val_loss: 0.7979 - val_mean_absolute_error: 0.6188 - 125ms/epoch - 2ms/step
# Epoch 258/1000
# 80/80 - 0s - loss: 0.2487 - mean_absolute_error: 0.3281 - val_loss: 0.8082 - val_mean_absolute_error: 0.6246 - 125ms/epoch - 2ms/step
# Epoch 259/1000
# 80/80 - 0s - loss: 0.2569 - mean_absolute_error: 0.3357 - val_loss: 0.7882 - val_mean_absolute_error: 0.6118 - 127ms/epoch - 2ms/step
# Epoch 260/1000
# 80/80 - 0s - loss: 0.2411 - mean_absolute_error: 0.3230 - val_loss: 0.8274 - val_mean_absolute_error: 0.6259 - 126ms/epoch - 2ms/step
# Epoch 261/1000
# 80/80 - 0s - loss: 0.2531 - mean_absolute_error: 0.3322 - val_loss: 0.7855 - val_mean_absolute_error: 0.6138 - 128ms/epoch - 2ms/step
# Epoch 262/1000
# 80/80 - 0s - loss: 0.2345 - mean_absolute_error: 0.3154 - val_loss: 0.7960 - val_mean_absolute_error: 0.6157 - 123ms/epoch - 2ms/step
# Epoch 263/1000
# 80/80 - 0s - loss: 0.2446 - mean_absolute_error: 0.3246 - val_loss: 0.8163 - val_mean_absolute_error: 0.6205 - 124ms/epoch - 2ms/step
# Epoch 264/1000
# 80/80 - 0s - loss: 0.2420 - mean_absolute_error: 0.3215 - val_loss: 0.8086 - val_mean_absolute_error: 0.6248 - 123ms/epoch - 2ms/step
# Epoch 265/1000
# 80/80 - 0s - loss: 0.2814 - mean_absolute_error: 0.3499 - val_loss: 0.7803 - val_mean_absolute_error: 0.6122 - 124ms/epoch - 2ms/step
# Epoch 266/1000
# 80/80 - 0s - loss: 0.2428 - mean_absolute_error: 0.3251 - val_loss: 0.8135 - val_mean_absolute_error: 0.6225 - 124ms/epoch - 2ms/step
# Epoch 267/1000
# 80/80 - 0s - loss: 0.2304 - mean_absolute_error: 0.3133 - val_loss: 0.8079 - val_mean_absolute_error: 0.6194 - 124ms/epoch - 2ms/step
# Epoch 268/1000
# 80/80 - 0s - loss: 0.2329 - mean_absolute_error: 0.3158 - val_loss: 0.8069 - val_mean_absolute_error: 0.6200 - 125ms/epoch - 2ms/step
# Epoch 269/1000
# 80/80 - 0s - loss: 0.2452 - mean_absolute_error: 0.3253 - val_loss: 0.8360 - val_mean_absolute_error: 0.6347 - 125ms/epoch - 2ms/step
# Epoch 270/1000
# 80/80 - 0s - loss: 0.2408 - mean_absolute_error: 0.3220 - val_loss: 0.8017 - val_mean_absolute_error: 0.6187 - 123ms/epoch - 2ms/step
# Epoch 271/1000
# 80/80 - 0s - loss: 0.2308 - mean_absolute_error: 0.3139 - val_loss: 0.8015 - val_mean_absolute_error: 0.6198 - 123ms/epoch - 2ms/step
# Epoch 272/1000
# 80/80 - 0s - loss: 0.2341 - mean_absolute_error: 0.3158 - val_loss: 0.8071 - val_mean_absolute_error: 0.6196 - 124ms/epoch - 2ms/step
# Epoch 273/1000
# 80/80 - 0s - loss: 0.2232 - mean_absolute_error: 0.3064 - val_loss: 0.8200 - val_mean_absolute_error: 0.6246 - 124ms/epoch - 2ms/step
# Epoch 274/1000
# 80/80 - 0s - loss: 0.2386 - mean_absolute_error: 0.3193 - val_loss: 0.8193 - val_mean_absolute_error: 0.6219 - 124ms/epoch - 2ms/step
# Epoch 275/1000
# 80/80 - 0s - loss: 0.2492 - mean_absolute_error: 0.3284 - val_loss: 0.8062 - val_mean_absolute_error: 0.6213 - 126ms/epoch - 2ms/step
# Epoch 276/1000
# 80/80 - 0s - loss: 0.2178 - mean_absolute_error: 0.3042 - val_loss: 0.8112 - val_mean_absolute_error: 0.6215 - 124ms/epoch - 2ms/step
# Epoch 277/1000
# 80/80 - 0s - loss: 0.2396 - mean_absolute_error: 0.3203 - val_loss: 0.8178 - val_mean_absolute_error: 0.6284 - 125ms/epoch - 2ms/step
# Epoch 278/1000
# 80/80 - 0s - loss: 0.2571 - mean_absolute_error: 0.3352 - val_loss: 0.8276 - val_mean_absolute_error: 0.6269 - 124ms/epoch - 2ms/step
# Epoch 279/1000
# 80/80 - 0s - loss: 0.2453 - mean_absolute_error: 0.3255 - val_loss: 0.7973 - val_mean_absolute_error: 0.6176 - 123ms/epoch - 2ms/step
# Epoch 280/1000
# 80/80 - 0s - loss: 0.2164 - mean_absolute_error: 0.3026 - val_loss: 0.8303 - val_mean_absolute_error: 0.6262 - 126ms/epoch - 2ms/step
# Epoch 281/1000
# 80/80 - 0s - loss: 0.2241 - mean_absolute_error: 0.3101 - val_loss: 0.7987 - val_mean_absolute_error: 0.6177 - 125ms/epoch - 2ms/step
# Epoch 282/1000
# 80/80 - 0s - loss: 0.2122 - mean_absolute_error: 0.2971 - val_loss: 0.8265 - val_mean_absolute_error: 0.6268 - 123ms/epoch - 2ms/step
# Epoch 283/1000
# 80/80 - 0s - loss: 0.2149 - mean_absolute_error: 0.3004 - val_loss: 0.8085 - val_mean_absolute_error: 0.6216 - 126ms/epoch - 2ms/step
# Epoch 284/1000
# 80/80 - 0s - loss: 0.2229 - mean_absolute_error: 0.3086 - val_loss: 0.8304 - val_mean_absolute_error: 0.6344 - 127ms/epoch - 2ms/step
# Epoch 285/1000
# 80/80 - 0s - loss: 0.2261 - mean_absolute_error: 0.3126 - val_loss: 0.8052 - val_mean_absolute_error: 0.6251 - 125ms/epoch - 2ms/step
# Epoch 286/1000
# 80/80 - 0s - loss: 0.2338 - mean_absolute_error: 0.3174 - val_loss: 0.8275 - val_mean_absolute_error: 0.6301 - 123ms/epoch - 2ms/step
# Epoch 287/1000
# 80/80 - 0s - loss: 0.2317 - mean_absolute_error: 0.3159 - val_loss: 0.8209 - val_mean_absolute_error: 0.6249 - 122ms/epoch - 2ms/step
# Epoch 288/1000
# 80/80 - 0s - loss: 0.2118 - mean_absolute_error: 0.2991 - val_loss: 0.8351 - val_mean_absolute_error: 0.6317 - 130ms/epoch - 2ms/step
# Epoch 289/1000
# 80/80 - 0s - loss: 0.2293 - mean_absolute_error: 0.3106 - val_loss: 0.8449 - val_mean_absolute_error: 0.6353 - 123ms/epoch - 2ms/step
# Epoch 290/1000
# 80/80 - 0s - loss: 0.2354 - mean_absolute_error: 0.3166 - val_loss: 0.8045 - val_mean_absolute_error: 0.6249 - 124ms/epoch - 2ms/step
# Epoch 291/1000
# 80/80 - 0s - loss: 0.2423 - mean_absolute_error: 0.3270 - val_loss: 0.8080 - val_mean_absolute_error: 0.6286 - 122ms/epoch - 2ms/step
# Epoch 292/1000
# 80/80 - 0s - loss: 0.2212 - mean_absolute_error: 0.3058 - val_loss: 0.8294 - val_mean_absolute_error: 0.6287 - 124ms/epoch - 2ms/step
# Epoch 293/1000
# 80/80 - 0s - loss: 0.2195 - mean_absolute_error: 0.3040 - val_loss: 0.8120 - val_mean_absolute_error: 0.6196 - 124ms/epoch - 2ms/step
# Epoch 294/1000
# 80/80 - 0s - loss: 0.1970 - mean_absolute_error: 0.2847 - val_loss: 0.8228 - val_mean_absolute_error: 0.6243 - 124ms/epoch - 2ms/step
# Epoch 295/1000
# 80/80 - 0s - loss: 0.2159 - mean_absolute_error: 0.3004 - val_loss: 0.8204 - val_mean_absolute_error: 0.6292 - 124ms/epoch - 2ms/step
# Epoch 296/1000
# 80/80 - 0s - loss: 0.2223 - mean_absolute_error: 0.3084 - val_loss: 0.8255 - val_mean_absolute_error: 0.6303 - 125ms/epoch - 2ms/step
# Epoch 297/1000
# 80/80 - 0s - loss: 0.2089 - mean_absolute_error: 0.2967 - val_loss: 0.8258 - val_mean_absolute_error: 0.6241 - 123ms/epoch - 2ms/step
# Epoch 298/1000
# 80/80 - 0s - loss: 0.2183 - mean_absolute_error: 0.3052 - val_loss: 0.8377 - val_mean_absolute_error: 0.6325 - 123ms/epoch - 2ms/step
# Epoch 299/1000
# 80/80 - 0s - loss: 0.2168 - mean_absolute_error: 0.3012 - val_loss: 0.8161 - val_mean_absolute_error: 0.6229 - 125ms/epoch - 2ms/step
# Epoch 300/1000
# 80/80 - 0s - loss: 0.2075 - mean_absolute_error: 0.2940 - val_loss: 0.8462 - val_mean_absolute_error: 0.6400 - 124ms/epoch - 2ms/step
# Epoch 301/1000
# 80/80 - 0s - loss: 0.2120 - mean_absolute_error: 0.2972 - val_loss: 0.8191 - val_mean_absolute_error: 0.6225 - 123ms/epoch - 2ms/step
# Epoch 302/1000
# 80/80 - 0s - loss: 0.1998 - mean_absolute_error: 0.2862 - val_loss: 0.8195 - val_mean_absolute_error: 0.6207 - 124ms/epoch - 2ms/step
# Epoch 303/1000
# 80/80 - 0s - loss: 0.2132 - mean_absolute_error: 0.3004 - val_loss: 0.8116 - val_mean_absolute_error: 0.6238 - 122ms/epoch - 2ms/step
# Epoch 304/1000
# 80/80 - 0s - loss: 0.2107 - mean_absolute_error: 0.2967 - val_loss: 0.8104 - val_mean_absolute_error: 0.6228 - 128ms/epoch - 2ms/step
# Epoch 305/1000
# 80/80 - 0s - loss: 0.2006 - mean_absolute_error: 0.2878 - val_loss: 0.8243 - val_mean_absolute_error: 0.6327 - 124ms/epoch - 2ms/step
# Epoch 306/1000
# 80/80 - 0s - loss: 0.2243 - mean_absolute_error: 0.3100 - val_loss: 0.8202 - val_mean_absolute_error: 0.6253 - 122ms/epoch - 2ms/step
# Epoch 307/1000
# 80/80 - 0s - loss: 0.2144 - mean_absolute_error: 0.3024 - val_loss: 0.8226 - val_mean_absolute_error: 0.6300 - 125ms/epoch - 2ms/step
# Epoch 308/1000
# 80/80 - 0s - loss: 0.2212 - mean_absolute_error: 0.3060 - val_loss: 0.8247 - val_mean_absolute_error: 0.6375 - 124ms/epoch - 2ms/step
# Epoch 309/1000
# 80/80 - 0s - loss: 0.2139 - mean_absolute_error: 0.3004 - val_loss: 0.8297 - val_mean_absolute_error: 0.6273 - 124ms/epoch - 2ms/step
# Epoch 310/1000
# 80/80 - 0s - loss: 0.2158 - mean_absolute_error: 0.3012 - val_loss: 0.8123 - val_mean_absolute_error: 0.6253 - 126ms/epoch - 2ms/step
# Epoch 311/1000
# 80/80 - 0s - loss: 0.2157 - mean_absolute_error: 0.2993 - val_loss: 0.8335 - val_mean_absolute_error: 0.6284 - 124ms/epoch - 2ms/step
# Epoch 312/1000
# 80/80 - 0s - loss: 0.1982 - mean_absolute_error: 0.2869 - val_loss: 0.8263 - val_mean_absolute_error: 0.6276 - 127ms/epoch - 2ms/step
# Epoch 313/1000
# 80/80 - 0s - loss: 0.2052 - mean_absolute_error: 0.2943 - val_loss: 0.8108 - val_mean_absolute_error: 0.6268 - 124ms/epoch - 2ms/step
# Epoch 314/1000
# 80/80 - 0s - loss: 0.1961 - mean_absolute_error: 0.2866 - val_loss: 0.8153 - val_mean_absolute_error: 0.6261 - 140ms/epoch - 2ms/step
# Epoch 315/1000
# 80/80 - 0s - loss: 0.2033 - mean_absolute_error: 0.2925 - val_loss: 0.8203 - val_mean_absolute_error: 0.6290 - 123ms/epoch - 2ms/step
# Epoch 316/1000
# 80/80 - 0s - loss: 0.1939 - mean_absolute_error: 0.2808 - val_loss: 0.8245 - val_mean_absolute_error: 0.6250 - 125ms/epoch - 2ms/step
# Epoch 317/1000
# 80/80 - 0s - loss: 0.1951 - mean_absolute_error: 0.2837 - val_loss: 0.8278 - val_mean_absolute_error: 0.6258 - 126ms/epoch - 2ms/step
# Epoch 318/1000
# 80/80 - 0s - loss: 0.2222 - mean_absolute_error: 0.3060 - val_loss: 0.8374 - val_mean_absolute_error: 0.6338 - 124ms/epoch - 2ms/step
# Epoch 319/1000
# 80/80 - 0s - loss: 0.2025 - mean_absolute_error: 0.2908 - val_loss: 0.8087 - val_mean_absolute_error: 0.6211 - 123ms/epoch - 2ms/step
# Epoch 320/1000
# 80/80 - 0s - loss: 0.1934 - mean_absolute_error: 0.2829 - val_loss: 0.8249 - val_mean_absolute_error: 0.6296 - 125ms/epoch - 2ms/step
# Epoch 321/1000
# 80/80 - 0s - loss: 0.2011 - mean_absolute_error: 0.2911 - val_loss: 0.8072 - val_mean_absolute_error: 0.6203 - 124ms/epoch - 2ms/step
# Epoch 322/1000
# 80/80 - 0s - loss: 0.1942 - mean_absolute_error: 0.2810 - val_loss: 0.8302 - val_mean_absolute_error: 0.6265 - 124ms/epoch - 2ms/step
# Epoch 323/1000
# ...
# Epoch 894/1000
# 80/80 - 0s - loss: 0.1055 - mean_absolute_error: 0.1915 - val_loss: 0.8206 - val_mean_absolute_error: 0.6269 - 127ms/epoch - 2ms/step
# Epoch 895/1000
# 80/80 - 0s - loss: 0.0956 - mean_absolute_error: 0.1796 - val_loss: 0.8326 - val_mean_absolute_error: 0.6281 - 125ms/epoch - 2ms/step
# Epoch 896/1000
# 80/80 - 0s - loss: 0.1031 - mean_absolute_error: 0.1915 - val_loss: 0.8378 - val_mean_absolute_error: 0.6342 - 124ms/epoch - 2ms/step
# Epoch 897/1000
# 80/80 - 0s - loss: 0.1334 - mean_absolute_error: 0.2210 - val_loss: 0.8700 - val_mean_absolute_error: 0.6452 - 126ms/epoch - 2ms/step
# Epoch 898/1000
# 80/80 - 0s - loss: 0.1535 - mean_absolute_error: 0.2522 - val_loss: 0.8339 - val_mean_absolute_error: 0.6334 - 124ms/epoch - 2ms/step
# Epoch 899/1000
# 80/80 - 0s - loss: 0.1053 - mean_absolute_error: 0.1955 - val_loss: 0.8358 - val_mean_absolute_error: 0.6303 - 127ms/epoch - 2ms/step
# Epoch 900/1000
# 80/80 - 0s - loss: 0.0999 - mean_absolute_error: 0.1832 - val_loss: 0.8328 - val_mean_absolute_error: 0.6303 - 124ms/epoch - 2ms/step
# Epoch 901/1000
# 80/80 - 0s - loss: 0.1253 - mean_absolute_error: 0.2153 - val_loss: 0.8254 - val_mean_absolute_error: 0.6311 - 124ms/epoch - 2ms/step
# Epoch 902/1000
# 80/80 - 0s - loss: 0.1137 - mean_absolute_error: 0.2040 - val_loss: 0.8382 - val_mean_absolute_error: 0.6289 - 123ms/epoch - 2ms/step
# Epoch 903/1000
# 80/80 - 0s - loss: 0.0987 - mean_absolute_error: 0.1810 - val_loss: 0.8293 - val_mean_absolute_error: 0.6308 - 123ms/epoch - 2ms/step
# Epoch 904/1000
# 80/80 - 0s - loss: 0.0943 - mean_absolute_error: 0.1765 - val_loss: 0.8078 - val_mean_absolute_error: 0.6208 - 123ms/epoch - 2ms/step
# Epoch 905/1000
# 80/80 - 0s - loss: 0.0947 - mean_absolute_error: 0.1791 - val_loss: 0.8304 - val_mean_absolute_error: 0.6263 - 123ms/epoch - 2ms/step
# Epoch 906/1000
# 80/80 - 0s - loss: 0.0969 - mean_absolute_error: 0.1779 - val_loss: 0.8384 - val_mean_absolute_error: 0.6312 - 127ms/epoch - 2ms/step
# Epoch 907/1000
# 80/80 - 0s - loss: 0.1049 - mean_absolute_error: 0.1887 - val_loss: 0.8407 - val_mean_absolute_error: 0.6342 - 123ms/epoch - 2ms/step
# Epoch 908/1000
# 80/80 - 0s - loss: 0.1094 - mean_absolute_error: 0.1981 - val_loss: 0.8457 - val_mean_absolute_error: 0.6354 - 123ms/epoch - 2ms/step
# Epoch 909/1000
# 80/80 - 0s - loss: 0.1104 - mean_absolute_error: 0.1941 - val_loss: 0.8426 - val_mean_absolute_error: 0.6323 - 124ms/epoch - 2ms/step
# Epoch 910/1000
# 80/80 - 0s - loss: 0.1022 - mean_absolute_error: 0.1885 - val_loss: 0.8448 - val_mean_absolute_error: 0.6322 - 123ms/epoch - 2ms/step
# Epoch 911/1000
# 80/80 - 0s - loss: 0.0976 - mean_absolute_error: 0.1813 - val_loss: 0.8374 - val_mean_absolute_error: 0.6324 - 124ms/epoch - 2ms/step
# Epoch 912/1000
# 80/80 - 0s - loss: 0.0931 - mean_absolute_error: 0.1748 - val_loss: 0.8257 - val_mean_absolute_error: 0.6269 - 124ms/epoch - 2ms/step
# Epoch 913/1000
# 80/80 - 0s - loss: 0.1096 - mean_absolute_error: 0.1949 - val_loss: 0.8698 - val_mean_absolute_error: 0.6447 - 124ms/epoch - 2ms/step
# Epoch 914/1000
# 80/80 - 0s - loss: 0.1162 - mean_absolute_error: 0.2071 - val_loss: 0.8311 - val_mean_absolute_error: 0.6276 - 124ms/epoch - 2ms/step
# Epoch 915/1000
# 80/80 - 0s - loss: 0.0933 - mean_absolute_error: 0.1787 - val_loss: 0.8212 - val_mean_absolute_error: 0.6282 - 127ms/epoch - 2ms/step
# Epoch 916/1000
# 80/80 - 0s - loss: 0.1148 - mean_absolute_error: 0.2023 - val_loss: 0.8567 - val_mean_absolute_error: 0.6378 - 123ms/epoch - 2ms/step
# Epoch 917/1000
# 80/80 - 0s - loss: 0.1131 - mean_absolute_error: 0.1976 - val_loss: 0.8338 - val_mean_absolute_error: 0.6313 - 125ms/epoch - 2ms/step
# Epoch 918/1000
# 80/80 - 0s - loss: 0.0981 - mean_absolute_error: 0.1833 - val_loss: 0.8365 - val_mean_absolute_error: 0.6301 - 124ms/epoch - 2ms/step
# Epoch 919/1000
# 80/80 - 0s - loss: 0.0911 - mean_absolute_error: 0.1722 - val_loss: 0.8306 - val_mean_absolute_error: 0.6331 - 124ms/epoch - 2ms/step
# Epoch 920/1000
# 80/80 - 0s - loss: 0.1026 - mean_absolute_error: 0.1870 - val_loss: 0.8387 - val_mean_absolute_error: 0.6307 - 125ms/epoch - 2ms/step
# Epoch 921/1000
# 80/80 - 0s - loss: 0.1007 - mean_absolute_error: 0.1861 - val_loss: 0.8475 - val_mean_absolute_error: 0.6350 - 122ms/epoch - 2ms/step
# Epoch 922/1000
# 80/80 - 0s - loss: 0.1025 - mean_absolute_error: 0.1850 - val_loss: 0.8411 - val_mean_absolute_error: 0.6336 - 125ms/epoch - 2ms/step
# Epoch 923/1000
# 80/80 - 0s - loss: 0.1090 - mean_absolute_error: 0.1939 - val_loss: 0.8330 - val_mean_absolute_error: 0.6316 - 124ms/epoch - 2ms/step
# Epoch 924/1000
# 80/80 - 0s - loss: 0.1081 - mean_absolute_error: 0.1932 - val_loss: 0.8524 - val_mean_absolute_error: 0.6388 - 123ms/epoch - 2ms/step
# Epoch 925/1000
# 80/80 - 0s - loss: 0.0995 - mean_absolute_error: 0.1840 - val_loss: 0.8504 - val_mean_absolute_error: 0.6337 - 124ms/epoch - 2ms/step
# Epoch 926/1000
# 80/80 - 0s - loss: 0.0948 - mean_absolute_error: 0.1813 - val_loss: 0.8357 - val_mean_absolute_error: 0.6324 - 125ms/epoch - 2ms/step
# Epoch 927/1000
# 80/80 - 0s - loss: 0.1049 - mean_absolute_error: 0.1854 - val_loss: 0.8256 - val_mean_absolute_error: 0.6270 - 123ms/epoch - 2ms/step
# Epoch 928/1000
# 80/80 - 0s - loss: 0.1117 - mean_absolute_error: 0.1996 - val_loss: 0.8244 - val_mean_absolute_error: 0.6285 - 123ms/epoch - 2ms/step
# Epoch 929/1000
# 80/80 - 0s - loss: 0.1020 - mean_absolute_error: 0.1887 - val_loss: 0.8335 - val_mean_absolute_error: 0.6325 - 123ms/epoch - 2ms/step
# Epoch 930/1000
# 80/80 - 0s - loss: 0.1024 - mean_absolute_error: 0.1867 - val_loss: 0.8449 - val_mean_absolute_error: 0.6377 - 124ms/epoch - 2ms/step
# Epoch 931/1000
# 80/80 - 0s - loss: 0.1140 - mean_absolute_error: 0.2046 - val_loss: 0.8310 - val_mean_absolute_error: 0.6304 - 126ms/epoch - 2ms/step
# Epoch 932/1000
# 80/80 - 0s - loss: 0.0923 - mean_absolute_error: 0.1758 - val_loss: 0.8207 - val_mean_absolute_error: 0.6243 - 124ms/epoch - 2ms/step
# Epoch 933/1000
# 80/80 - 0s - loss: 0.1026 - mean_absolute_error: 0.1868 - val_loss: 0.8367 - val_mean_absolute_error: 0.6314 - 124ms/epoch - 2ms/step
# Epoch 934/1000
# 80/80 - 0s - loss: 0.0977 - mean_absolute_error: 0.1849 - val_loss: 0.8437 - val_mean_absolute_error: 0.6353 - 123ms/epoch - 2ms/step
# Epoch 935/1000
# 80/80 - 0s - loss: 0.0908 - mean_absolute_error: 0.1723 - val_loss: 0.8317 - val_mean_absolute_error: 0.6298 - 123ms/epoch - 2ms/step
# Epoch 936/1000
# 80/80 - 0s - loss: 0.0986 - mean_absolute_error: 0.1822 - val_loss: 0.8409 - val_mean_absolute_error: 0.6348 - 122ms/epoch - 2ms/step
# Epoch 937/1000
# 80/80 - 0s - loss: 0.0935 - mean_absolute_error: 0.1746 - val_loss: 0.8394 - val_mean_absolute_error: 0.6295 - 122ms/epoch - 2ms/step
# Epoch 938/1000
# 80/80 - 0s - loss: 0.0921 - mean_absolute_error: 0.1730 - val_loss: 0.8443 - val_mean_absolute_error: 0.6341 - 124ms/epoch - 2ms/step
# Epoch 939/1000
# 80/80 - 0s - loss: 0.0961 - mean_absolute_error: 0.1808 - val_loss: 0.8530 - val_mean_absolute_error: 0.6362 - 123ms/epoch - 2ms/step
# Epoch 940/1000
# 80/80 - 0s - loss: 0.0925 - mean_absolute_error: 0.1764 - val_loss: 0.8265 - val_mean_absolute_error: 0.6266 - 123ms/epoch - 2ms/step
# Epoch 941/1000
# 80/80 - 0s - loss: 0.0950 - mean_absolute_error: 0.1774 - val_loss: 0.8466 - val_mean_absolute_error: 0.6338 - 123ms/epoch - 2ms/step
# Epoch 942/1000
# 80/80 - 0s - loss: 0.0991 - mean_absolute_error: 0.1890 - val_loss: 0.8452 - val_mean_absolute_error: 0.6341 - 124ms/epoch - 2ms/step
# Epoch 943/1000
# 80/80 - 0s - loss: 0.0955 - mean_absolute_error: 0.1806 - val_loss: 0.8510 - val_mean_absolute_error: 0.6361 - 124ms/epoch - 2ms/step
# Epoch 944/1000
# 80/80 - 0s - loss: 0.1550 - mean_absolute_error: 0.2398 - val_loss: 0.8338 - val_mean_absolute_error: 0.6351 - 123ms/epoch - 2ms/step
# Epoch 945/1000
# 80/80 - 0s - loss: 0.1164 - mean_absolute_error: 0.2088 - val_loss: 0.8423 - val_mean_absolute_error: 0.6372 - 124ms/epoch - 2ms/step
# Epoch 946/1000
# 80/80 - 0s - loss: 0.1011 - mean_absolute_error: 0.1912 - val_loss: 0.8233 - val_mean_absolute_error: 0.6273 - 124ms/epoch - 2ms/step
# Epoch 947/1000
# 80/80 - 0s - loss: 0.0992 - mean_absolute_error: 0.1818 - val_loss: 0.8261 - val_mean_absolute_error: 0.6267 - 128ms/epoch - 2ms/step
# Epoch 948/1000
# 80/80 - 0s - loss: 0.0958 - mean_absolute_error: 0.1786 - val_loss: 0.8429 - val_mean_absolute_error: 0.6330 - 123ms/epoch - 2ms/step
# Epoch 949/1000
# 80/80 - 0s - loss: 0.0981 - mean_absolute_error: 0.1823 - val_loss: 0.8350 - val_mean_absolute_error: 0.6296 - 125ms/epoch - 2ms/step
# Epoch 950/1000
# 80/80 - 0s - loss: 0.1103 - mean_absolute_error: 0.1996 - val_loss: 0.8410 - val_mean_absolute_error: 0.6346 - 124ms/epoch - 2ms/step
# Epoch 951/1000
# 80/80 - 0s - loss: 0.1141 - mean_absolute_error: 0.1998 - val_loss: 0.8275 - val_mean_absolute_error: 0.6336 - 123ms/epoch - 2ms/step
# Epoch 952/1000
# 80/80 - 0s - loss: 0.1029 - mean_absolute_error: 0.1875 - val_loss: 0.8314 - val_mean_absolute_error: 0.6290 - 123ms/epoch - 2ms/step
# Epoch 953/1000
# 80/80 - 0s - loss: 0.0908 - mean_absolute_error: 0.1742 - val_loss: 0.8258 - val_mean_absolute_error: 0.6269 - 122ms/epoch - 2ms/step
# Epoch 954/1000
# 80/80 - 0s - loss: 0.0940 - mean_absolute_error: 0.1751 - val_loss: 0.8453 - val_mean_absolute_error: 0.6401 - 124ms/epoch - 2ms/step
# Epoch 955/1000
# 80/80 - 0s - loss: 0.1072 - mean_absolute_error: 0.1915 - val_loss: 0.8298 - val_mean_absolute_error: 0.6309 - 123ms/epoch - 2ms/step
# Epoch 956/1000
# 80/80 - 0s - loss: 0.0892 - mean_absolute_error: 0.1742 - val_loss: 0.8327 - val_mean_absolute_error: 0.6293 - 122ms/epoch - 2ms/step
# Epoch 957/1000
# 80/80 - 0s - loss: 0.0940 - mean_absolute_error: 0.1761 - val_loss: 0.8200 - val_mean_absolute_error: 0.6269 - 123ms/epoch - 2ms/step
# Epoch 958/1000
# 80/80 - 0s - loss: 0.1004 - mean_absolute_error: 0.1872 - val_loss: 0.8306 - val_mean_absolute_error: 0.6299 - 123ms/epoch - 2ms/step
# Epoch 959/1000
# 80/80 - 0s - loss: 0.1056 - mean_absolute_error: 0.1898 - val_loss: 0.8346 - val_mean_absolute_error: 0.6333 - 124ms/epoch - 2ms/step
# Epoch 960/1000
# 80/80 - 0s - loss: 0.0957 - mean_absolute_error: 0.1781 - val_loss: 0.8327 - val_mean_absolute_error: 0.6321 - 123ms/epoch - 2ms/step
# Epoch 961/1000
# 80/80 - 0s - loss: 0.1131 - mean_absolute_error: 0.1995 - val_loss: 0.8632 - val_mean_absolute_error: 0.6487 - 124ms/epoch - 2ms/step
# Epoch 962/1000
# 80/80 - 0s - loss: 0.1093 - mean_absolute_error: 0.1974 - val_loss: 0.8429 - val_mean_absolute_error: 0.6316 - 127ms/epoch - 2ms/step
# Epoch 963/1000
# 80/80 - 0s - loss: 0.0908 - mean_absolute_error: 0.1733 - val_loss: 0.8480 - val_mean_absolute_error: 0.6364 - 124ms/epoch - 2ms/step
# Epoch 964/1000
# 80/80 - 0s - loss: 0.1006 - mean_absolute_error: 0.1833 - val_loss: 0.8408 - val_mean_absolute_error: 0.6374 - 125ms/epoch - 2ms/step
# Epoch 965/1000
# 80/80 - 0s - loss: 0.1077 - mean_absolute_error: 0.1920 - val_loss: 0.8606 - val_mean_absolute_error: 0.6444 - 124ms/epoch - 2ms/step
# Epoch 966/1000
# 80/80 - 0s - loss: 0.1059 - mean_absolute_error: 0.1921 - val_loss: 0.8335 - val_mean_absolute_error: 0.6326 - 128ms/epoch - 2ms/step
# Epoch 967/1000
# 80/80 - 0s - loss: 0.0989 - mean_absolute_error: 0.1837 - val_loss: 0.8279 - val_mean_absolute_error: 0.6276 - 126ms/epoch - 2ms/step
# Epoch 968/1000
# 80/80 - 0s - loss: 0.0942 - mean_absolute_error: 0.1777 - val_loss: 0.8360 - val_mean_absolute_error: 0.6303 - 124ms/epoch - 2ms/step
# Epoch 969/1000
# 80/80 - 0s - loss: 0.0928 - mean_absolute_error: 0.1768 - val_loss: 0.8353 - val_mean_absolute_error: 0.6327 - 126ms/epoch - 2ms/step
# Epoch 970/1000
# 80/80 - 0s - loss: 0.1040 - mean_absolute_error: 0.1894 - val_loss: 0.8439 - val_mean_absolute_error: 0.6371 - 123ms/epoch - 2ms/step
# Epoch 971/1000
# 80/80 - 0s - loss: 0.0951 - mean_absolute_error: 0.1802 - val_loss: 0.8621 - val_mean_absolute_error: 0.6421 - 123ms/epoch - 2ms/step
# Epoch 972/1000
# 80/80 - 0s - loss: 0.1268 - mean_absolute_error: 0.2206 - val_loss: 0.8393 - val_mean_absolute_error: 0.6330 - 124ms/epoch - 2ms/step
# Epoch 973/1000
# 80/80 - 0s - loss: 0.1009 - mean_absolute_error: 0.1924 - val_loss: 0.8611 - val_mean_absolute_error: 0.6381 - 124ms/epoch - 2ms/step
# Epoch 974/1000
# 80/80 - 0s - loss: 0.1045 - mean_absolute_error: 0.1886 - val_loss: 0.8559 - val_mean_absolute_error: 0.6359 - 125ms/epoch - 2ms/step
# Epoch 975/1000
# 80/80 - 0s - loss: 0.0968 - mean_absolute_error: 0.1827 - val_loss: 0.8247 - val_mean_absolute_error: 0.6292 - 124ms/epoch - 2ms/step
# Epoch 976/1000
# 80/80 - 0s - loss: 0.0978 - mean_absolute_error: 0.1820 - val_loss: 0.8381 - val_mean_absolute_error: 0.6318 - 124ms/epoch - 2ms/step
# Epoch 977/1000
# 80/80 - 0s - loss: 0.0930 - mean_absolute_error: 0.1769 - val_loss: 0.8345 - val_mean_absolute_error: 0.6294 - 127ms/epoch - 2ms/step
# Epoch 978/1000
# 80/80 - 0s - loss: 0.0963 - mean_absolute_error: 0.1795 - val_loss: 0.8348 - val_mean_absolute_error: 0.6331 - 123ms/epoch - 2ms/step
# Epoch 979/1000
# 80/80 - 0s - loss: 0.1098 - mean_absolute_error: 0.1970 - val_loss: 0.8466 - val_mean_absolute_error: 0.6383 - 139ms/epoch - 2ms/step
# Epoch 980/1000
# 80/80 - 0s - loss: 0.1124 - mean_absolute_error: 0.1991 - val_loss: 0.8225 - val_mean_absolute_error: 0.6277 - 124ms/epoch - 2ms/step
# Epoch 981/1000
# 80/80 - 0s - loss: 0.0915 - mean_absolute_error: 0.1761 - val_loss: 0.8466 - val_mean_absolute_error: 0.6358 - 125ms/epoch - 2ms/step
# Epoch 982/1000
# 80/80 - 0s - loss: 0.1013 - mean_absolute_error: 0.1825 - val_loss: 0.8559 - val_mean_absolute_error: 0.6422 - 124ms/epoch - 2ms/step
# Epoch 983/1000
# 80/80 - 0s - loss: 0.1146 - mean_absolute_error: 0.2056 - val_loss: 0.8408 - val_mean_absolute_error: 0.6352 - 124ms/epoch - 2ms/step
# Epoch 984/1000
# 80/80 - 0s - loss: 0.0959 - mean_absolute_error: 0.1801 - val_loss: 0.8380 - val_mean_absolute_error: 0.6335 - 124ms/epoch - 2ms/step
# Epoch 985/1000
# 80/80 - 0s - loss: 0.1006 - mean_absolute_error: 0.1848 - val_loss: 0.8553 - val_mean_absolute_error: 0.6413 - 123ms/epoch - 2ms/step
# Epoch 986/1000
# 80/80 - 0s - loss: 0.1052 - mean_absolute_error: 0.1912 - val_loss: 0.8948 - val_mean_absolute_error: 0.6554 - 124ms/epoch - 2ms/step
# Epoch 987/1000
# 80/80 - 0s - loss: 0.1086 - mean_absolute_error: 0.1974 - val_loss: 0.8376 - val_mean_absolute_error: 0.6317 - 124ms/epoch - 2ms/step
# Epoch 988/1000
# 80/80 - 0s - loss: 0.0926 - mean_absolute_error: 0.1749 - val_loss: 0.8443 - val_mean_absolute_error: 0.6352 - 123ms/epoch - 2ms/step
# Epoch 989/1000
# 80/80 - 0s - loss: 0.0955 - mean_absolute_error: 0.1761 - val_loss: 0.8405 - val_mean_absolute_error: 0.6338 - 124ms/epoch - 2ms/step
# Epoch 990/1000
# 80/80 - 0s - loss: 0.1111 - mean_absolute_error: 0.2021 - val_loss: 0.8504 - val_mean_absolute_error: 0.6407 - 125ms/epoch - 2ms/step
# Epoch 991/1000
# 80/80 - 0s - loss: 0.1038 - mean_absolute_error: 0.1909 - val_loss: 0.8398 - val_mean_absolute_error: 0.6325 - 123ms/epoch - 2ms/step
# Epoch 992/1000
# 80/80 - 0s - loss: 0.0952 - mean_absolute_error: 0.1816 - val_loss: 0.8494 - val_mean_absolute_error: 0.6369 - 127ms/epoch - 2ms/step
# Epoch 993/1000
# 80/80 - 0s - loss: 0.0941 - mean_absolute_error: 0.1769 - val_loss: 0.8419 - val_mean_absolute_error: 0.6381 - 124ms/epoch - 2ms/step
# Epoch 994/1000
# 80/80 - 0s - loss: 0.1000 - mean_absolute_error: 0.1822 - val_loss: 0.8309 - val_mean_absolute_error: 0.6305 - 123ms/epoch - 2ms/step
# Epoch 995/1000
# 80/80 - 0s - loss: 0.1005 - mean_absolute_error: 0.1855 - val_loss: 0.8541 - val_mean_absolute_error: 0.6373 - 123ms/epoch - 2ms/step
# Epoch 996/1000
# 80/80 - 0s - loss: 0.0938 - mean_absolute_error: 0.1743 - val_loss: 0.8350 - val_mean_absolute_error: 0.6316 - 124ms/epoch - 2ms/step
# Epoch 997/1000
# 80/80 - 0s - loss: 0.0920 - mean_absolute_error: 0.1734 - val_loss: 0.8421 - val_mean_absolute_error: 0.6323 - 125ms/epoch - 2ms/step
# Epoch 998/1000
# 80/80 - 0s - loss: 0.1064 - mean_absolute_error: 0.1951 - val_loss: 0.8442 - val_mean_absolute_error: 0.6364 - 125ms/epoch - 2ms/step
# Epoch 999/1000
# 80/80 - 0s - loss: 0.0933 - mean_absolute_error: 0.1814 - val_loss: 0.8383 - val_mean_absolute_error: 0.6324 - 124ms/epoch - 2ms/step
# Epoch 1000/1000
# 80/80 - 0s - loss: 0.1087 - mean_absolute_error: 0.1941 - val_loss: 0.8584 - val_mean_absolute_error: 0.6391 - 123ms/epoch - 2ms/step

# %% [markdown]
# #### Llamamos y evaluamos

# %%
#LLamamos al modelo
model = models.load_model("model_Noise_five.keras")

#model.summary()

#Evaluamos el modelo
scores = model.evaluate(x_val_norm, y_val_norm, verbose=0)
print('MSE:',scores[0],'\nMAE:', scores[1])  


#Predecimos los valores con nuestro modelo
y_pred_norm = model.predict(x_val_norm)
# Out:
# MSE: 0.858383059501648
# MAE: 0.6391374468803406
# 32/32 [==============================] - 0s 775us/step

# %% [markdown]
# #### Dibujamos los resultados

# %% [markdown]
# ##### Predicción de cada parámetro

# %%
# Desnormalizamos los datos de salida de validación
y_val_denorm = scaler_y.inverse_transform(y_val_norm)
y_pred_denorm = scaler_y.inverse_transform(y_pred_norm)

#Dibujamos los datos
symbols = [r'$\kappa$', r'$\Delta E$', r'$\gamma$', r'$g$']

# Crear subgráficos para cada variable
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 9))
fig.suptitle('Comparación entre valor real y la predicción')

for i, ax in enumerate(axes.flatten()):
    ax.plot(y_val_denorm[:, i], y_pred_denorm[:, i], label=f'Predicción {symbols[i]}', marker='o', linestyle='',
             markersize=3, color='cornflowerblue')
    ax.plot([y_val_denorm[:, i].min(), y_val_denorm[:, i].max()], [y_val_denorm[:, i].min(), y_val_denorm[:, i].max()],
            linestyle='-', color='red', linewidth=1, label=f'{symbols[i]} teórico')
    ax.set_xlabel('Valor real')
    ax.set_ylabel('Predicción')
    ax.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ##### Curvas Validación VS Predicción
#
# Si jugamos con la función, llegamos a:
#
# $$
# t(\omega)=\frac{-\kappa\left[(\Delta E-\omega)-i\gamma\right]}{\left[(\Omega-\omega)(\Delta E-\omega)-\kappa\gamma-g^2\right]-i\left[(\Omega-\omega)\gamma+(\Delta E-\omega)\kappa\right]}
# $$
#
# Sacamos los polos de la parte real del denominador, obteniendo:
# $$
# \omega_1=\frac{(\Delta E+\Omega)+\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# $$
# \omega_2=\frac{(\Delta E+\Omega)-\sqrt{(\Delta E-\Omega)^2+4(\kappa\gamma+g^2)}}{2}
# $$
# Si queremos el valor de g:
# $$g=\frac{\sqrt{|\omega_1-\omega_2|^2-(\Omega-\Delta E)^2-4\kappa\gamma}}{2}$$
#
# Ahora, junto a las curvas, dibujaremos líneas verticales correspondientes a esos polos y escribimnos el valor de la resta de sus valores

# %%
def w_1(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) + np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

def w_2(k, Omega, DeltaE, gamma, g):
    return 0.5 * ((DeltaE + Omega) - np.sqrt((DeltaE - Omega)**2 + 4*(k * gamma + g**2)))

# %%
k_pred = y_pred_denorm[:, 0]
k_val = y_val_denorm[:, 0]
DeltaE_pred = y_pred_denorm[:, 1]
DeltaE_val = y_val_denorm[:, 1]
gamma_pred = y_pred_denorm[:, 2]
gamma_val = y_val_denorm[:, 2]
g_pred = y_pred_denorm[:, 3]
g_val = y_val_denorm[:, 3]

t_values_pred = np.zeros((x_val.shape[0], len(w_values)))
t_values_val_noise = t_values_noise[indices_val]
t_values_val = t_values[indices_val]

for i in range (x_val.shape[0]):
    t_values_pred[i,:] = t_w(w_values, k_pred[i], Omega, DeltaE_pred[i], gamma_pred[i], g_pred[i])

w1 = w2 = np.zeros(x_val.shape[0])

w1=w_1(k_val, Omega, DeltaE_val, gamma_val, g_val)
w2=w_2(k_val, Omega, DeltaE_val, gamma_val, g_val)

i = 0
while i < x_val.shape[0]:
    plt.clf()  # Limpia la figura antes de cada iteración
    plt.plot(w_values, t_values_val[i, :], color="b", label="Curva real")
    plt.plot(w_values, t_values_val_noise[i, :], color="g", label="Curva con ruido")
    plt.plot(w_values, t_values_pred[i, :], color="r", linestyle="--", label="Predicción de la red")
    
    if w_values.min() <= w1[i] <= w_values.max():
        plt.vlines(w1[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
    if w_values.min() <= w2[i] <= w_values.max():
        plt.vlines(w2[i], 0, t_values_val[i].max(), colors='black', linewidth=0.5)
   
    if w_values.min() <= w1[i] <= w_values.max() and w_values.min() <= w2[i] <= w_values.max():
        w_diff = abs(w1[i] - w2[i])
        if w_diff < 0.08:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 *7, w1[i], w2[i],
                        colors='black', linestyle='--', linewidth=0.35)
            smaller_w = min(w1[i], w2[i])
            plt.text(smaller_w-0.01, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='right', va='bottom')
        else:
            plt.hlines((t_values_val[i].min() + t_values_val[i].max()) / 10 * 7, w1[i], w2[i], 
                       colors='black', linestyle='--', linewidth=0.35)
            plt.text((w1[i] + w2[i]) / 2, (t_values_val[i].min() + t_values_val[i].max()) / 10 * 7,
                      f'|$\omega_1$-$\omega_2$| = {w_diff:.5f}', ha='center', va='bottom')
   
    plt.title(f"Predicción vs Validación. Curva número: {i}")
    plt.xlabel(r"$\omega$ (Hz)")
    plt.ylabel(r"t ($\omega$)")
    plt.legend()
    plt.ylim(0, None) 

    # Muestra los valores como un recuadro dentro de la gráfica
    text = f"κ real = {k_val[i]:.7f}, κ pred = {k_pred[i]:.7f}\n"\
           f"ΔE real = {DeltaE_val[i]:.5f}, ΔE pred = {DeltaE_pred[i]:.5f}\n"\
           f"γ real = {gamma_val[i]:.7f}, γ pred = {gamma_pred[i]:.7f}\n"\
           f"g real = {g_val[i]:.7f}, g pred = {g_pred[i]:.7f}"
    plt.text(0.015, 0.975, text, transform=plt.gca().transAxes, fontsize=8, verticalalignment='top', 
             bbox=dict(facecolor='white', alpha=0.8))

    # Muestra la figura
    display(plt.gcf())
    clear_output(wait=True)
    
    if keyboard.is_pressed('esc'): 
        break
    if keyboard.is_pressed('right'): 
        i += 1
    if keyboard.is_pressed('left'): 
        i -= 1       
        if i < 0:
            i += 1
